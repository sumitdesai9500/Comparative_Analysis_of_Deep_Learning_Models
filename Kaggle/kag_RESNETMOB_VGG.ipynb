# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # ResnetMobile_VGG

# %% [markdown]
# # Model Summary

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Concatenate
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2, VGG16
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the MobileNetV2 model
mobilenet_model = MobileNetV2(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                              include_top=False,
                              weights='imagenet')

# Define the VGG16 model
vgg16_model = VGG16(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                    include_top=False,
                    weights='imagenet')

# Freeze the layers in both base models
mobilenet_model.trainable = False
vgg16_model.trainable = False

# Define input layer
input_layer = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

# Obtain outputs from both models
mobilenet_output = mobilenet_model(input_layer)
vgg16_output = vgg16_model(input_layer)

# Flatten the outputs
mobilenet_flatten = Flatten()(mobilenet_output)
vgg16_flatten = Flatten()(vgg16_output)

# Concatenate the outputs
concatenated = Concatenate()([mobilenet_flatten, vgg16_flatten])

# Add dense layers for classification
x = Dense(128, activation='relu')(concatenated)
output_layer = Dense(NUM_CLASSES, activation='softmax')(x)

# Create the model
combined_model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
combined_model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
combined_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 112, 80, 3)  0           []
#                                 ]
#
#  mobilenetv2_1.00_224 (Function  (None, 4, 3, 1280)  2257984     ['input_3[0][0]']
#  al)
#
#  vgg16 (Functional)             (None, 3, 2, 512)    14714688    ['input_3[0][0]']
#
#  flatten (Flatten)              (None, 15360)        0           ['mobilenetv2_1.00_224[0][0]']
#
#  flatten_1 (Flatten)            (None, 3072)         0           ['vgg16[0][0]']
#
#  concatenate (Concatenate)      (None, 18432)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense (Dense)                  (None, 128)          2359424     ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 13)           1677        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 19,333,773
# Trainable params: 2,361,101
# Non-trainable params: 16,972,672
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Concatenate
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2, VGG16
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the MobileNetV2 model
mobilenet_model = MobileNetV2(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                              include_top=False,
                              weights='imagenet')

# Define the VGG16 model
vgg16_model = VGG16(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                    include_top=False,
                    weights='imagenet')

# Freeze the layers in both base models
mobilenet_model.trainable = False
vgg16_model.trainable = False

# Define input layer
input_layer = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

# Obtain outputs from both models
mobilenet_output = mobilenet_model(input_layer)
vgg16_output = vgg16_model(input_layer)

# Flatten the outputs
mobilenet_flatten = Flatten()(mobilenet_output)
vgg16_flatten = Flatten()(vgg16_output)

# Concatenate the outputs
concatenated = Concatenate()([mobilenet_flatten, vgg16_flatten])

# Add dense layers for classification
x = Dense(128, activation='relu')(concatenated)
output_layer = Dense(NUM_CLASSES, activation='softmax')(x)

# Create the model
combined_model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
combined_model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = combined_model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = combined_model.evaluate(train_generator)
    val_loss, val_acc = combined_model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    combined_model.save(f'resnetMobile-vgg_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 104 images belonging to 13 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 10s 360ms/step - loss: 14.1004 - accuracy: 0.1067
# Epoch 2/100
# 5/5 [==============================] - 0s 59ms/step - loss: 10.2493 - accuracy: 0.3333
# Epoch 3/100
# 5/5 [==============================] - 0s 52ms/step - loss: 4.9704 - accuracy: 0.4400
# Epoch 4/100
# 5/5 [==============================] - 0s 61ms/step - loss: 1.5800 - accuracy: 0.6800
# Epoch 5/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.3074 - accuracy: 0.6667
# Epoch 6/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.7249 - accuracy: 0.8133
# Epoch 7/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1632 - accuracy: 0.9600
# Epoch 8/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1735 - accuracy: 0.9625
# Epoch 9/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1371 - accuracy: 0.9600
# Epoch 10/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0664 - accuracy: 0.9867
# Epoch 11/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0589 - accuracy: 0.9867
# Epoch 12/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0532 - accuracy: 0.9867
# Epoch 13/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0367 - accuracy: 0.9867
# Epoch 14/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 46ms/step - loss: 9.3898e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.3547e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0013 - accuracy: 1.0000
# 6/6 [==============================] - 1s 39ms/step - loss: 0.0012 - accuracy: 1.0000
# 1/1 [==============================] - 1s 1s/step - loss: 0.1446 - accuracy: 0.9231
# Fold 1:
# Train accuracy: 1.0, Validation accuracy: 0.9230769276618958
# Training time for fold 1: 40.30898690223694 seconds
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 50ms/step - loss: 8.7466e-04 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.7539e-04 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.5537e-04 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.9552e-04 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 52ms/step - loss: 9.6938e-04 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.6561e-04 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 51ms/step - loss: 9.1493e-04 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.4709e-04 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 51ms/step - loss: 8.6110e-04 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.4159e-04 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 47ms/step - loss: 8.9606e-04 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.2062e-04 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.2028e-04 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 50ms/step - loss: 6.6941e-04 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.0438e-04 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 52ms/step - loss: 8.9501e-04 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 51ms/step - loss: 8.5668e-04 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 49ms/step - loss: 6.7178e-04 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 49ms/step - loss: 8.1323e-04 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 52ms/step - loss: 8.0113e-04 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 50ms/step - loss: 7.9516e-04 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 43ms/step - loss: 7.9783e-04 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 49ms/step - loss: 7.8360e-04 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 50ms/step - loss: 7.9892e-04 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 50ms/step - loss: 8.0877e-04 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.4697e-04 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 52ms/step - loss: 7.5872e-04 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 50ms/step - loss: 7.8598e-04 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 50ms/step - loss: 6.0788e-04 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 49ms/step - loss: 7.0497e-04 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 49ms/step - loss: 7.4696e-04 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 47ms/step - loss: 6.9072e-04 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 54ms/step - loss: 7.1799e-04 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 49ms/step - loss: 6.7793e-04 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 51ms/step - loss: 6.6496e-04 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 53ms/step - loss: 6.3560e-04 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 48ms/step - loss: 6.6270e-04 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.0129e-04 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 47ms/step - loss: 6.8044e-04 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 50ms/step - loss: 6.3727e-04 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 49ms/step - loss: 6.0834e-04 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.3229e-04 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 46ms/step - loss: 6.7620e-04 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.9906e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.5919e-04 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 47ms/step - loss: 5.8612e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 56ms/step - loss: 6.0950e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.8155e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 50ms/step - loss: 5.6834e-04 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.9681e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 44ms/step - loss: 5.6606e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 47ms/step - loss: 5.4468e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.9120e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 47ms/step - loss: 5.5529e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.4873e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.7445e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 51ms/step - loss: 5.4456e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 47ms/step - loss: 5.5826e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 46ms/step - loss: 5.1340e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.9313e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 50ms/step - loss: 5.5458e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 47ms/step - loss: 5.4382e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.2802e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.0088e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 46ms/step - loss: 4.9218e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 47ms/step - loss: 5.0562e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.1076e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 46ms/step - loss: 4.7257e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.8179e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.7607e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.5121e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.1247e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.5232e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 51ms/step - loss: 4.5425e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.8824e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.5370e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 50ms/step - loss: 4.7136e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.4792e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.4940e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - ETA: 0s - loss: 4.4944e-04 - accuracy: 1.00 - 0s 51ms/step - loss: 4.4060e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.4807e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 50ms/step - loss: 4.2626e-04 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.1929e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 51ms/step - loss: 4.4726e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.3306e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.1415e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.1429e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.0513e-04 - accuracy: 1.0000
# 6/6 [==============================] - 0s 38ms/step - loss: 3.9357e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1037 - accuracy: 1.0000
# Fold 2:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 2: 68.35799384117126 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 0s 55ms/step - loss: 3.8654e-04 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 47ms/step - loss: 4.2208e-04 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 0s 52ms/step - loss: 4.1625e-04 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.0532e-04 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 0s 54ms/step - loss: 3.8009e-04 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.0062e-04 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.9251e-04 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 49ms/step - loss: 4.0342e-04 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.6843e-04 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.7116e-04 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 46ms/step - loss: 3.6081e-04 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.2449e-04 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.9316e-04 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.4611e-04 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 46ms/step - loss: 3.3969e-04 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.8108e-04 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 46ms/step - loss: 3.4570e-04 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.5351e-04 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.7183e-04 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 47ms/step - loss: 3.4684e-04 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 46ms/step - loss: 3.5617e-04 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.4238e-04 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.9972e-04 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 50ms/step - loss: 3.3078e-04 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.4028e-04 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 47ms/step - loss: 3.3875e-04 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.8177e-04 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.4484e-04 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 46ms/step - loss: 3.3465e-04 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 50ms/step - loss: 3.3819e-04 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 54ms/step - loss: 3.0096e-04 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 60ms/step - loss: 3.3800e-04 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 53ms/step - loss: 3.2763e-04 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 59ms/step - loss: 3.1418e-04 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 50ms/step - loss: 3.3011e-04 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.2507e-04 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.2547e-04 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 48ms/step - loss: 3.0100e-04 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.9479e-04 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 47ms/step - loss: 3.0990e-04 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.8728e-04 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.3807e-04 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 50ms/step - loss: 2.8799e-04 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.8339e-04 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.3582e-04 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.8099e-04 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 56ms/step - loss: 2.7018e-04 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 61ms/step - loss: 2.7666e-04 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 54ms/step - loss: 2.7046e-04 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.9454e-04 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.2635e-04 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.6546e-04 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.6578e-04 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.3630e-04 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.2611e-04 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.6167e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.4761e-04 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.5708e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.5853e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.6590e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.1858e-04 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.3998e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.5296e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.7522e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 55ms/step - loss: 2.2689e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.9971e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.3493e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.6398e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.4582e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 50ms/step - loss: 2.4633e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.4768e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.4962e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.3716e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.3600e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.2612e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 54ms/step - loss: 2.2394e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.0052e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.2319e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.3675e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 54ms/step - loss: 2.2755e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 69ms/step - loss: 2.2830e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 86ms/step - loss: 2.1998e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 68ms/step - loss: 2.2317e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.2173e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.8800e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.1935e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 51ms/step - loss: 2.0721e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.8133e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.0865e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 50ms/step - loss: 2.2969e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 50ms/step - loss: 2.1818e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.1710e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.0183e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 50ms/step - loss: 2.0594e-04 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 50ms/step - loss: 2.1353e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 53ms/step - loss: 2.1258e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.0475e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.7806e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.1418e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.0605e-04 - accuracy: 1.0000
# 6/6 [==============================] - 0s 40ms/step - loss: 1.9891e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0840 - accuracy: 1.0000
# Fold 3:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 3: 97.1900520324707 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 0s 52ms/step - loss: 2.0145e-04 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.9625e-04 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.1052e-04 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.9459e-04 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.7163e-04 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.9783e-04 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.9304e-04 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.6144e-04 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.8723e-04 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.9953e-04 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 54ms/step - loss: 1.9941e-04 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.0157e-04 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.9649e-04 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.7155e-04 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.8329e-04 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.7705e-04 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.8592e-04 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.8499e-04 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.6753e-04 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.6134e-04 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.8750e-04 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.8240e-04 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.7987e-04 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.7500e-04 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.7942e-04 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.7576e-04 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 56ms/step - loss: 1.8243e-04 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.7621e-04 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.7013e-04 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.7890e-04 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.8718e-04 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.6991e-04 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.7688e-04 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.7077e-04 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.7849e-04 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.4118e-04 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.6599e-04 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.6327e-04 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.6097e-04 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.4117e-04 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.6756e-04 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.6062e-04 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 54ms/step - loss: 1.5325e-04 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.3829e-04 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.6501e-04 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.5820e-04 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.5942e-04 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.6060e-04 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.3580e-04 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.5505e-04 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.2687e-04 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.4772e-04 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.4807e-04 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.4517e-04 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.4708e-04 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.4668e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 57ms/step - loss: 1.4889e-04 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.5113e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.4542e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.4933e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.6085e-04 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.4625e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.5009e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.3917e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.4980e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.4111e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.3756e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.4135e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.4286e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.3121e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.4058e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 51ms/step - loss: 1.3585e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.3016e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.3454e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.1671e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.3866e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.2004e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.2374e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.3338e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.2478e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.3006e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.2397e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.3430e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.2218e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.2461e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.3636e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.3275e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.2496e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.2788e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.1915e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.1985e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.2340e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.2921e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.2443e-04 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.1356e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.1812e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.2537e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.0568e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.8641e-05 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.1892e-04 - accuracy: 1.0000
# 6/6 [==============================] - 0s 40ms/step - loss: 1.1711e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0686 - accuracy: 1.0000
# Fold 4:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 4: 124.83264899253845 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 0s 54ms/step - loss: 1.2517e-04 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.2196e-04 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.1238e-04 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.1612e-04 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.1446e-04 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.0318e-04 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.1802e-04 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.1616e-04 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.0074e-04 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.7395e-05 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.6974e-05 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.1128e-04 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.1010e-04 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 54ms/step - loss: 1.1291e-04 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.0378e-04 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.1288e-04 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.9435e-05 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.1234e-04 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.0909e-04 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.1220e-04 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.0388e-05 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 50ms/step - loss: 8.9396e-05 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.0423e-04 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.1158e-04 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 47ms/step - loss: 9.8528e-05 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 58ms/step - loss: 1.1128e-04 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.0685e-04 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.0338e-04 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.1415e-04 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.0691e-04 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.0390e-04 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 53ms/step - loss: 1.0092e-04 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.0894e-04 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.0392e-04 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.1993e-05 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.0738e-04 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 48ms/step - loss: 8.3943e-05 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.0150e-04 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 49ms/step - loss: 8.5727e-05 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 58ms/step - loss: 1.0660e-04 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 54ms/step - loss: 9.6737e-05 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.0129e-04 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 51ms/step - loss: 1.0014e-04 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.5913e-05 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.0109e-04 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.5790e-05 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.3809e-05 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 48ms/step - loss: 8.7174e-05 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.5640e-05 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 53ms/step - loss: 7.8620e-05 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.4136e-05 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.0137e-04 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 46ms/step - loss: 9.1020e-05 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.0082e-05 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.9817e-05 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.1238e-05 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 48ms/step - loss: 8.5900e-05 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 48ms/step - loss: 8.5045e-05 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.3835e-05 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 55ms/step - loss: 8.8986e-05 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 48ms/step - loss: 8.6008e-05 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 52ms/step - loss: 8.7731e-05 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 46ms/step - loss: 9.3479e-05 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.5978e-05 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 46ms/step - loss: 9.3476e-05 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 48ms/step - loss: 7.1600e-05 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 51ms/step - loss: 9.2068e-05 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.0384e-05 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 73ms/step - loss: 8.9214e-05 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 67ms/step - loss: 9.1032e-05 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 56ms/step - loss: 8.8406e-05 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 51ms/step - loss: 9.0269e-05 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 54ms/step - loss: 8.1677e-05 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 49ms/step - loss: 8.4501e-05 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 47ms/step - loss: 8.6327e-05 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 47ms/step - loss: 8.9309e-05 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 51ms/step - loss: 7.8848e-05 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 47ms/step - loss: 8.1089e-05 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 48ms/step - loss: 8.7153e-05 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 50ms/step - loss: 8.6308e-05 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 51ms/step - loss: 8.3508e-05 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 49ms/step - loss: 8.1952e-05 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 56ms/step - loss: 8.0229e-05 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 49ms/step - loss: 7.5707e-05 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 48ms/step - loss: 8.5304e-05 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 56ms/step - loss: 7.0206e-05 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 52ms/step - loss: 8.2030e-05 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 64ms/step - loss: 8.4201e-05 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 92ms/step - loss: 8.3348e-05 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 67ms/step - loss: 7.2313e-05 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 57ms/step - loss: 8.4117e-05 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 56ms/step - loss: 8.0403e-05 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 57ms/step - loss: 7.8380e-05 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 58ms/step - loss: 7.8076e-05 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 58ms/step - loss: 8.1237e-05 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 51ms/step - loss: 7.4884e-05 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 58ms/step - loss: 8.0546e-05 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 53ms/step - loss: 7.3773e-05 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 52ms/step - loss: 6.4067e-05 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 52ms/step - loss: 7.3461e-05 - accuracy: 1.0000
# 6/6 [==============================] - 0s 39ms/step - loss: 7.5140e-05 - accuracy: 1.0000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0574 - accuracy: 1.0000
# Fold 5:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 5: 154.48223638534546 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 100.0 %
# Average Validation Accuracy: 98.46153855323792 %
# Average Training Time: 97.03438363075256
# Total Training Time: 154.8548767566681

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
#plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = combined_model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = combined_model.predict(train_generator)
validation_predictions = combined_model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsResnetMObile-Vggkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+---------------------+---------------------+---------------------+---------+
# | Class |      Precision      |        Recall       |       F1 Score      | Support |
# +-------+---------------------+---------------------+---------------------+---------+
# |   a   |         0.0         |         0.0         |         0.0         |    7    |
# |  bye  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  can  |         0.0         |         0.0         |         0.0         |    7    |
# |  cat  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  demo | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  dog  |         0.0         |         0.0         |         0.0         |    7    |
# | hello |         0.0         |         0.0         |         0.0         |    7    |
# |  here | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   is  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  lips | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   my  |         0.0         |         0.0         |         0.0         |    7    |
# |  read | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  you  |         0.0         |         0.0         |         0.0         |    7    |
# +-------+---------------------+---------------------+---------------------+---------+
#
# Validation Metrics:
# +-------+-----------+--------+----------+---------+
# | Class | Precision | Recall | F1 Score | Support |
# +-------+-----------+--------+----------+---------+
# |   a   |    1.0    |  1.0   |   1.0    |    1    |
# |  bye  |    1.0    |  1.0   |   1.0    |    1    |
# |  can  |    1.0    |  1.0   |   1.0    |    1    |
# |  cat  |    1.0    |  1.0   |   1.0    |    1    |
# |  demo |    1.0    |  1.0   |   1.0    |    1    |
# |  dog  |    1.0    |  1.0   |   1.0    |    1    |
# | hello |    1.0    |  1.0   |   1.0    |    1    |
# |  here |    1.0    |  1.0   |   1.0    |    1    |
# |   is  |    1.0    |  1.0   |   1.0    |    1    |
# |  lips |    1.0    |  1.0   |   1.0    |    1    |
# |   my  |    1.0    |  1.0   |   1.0    |    1    |
# |  read |    1.0    |  1.0   |   1.0    |    1    |
# |  you  |    1.0    |  1.0   |   1.0    |    1    |
# +-------+-----------+--------+----------+---------+
# Combined metrics saved to combined_metricsResnetMObile-Vggkfold5.xlsx

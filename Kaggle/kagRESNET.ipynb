# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # Resnet

# %% [markdown]
# # Model summary

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
from tensorflow.keras.applications import ResNet50
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the ResNet50 model
model = ResNet50(include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))


# Add new layers to the model
x = model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

# Combine the original model with the new layers
model = tf.keras.models.Model(inputs=model.input, outputs=predictions)


    # Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Found 104 images belonging to 13 classes.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 80, 3)  0           []
#                                 ]
#
#  conv1_pad (ZeroPadding2D)      (None, 118, 86, 3)   0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 56, 40, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 56, 40, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 56, 40, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 58, 42, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 28, 20, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 28, 20, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 28, 20, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 28, 20, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 28, 20, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 28, 20, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 28, 20, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 28, 20, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 28, 20, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 28, 20, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 28, 20, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 28, 20, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 28, 20, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 28, 20, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 28, 20, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 28, 20, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 28, 20, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 28, 20, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 28, 20, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 28, 20, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 28, 20, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 28, 20, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 28, 20, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 28, 20, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 28, 20, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 28, 20, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 20, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 20, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 20, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 20, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 28, 20, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 28, 20, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 28, 20, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 14, 10, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 14, 10, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 14, 10, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 14, 10, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 14, 10, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 14, 10, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 14, 10, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 14, 10, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 14, 10, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 14, 10, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 14, 10, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 14, 10, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 14, 10, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 14, 10, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 14, 10, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 14, 10, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 14, 10, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 14, 10, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 14, 10, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 14, 10, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 14, 10, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 14, 10, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 14, 10, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 14, 10, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 14, 10, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 14, 10, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 14, 10, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 14, 10, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 14, 10, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 14, 10, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 14, 10, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 14, 10, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 14, 10, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 14, 10, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 14, 10, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 10, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 10, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 10, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 10, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 14, 10, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 14, 10, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 14, 10, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 5, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 5, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 7, 5, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 7, 5, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 7, 5, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 7, 5, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 7, 5, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 7, 5, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 5, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 5, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 7, 5, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 7, 5, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 7, 5, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 7, 5, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 5, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 5, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 7, 5, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 7, 5, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 7, 5, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 7, 5, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 5, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 5, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 7, 5, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 7, 5, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 7, 5, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 7, 5, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 5, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 5, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 7, 5, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 7, 5, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 7, 5, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 7, 5, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 5, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 5, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 5, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 5, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 5, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 7, 5, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 7, 5, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 7, 5, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 3, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 3, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 3, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 3, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 3, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 3, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 3, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 3, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 4, 3, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 4, 3, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 4, 3, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 4, 3, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 3, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 3, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 3, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 3, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 3, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 4, 3, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 3, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 4, 3, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 4, 3, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 4, 3, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 3, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 3, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 3, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 3, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 3, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 3, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 3, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 4, 3, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 4, 3, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 4, 3, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten (Flatten)              (None, 24576)        0           ['conv5_block3_out[0][0]']
#
#  dense (Dense)                  (None, 128)          3145856     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 13)           1677        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 26,735,245
# Trainable params: 26,682,125
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
from tensorflow.keras.applications import ResNet50
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the ResNet50 model
model = ResNet50(include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))


# Add new layers to the model
x = model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

# Combine the original model with the new layers
model = tf.keras.models.Model(inputs=model.input, outputs=predictions)


    # Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'resnet_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 104 images belonging to 13 classes.
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 14s 433ms/step - loss: 8.0276 - accuracy: 0.0533
# Epoch 2/100
# 5/5 [==============================] - 1s 99ms/step - loss: 3.7355 - accuracy: 0.2267
# Epoch 3/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.9628 - accuracy: 0.3600
# Epoch 4/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.9232 - accuracy: 0.4000
# Epoch 5/100
# 5/5 [==============================] - 1s 98ms/step - loss: 1.6199 - accuracy: 0.4133
# Epoch 6/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.6763 - accuracy: 0.3733
# Epoch 7/100
# 5/5 [==============================] - 1s 99ms/step - loss: 2.1127 - accuracy: 0.4133
# Epoch 8/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.7585 - accuracy: 0.5200
# Epoch 9/100
# 5/5 [==============================] - 1s 99ms/step - loss: 1.4213 - accuracy: 0.5200
# Epoch 10/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.0174 - accuracy: 0.6800
# Epoch 11/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.1362 - accuracy: 0.6267
# Epoch 12/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.0272 - accuracy: 0.6400
# Epoch 13/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.9066 - accuracy: 0.7467
# Epoch 14/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.7455 - accuracy: 0.7733
# Epoch 15/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.7042 - accuracy: 0.8133
# Epoch 16/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.8025 - accuracy: 0.7333
# Epoch 17/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.6195 - accuracy: 0.8000
# Epoch 18/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.5960 - accuracy: 0.8133
# Epoch 19/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.6804 - accuracy: 0.7600
# Epoch 20/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.8895 - accuracy: 0.7250
# Epoch 21/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.7637 - accuracy: 0.8533
# Epoch 22/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.6501 - accuracy: 0.8267
# Epoch 23/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.5216 - accuracy: 0.8133
# Epoch 24/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.3825 - accuracy: 0.8750
# Epoch 25/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.4349 - accuracy: 0.8500
# Epoch 26/100
# 5/5 [==============================] - 1s 96ms/step - loss: 0.6485 - accuracy: 0.8267
# Epoch 27/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.6829 - accuracy: 0.7867
# Epoch 28/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.6139 - accuracy: 0.8267
# Epoch 29/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.4099 - accuracy: 0.8667
# Epoch 30/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.3038 - accuracy: 0.9200
# Epoch 31/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.2204 - accuracy: 0.9000
# Epoch 32/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.2357 - accuracy: 0.9067
# Epoch 33/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.1937 - accuracy: 0.9333
# Epoch 34/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2574 - accuracy: 0.9067
# Epoch 35/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.2180 - accuracy: 0.9125
# Epoch 36/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.2416 - accuracy: 0.9067
# Epoch 37/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.4062 - accuracy: 0.9067
# Epoch 38/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.3772 - accuracy: 0.8800
# Epoch 39/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.1776 - accuracy: 0.9333
# Epoch 40/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2798 - accuracy: 0.9200
# Epoch 41/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1700 - accuracy: 0.9375
# Epoch 42/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.4749 - accuracy: 0.8533
# Epoch 43/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.7291 - accuracy: 0.8800
# Epoch 44/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.5287 - accuracy: 0.9375
# Epoch 45/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.7881 - accuracy: 0.8625
# Epoch 46/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.2964 - accuracy: 0.8800
# Epoch 47/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2184 - accuracy: 0.9333
# Epoch 48/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.2769 - accuracy: 0.9600
# Epoch 49/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0704 - accuracy: 0.9733
# Epoch 50/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.1297 - accuracy: 0.9625
# Epoch 51/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1476 - accuracy: 0.9733
# Epoch 52/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.1923 - accuracy: 0.9467
# Epoch 53/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0572 - accuracy: 0.9750
# Epoch 54/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0946 - accuracy: 0.9600
# Epoch 55/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.1301 - accuracy: 0.9600
# Epoch 56/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0368 - accuracy: 0.9867
# Epoch 58/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0198 - accuracy: 0.9867
# Epoch 59/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0278 - accuracy: 0.9733
# Epoch 60/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0968 - accuracy: 0.9600
# Epoch 63/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0922 - accuracy: 0.9600
# Epoch 64/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0561 - accuracy: 0.9867
# Epoch 65/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0372 - accuracy: 0.9733
# Epoch 66/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1783 - accuracy: 0.9600
# Epoch 70/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.4393 - accuracy: 0.8750
# Epoch 71/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.3001 - accuracy: 0.9250
# Epoch 72/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.9985 - accuracy: 0.8400
# Epoch 73/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.5550 - accuracy: 0.8667
# Epoch 74/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.3198 - accuracy: 0.8800
# Epoch 75/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.3288 - accuracy: 0.8667
# Epoch 76/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.5596 - accuracy: 0.8400
# Epoch 77/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1293 - accuracy: 0.9867
# Epoch 78/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.2699 - accuracy: 0.9200
# Epoch 79/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.2125 - accuracy: 0.9200
# Epoch 80/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.6321 - accuracy: 0.9067
# Epoch 81/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.6309 - accuracy: 0.8667
# Epoch 82/100
# 5/5 [==============================] - 1s 98ms/step - loss: 1.0795 - accuracy: 0.7867
# Epoch 83/100
# 5/5 [==============================] - 1s 103ms/step - loss: 1.0370 - accuracy: 0.8667
# Epoch 84/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.4275 - accuracy: 0.8800
# Epoch 85/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.3475 - accuracy: 0.8933
# Epoch 86/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.2399 - accuracy: 0.9333
# Epoch 87/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1393 - accuracy: 0.9600
# Epoch 88/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.2104 - accuracy: 0.9733
# Epoch 89/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.2325 - accuracy: 0.9333
# Epoch 90/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1016 - accuracy: 0.9600
# Epoch 93/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0297 - accuracy: 0.9875
# Epoch 94/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0397 - accuracy: 0.9733
# Epoch 95/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0747 - accuracy: 0.9733
# Epoch 96/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.1340 - accuracy: 0.9750
# Epoch 97/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0513 - accuracy: 0.9867
# Epoch 98/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0815 - accuracy: 0.9467
# Epoch 99/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.1090 - accuracy: 0.9625
# Epoch 100/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0268 - accuracy: 1.0000
# 6/6 [==============================] - 1s 34ms/step - loss: 4.6884 - accuracy: 0.1099
# 1/1 [==============================] - 1s 542ms/step - loss: 5.1997 - accuracy: 0.0769
# Fold 1:
# Train accuracy: 0.10989011079072952, Validation accuracy: 0.07692307978868484
# Training time for fold 1: 70.1051607131958 seconds
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0543 - accuracy: 0.9867
# Epoch 2/100
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.1147 - accuracy: 0.9867
# Epoch 4/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0067 - accuracy: 1.0000 0s - loss: 0.0076 - accuracy:
# Epoch 7/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0193 - accuracy: 0.9867
# Epoch 8/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0530 - accuracy: 0.9733
# Epoch 11/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.5304 - accuracy: 0.9867
# Epoch 12/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0756 - accuracy: 0.9733
# Epoch 13/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0713 - accuracy: 0.9733
# Epoch 14/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.1088 - accuracy: 0.9867
# Epoch 16/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2110 - accuracy: 0.9625
# Epoch 17/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0547 - accuracy: 0.9867
# Epoch 18/100
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0631 - accuracy: 0.9733
# Epoch 19/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0491 - accuracy: 0.9867
# Epoch 21/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1906 - accuracy: 0.9750
# Epoch 22/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.0807 - accuracy: 0.9733
# Epoch 23/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.0563 - accuracy: 0.9733
# Epoch 25/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.2624 - accuracy: 0.9067
# Epoch 27/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.1556 - accuracy: 0.9600
# Epoch 29/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0977 - accuracy: 0.9733
# Epoch 30/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0610 - accuracy: 0.9750
# Epoch 31/100
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0185 - accuracy: 0.9875
# Epoch 33/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0717 - accuracy: 0.9867
# Epoch 34/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 97ms/step - loss: 0.2410 - accuracy: 0.9733
# Epoch 36/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.1083 - accuracy: 0.9600
# Epoch 37/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0800 - accuracy: 0.9625
# Epoch 38/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.0437 - accuracy: 0.9867
# Epoch 39/100
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0797 - accuracy: 0.9733
# Epoch 40/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0881 - accuracy: 0.9600
# Epoch 41/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.2052 - accuracy: 0.9600
# Epoch 42/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.3402 - accuracy: 0.9333
# Epoch 43/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.6595 - accuracy: 0.9067
# Epoch 44/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.1703 - accuracy: 0.8933
# Epoch 45/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.5917 - accuracy: 0.8750
# Epoch 46/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.5078 - accuracy: 0.9200
# Epoch 47/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0768 - accuracy: 0.9875
# Epoch 48/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.5642 - accuracy: 0.9000
# Epoch 49/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1361 - accuracy: 0.9733
# Epoch 50/100
# 5/5 [==============================] - 0s 97ms/step - loss: 0.2875 - accuracy: 0.9467
# Epoch 51/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1589 - accuracy: 0.9333
# Epoch 52/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0491 - accuracy: 0.9733
# Epoch 53/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1103 - accuracy: 0.9625
# Epoch 54/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1148 - accuracy: 0.9733
# Epoch 55/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.2262 - accuracy: 0.9067
# Epoch 56/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.6175 - accuracy: 0.8750
# Epoch 57/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.8655 - accuracy: 0.8400
# Epoch 58/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.5804 - accuracy: 0.8533
# Epoch 59/100
# 5/5 [==============================] - 0s 95ms/step - loss: 0.2691 - accuracy: 0.9333
# Epoch 60/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.3240 - accuracy: 0.9067
# Epoch 61/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.1418 - accuracy: 0.9600
# Epoch 62/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2411 - accuracy: 0.9333
# Epoch 63/100
# 5/5 [==============================] - 0s 103ms/step - loss: 0.2321 - accuracy: 0.9333
# Epoch 64/100
# 5/5 [==============================] - 0s 101ms/step - loss: 0.0779 - accuracy: 0.9867
# Epoch 65/100
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0481 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1564 - accuracy: 0.9467
# Epoch 67/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0480 - accuracy: 0.9867
# Epoch 68/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.6135 - accuracy: 0.9200
# Epoch 69/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.4914 - accuracy: 0.9333
# Epoch 70/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.3166 - accuracy: 0.9467
# Epoch 71/100
# 5/5 [==============================] - 1s 118ms/step - loss: 0.2515 - accuracy: 0.9625
# Epoch 72/100
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0483 - accuracy: 0.9867
# Epoch 74/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.1374 - accuracy: 0.9600
# Epoch 75/100
# 5/5 [==============================] - 1s 150ms/step - loss: 0.1209 - accuracy: 0.9750
# Epoch 76/100
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0187 - accuracy: 0.9875
# Epoch 77/100
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0247 - accuracy: 0.9867
# Epoch 78/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.1018 - accuracy: 0.9867
# Epoch 79/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.2220 - accuracy: 0.9867
# Epoch 80/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.1404 - accuracy: 0.9733
# Epoch 81/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0359 - accuracy: 0.9867
# Epoch 82/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0750 - accuracy: 0.9733
# Epoch 83/100
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0254 - accuracy: 0.9867
# Epoch 84/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.3974 - accuracy: 0.9750
# Epoch 85/100
# 5/5 [==============================] - 1s 114ms/step - loss: 0.5682 - accuracy: 0.9467
# Epoch 86/100
# 5/5 [==============================] - 1s 121ms/step - loss: 0.2113 - accuracy: 0.9600
# Epoch 87/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.3275 - accuracy: 0.9067
# Epoch 88/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.2079 - accuracy: 0.9600
# Epoch 89/100
# 5/5 [==============================] - 1s 120ms/step - loss: 0.6463 - accuracy: 0.9067
# Epoch 90/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.1098 - accuracy: 0.8933
# Epoch 91/100
# 5/5 [==============================] - 1s 96ms/step - loss: 0.5319 - accuracy: 0.9067
# Epoch 92/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.3025 - accuracy: 0.9200
# Epoch 93/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.7459 - accuracy: 0.8933
# Epoch 94/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.3323 - accuracy: 0.8800
# Epoch 95/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.1120 - accuracy: 0.9875
# Epoch 96/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.1302 - accuracy: 0.9600
# Epoch 97/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0313 - accuracy: 0.9867
# Epoch 98/100
# 5/5 [==============================] - 1s 119ms/step - loss: 0.1602 - accuracy: 0.9250
# Epoch 99/100
# 5/5 [==============================] - 1s 147ms/step - loss: 0.5832 - accuracy: 0.9467
# Epoch 100/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.2327 - accuracy: 0.9600
# 6/6 [==============================] - 0s 35ms/step - loss: 1.4785 - accuracy: 0.6044
# 1/1 [==============================] - 0s 73ms/step - loss: 2.4628 - accuracy: 0.2308
# Fold 2:
# Train accuracy: 0.6043956279754639, Validation accuracy: 0.23076923191547394
# Training time for fold 2: 128.1650459766388 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.3847 - accuracy: 0.8800
# Epoch 2/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0763 - accuracy: 0.9733
# Epoch 3/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0386 - accuracy: 0.9867
# Epoch 4/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0349 - accuracy: 0.9733
# Epoch 5/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0395 - accuracy: 0.9875
# Epoch 6/100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.3358 - accuracy: 0.9333
# Epoch 7/100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.2743 - accuracy: 0.9333
# Epoch 8/100
# 5/5 [==============================] - 1s 126ms/step - loss: 0.3004 - accuracy: 0.9333
# Epoch 9/100
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 1s 128ms/step - loss: 0.1464 - accuracy: 0.9733
# Epoch 12/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0720 - accuracy: 0.9600
# Epoch 14/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0693 - accuracy: 0.9733
# Epoch 16/100
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0219 - accuracy: 0.9867
# Epoch 17/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 1s 120ms/step - loss: 0.1040 - accuracy: 0.9750
# Epoch 19/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0281 - accuracy: 0.9867
# Epoch 20/100
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.2366 - accuracy: 0.9867
# Epoch 22/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.1048 - accuracy: 0.9733
# Epoch 23/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0474 - accuracy: 0.9750
# Epoch 25/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.1901 - accuracy: 0.9500
# Epoch 26/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1948 - accuracy: 0.9733
# Epoch 27/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2077 - accuracy: 0.9733
# Epoch 28/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1945 - accuracy: 0.9467
# Epoch 29/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0719 - accuracy: 0.9467
# Epoch 30/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0786 - accuracy: 0.9600
# Epoch 31/100
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0403 - accuracy: 0.9867
# Epoch 32/100
# 5/5 [==============================] - 1s 142ms/step - loss: 0.8048 - accuracy: 0.9733
# Epoch 33/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.3964 - accuracy: 0.9600
# Epoch 34/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.3735 - accuracy: 0.9467
# Epoch 35/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0881 - accuracy: 0.9600
# Epoch 36/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.6586 - accuracy: 0.9333
# Epoch 37/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0569 - accuracy: 0.9867
# Epoch 39/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0539 - accuracy: 0.9867
# Epoch 40/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.1436 - accuracy: 0.9867
# Epoch 41/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0178 - accuracy: 0.9867
# Epoch 43/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0350 - accuracy: 0.9867
# Epoch 44/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0781 - accuracy: 0.9733
# Epoch 48/100
# 5/5 [==============================] - 1s 102ms/step - loss: 5.3826e-04 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 1s 104ms/step - loss: 7.1591e-04 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.2532 - accuracy: 0.9733
# Epoch 51/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0774 - accuracy: 0.9733
# Epoch 52/100
# 5/5 [==============================] - 1s 104ms/step - loss: 8.2573e-04 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 1s 110ms/step - loss: 7.3663e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 1s 106ms/step - loss: 9.9291e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 1s 112ms/step - loss: 2.4495e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.6753e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 1s 108ms/step - loss: 2.5434e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 1s 107ms/step - loss: 1.1723e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 1s 103ms/step - loss: 1.8731e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 1s 108ms/step - loss: 1.7725e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.4450e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 1s 108ms/step - loss: 1.5565e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 1s 110ms/step - loss: 1.8105e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 1s 105ms/step - loss: 1.1136e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 1s 109ms/step - loss: 1.0714e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 1s 111ms/step - loss: 1.7713e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 1s 111ms/step - loss: 6.7552e-05 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 1s 103ms/step - loss: 1.1928e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 1s 105ms/step - loss: 5.9707e-05 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 1s 109ms/step - loss: 6.3284e-05 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 1s 110ms/step - loss: 8.7891e-05 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 1s 107ms/step - loss: 7.8910e-05 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 1s 113ms/step - loss: 2.8910e-05 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 1s 115ms/step - loss: 2.6206e-05 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 1s 110ms/step - loss: 1.1439e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 1s 105ms/step - loss: 5.6681e-05 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 1s 106ms/step - loss: 8.3596e-05 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 1s 110ms/step - loss: 5.3520e-05 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 1s 108ms/step - loss: 1.3067e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 1s 108ms/step - loss: 6.0172e-05 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 1s 109ms/step - loss: 1.4298e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 1s 108ms/step - loss: 2.8019e-05 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 1s 110ms/step - loss: 1.9264e-05 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 1s 110ms/step - loss: 8.9947e-05 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 1s 117ms/step - loss: 1.5566e-05 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 1s 117ms/step - loss: 3.6641e-05 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 1s 109ms/step - loss: 3.7119e-05 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 1s 108ms/step - loss: 1.4894e-05 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 1s 105ms/step - loss: 3.6268e-05 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 1s 117ms/step - loss: 3.6915e-05 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 1s 112ms/step - loss: 1.4352e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 1s 105ms/step - loss: 3.3895e-05 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 1s 108ms/step - loss: 2.1354e-05 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 1s 111ms/step - loss: 7.9059e-05 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 1s 104ms/step - loss: 3.4416e-05 - accuracy: 1.0000
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2371e-05 - accuracy: 1.0000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0344 - accuracy: 1.0000
# Fold 3:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 3: 188.44895958900452 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0090 - accuracy: 0.9875
# Epoch 2/100
# 5/5 [==============================] - 1s 113ms/step - loss: 5.2041e-05 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.4472e-04 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0342 - accuracy: 0.9867
# Epoch 5/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0305 - accuracy: 0.9867
# Epoch 6/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0478 - accuracy: 0.9867
# Epoch 7/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0332 - accuracy: 0.9867
# Epoch 9/100
# 5/5 [==============================] - 1s 117ms/step - loss: 4.3274e-04 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 1s 118ms/step - loss: 4.0206e-04 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 1s 114ms/step - loss: 1.9222e-04 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.4194 - accuracy: 0.9867
# Epoch 15/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0955 - accuracy: 0.9867
# Epoch 16/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.6358 - accuracy: 0.9733
# Epoch 17/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.5872 - accuracy: 0.9200
# Epoch 18/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.4063 - accuracy: 0.9600
# Epoch 19/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0366 - accuracy: 0.9733
# Epoch 20/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.2427 - accuracy: 0.9500
# Epoch 21/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.1428 - accuracy: 0.9600
# Epoch 22/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.3213 - accuracy: 0.9600
# Epoch 23/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.5844 - accuracy: 0.9200
# Epoch 24/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.5114 - accuracy: 0.9467
# Epoch 25/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.2145 - accuracy: 0.9333
# Epoch 26/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.1655 - accuracy: 0.9467
# Epoch 27/100
# 5/5 [==============================] - 1s 98ms/step - loss: 0.7737 - accuracy: 0.9067
# Epoch 28/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.2270 - accuracy: 0.9333
# Epoch 29/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.2243 - accuracy: 0.9467
# Epoch 30/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.4918 - accuracy: 0.9733
# Epoch 31/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0664 - accuracy: 0.9733
# Epoch 32/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0383 - accuracy: 0.9867
# Epoch 33/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0227 - accuracy: 0.9867
# Epoch 34/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0886 - accuracy: 0.9733
# Epoch 35/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.1899 - accuracy: 0.9333
# Epoch 36/100
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0615 - accuracy: 0.9867
# Epoch 37/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1116 - accuracy: 0.9600
# Epoch 38/100
# 5/5 [==============================] - 1s 99ms/step - loss: 0.1422 - accuracy: 0.9733
# Epoch 39/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0428 - accuracy: 0.9733
# Epoch 40/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.2203 - accuracy: 0.9600
# Epoch 41/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0814 - accuracy: 0.9625
# Epoch 42/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.2279 - accuracy: 0.9875
# Epoch 45/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0391 - accuracy: 0.9867
# Epoch 47/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 1s 101ms/step - loss: 3.3709e-04 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0299 - accuracy: 0.9867
# Epoch 51/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0308 - accuracy: 0.9867
# Epoch 52/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.5908 - accuracy: 0.9867
# Epoch 54/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1375 - accuracy: 0.9733
# Epoch 55/100
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0654 - accuracy: 0.9867
# Epoch 56/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.8182 - accuracy: 0.9733
# Epoch 57/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.1049 - accuracy: 0.9733
# Epoch 58/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0141 - accuracy: 0.9867
# Epoch 59/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 1s 104ms/step - loss: 6.4892e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 1s 101ms/step - loss: 9.2622e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 1s 105ms/step - loss: 2.0823e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0649 - accuracy: 0.9867
# Epoch 67/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.3243e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 1s 99ms/step - loss: 2.8539e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 1s 100ms/step - loss: 9.4356e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 1s 106ms/step - loss: 7.4364e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 1s 107ms/step - loss: 6.0896e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.5971e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.2060e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 1s 104ms/step - loss: 2.4331e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 1s 103ms/step - loss: 2.6467e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 1s 101ms/step - loss: 6.2515e-05 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 1s 109ms/step - loss: 3.0420e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 1s 108ms/step - loss: 1.3710e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 1s 107ms/step - loss: 1.0405e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 1s 108ms/step - loss: 5.6557e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.8188e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 1s 103ms/step - loss: 8.5804e-05 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 1s 107ms/step - loss: 4.5314e-05 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 1s 101ms/step - loss: 6.8503e-05 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 1s 100ms/step - loss: 3.0636e-05 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 1s 102ms/step - loss: 6.1813e-05 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 1s 104ms/step - loss: 4.9428e-05 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.0569e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 1s 101ms/step - loss: 1.2088e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 1s 102ms/step - loss: 6.2342e-05 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 1s 106ms/step - loss: 2.5783e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.6193e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 1s 107ms/step - loss: 2.4296e-05 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.5474e-05 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 1s 103ms/step - loss: 7.1812e-05 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 1s 101ms/step - loss: 4.3243e-05 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 1s 102ms/step - loss: 5.3812e-05 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 1s 105ms/step - loss: 5.2041e-05 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 1s 103ms/step - loss: 3.9363e-05 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 1s 104ms/step - loss: 2.4527e-05 - accuracy: 1.0000
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1564e-05 - accuracy: 1.0000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0118 - accuracy: 1.0000
# Fold 4:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 4: 247.11175680160522 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 110ms/step - loss: 1.3443e-05 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 1s 101ms/step - loss: 2.4940e-05 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.4315e-04 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.0945e-04 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 1s 102ms/step - loss: 4.4544e-05 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 1s 103ms/step - loss: 9.1193e-05 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 1s 101ms/step - loss: 1.9887e-05 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 1s 102ms/step - loss: 2.3723e-04 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 1s 106ms/step - loss: 3.9230e-05 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 1s 108ms/step - loss: 3.8903e-05 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0781 - accuracy: 0.9867
# Epoch 12/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 1s 104ms/step - loss: 2.1041e-04 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 1s 106ms/step - loss: 3.4976e-04 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 1s 105ms/step - loss: 5.1036e-05 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 1s 103ms/step - loss: 8.4344e-05 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 1s 105ms/step - loss: 6.2138e-05 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 1s 100ms/step - loss: 5.1265e-05 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 1s 105ms/step - loss: 6.2261e-05 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.5470e-04 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 1s 102ms/step - loss: 9.2066e-05 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 1s 101ms/step - loss: 6.7532e-05 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 1s 106ms/step - loss: 3.7429e-05 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 1s 107ms/step - loss: 2.9506e-05 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 1s 105ms/step - loss: 3.8840e-05 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 1s 100ms/step - loss: 5.7171e-04 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 1s 107ms/step - loss: 2.0020e-05 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.7179e-05 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 1s 104ms/step - loss: 3.9264e-05 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 1s 103ms/step - loss: 9.6457e-05 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 1s 100ms/step - loss: 4.6796e-05 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 1s 104ms/step - loss: 3.3664e-05 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 1s 99ms/step - loss: 1.7950e-05 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 1s 103ms/step - loss: 2.8910e-05 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 1s 104ms/step - loss: 3.4625e-05 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 1s 105ms/step - loss: 4.4945e-05 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 1s 100ms/step - loss: 5.0489e-05 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 1s 102ms/step - loss: 2.7546e-05 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 1s 101ms/step - loss: 2.1336e-05 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 1s 106ms/step - loss: 4.2842e-05 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 1s 104ms/step - loss: 3.7368e-05 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 1s 104ms/step - loss: 9.0890e-06 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 1s 104ms/step - loss: 2.0761e-05 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 1s 105ms/step - loss: 5.8457e-05 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 1s 101ms/step - loss: 5.1934e-05 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.5382e-05 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 1s 104ms/step - loss: 3.7695e-05 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 1s 105ms/step - loss: 2.2043e-05 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 1s 105ms/step - loss: 3.5925e-05 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 1s 102ms/step - loss: 9.9650e-05 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 1s 100ms/step - loss: 2.4506e-05 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 1s 99ms/step - loss: 2.1932e-05 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 1s 105ms/step - loss: 5.4235e-05 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 1s 107ms/step - loss: 4.0277e-05 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 1s 99ms/step - loss: 2.1992e-05 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 1s 106ms/step - loss: 3.8276e-05 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 1s 103ms/step - loss: 2.2654e-05 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 1s 101ms/step - loss: 4.7082e-05 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 1s 104ms/step - loss: 3.5266e-05 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 1s 102ms/step - loss: 4.3829e-05 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 1s 104ms/step - loss: 4.2758e-05 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 1s 109ms/step - loss: 5.3543e-05 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 1s 103ms/step - loss: 1.4051e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 1s 105ms/step - loss: 1.0332e-05 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 1s 104ms/step - loss: 2.9389e-05 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 1s 103ms/step - loss: 2.8190e-05 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 1s 100ms/step - loss: 2.0079e-05 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.0482e-05 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 1s 103ms/step - loss: 1.4747e-05 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.6809e-05 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 1s 104ms/step - loss: 2.1933e-05 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 1s 103ms/step - loss: 3.8148e-05 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 1s 112ms/step - loss: 2.0488e-05 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.4333e-05 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 1s 107ms/step - loss: 1.3630e-05 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 1s 102ms/step - loss: 4.1589e-05 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.7476e-05 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.4666e-05 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 1s 101ms/step - loss: 5.3184e-05 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 1s 115ms/step - loss: 4.9782e-05 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 1s 105ms/step - loss: 1.8810e-05 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 1s 100ms/step - loss: 1.2277e-05 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 1s 105ms/step - loss: 1.3236e-05 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.3279e-05 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 1s 103ms/step - loss: 1.0428e-05 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 1s 114ms/step - loss: 9.6139e-06 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.3911e-05 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 1s 102ms/step - loss: 1.9089e-05 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 1s 101ms/step - loss: 2.2440e-05 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 1s 104ms/step - loss: 7.8765e-06 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 1s 105ms/step - loss: 2.0634e-05 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.3530e-05 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 1s 102ms/step - loss: 7.8801e-06 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 1s 102ms/step - loss: 3.4751e-05 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 1s 101ms/step - loss: 1.4286e-05 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 1s 104ms/step - loss: 1.5326e-05 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 1s 103ms/step - loss: 1.3693e-05 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 1s 104ms/step - loss: 2.5421e-05 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 1s 101ms/step - loss: 7.4208e-06 - accuracy: 1.0000
# 6/6 [==============================] - 0s 30ms/step - loss: 3.2631e-06 - accuracy: 1.0000
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0059 - accuracy: 1.0000
# Fold 5:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 5: 304.4508581161499 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 74.28571477532387 %
# Average Validation Accuracy: 66.15384623408318 %
# Average Training Time: 187.65635623931885
# Total Training Time: 305.6133222579956

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
#plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsResnetkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+---------------------+---------------------+---------------------+---------+
# | Class |      Precision      |        Recall       |       F1 Score      | Support |
# +-------+---------------------+---------------------+---------------------+---------+
# |   a   |         0.0         |         0.0         |         0.0         |    7    |
# |  bye  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  can  |         0.0         |         0.0         |         0.0         |    7    |
# |  cat  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  demo | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  dog  |         0.0         |         0.0         |         0.0         |    7    |
# | hello |         0.0         |         0.0         |         0.0         |    7    |
# |  here | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   is  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  lips | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   my  |         0.0         |         0.0         |         0.0         |    7    |
# |  read | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  you  |         0.0         |         0.0         |         0.0         |    7    |
# +-------+---------------------+---------------------+---------------------+---------+
#
# Validation Metrics:
# +-------+-----------+--------+----------+---------+
# | Class | Precision | Recall | F1 Score | Support |
# +-------+-----------+--------+----------+---------+
# |   a   |    1.0    |  1.0   |   1.0    |    1    |
# |  bye  |    1.0    |  1.0   |   1.0    |    1    |
# |  can  |    1.0    |  1.0   |   1.0    |    1    |
# |  cat  |    1.0    |  1.0   |   1.0    |    1    |
# |  demo |    1.0    |  1.0   |   1.0    |    1    |
# |  dog  |    1.0    |  1.0   |   1.0    |    1    |
# | hello |    1.0    |  1.0   |   1.0    |    1    |
# |  here |    1.0    |  1.0   |   1.0    |    1    |
# |   is  |    1.0    |  1.0   |   1.0    |    1    |
# |  lips |    1.0    |  1.0   |   1.0    |    1    |
# |   my  |    1.0    |  1.0   |   1.0    |    1    |
# |  read |    1.0    |  1.0   |   1.0    |    1    |
# |  you  |    1.0    |  1.0   |   1.0    |    1    |
# +-------+-----------+--------+----------+---------+
# Combined metrics saved to combined_metricsResnetkfold5.xlsx

# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # VGG_lstm

# %% [markdown]
# # Model Summary

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Input, Reshape
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2, VGG16
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Load pre-trained VGG-16 model, excluding the top classifier layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

# Freeze pre-trained layers to prevent them from being updated during training
for layer in base_model.layers:
    layer.trainable = False

# Define the model architecture
inputs = Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))  # Input layer for images

# Extract features using VGG-16
vgg_features = base_model(inputs)

# **Reshape features to ensure compatibility with LSTM (remove unnecessary dimension):**
# Adjust the shape based on the actual dimensions of `vgg_features` (e.g., if features are (None, 7, 7, 512), reshape to (None, 7, 512))
desired_feature_shape = (vgg_features.shape[1], vgg_features.shape[2] * vgg_features.shape[3])  # Calculate desired shape
reshaped_features = Reshape(desired_feature_shape)(vgg_features)

# Define the LSTM-based classifier
lstm_1 = LSTM(128, return_sequences=True)(reshaped_features)  # First LSTM layer
lstm_2 = LSTM(32)(lstm_1)                                     # Second LSTM layer

Dropout(0.7)
# Final dense layer for classification
predictions = Dense(NUM_CLASSES, activation='softmax')(lstm_2)

# Create the final model
model = tf.keras.Model(inputs=inputs, outputs=predictions)
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(clipnorm=1),  # Create Adam optimizer with clipnorm
              loss='categorical_crossentropy',
              metrics=['accuracy'],
              run_eagerly=True,  # Enables early stopping callbacks
              )
# Out:
# Found 104 images belonging to 13 classes.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 112, 80, 3)]      0
#
#  vgg16 (Functional)          (None, 3, 2, 512)         14714688
#
#  reshape (Reshape)           (None, 3, 1024)           0
#
#  lstm (LSTM)                 (None, 3, 128)            590336
#
#  lstm_1 (LSTM)               (None, 32)                20608
#
#  dense (Dense)               (None, 13)                429
#
# =================================================================
# Total params: 15,326,061
# Trainable params: 611,373
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Input, Reshape
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2, VGG16
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Load pre-trained VGG-16 model, excluding the top classifier layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

# Freeze pre-trained layers to prevent them from being updated during training
for layer in base_model.layers:
    layer.trainable = False

# Define the model architecture
inputs = Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))  # Input layer for images

# Extract features using VGG-16
vgg_features = base_model(inputs)

# **Reshape features to ensure compatibility with LSTM (remove unnecessary dimension):**
# Adjust the shape based on the actual dimensions of `vgg_features` (e.g., if features are (None, 7, 7, 512), reshape to (None, 7, 512))
desired_feature_shape = (vgg_features.shape[1], vgg_features.shape[2] * vgg_features.shape[3])  # Calculate desired shape
reshaped_features = Reshape(desired_feature_shape)(vgg_features)

# Define the LSTM-based classifier
lstm_1 = LSTM(128, return_sequences=True)(reshaped_features)  # First LSTM layer
lstm_2 = LSTM(32)(lstm_1)                                     # Second LSTM layer

Dropout(0.7)
# Final dense layer for classification
predictions = Dense(NUM_CLASSES, activation='softmax')(lstm_2)

# Create the final model
model = tf.keras.Model(inputs=inputs, outputs=predictions)
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(clipnorm=1),  # Create Adam optimizer with clipnorm
              loss='categorical_crossentropy',
              metrics=['accuracy'],
              run_eagerly=True,  # Enables early stopping callbacks
              )

# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'VGG-lstm_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 104 images belonging to 13 classes.
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 15s 1s/step - loss: 2.5741 - accuracy: 0.0933
# Epoch 2/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.5833 - accuracy: 0.0533
# Epoch 3/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.5718 - accuracy: 0.0667
# Epoch 4/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.5708 - accuracy: 0.0667
# Epoch 5/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.5740 - accuracy: 0.0533
# Epoch 6/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5652 - accuracy: 0.0800
# Epoch 7/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.5634 - accuracy: 0.0800
# Epoch 8/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.5675 - accuracy: 0.0750
# Epoch 9/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.5680 - accuracy: 0.0667
# Epoch 10/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.5683 - accuracy: 0.0533
# Epoch 11/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.5652 - accuracy: 0.1067
# Epoch 12/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.5623 - accuracy: 0.1067
# Epoch 13/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.5599 - accuracy: 0.1000
# Epoch 14/100
# 5/5 [==============================] - 1s 202ms/step - loss: 2.5569 - accuracy: 0.0875
# Epoch 15/100
# 5/5 [==============================] - 1s 198ms/step - loss: 2.5588 - accuracy: 0.1067
# Epoch 16/100
# 5/5 [==============================] - 1s 200ms/step - loss: 2.5643 - accuracy: 0.0800
# Epoch 17/100
# 5/5 [==============================] - 1s 199ms/step - loss: 2.5595 - accuracy: 0.1467
# Epoch 18/100
# 5/5 [==============================] - 1s 200ms/step - loss: 2.5599 - accuracy: 0.0533
# Epoch 19/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.5575 - accuracy: 0.0933
# Epoch 20/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.5558 - accuracy: 0.1067
# Epoch 21/100
# 5/5 [==============================] - 1s 204ms/step - loss: 2.5529 - accuracy: 0.1333
# Epoch 22/100
# 5/5 [==============================] - 1s 202ms/step - loss: 2.5528 - accuracy: 0.1733
# Epoch 23/100
# 5/5 [==============================] - 1s 206ms/step - loss: 2.5547 - accuracy: 0.1333
# Epoch 24/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.5507 - accuracy: 0.1600
# Epoch 25/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5488 - accuracy: 0.1625
# Epoch 26/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.5443 - accuracy: 0.1733
# Epoch 27/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.5512 - accuracy: 0.1333
# Epoch 28/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.5526 - accuracy: 0.1200
# Epoch 29/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.5463 - accuracy: 0.1467
# Epoch 30/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.5519 - accuracy: 0.0933
# Epoch 31/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.5476 - accuracy: 0.1200
# Epoch 32/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5438 - accuracy: 0.1250
# Epoch 33/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.5425 - accuracy: 0.1467
# Epoch 34/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.5450 - accuracy: 0.1333
# Epoch 35/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.5402 - accuracy: 0.1333
# Epoch 36/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5441 - accuracy: 0.1625
# Epoch 37/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.5416 - accuracy: 0.1200
# Epoch 38/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.5346 - accuracy: 0.2133
# Epoch 39/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5405 - accuracy: 0.1200
# Epoch 40/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.5355 - accuracy: 0.1500
# Epoch 41/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5417 - accuracy: 0.2000
# Epoch 42/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.5375 - accuracy: 0.1867
# Epoch 43/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.5383 - accuracy: 0.1625
# Epoch 44/100
# 5/5 [==============================] - 1s 200ms/step - loss: 2.5339 - accuracy: 0.2375
# Epoch 45/100
# 5/5 [==============================] - 1s 198ms/step - loss: 2.5362 - accuracy: 0.2267
# Epoch 46/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.5323 - accuracy: 0.2000
# Epoch 47/100
# 5/5 [==============================] - 1s 197ms/step - loss: 2.5311 - accuracy: 0.2800
# Epoch 48/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.5286 - accuracy: 0.2800
# Epoch 49/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.5251 - accuracy: 0.3067
# Epoch 50/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.5294 - accuracy: 0.2667
# Epoch 51/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5276 - accuracy: 0.2400
# Epoch 52/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5275 - accuracy: 0.2133
# Epoch 53/100
# 5/5 [==============================] - 1s 195ms/step - loss: 2.5277 - accuracy: 0.2500
# Epoch 54/100
# 5/5 [==============================] - 1s 200ms/step - loss: 2.5260 - accuracy: 0.2875
# Epoch 55/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.5232 - accuracy: 0.3125
# Epoch 56/100
# 5/5 [==============================] - 1s 195ms/step - loss: 2.5251 - accuracy: 0.2667
# Epoch 57/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.5242 - accuracy: 0.2400
# Epoch 58/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.5196 - accuracy: 0.3067
# Epoch 59/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.5145 - accuracy: 0.2800
# Epoch 60/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.5176 - accuracy: 0.2400
# Epoch 61/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.5174 - accuracy: 0.2800
# Epoch 62/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.5170 - accuracy: 0.3125
# Epoch 63/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.5071 - accuracy: 0.3600
# Epoch 64/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.5200 - accuracy: 0.2933
# Epoch 65/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.5118 - accuracy: 0.3733
# Epoch 66/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.5129 - accuracy: 0.3467
# Epoch 67/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.5077 - accuracy: 0.2533
# Epoch 68/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.5140 - accuracy: 0.2667
# Epoch 69/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.4990 - accuracy: 0.3467
# Epoch 70/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.5065 - accuracy: 0.2800
# Epoch 71/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.5099 - accuracy: 0.2533
# Epoch 72/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.5048 - accuracy: 0.2667
# Epoch 73/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.4988 - accuracy: 0.3467
# Epoch 74/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.5075 - accuracy: 0.2750
# Epoch 75/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.5052 - accuracy: 0.2933
# Epoch 76/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.4980 - accuracy: 0.3000
# Epoch 77/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.4954 - accuracy: 0.3200
# Epoch 78/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.4948 - accuracy: 0.2933
# Epoch 79/100
# 5/5 [==============================] - 1s 196ms/step - loss: 2.5029 - accuracy: 0.2400
# Epoch 80/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.4878 - accuracy: 0.3333
# Epoch 81/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.4858 - accuracy: 0.3875
# Epoch 82/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.4914 - accuracy: 0.3125
# Epoch 83/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.4856 - accuracy: 0.3467
# Epoch 84/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.4833 - accuracy: 0.3200
# Epoch 85/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.4820 - accuracy: 0.3200
# Epoch 86/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.4778 - accuracy: 0.3200
# Epoch 87/100
# 5/5 [==============================] - 1s 197ms/step - loss: 2.4730 - accuracy: 0.3067
# Epoch 88/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.4823 - accuracy: 0.2933
# Epoch 89/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.4740 - accuracy: 0.3375
# Epoch 90/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.4699 - accuracy: 0.3733
# Epoch 91/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.4801 - accuracy: 0.3600
# Epoch 92/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.4784 - accuracy: 0.3500
# Epoch 93/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.4709 - accuracy: 0.3200
# Epoch 94/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.4670 - accuracy: 0.3200
# Epoch 95/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.4701 - accuracy: 0.2375
# Epoch 96/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.4591 - accuracy: 0.2933
# Epoch 97/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.4605 - accuracy: 0.3200
# Epoch 98/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.4528 - accuracy: 0.3600
# Epoch 99/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.4599 - accuracy: 0.2667
# Epoch 100/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.4582 - accuracy: 0.2933
# 6/6 [==============================] - 0s 68ms/step - loss: 2.4501 - accuracy: 0.3407
# 1/1 [==============================] - 2s 2s/step - loss: 2.5540 - accuracy: 0.0769
# Fold 1:
# Train accuracy: 0.34065935015678406, Validation accuracy: 0.07692307978868484
# Training time for fold 1: 115.54341006278992 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 197ms/step - loss: 2.4498 - accuracy: 0.3200
# Epoch 2/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.4441 - accuracy: 0.2533
# Epoch 3/100
# 5/5 [==============================] - 1s 195ms/step - loss: 2.4505 - accuracy: 0.2750
# Epoch 4/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.4490 - accuracy: 0.2800
# Epoch 5/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.4331 - accuracy: 0.3333
# Epoch 6/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.4414 - accuracy: 0.2875
# Epoch 7/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.4418 - accuracy: 0.3067
# Epoch 8/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.4396 - accuracy: 0.2933
# Epoch 9/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.4325 - accuracy: 0.3733
# Epoch 10/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.4334 - accuracy: 0.3333
# Epoch 11/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.4358 - accuracy: 0.3067
# Epoch 12/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.4273 - accuracy: 0.3200
# Epoch 13/100
# 5/5 [==============================] - 1s 199ms/step - loss: 2.4331 - accuracy: 0.2533
# Epoch 14/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.4269 - accuracy: 0.2800
# Epoch 15/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.4132 - accuracy: 0.3067
# Epoch 16/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.4090 - accuracy: 0.3333
# Epoch 17/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.4146 - accuracy: 0.3200
# Epoch 18/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.4058 - accuracy: 0.3867
# Epoch 19/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.4288 - accuracy: 0.3067
# Epoch 20/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.4029 - accuracy: 0.3333
# Epoch 21/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.4191 - accuracy: 0.3250
# Epoch 22/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.4079 - accuracy: 0.3750
# Epoch 23/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.3910 - accuracy: 0.4267
# Epoch 24/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.3947 - accuracy: 0.4133
# Epoch 25/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.3982 - accuracy: 0.3625
# Epoch 26/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.4084 - accuracy: 0.3333
# Epoch 27/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.4001 - accuracy: 0.3067
# Epoch 28/100
# 5/5 [==============================] - 1s 196ms/step - loss: 2.3861 - accuracy: 0.3467
# Epoch 29/100
# 5/5 [==============================] - 1s 200ms/step - loss: 2.3889 - accuracy: 0.3333
# Epoch 30/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.3898 - accuracy: 0.2933
# Epoch 31/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.3775 - accuracy: 0.3875
# Epoch 32/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.3796 - accuracy: 0.3867
# Epoch 33/100
# 5/5 [==============================] - 1s 183ms/step - loss: 2.3902 - accuracy: 0.3867
# Epoch 34/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.3639 - accuracy: 0.3733
# Epoch 35/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.3664 - accuracy: 0.4000
# Epoch 36/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.3871 - accuracy: 0.3467
# Epoch 37/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.3517 - accuracy: 0.3867
# Epoch 38/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.3648 - accuracy: 0.3875
# Epoch 39/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.3675 - accuracy: 0.3867
# Epoch 40/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.3502 - accuracy: 0.4267
# Epoch 41/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.3596 - accuracy: 0.3750
# Epoch 42/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.3479 - accuracy: 0.3867
# Epoch 43/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.3612 - accuracy: 0.2800
# Epoch 44/100
# 5/5 [==============================] - 1s 183ms/step - loss: 2.3623 - accuracy: 0.3733
# Epoch 45/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.3458 - accuracy: 0.3733
# Epoch 46/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.3310 - accuracy: 0.3733
# Epoch 47/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.3394 - accuracy: 0.3125
# Epoch 48/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.3294 - accuracy: 0.3733
# Epoch 49/100
# 5/5 [==============================] - 1s 179ms/step - loss: 2.3085 - accuracy: 0.3867
# Epoch 50/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.3351 - accuracy: 0.3867
# Epoch 51/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.3244 - accuracy: 0.4133
# Epoch 52/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.3353 - accuracy: 0.3333
# Epoch 53/100
# 5/5 [==============================] - 1s 181ms/step - loss: 2.3111 - accuracy: 0.3600
# Epoch 54/100
# 5/5 [==============================] - 1s 233ms/step - loss: 2.2948 - accuracy: 0.4267
# Epoch 55/100
# 5/5 [==============================] - 1s 289ms/step - loss: 2.3112 - accuracy: 0.3500
# Epoch 56/100
# 5/5 [==============================] - 1s 279ms/step - loss: 2.2861 - accuracy: 0.3750
# Epoch 57/100
# 5/5 [==============================] - 1s 285ms/step - loss: 2.2982 - accuracy: 0.4000
# Epoch 58/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.3036 - accuracy: 0.3867
# Epoch 59/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.2810 - accuracy: 0.3867
# Epoch 60/100
# 5/5 [==============================] - 1s 182ms/step - loss: 2.2603 - accuracy: 0.3733
# Epoch 61/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.3010 - accuracy: 0.3467
# Epoch 62/100
# 5/5 [==============================] - 1s 182ms/step - loss: 2.2785 - accuracy: 0.3867
# Epoch 63/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.2923 - accuracy: 0.2800
# Epoch 64/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.3034 - accuracy: 0.3333
# Epoch 65/100
# 5/5 [==============================] - 1s 180ms/step - loss: 2.2852 - accuracy: 0.3867
# Epoch 66/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.2802 - accuracy: 0.3625
# Epoch 67/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.2786 - accuracy: 0.3375
# Epoch 68/100
# 5/5 [==============================] - 1s 212ms/step - loss: 2.2801 - accuracy: 0.3467
# Epoch 69/100
# 5/5 [==============================] - 1s 140ms/step - loss: 2.2408 - accuracy: 0.4133
# Epoch 70/100
# 5/5 [==============================] - 1s 142ms/step - loss: 2.2586 - accuracy: 0.4000
# Epoch 71/100
# 5/5 [==============================] - 1s 141ms/step - loss: 2.2569 - accuracy: 0.3733
# Epoch 72/100
# 5/5 [==============================] - 1s 183ms/step - loss: 2.2300 - accuracy: 0.4000
# Epoch 73/100
# 5/5 [==============================] - 1s 183ms/step - loss: 2.2161 - accuracy: 0.4000
# Epoch 74/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.2418 - accuracy: 0.3467
# Epoch 75/100
# 5/5 [==============================] - 1s 183ms/step - loss: 2.2595 - accuracy: 0.4133
# Epoch 76/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.2429 - accuracy: 0.4000
# Epoch 77/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.2725 - accuracy: 0.3600
# Epoch 78/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.2370 - accuracy: 0.3200
# Epoch 79/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.2099 - accuracy: 0.3875
# Epoch 80/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.2099 - accuracy: 0.4400
# Epoch 81/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.2415 - accuracy: 0.3600
# Epoch 82/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.2063 - accuracy: 0.4000
# Epoch 83/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.1949 - accuracy: 0.4000
# Epoch 84/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.2125 - accuracy: 0.3467
# Epoch 85/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.2031 - accuracy: 0.4250
# Epoch 86/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.2007 - accuracy: 0.4133
# Epoch 87/100
# 5/5 [==============================] - 1s 200ms/step - loss: 2.1942 - accuracy: 0.4000
# Epoch 88/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.1755 - accuracy: 0.3733
# Epoch 89/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.1823 - accuracy: 0.3750
# Epoch 90/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.2075 - accuracy: 0.4000
# Epoch 91/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.1627 - accuracy: 0.4267
# Epoch 92/100
# 5/5 [==============================] - 1s 197ms/step - loss: 2.2114 - accuracy: 0.4125
# Epoch 93/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.1600 - accuracy: 0.4375
# Epoch 94/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.1778 - accuracy: 0.4000
# Epoch 95/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.1931 - accuracy: 0.4533
# Epoch 96/100
# 5/5 [==============================] - 1s 200ms/step - loss: 2.1384 - accuracy: 0.4267
# Epoch 97/100
# 5/5 [==============================] - 1s 202ms/step - loss: 2.1669 - accuracy: 0.4133
# Epoch 98/100
# 5/5 [==============================] - 1s 194ms/step - loss: 2.1637 - accuracy: 0.3867
# Epoch 99/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.1530 - accuracy: 0.3733
# Epoch 100/100
# 5/5 [==============================] - 1s 204ms/step - loss: 2.1595 - accuracy: 0.3867
# 6/6 [==============================] - 1s 73ms/step - loss: 2.1344 - accuracy: 0.3956
# 1/1 [==============================] - 0s 115ms/step - loss: 2.5461 - accuracy: 0.0769
# Fold 2:
# Train accuracy: 0.3956044018268585, Validation accuracy: 0.07692307978868484
# Training time for fold 2: 214.61107683181763 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.1814 - accuracy: 0.3867
# Epoch 2/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.1576 - accuracy: 0.3733
# Epoch 3/100
# 5/5 [==============================] - 1s 184ms/step - loss: 2.1114 - accuracy: 0.4133
# Epoch 4/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.0805 - accuracy: 0.4133
# Epoch 5/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.1518 - accuracy: 0.4000
# Epoch 6/100
# 5/5 [==============================] - 1s 183ms/step - loss: 2.1409 - accuracy: 0.3200
# Epoch 7/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.1139 - accuracy: 0.4000
# Epoch 8/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.1225 - accuracy: 0.3733
# Epoch 9/100
# 5/5 [==============================] - 1s 183ms/step - loss: 2.1283 - accuracy: 0.3867
# Epoch 10/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.0929 - accuracy: 0.4267
# Epoch 11/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.1143 - accuracy: 0.4267
# Epoch 12/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.1331 - accuracy: 0.4000
# Epoch 13/100
# 5/5 [==============================] - 1s 204ms/step - loss: 2.1079 - accuracy: 0.4667
# Epoch 14/100
# 5/5 [==============================] - 1s 144ms/step - loss: 2.1031 - accuracy: 0.3867
# Epoch 15/100
# 5/5 [==============================] - 1s 141ms/step - loss: 2.0610 - accuracy: 0.4133
# Epoch 16/100
# 5/5 [==============================] - 1s 145ms/step - loss: 2.0796 - accuracy: 0.4133
# Epoch 17/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.0961 - accuracy: 0.4125
# Epoch 18/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.0771 - accuracy: 0.4125
# Epoch 19/100
# 5/5 [==============================] - 1s 195ms/step - loss: 2.0394 - accuracy: 0.4267
# Epoch 20/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.1190 - accuracy: 0.4000
# Epoch 21/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.0402 - accuracy: 0.4533
# Epoch 22/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.0817 - accuracy: 0.4250
# Epoch 23/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.0558 - accuracy: 0.4267
# Epoch 24/100
# 5/5 [==============================] - 1s 190ms/step - loss: 2.0334 - accuracy: 0.4400
# Epoch 25/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.0345 - accuracy: 0.4000
# Epoch 26/100
# 5/5 [==============================] - 1s 192ms/step - loss: 2.0608 - accuracy: 0.4000
# Epoch 27/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.0295 - accuracy: 0.4533
# Epoch 28/100
# 5/5 [==============================] - 1s 196ms/step - loss: 1.9747 - accuracy: 0.4800
# Epoch 29/100
# 5/5 [==============================] - 1s 189ms/step - loss: 1.9949 - accuracy: 0.4133
# Epoch 30/100
# 5/5 [==============================] - 1s 189ms/step - loss: 2.0642 - accuracy: 0.4267
# Epoch 31/100
# 5/5 [==============================] - 1s 193ms/step - loss: 2.0163 - accuracy: 0.4500
# Epoch 32/100
# 5/5 [==============================] - 1s 185ms/step - loss: 2.0396 - accuracy: 0.4000
# Epoch 33/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.9945 - accuracy: 0.4133
# Epoch 34/100
# 5/5 [==============================] - 1s 188ms/step - loss: 2.0221 - accuracy: 0.3733
# Epoch 35/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.0251 - accuracy: 0.4533
# Epoch 36/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.0125 - accuracy: 0.4000
# Epoch 37/100
# 5/5 [==============================] - 1s 191ms/step - loss: 2.0511 - accuracy: 0.4250
# Epoch 38/100
# 5/5 [==============================] - 1s 199ms/step - loss: 2.0344 - accuracy: 0.4000
# Epoch 39/100
# 5/5 [==============================] - 1s 189ms/step - loss: 1.9936 - accuracy: 0.4533
# Epoch 40/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.9558 - accuracy: 0.4800
# Epoch 41/100
# 5/5 [==============================] - 1s 191ms/step - loss: 1.9730 - accuracy: 0.4267
# Epoch 42/100
# 5/5 [==============================] - 1s 197ms/step - loss: 1.9942 - accuracy: 0.3867
# Epoch 43/100
# 5/5 [==============================] - 1s 187ms/step - loss: 2.0036 - accuracy: 0.4000
# Epoch 44/100
# 5/5 [==============================] - 1s 186ms/step - loss: 2.0211 - accuracy: 0.4800
# Epoch 45/100
# 5/5 [==============================] - 1s 197ms/step - loss: 1.9957 - accuracy: 0.4625
# Epoch 46/100
# 5/5 [==============================] - 1s 193ms/step - loss: 1.9750 - accuracy: 0.4267
# Epoch 47/100
# 5/5 [==============================] - 1s 190ms/step - loss: 1.9746 - accuracy: 0.4375
# Epoch 48/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.9479 - accuracy: 0.5200
# Epoch 49/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.9238 - accuracy: 0.4667
# Epoch 50/100
# 5/5 [==============================] - 1s 183ms/step - loss: 1.9669 - accuracy: 0.4400
# Epoch 51/100
# 5/5 [==============================] - 1s 189ms/step - loss: 1.9582 - accuracy: 0.5333
# Epoch 52/100
# 5/5 [==============================] - 1s 190ms/step - loss: 1.9655 - accuracy: 0.4667
# Epoch 53/100
# 5/5 [==============================] - 1s 187ms/step - loss: 1.9341 - accuracy: 0.4375
# Epoch 54/100
# 5/5 [==============================] - 1s 186ms/step - loss: 1.8954 - accuracy: 0.5200
# Epoch 55/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.9885 - accuracy: 0.4400
# Epoch 56/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.9098 - accuracy: 0.4800
# Epoch 57/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.9536 - accuracy: 0.4875
# Epoch 58/100
# 5/5 [==============================] - 1s 190ms/step - loss: 1.9363 - accuracy: 0.4375
# Epoch 59/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.9165 - accuracy: 0.4533
# Epoch 60/100
# 5/5 [==============================] - 1s 190ms/step - loss: 1.8364 - accuracy: 0.5333
# Epoch 61/100
# 5/5 [==============================] - 1s 185ms/step - loss: 1.8743 - accuracy: 0.5067
# Epoch 62/100
# 5/5 [==============================] - 1s 186ms/step - loss: 1.8921 - accuracy: 0.4800
# Epoch 63/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.8893 - accuracy: 0.4800
# Epoch 64/100
# 5/5 [==============================] - 1s 185ms/step - loss: 1.8750 - accuracy: 0.4800
# Epoch 65/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.9015 - accuracy: 0.4267
# Epoch 66/100
# 5/5 [==============================] - 1s 183ms/step - loss: 1.8597 - accuracy: 0.4667
# Epoch 67/100
# 5/5 [==============================] - 1s 180ms/step - loss: 1.8574 - accuracy: 0.5200
# Epoch 68/100
# 5/5 [==============================] - 1s 189ms/step - loss: 1.8882 - accuracy: 0.4933
# Epoch 69/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.8269 - accuracy: 0.5200
# Epoch 70/100
# 5/5 [==============================] - 1s 184ms/step - loss: 1.8611 - accuracy: 0.5200
# Epoch 71/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.9063 - accuracy: 0.4667
# Epoch 72/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.8191 - accuracy: 0.5067
# Epoch 73/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.8403 - accuracy: 0.5333
# Epoch 74/100
# 5/5 [==============================] - 1s 184ms/step - loss: 1.8490 - accuracy: 0.4933
# Epoch 75/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.8823 - accuracy: 0.5067
# Epoch 76/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7572 - accuracy: 0.5067
# Epoch 77/100
# 5/5 [==============================] - 1s 180ms/step - loss: 1.7911 - accuracy: 0.5467
# Epoch 78/100
# 5/5 [==============================] - 1s 187ms/step - loss: 1.8198 - accuracy: 0.5250
# Epoch 79/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.7717 - accuracy: 0.4933
# Epoch 80/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.7862 - accuracy: 0.5250
# Epoch 81/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.8239 - accuracy: 0.4933
# Epoch 82/100
# 5/5 [==============================] - 1s 184ms/step - loss: 1.7705 - accuracy: 0.5333
# Epoch 83/100
# 5/5 [==============================] - 1s 189ms/step - loss: 1.8702 - accuracy: 0.4800
# Epoch 84/100
# 5/5 [==============================] - 1s 180ms/step - loss: 1.7459 - accuracy: 0.5200
# Epoch 85/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7426 - accuracy: 0.5333
# Epoch 86/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7645 - accuracy: 0.5467
# Epoch 87/100
# 5/5 [==============================] - 1s 178ms/step - loss: 1.7621 - accuracy: 0.4800
# Epoch 88/100
# 5/5 [==============================] - 1s 183ms/step - loss: 1.8121 - accuracy: 0.5067
# Epoch 89/100
# 5/5 [==============================] - 1s 189ms/step - loss: 1.7720 - accuracy: 0.5500
# Epoch 90/100
# 5/5 [==============================] - 1s 191ms/step - loss: 1.7459 - accuracy: 0.5250
# Epoch 91/100
# 5/5 [==============================] - 1s 183ms/step - loss: 1.7877 - accuracy: 0.5200
# Epoch 92/100
# 5/5 [==============================] - 1s 186ms/step - loss: 1.7430 - accuracy: 0.5333
# Epoch 93/100
# 5/5 [==============================] - 1s 183ms/step - loss: 1.6943 - accuracy: 0.5600
# Epoch 94/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7102 - accuracy: 0.5867
# Epoch 95/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7804 - accuracy: 0.5200
# Epoch 96/100
# 5/5 [==============================] - 1s 186ms/step - loss: 1.7438 - accuracy: 0.4933
# Epoch 97/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7307 - accuracy: 0.5733
# Epoch 98/100
# 5/5 [==============================] - 1s 187ms/step - loss: 1.7809 - accuracy: 0.5125
# Epoch 99/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.7571 - accuracy: 0.4800
# Epoch 100/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.6837 - accuracy: 0.6133
# 6/6 [==============================] - 0s 65ms/step - loss: 1.7309 - accuracy: 0.5385
# 1/1 [==============================] - 0s 107ms/step - loss: 2.4394 - accuracy: 0.0769
# Fold 3:
# Train accuracy: 0.5384615659713745, Validation accuracy: 0.07692307978868484
# Training time for fold 3: 311.0467586517334 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 187ms/step - loss: 1.7628 - accuracy: 0.5067
# Epoch 2/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.6631 - accuracy: 0.5867
# Epoch 3/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.6993 - accuracy: 0.5467
# Epoch 4/100
# 5/5 [==============================] - 1s 185ms/step - loss: 1.7537 - accuracy: 0.5375
# Epoch 5/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7096 - accuracy: 0.5467
# Epoch 6/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.7586 - accuracy: 0.5067
# Epoch 7/100
# 5/5 [==============================] - 1s 187ms/step - loss: 1.6462 - accuracy: 0.5467
# Epoch 8/100
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6917 - accuracy: 0.5467
# Epoch 9/100
# 5/5 [==============================] - 1s 183ms/step - loss: 1.6685 - accuracy: 0.5733
# Epoch 10/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.6922 - accuracy: 0.5200
# Epoch 11/100
# 5/5 [==============================] - 1s 187ms/step - loss: 1.7566 - accuracy: 0.5333
# Epoch 12/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.6995 - accuracy: 0.5067
# Epoch 13/100
# 5/5 [==============================] - 1s 180ms/step - loss: 1.6890 - accuracy: 0.6000
# Epoch 14/100
# 5/5 [==============================] - 1s 187ms/step - loss: 1.6401 - accuracy: 0.6000
# Epoch 15/100
# 5/5 [==============================] - 1s 183ms/step - loss: 1.6949 - accuracy: 0.5200
# Epoch 16/100
# 5/5 [==============================] - 1s 180ms/step - loss: 1.6265 - accuracy: 0.6133
# Epoch 17/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.6355 - accuracy: 0.5733
# Epoch 18/100
# 5/5 [==============================] - 1s 180ms/step - loss: 1.6915 - accuracy: 0.5067
# Epoch 19/100
# 5/5 [==============================] - 1s 181ms/step - loss: 1.6295 - accuracy: 0.5600
# Epoch 20/100
# 5/5 [==============================] - 1s 187ms/step - loss: 1.6568 - accuracy: 0.5600
# Epoch 21/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.5902 - accuracy: 0.6133
# Epoch 22/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.5551 - accuracy: 0.6533
# Epoch 23/100
# 5/5 [==============================] - 1s 193ms/step - loss: 1.6141 - accuracy: 0.5500
# Epoch 24/100
# 5/5 [==============================] - 1s 183ms/step - loss: 1.6013 - accuracy: 0.5467
# Epoch 25/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.5818 - accuracy: 0.5867
# Epoch 26/100
# 5/5 [==============================] - 1s 189ms/step - loss: 1.5997 - accuracy: 0.6000
# Epoch 27/100
# 5/5 [==============================] - 1s 210ms/step - loss: 1.6080 - accuracy: 0.6400
# Epoch 28/100
# 5/5 [==============================] - 1s 189ms/step - loss: 1.6061 - accuracy: 0.5733
# Epoch 29/100
# 5/5 [==============================] - 1s 231ms/step - loss: 1.5968 - accuracy: 0.5867
# Epoch 30/100
# 5/5 [==============================] - 1s 205ms/step - loss: 1.5678 - accuracy: 0.6133
# Epoch 31/100
# 5/5 [==============================] - 1s 192ms/step - loss: 1.5812 - accuracy: 0.5733
# Epoch 32/100
# 5/5 [==============================] - 1s 185ms/step - loss: 1.5823 - accuracy: 0.6133
# Epoch 33/100
# 5/5 [==============================] - 1s 182ms/step - loss: 1.5805 - accuracy: 0.6000
# Epoch 34/100
# 5/5 [==============================] - 1s 185ms/step - loss: 1.6130 - accuracy: 0.5467
# Epoch 35/100
# 5/5 [==============================] - 1s 223ms/step - loss: 1.5172 - accuracy: 0.6533
# Epoch 36/100
# 5/5 [==============================] - 1s 191ms/step - loss: 1.5279 - accuracy: 0.6533
# Epoch 37/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.5259 - accuracy: 0.6133
# Epoch 38/100
# 5/5 [==============================] - 1s 188ms/step - loss: 1.4880 - accuracy: 0.6400
# Epoch 39/100
# 5/5 [==============================] - 1s 196ms/step - loss: 1.5917 - accuracy: 0.5867
# Epoch 40/100
# 5/5 [==============================] - 1s 151ms/step - loss: 1.5530 - accuracy: 0.6500
# Epoch 41/100
# 5/5 [==============================] - 1s 178ms/step - loss: 1.5399 - accuracy: 0.6375
# Epoch 42/100
# 5/5 [==============================] - 1s 191ms/step - loss: 1.5237 - accuracy: 0.6400
# Epoch 43/100
# 5/5 [==============================] - 1s 138ms/step - loss: 1.5503 - accuracy: 0.6133
# Epoch 44/100
# 5/5 [==============================] - 1s 135ms/step - loss: 1.5034 - accuracy: 0.6533
# Epoch 45/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.4804 - accuracy: 0.6267
# Epoch 46/100
# 5/5 [==============================] - 1s 134ms/step - loss: 1.5991 - accuracy: 0.5333
# Epoch 47/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.5175 - accuracy: 0.6267
# Epoch 48/100
# 5/5 [==============================] - 1s 139ms/step - loss: 1.5434 - accuracy: 0.5867
# Epoch 49/100
# 5/5 [==============================] - 1s 130ms/step - loss: 1.4885 - accuracy: 0.6375
# Epoch 50/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.4977 - accuracy: 0.6400
# Epoch 51/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.4815 - accuracy: 0.6267
# Epoch 52/100
# 5/5 [==============================] - 1s 136ms/step - loss: 1.4866 - accuracy: 0.5867
# Epoch 53/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.4968 - accuracy: 0.5600
# Epoch 54/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.4819 - accuracy: 0.6267
# Epoch 55/100
# 5/5 [==============================] - 1s 134ms/step - loss: 1.4854 - accuracy: 0.6250
# Epoch 56/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.4773 - accuracy: 0.6000
# Epoch 57/100
# 5/5 [==============================] - 1s 134ms/step - loss: 1.4546 - accuracy: 0.5733
# Epoch 58/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.4640 - accuracy: 0.5867
# Epoch 59/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.5132 - accuracy: 0.6000
# Epoch 60/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.4323 - accuracy: 0.6400
# Epoch 61/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.4369 - accuracy: 0.6133
# Epoch 62/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.4325 - accuracy: 0.6133
# Epoch 63/100
# 5/5 [==============================] - 1s 130ms/step - loss: 1.4584 - accuracy: 0.6267
# Epoch 64/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.4253 - accuracy: 0.6533
# Epoch 65/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.4097 - accuracy: 0.6267
# Epoch 66/100
# 5/5 [==============================] - 1s 136ms/step - loss: 1.3934 - accuracy: 0.6400
# Epoch 67/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.4668 - accuracy: 0.5333
# Epoch 68/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.4270 - accuracy: 0.6133
# Epoch 69/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.4365 - accuracy: 0.6000
# Epoch 70/100
# 5/5 [==============================] - 1s 132ms/step - loss: 1.4091 - accuracy: 0.6133
# Epoch 71/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.4228 - accuracy: 0.5733
# Epoch 72/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.3605 - accuracy: 0.6133
# Epoch 73/100
# 5/5 [==============================] - 1s 132ms/step - loss: 1.4445 - accuracy: 0.5875
# Epoch 74/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.4109 - accuracy: 0.6000
# Epoch 75/100
# 5/5 [==============================] - 1s 132ms/step - loss: 1.3956 - accuracy: 0.6400
# Epoch 76/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.4235 - accuracy: 0.6000
# Epoch 77/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.4224 - accuracy: 0.6533
# Epoch 78/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.3511 - accuracy: 0.6267
# Epoch 79/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.3543 - accuracy: 0.6267
# Epoch 80/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.3167 - accuracy: 0.6800
# Epoch 81/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.3363 - accuracy: 0.6400
# Epoch 82/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.3759 - accuracy: 0.5867
# Epoch 83/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.3264 - accuracy: 0.6800
# Epoch 84/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.3595 - accuracy: 0.6133
# Epoch 85/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.3298 - accuracy: 0.6133
# Epoch 86/100
# 5/5 [==============================] - 1s 133ms/step - loss: 1.3557 - accuracy: 0.5867
# Epoch 87/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.3452 - accuracy: 0.6250
# Epoch 88/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.2996 - accuracy: 0.6267
# Epoch 89/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.3420 - accuracy: 0.6133
# Epoch 90/100
# 5/5 [==============================] - 1s 133ms/step - loss: 1.2977 - accuracy: 0.6500
# Epoch 91/100
# 5/5 [==============================] - 1s 146ms/step - loss: 1.2580 - accuracy: 0.6533
# Epoch 92/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.2845 - accuracy: 0.5867
# Epoch 93/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.3179 - accuracy: 0.6400
# Epoch 94/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.3436 - accuracy: 0.5733
# Epoch 95/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.2290 - accuracy: 0.6667
# Epoch 96/100
# 5/5 [==============================] - 1s 124ms/step - loss: 1.3292 - accuracy: 0.6533
# Epoch 97/100
# 5/5 [==============================] - 1s 135ms/step - loss: 1.2458 - accuracy: 0.6625
# Epoch 98/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.2867 - accuracy: 0.6133
# Epoch 99/100
# 5/5 [==============================] - 1s 123ms/step - loss: 1.2714 - accuracy: 0.6133
# Epoch 100/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.2712 - accuracy: 0.6625
# 6/6 [==============================] - 0s 41ms/step - loss: 1.2404 - accuracy: 0.6374
# 1/1 [==============================] - 0s 80ms/step - loss: 2.0458 - accuracy: 0.1538
# Fold 4:
# Train accuracy: 0.6373626589775085, Validation accuracy: 0.1538461595773697
# Training time for fold 4: 392.16660237312317 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 136ms/step - loss: 1.2416 - accuracy: 0.6667
# Epoch 2/100
# 5/5 [==============================] - 1s 130ms/step - loss: 1.2555 - accuracy: 0.6375
# Epoch 3/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.3124 - accuracy: 0.6133
# Epoch 4/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.3109 - accuracy: 0.5600
# Epoch 5/100
# 5/5 [==============================] - 1s 124ms/step - loss: 1.2389 - accuracy: 0.6800
# Epoch 6/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.2059 - accuracy: 0.6400
# Epoch 7/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.2140 - accuracy: 0.7067
# Epoch 8/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.2605 - accuracy: 0.6933
# Epoch 9/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.1938 - accuracy: 0.7067
# Epoch 10/100
# 5/5 [==============================] - 1s 124ms/step - loss: 1.2202 - accuracy: 0.6667
# Epoch 11/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.2622 - accuracy: 0.6267
# Epoch 12/100
# 5/5 [==============================] - 1s 136ms/step - loss: 1.2189 - accuracy: 0.7200
# Epoch 13/100
# 5/5 [==============================] - 1s 133ms/step - loss: 1.1851 - accuracy: 0.6875
# Epoch 14/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.2402 - accuracy: 0.6933
# Epoch 15/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.2307 - accuracy: 0.6375
# Epoch 16/100
# 5/5 [==============================] - 1s 124ms/step - loss: 1.2375 - accuracy: 0.6267
# Epoch 17/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.1779 - accuracy: 0.7200
# Epoch 18/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.2005 - accuracy: 0.6400
# Epoch 19/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.2069 - accuracy: 0.6400
# Epoch 20/100
# 5/5 [==============================] - 1s 135ms/step - loss: 1.1752 - accuracy: 0.6933
# Epoch 21/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.1281 - accuracy: 0.7067
# Epoch 22/100
# 5/5 [==============================] - 1s 124ms/step - loss: 1.2182 - accuracy: 0.6400
# Epoch 23/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.2182 - accuracy: 0.6400
# Epoch 24/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.1745 - accuracy: 0.7200
# Epoch 25/100
# 5/5 [==============================] - 1s 133ms/step - loss: 1.1551 - accuracy: 0.6667
# Epoch 26/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.1424 - accuracy: 0.7067
# Epoch 27/100
# 5/5 [==============================] - 1s 134ms/step - loss: 1.1530 - accuracy: 0.6933
# Epoch 28/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.1686 - accuracy: 0.6800
# Epoch 29/100
# 5/5 [==============================] - 1s 130ms/step - loss: 1.1561 - accuracy: 0.6267
# Epoch 30/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.1547 - accuracy: 0.6800
# Epoch 31/100
# 5/5 [==============================] - 1s 132ms/step - loss: 1.1213 - accuracy: 0.7200
# Epoch 32/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.1351 - accuracy: 0.6750
# Epoch 33/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.1392 - accuracy: 0.6267
# Epoch 34/100
# 5/5 [==============================] - 1s 130ms/step - loss: 1.1168 - accuracy: 0.6800
# Epoch 35/100
# 5/5 [==============================] - 1s 140ms/step - loss: 1.1601 - accuracy: 0.6667
# Epoch 36/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.1709 - accuracy: 0.7067
# Epoch 37/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.1509 - accuracy: 0.6933
# Epoch 38/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.1556 - accuracy: 0.7067
# Epoch 39/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.1134 - accuracy: 0.6667
# Epoch 40/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.1307 - accuracy: 0.6500
# Epoch 41/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.0560 - accuracy: 0.7333
# Epoch 42/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.1285 - accuracy: 0.6800
# Epoch 43/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.1131 - accuracy: 0.7000
# Epoch 44/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0885 - accuracy: 0.6667
# Epoch 45/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0645 - accuracy: 0.7067
# Epoch 46/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.1698 - accuracy: 0.6667
# Epoch 47/100
# 5/5 [==============================] - 1s 130ms/step - loss: 1.0985 - accuracy: 0.6667
# Epoch 48/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0837 - accuracy: 0.6800
# Epoch 49/100
# 5/5 [==============================] - 1s 130ms/step - loss: 1.0848 - accuracy: 0.6750
# Epoch 50/100
# 5/5 [==============================] - 1s 124ms/step - loss: 1.0308 - accuracy: 0.7067
# Epoch 51/100
# 5/5 [==============================] - 1s 132ms/step - loss: 1.0715 - accuracy: 0.6800
# Epoch 52/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.1224 - accuracy: 0.6400
# Epoch 53/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0692 - accuracy: 0.7067
# Epoch 54/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.0682 - accuracy: 0.6500
# Epoch 55/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0914 - accuracy: 0.7067
# Epoch 56/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.0822 - accuracy: 0.6800
# Epoch 57/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.0678 - accuracy: 0.7333
# Epoch 58/100
# 5/5 [==============================] - 1s 130ms/step - loss: 1.0899 - accuracy: 0.7467
# Epoch 59/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.0533 - accuracy: 0.7375
# Epoch 60/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.0831 - accuracy: 0.7200
# Epoch 61/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0589 - accuracy: 0.7467
# Epoch 62/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.0510 - accuracy: 0.6933
# Epoch 63/100
# 5/5 [==============================] - 1s 125ms/step - loss: 0.9925 - accuracy: 0.7467
# Epoch 64/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.0360 - accuracy: 0.6933
# Epoch 65/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.0164 - accuracy: 0.7200
# Epoch 66/100
# 5/5 [==============================] - 1s 135ms/step - loss: 1.0491 - accuracy: 0.6800
# Epoch 67/100
# 5/5 [==============================] - 1s 131ms/step - loss: 0.9969 - accuracy: 0.7067
# Epoch 68/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0367 - accuracy: 0.7067
# Epoch 69/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.0398 - accuracy: 0.7125
# Epoch 70/100
# 5/5 [==============================] - 1s 126ms/step - loss: 0.9920 - accuracy: 0.7200
# Epoch 71/100
# 5/5 [==============================] - 1s 129ms/step - loss: 1.0868 - accuracy: 0.7333
# Epoch 72/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0018 - accuracy: 0.6800
# Epoch 73/100
# 5/5 [==============================] - 1s 139ms/step - loss: 1.0121 - accuracy: 0.7333
# Epoch 74/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0137 - accuracy: 0.7200
# Epoch 75/100
# 5/5 [==============================] - 1s 128ms/step - loss: 1.0484 - accuracy: 0.7200
# Epoch 76/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0165 - accuracy: 0.7200
# Epoch 77/100
# 5/5 [==============================] - 1s 127ms/step - loss: 1.0262 - accuracy: 0.6933
# Epoch 78/100
# 5/5 [==============================] - 1s 125ms/step - loss: 1.0384 - accuracy: 0.7067
# Epoch 79/100
# 5/5 [==============================] - 1s 131ms/step - loss: 0.9665 - accuracy: 0.7733
# Epoch 80/100
# 5/5 [==============================] - 1s 133ms/step - loss: 0.9468 - accuracy: 0.7333
# Epoch 81/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0037 - accuracy: 0.6933
# Epoch 82/100
# 5/5 [==============================] - 1s 132ms/step - loss: 0.9889 - accuracy: 0.7200
# Epoch 83/100
# 5/5 [==============================] - 1s 126ms/step - loss: 1.0157 - accuracy: 0.6800
# Epoch 84/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.0135 - accuracy: 0.7067
# Epoch 85/100
# 5/5 [==============================] - 1s 124ms/step - loss: 1.0013 - accuracy: 0.7200
# Epoch 86/100
# 5/5 [==============================] - 1s 125ms/step - loss: 0.9464 - accuracy: 0.7733
# Epoch 87/100
# 5/5 [==============================] - 1s 129ms/step - loss: 0.9755 - accuracy: 0.7333
# Epoch 88/100
# 5/5 [==============================] - 1s 131ms/step - loss: 0.9824 - accuracy: 0.7000
# Epoch 89/100
# 5/5 [==============================] - 1s 129ms/step - loss: 0.9963 - accuracy: 0.7200
# Epoch 90/100
# 5/5 [==============================] - 1s 124ms/step - loss: 1.0261 - accuracy: 0.6933
# Epoch 91/100
# 5/5 [==============================] - 1s 127ms/step - loss: 0.9587 - accuracy: 0.7200
# Epoch 92/100
# 5/5 [==============================] - 1s 124ms/step - loss: 0.9335 - accuracy: 0.6933
# Epoch 93/100
# 5/5 [==============================] - 1s 127ms/step - loss: 0.8949 - accuracy: 0.7733
# Epoch 94/100
# 5/5 [==============================] - 1s 133ms/step - loss: 0.9939 - accuracy: 0.7067
# Epoch 95/100
# 5/5 [==============================] - 1s 130ms/step - loss: 0.9785 - accuracy: 0.7125
# Epoch 96/100
# 5/5 [==============================] - 1s 131ms/step - loss: 0.9659 - accuracy: 0.7200
# Epoch 97/100
# 5/5 [==============================] - 1s 128ms/step - loss: 0.9686 - accuracy: 0.7733
# Epoch 98/100
# 5/5 [==============================] - 1s 125ms/step - loss: 0.9164 - accuracy: 0.7467
# Epoch 99/100
# 5/5 [==============================] - 1s 126ms/step - loss: 0.9525 - accuracy: 0.7467
# Epoch 100/100
# 5/5 [==============================] - 1s 130ms/step - loss: 0.8806 - accuracy: 0.7867
# 6/6 [==============================] - 0s 47ms/step - loss: 0.9155 - accuracy: 0.7692
# 1/1 [==============================] - 0s 74ms/step - loss: 1.6458 - accuracy: 0.3077
# Fold 5:
# Train accuracy: 0.7692307829856873, Validation accuracy: 0.3076923191547394
# Training time for fold 5: 459.632807970047 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 53.626375198364265 %
# Average Validation Accuracy: 13.846154361963272 %
# Average Training Time: 298.6003310203552
# Total Training Time: 459.7534713745117

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
#plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsVGG-lstmkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Metrics:
# +-------+---------------------+---------------------+---------------------+---------+
# | Class |      Precision      |        Recall       |       F1 Score      | Support |
# +-------+---------------------+---------------------+---------------------+---------+
# |   a   |         0.0         |         0.0         |         0.0         |    7    |
# |  bye  |  0.2222222222222222 |  0.2857142857142857 |         0.25        |    7    |
# |  can  |         0.0         |         0.0         |         0.0         |    7    |
# |  cat  |         0.0         |         0.0         |         0.0         |    7    |
# |  demo | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  dog  |         0.0         |         0.0         |         0.0         |    7    |
# | hello |         0.0         |         0.0         |         0.0         |    7    |
# |  here | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   is  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  lips | 0.18181818181818182 |  0.2857142857142857 |  0.2222222222222222 |    7    |
# |   my  |         0.0         |         0.0         |         0.0         |    7    |
# |  read |         0.2         | 0.14285714285714285 | 0.16666666666666666 |    7    |
# |  you  |  0.1111111111111111 | 0.14285714285714285 |        0.125        |    7    |
# +-------+---------------------+---------------------+---------------------+---------+
#
# Validation Metrics:
# +-------+--------------------+--------+--------------------+---------+
# | Class |     Precision      | Recall |      F1 Score      | Support |
# +-------+--------------------+--------+--------------------+---------+
# |   a   |        0.0         |  0.0   |        0.0         |    1    |
# |  bye  |        0.0         |  0.0   |        0.0         |    1    |
# |  can  |        0.0         |  0.0   |        0.0         |    1    |
# |  cat  |        0.0         |  0.0   |        0.0         |    1    |
# |  demo | 0.3333333333333333 |  1.0   |        0.5         |    1    |
# |  dog  |        0.0         |  0.0   |        0.0         |    1    |
# | hello |        0.0         |  0.0   |        0.0         |    1    |
# |  here |        0.0         |  0.0   |        0.0         |    1    |
# |   is  |        1.0         |  1.0   |        1.0         |    1    |
# |  lips |        0.0         |  0.0   |        0.0         |    1    |
# |   my  |        0.5         |  1.0   | 0.6666666666666666 |    1    |
# |  read |        0.5         |  1.0   | 0.6666666666666666 |    1    |
# |  you  |        0.0         |  0.0   |        0.0         |    1    |
# +-------+--------------------+--------+--------------------+---------+
# Combined metrics saved to combined_metricsVGG-lstmkfold5.xlsx

# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # CNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Track start time
start_time = time.time()

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []
comp_times = []

# Define the CNN model
model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax')
   ])

    # Compile the model
model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Found 104 images belonging to 13 classes.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 110, 78, 64)       1792
#
#  max_pooling2d (MaxPooling2D  (None, 55, 39, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 53, 37, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 26, 18, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 24, 16, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 8, 128)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 6, 128)        147584
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 3, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 1920)              0
#
#  dense (Dense)               (None, 512)               983552
#
#  dense_1 (Dense)             (None, 13)                6669
#
# =================================================================
# Total params: 1,361,037
# Trainable params: 1,361,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Track start time
start_time = time.time()

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []
comp_times = []

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Define the CNN model
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'cnn_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 104 images belonging to 13 classes.
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 2s 49ms/step - loss: 2.6374 - accuracy: 0.0800
# Epoch 2/100
# 5/5 [==============================] - 0s 52ms/step - loss: 2.5721 - accuracy: 0.0400
# Epoch 3/100
# 5/5 [==============================] - 0s 37ms/step - loss: 2.5658 - accuracy: 0.0267
# Epoch 4/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.5622 - accuracy: 0.0800
# Epoch 5/100
# 5/5 [==============================] - 0s 62ms/step - loss: 2.5607 - accuracy: 0.0800
# Epoch 6/100
# 5/5 [==============================] - 0s 56ms/step - loss: 2.5539 - accuracy: 0.0667
# Epoch 7/100
# 5/5 [==============================] - 0s 45ms/step - loss: 2.5363 - accuracy: 0.0933
# Epoch 8/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.5170 - accuracy: 0.1600
# Epoch 9/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.3983 - accuracy: 0.1875
# Epoch 10/100
# 5/5 [==============================] - 0s 28ms/step - loss: 2.2489 - accuracy: 0.2133
# Epoch 11/100
# 5/5 [==============================] - 0s 44ms/step - loss: 2.1471 - accuracy: 0.2533
# Epoch 12/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.8476 - accuracy: 0.4133
# Epoch 13/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.6347 - accuracy: 0.4533
# Epoch 14/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.7667 - accuracy: 0.3600
# Epoch 15/100
# 5/5 [==============================] - 0s 27ms/step - loss: 1.4427 - accuracy: 0.5333
# Epoch 16/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.3020 - accuracy: 0.5467
# Epoch 17/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.1809 - accuracy: 0.6133
# Epoch 18/100
# 5/5 [==============================] - 0s 28ms/step - loss: 1.0231 - accuracy: 0.7200
# Epoch 19/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.8261 - accuracy: 0.6625
# Epoch 20/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.0384 - accuracy: 0.6933
# Epoch 21/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6133 - accuracy: 0.8000
# Epoch 22/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5884 - accuracy: 0.8133
# Epoch 23/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4341 - accuracy: 0.8400
# Epoch 24/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3811 - accuracy: 0.8933
# Epoch 25/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3646 - accuracy: 0.8875
# Epoch 26/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1655 - accuracy: 0.9733
# Epoch 27/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2860 - accuracy: 0.9125
# Epoch 28/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3850 - accuracy: 0.8400
# Epoch 29/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2375 - accuracy: 0.9250
# Epoch 30/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2437 - accuracy: 0.9467
# Epoch 31/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1596 - accuracy: 0.9625
# Epoch 32/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1377 - accuracy: 0.9500
# Epoch 33/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0706 - accuracy: 0.9867
# Epoch 34/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0665 - accuracy: 0.9733
# Epoch 36/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0881 - accuracy: 0.9867
# Epoch 37/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0903 - accuracy: 0.9733
# Epoch 38/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2411 - accuracy: 0.9200
# Epoch 39/100
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0996 - accuracy: 0.9733
# Epoch 40/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0585 - accuracy: 0.9875
# Epoch 42/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0718 - accuracy: 0.9867
# Epoch 43/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0297 - accuracy: 0.9867
# Epoch 44/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 35ms/step - loss: 8.2844e-04 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 61ms/step - loss: 7.3191e-04 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 60ms/step - loss: 6.8530e-04 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 66ms/step - loss: 5.5081e-04 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 61ms/step - loss: 6.6067e-04 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 61ms/step - loss: 5.0759e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 56ms/step - loss: 5.1485e-04 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 75ms/step - loss: 4.4749e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 62ms/step - loss: 4.7336e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 51ms/step - loss: 3.7963e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 65ms/step - loss: 3.3822e-04 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 57ms/step - loss: 3.2890e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 56ms/step - loss: 3.3045e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 62ms/step - loss: 2.9965e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 57ms/step - loss: 2.7389e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 68ms/step - loss: 3.1369e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 74ms/step - loss: 3.2998e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 58ms/step - loss: 2.4862e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 56ms/step - loss: 3.0868e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 54ms/step - loss: 2.7496e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 87ms/step - loss: 2.8725e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 58ms/step - loss: 2.4981e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 60ms/step - loss: 1.8476e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 53ms/step - loss: 2.2516e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 60ms/step - loss: 2.1071e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 59ms/step - loss: 2.2996e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 69ms/step - loss: 1.9978e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.8506e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 92ms/step - loss: 2.3124e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 69ms/step - loss: 2.4091e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 59ms/step - loss: 8.5072e-05 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 92ms/step - loss: 2.0561e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 82ms/step - loss: 1.5386e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 72ms/step - loss: 1.7827e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 54ms/step - loss: 2.0611e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 54ms/step - loss: 1.8862e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 56ms/step - loss: 1.8703e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 56ms/step - loss: 1.3922e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 54ms/step - loss: 1.7251e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 66ms/step - loss: 1.1970e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.2980e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 55ms/step - loss: 1.8461e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 53ms/step - loss: 1.6022e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.3532e-04 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.3713e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.2394e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.5678e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.2239e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.3426e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.4882e-04 - accuracy: 1.0000
# 6/6 [==============================] - 0s 13ms/step - loss: 1.2763e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1019 - accuracy: 1.0000
# Fold 1:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 1: 33.8277051448822 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 52ms/step - loss: 2.6128 - accuracy: 0.0667
# Epoch 2/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.5689 - accuracy: 0.0933
# Epoch 3/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.5689 - accuracy: 0.0800
# Epoch 4/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.5603 - accuracy: 0.1250
# Epoch 5/100
# 5/5 [==============================] - 0s 29ms/step - loss: 2.5511 - accuracy: 0.1867
# Epoch 6/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.5292 - accuracy: 0.2000
# Epoch 7/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.5126 - accuracy: 0.2267
# Epoch 8/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.3986 - accuracy: 0.2267
# Epoch 9/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.2727 - accuracy: 0.3200
# Epoch 10/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.1090 - accuracy: 0.3333
# Epoch 11/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.0265 - accuracy: 0.3467
# Epoch 12/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.7157 - accuracy: 0.5200
# Epoch 13/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.7483 - accuracy: 0.4133
# Epoch 14/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.5678 - accuracy: 0.4933
# Epoch 15/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.3214 - accuracy: 0.5600
# Epoch 16/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.1048 - accuracy: 0.6533
# Epoch 17/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.1167 - accuracy: 0.6667
# Epoch 18/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7642 - accuracy: 0.7125
# Epoch 19/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7301 - accuracy: 0.7333
# Epoch 20/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.6384 - accuracy: 0.7867
# Epoch 21/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.5736 - accuracy: 0.8000
# Epoch 22/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3899 - accuracy: 0.8933
# Epoch 23/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4982 - accuracy: 0.8400
# Epoch 24/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3909 - accuracy: 0.8875
# Epoch 25/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3262 - accuracy: 0.8800
# Epoch 26/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1679 - accuracy: 0.9733
# Epoch 27/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1914 - accuracy: 0.9467
# Epoch 28/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1939 - accuracy: 0.9333
# Epoch 29/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3049 - accuracy: 0.9200
# Epoch 30/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2575 - accuracy: 0.8933
# Epoch 31/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2306 - accuracy: 0.9333
# Epoch 32/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1097 - accuracy: 0.9733
# Epoch 33/100
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0718 - accuracy: 0.9733
# Epoch 34/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0698 - accuracy: 0.9867
# Epoch 35/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1930 - accuracy: 0.9333
# Epoch 36/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1215 - accuracy: 0.9600
# Epoch 37/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0891 - accuracy: 0.9867
# Epoch 38/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0495 - accuracy: 0.9867
# Epoch 40/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0274 - accuracy: 0.9867
# Epoch 42/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0242 - accuracy: 0.9867
# Epoch 47/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0451 - accuracy: 0.9867
# Epoch 49/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0175 - accuracy: 0.9867
# Epoch 51/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0275 - accuracy: 0.9867
# Epoch 52/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0777 - accuracy: 0.9867
# Epoch 54/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0184 - accuracy: 0.9867
# Epoch 55/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0746 - accuracy: 0.9867
# Epoch 56/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 32ms/step - loss: 9.0791e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 33ms/step - loss: 6.7922e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 34ms/step - loss: 7.6716e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 33ms/step - loss: 5.3851e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 35ms/step - loss: 6.0013e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 38ms/step - loss: 5.3138e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 32ms/step - loss: 4.0793e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.3969e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.6543e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6884e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 35ms/step - loss: 3.8339e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 46ms/step - loss: 3.4130e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.4273e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 36ms/step - loss: 3.2375e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.0665e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.1345e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.7118e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.8884e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.0846e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.5779e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.4346e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.2001e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.3426e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.2877e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.9602e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.6649e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.9238e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.4994e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.7381e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.7274e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.5553e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.7590e-05 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.7373e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.3693e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.3594e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1171e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.5010e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2881e-04 - accuracy: 1.0000
# 6/6 [==============================] - 0s 14ms/step - loss: 1.2537e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0383 - accuracy: 1.0000
# Fold 2:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 2: 58.06503748893738 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 41ms/step - loss: 2.6129 - accuracy: 0.0267
# Epoch 2/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.5694 - accuracy: 0.1067
# Epoch 3/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.5665 - accuracy: 0.1067
# Epoch 4/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.5646 - accuracy: 0.0875
# Epoch 5/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.5610 - accuracy: 0.0667
# Epoch 6/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.5508 - accuracy: 0.1333
# Epoch 7/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.5829 - accuracy: 0.1250
# Epoch 8/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.5206 - accuracy: 0.2533
# Epoch 9/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.4815 - accuracy: 0.2125
# Epoch 10/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.3732 - accuracy: 0.3067
# Epoch 11/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.1559 - accuracy: 0.3600
# Epoch 12/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.9610 - accuracy: 0.3600
# Epoch 13/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.7817 - accuracy: 0.4267
# Epoch 14/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.7515 - accuracy: 0.4533
# Epoch 15/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.6244 - accuracy: 0.4667
# Epoch 16/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.4112 - accuracy: 0.5500
# Epoch 17/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.1585 - accuracy: 0.6267
# Epoch 18/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.0546 - accuracy: 0.6533
# Epoch 19/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1392 - accuracy: 0.6267
# Epoch 20/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.8248 - accuracy: 0.7067
# Epoch 21/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7836 - accuracy: 0.7600
# Epoch 22/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6587 - accuracy: 0.7867
# Epoch 23/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5431 - accuracy: 0.8667
# Epoch 24/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4873 - accuracy: 0.8400
# Epoch 25/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3352 - accuracy: 0.8667
# Epoch 26/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2637 - accuracy: 0.9200
# Epoch 27/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2814 - accuracy: 0.9067
# Epoch 28/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2627 - accuracy: 0.9200
# Epoch 29/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2167 - accuracy: 0.9200
# Epoch 30/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1586 - accuracy: 0.9600
# Epoch 31/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0999 - accuracy: 0.9867
# Epoch 32/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1533 - accuracy: 0.9467
# Epoch 33/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2068 - accuracy: 0.9250
# Epoch 34/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1976 - accuracy: 0.9467
# Epoch 35/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1215 - accuracy: 0.9750
# Epoch 36/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0562 - accuracy: 0.9867
# Epoch 37/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0547 - accuracy: 0.9867
# Epoch 38/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0730 - accuracy: 0.9875
# Epoch 39/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0443 - accuracy: 0.9875
# Epoch 40/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0443 - accuracy: 0.9750
# Epoch 41/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 30ms/step - loss: 7.2143e-04 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 31ms/step - loss: 9.5244e-04 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 36ms/step - loss: 9.0242e-04 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 33ms/step - loss: 6.1111e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.8379e-04 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 32ms/step - loss: 6.2126e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 31ms/step - loss: 6.8588e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 32ms/step - loss: 5.7414e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 30ms/step - loss: 5.9813e-04 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 33ms/step - loss: 5.8652e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 32ms/step - loss: 4.1187e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 31ms/step - loss: 5.3147e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 31ms/step - loss: 5.2536e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 31ms/step - loss: 4.0928e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 35ms/step - loss: 4.6719e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 30ms/step - loss: 4.2251e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.3028e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.6698e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.5701e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.0133e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.9778e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.6759e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.9779e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.1585e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.2027e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.5468e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.0220e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.6564e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.9954e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.0161e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.6989e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.9525e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.4108e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.7989e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.0282e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.6869e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.3229e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.4917e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.6050e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.1679e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.3681e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.5018e-04 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.7554e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.1032e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.8746e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.7761e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.8423e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.9050e-04 - accuracy: 1.0000
# 6/6 [==============================] - 0s 16ms/step - loss: 1.5846e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0725 - accuracy: 1.0000
# Fold 3:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 3: 78.65326738357544 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 53ms/step - loss: 2.6315 - accuracy: 0.0250
# Epoch 2/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.5705 - accuracy: 0.0400
# Epoch 3/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.5662 - accuracy: 0.0533
# Epoch 4/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.5673 - accuracy: 0.0533
# Epoch 5/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.5623 - accuracy: 0.1333
# Epoch 6/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.5625 - accuracy: 0.0800
# Epoch 7/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.5582 - accuracy: 0.1067
# Epoch 8/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.5341 - accuracy: 0.1467
# Epoch 9/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.4904 - accuracy: 0.1333
# Epoch 10/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.2775 - accuracy: 0.2667
# Epoch 11/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.0965 - accuracy: 0.3250
# Epoch 12/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.8921 - accuracy: 0.4133
# Epoch 13/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.6655 - accuracy: 0.4125
# Epoch 14/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.6416 - accuracy: 0.4267
# Epoch 15/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.4119 - accuracy: 0.4933
# Epoch 16/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.3116 - accuracy: 0.6000
# Epoch 17/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.0687 - accuracy: 0.6133
# Epoch 18/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.8295 - accuracy: 0.7200
# Epoch 19/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.8543 - accuracy: 0.7333
# Epoch 20/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7699 - accuracy: 0.7600
# Epoch 21/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7723 - accuracy: 0.7733
# Epoch 22/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5210 - accuracy: 0.8533
# Epoch 23/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3910 - accuracy: 0.8933
# Epoch 24/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.5204 - accuracy: 0.8500
# Epoch 25/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3838 - accuracy: 0.8533
# Epoch 26/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2305 - accuracy: 0.9333
# Epoch 27/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2798 - accuracy: 0.9200
# Epoch 28/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2586 - accuracy: 0.9200
# Epoch 29/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2433 - accuracy: 0.9467
# Epoch 30/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2980 - accuracy: 0.9067
# Epoch 31/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1456 - accuracy: 0.9375
# Epoch 32/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1998 - accuracy: 0.9467
# Epoch 33/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3395 - accuracy: 0.9333
# Epoch 34/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2169 - accuracy: 0.9200
# Epoch 35/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2339 - accuracy: 0.8933
# Epoch 36/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1987 - accuracy: 0.9333
# Epoch 37/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1251 - accuracy: 0.9867
# Epoch 38/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0945 - accuracy: 0.9733
# Epoch 39/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0956 - accuracy: 0.9733
# Epoch 40/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0403 - accuracy: 0.9867
# Epoch 42/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 33ms/step - loss: 9.6526e-04 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 31ms/step - loss: 7.3657e-04 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 34ms/step - loss: 9.5959e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 31ms/step - loss: 9.2759e-04 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 30ms/step - loss: 6.2925e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 31ms/step - loss: 6.7354e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 32ms/step - loss: 8.4389e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 30ms/step - loss: 7.8626e-04 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 32ms/step - loss: 6.0862e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 30ms/step - loss: 5.2357e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 30ms/step - loss: 7.1403e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 32ms/step - loss: 5.5186e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 33ms/step - loss: 5.4480e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 37ms/step - loss: 6.0553e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 30ms/step - loss: 3.2350e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 32ms/step - loss: 5.3355e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.9055e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 45ms/step - loss: 3.9448e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 31ms/step - loss: 4.6732e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 32ms/step - loss: 4.4021e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.4723e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 33ms/step - loss: 4.9060e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.9908e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 33ms/step - loss: 4.2835e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 34ms/step - loss: 3.4721e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.6755e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.7374e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.0051e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.5505e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.5574e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.8018e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.6359e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.6911e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.4752e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.4919e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.1694e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 30ms/step - loss: 3.2858e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.2041e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.7426e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 36ms/step - loss: 2.3234e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.8412e-04 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.1031e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.3441e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.4910e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.5514e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.3274e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.8443e-04 - accuracy: 1.0000
# 6/6 [==============================] - 0s 14ms/step - loss: 2.0523e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3007 - accuracy: 0.8462
# Fold 4:
# Train accuracy: 1.0, Validation accuracy: 0.8461538553237915
# Training time for fold 4: 99.21485900878906 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 1s 40ms/step - loss: 2.6593 - accuracy: 0.0667
# Epoch 2/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.5674 - accuracy: 0.0933
# Epoch 3/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.5640 - accuracy: 0.0800
# Epoch 4/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.5667 - accuracy: 0.0667
# Epoch 5/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.5605 - accuracy: 0.1067
# Epoch 6/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.5576 - accuracy: 0.0933
# Epoch 7/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.5473 - accuracy: 0.0875
# Epoch 8/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.5093 - accuracy: 0.1250
# Epoch 9/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.4603 - accuracy: 0.1733
# Epoch 10/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.3116 - accuracy: 0.2000
# Epoch 11/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.2112 - accuracy: 0.2933
# Epoch 12/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.9866 - accuracy: 0.3733
# Epoch 13/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.8765 - accuracy: 0.4133
# Epoch 14/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.8129 - accuracy: 0.4400
# Epoch 15/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.6030 - accuracy: 0.4800
# Epoch 16/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.4903 - accuracy: 0.5600
# Epoch 17/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.2274 - accuracy: 0.6000
# Epoch 18/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.2746 - accuracy: 0.5200
# Epoch 19/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.0189 - accuracy: 0.6667
# Epoch 20/100
# 5/5 [==============================] - 0s 29ms/step - loss: 1.0500 - accuracy: 0.6400
# Epoch 21/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7419 - accuracy: 0.7333
# Epoch 22/100
# 5/5 [==============================] - 0s 38ms/step - loss: 0.6536 - accuracy: 0.7733
# Epoch 23/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6251 - accuracy: 0.7867
# Epoch 24/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.5167 - accuracy: 0.8267
# Epoch 25/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4705 - accuracy: 0.8667
# Epoch 26/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5306 - accuracy: 0.8125
# Epoch 27/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6811 - accuracy: 0.8400
# Epoch 28/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5292 - accuracy: 0.9333
# Epoch 29/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3092 - accuracy: 0.9467
# Epoch 30/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2355 - accuracy: 0.9600
# Epoch 31/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1875 - accuracy: 0.9600
# Epoch 32/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1067 - accuracy: 0.9733
# Epoch 33/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2132 - accuracy: 0.9467
# Epoch 35/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3710 - accuracy: 0.9467
# Epoch 36/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7340 - accuracy: 0.9467
# Epoch 37/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3522 - accuracy: 0.8800
# Epoch 38/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2575 - accuracy: 0.9467
# Epoch 39/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1165 - accuracy: 0.9875
# Epoch 40/100
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0882 - accuracy: 0.9750
# Epoch 41/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0621 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0806 - accuracy: 0.9733
# Epoch 43/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0519 - accuracy: 0.9867
# Epoch 44/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 32ms/step - loss: 9.6260e-04 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 31ms/step - loss: 7.9173e-04 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 31ms/step - loss: 7.4447e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 32ms/step - loss: 8.2992e-04 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 40ms/step - loss: 4.5907e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 32ms/step - loss: 6.5808e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 31ms/step - loss: 6.6121e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 32ms/step - loss: 4.3949e-04 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 30ms/step - loss: 4.4745e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 31ms/step - loss: 4.7023e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 31ms/step - loss: 5.5038e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 30ms/step - loss: 3.2911e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 32ms/step - loss: 4.1353e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 31ms/step - loss: 4.4916e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.9555e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.8019e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 31ms/step - loss: 3.8527e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.6047e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 32ms/step - loss: 3.6068e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 30ms/step - loss: 3.0031e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 33ms/step - loss: 3.0305e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.4220e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.9126e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 34ms/step - loss: 3.0970e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.4199e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 33ms/step - loss: 2.8356e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.9873e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.0680e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.8895e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.7763e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.4558e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.7912e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 31ms/step - loss: 2.2486e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.9170e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 30ms/step - loss: 1.7218e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 30ms/step - loss: 2.1329e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.5400e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.4020e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.4076e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 32ms/step - loss: 2.2125e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.0108e-04 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.8460e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.4862e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.8700e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.6468e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6473e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 31ms/step - loss: 1.8762e-04 - accuracy: 1.0000
# 6/6 [==============================] - 0s 17ms/step - loss: 1.6097e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0760 - accuracy: 0.9231
# Fold 5:
# Train accuracy: 1.0, Validation accuracy: 0.9230769276618958
# Training time for fold 5: 119.83389687538147 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 100.0 %
# Average Validation Accuracy: 95.38461565971375 %
# Average Training Time: 77.91895318031311
# Total Training Time: 119.90945053100586

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
#plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsCNNkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+---------------------+---------------------+---------------------+---------+
# | Class |      Precision      |        Recall       |       F1 Score      | Support |
# +-------+---------------------+---------------------+---------------------+---------+
# |   a   |         0.0         |         0.0         |         0.0         |    7    |
# |  bye  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  can  |         0.0         |         0.0         |         0.0         |    7    |
# |  cat  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  demo | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  dog  |         0.0         |         0.0         |         0.0         |    7    |
# | hello |         0.0         |         0.0         |         0.0         |    7    |
# |  here | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   is  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  lips | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   my  |         0.0         |         0.0         |         0.0         |    7    |
# |  read | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  you  |         0.0         |         0.0         |         0.0         |    7    |
# +-------+---------------------+---------------------+---------------------+---------+
#
# Validation Metrics:
# +-------+-----------+--------+--------------------+---------+
# | Class | Precision | Recall |      F1 Score      | Support |
# +-------+-----------+--------+--------------------+---------+
# |   a   |    1.0    |  1.0   |        1.0         |    1    |
# |  bye  |    1.0    |  1.0   |        1.0         |    1    |
# |  can  |    1.0    |  1.0   |        1.0         |    1    |
# |  cat  |    1.0    |  1.0   |        1.0         |    1    |
# |  demo |    1.0    |  1.0   |        1.0         |    1    |
# |  dog  |    0.5    |  1.0   | 0.6666666666666666 |    1    |
# | hello |    1.0    |  1.0   |        1.0         |    1    |
# |  here |    0.0    |  0.0   |        0.0         |    1    |
# |   is  |    1.0    |  1.0   |        1.0         |    1    |
# |  lips |    1.0    |  1.0   |        1.0         |    1    |
# |   my  |    1.0    |  1.0   |        1.0         |    1    |
# |  read |    1.0    |  1.0   |        1.0         |    1    |
# |  you  |    1.0    |  1.0   |        1.0         |    1    |
# +-------+-----------+--------+--------------------+---------+
# Combined metrics saved to combined_metricsCNNkfold5.xlsx
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# # Create an ImageDataGenerator object
# datagen = ImageDataGenerator(rescale=1./255)

# # Create a generator
# generator = datagen.flow_from_directory(
#     'D:\\New Dataset Lip Movement Projec\\FINAL YEAR PROJECT\\output_denoised_image_folder',
#     target_size=(150, 150),
#     batch_size=16,
#     class_mode='binary'
# )

# print(generator.batch_size)
# Out:
# Found 298 images belonging to 17 classes.
# 16

# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # CNN_RNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []
 # Define the CNN model
model = Sequential([
    Conv2D(128, (3, 3), activation='relu', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Reshape((5, 384)),
    LSTM(256),
    Dense(512, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')
])

    # Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Found 104 images belonging to 13 classes.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 110, 78, 128)      3584
#
#  max_pooling2d (MaxPooling2D  (None, 55, 39, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 53, 37, 256)       295168
#
#  max_pooling2d_1 (MaxPooling  (None, 26, 18, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 24, 16, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 8, 256)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 6, 128)        295040
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 3, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 1920)              0
#
#  reshape (Reshape)           (None, 5, 384)            0
#
#  lstm (LSTM)                 (None, 256)               656384
#
#  dense (Dense)               (None, 512)               131584
#
#  dense_1 (Dense)             (None, 13)                6669
#
# =================================================================
# Total params: 1,978,509
# Trainable params: 1,978,509
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
import time

# Define constants
IMAGE_SIZE = (112, 80)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 13  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []
 # Define the CNN model
model = Sequential([
    Conv2D(128, (3, 3), activation='relu', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Reshape((5, 384)),
    LSTM(256),
    Dense(512, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')
])

    # Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'cnn-rnn_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 104 images belonging to 13 classes.
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 10s 255ms/step - loss: 2.5993 - accuracy: 0.0933
# Epoch 2/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.5691 - accuracy: 0.0533
# Epoch 3/100
# 5/5 [==============================] - 0s 48ms/step - loss: 2.5658 - accuracy: 0.0667
# Epoch 4/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.5705 - accuracy: 0.0875
# Epoch 5/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5652 - accuracy: 0.0800
# Epoch 6/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5668 - accuracy: 0.0667
# Epoch 7/100
# 5/5 [==============================] - 0s 49ms/step - loss: 2.5646 - accuracy: 0.0800
# Epoch 8/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5687 - accuracy: 0.0400
# Epoch 9/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5653 - accuracy: 0.0933
# Epoch 10/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.5653 - accuracy: 0.0800
# Epoch 11/100
# 5/5 [==============================] - 0s 45ms/step - loss: 2.5659 - accuracy: 0.0800
# Epoch 12/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5653 - accuracy: 0.0533
# Epoch 13/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5640 - accuracy: 0.0933
# Epoch 14/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.5661 - accuracy: 0.0625
# Epoch 15/100
# 5/5 [==============================] - 0s 54ms/step - loss: 2.5657 - accuracy: 0.0875
# Epoch 16/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5659 - accuracy: 0.0800
# Epoch 17/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5666 - accuracy: 0.0533
# Epoch 18/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5647 - accuracy: 0.0800
# Epoch 19/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5655 - accuracy: 0.0933
# Epoch 20/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5666 - accuracy: 0.0133
# Epoch 21/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5631 - accuracy: 0.0933
# Epoch 22/100
# 5/5 [==============================] - 0s 44ms/step - loss: 2.5703 - accuracy: 0.0800
# Epoch 23/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5597 - accuracy: 0.0933
# Epoch 24/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5587 - accuracy: 0.1200
# Epoch 25/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5517 - accuracy: 0.0533
# Epoch 26/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.5209 - accuracy: 0.0933
# Epoch 27/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.5300 - accuracy: 0.1600
# Epoch 28/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.4374 - accuracy: 0.1600
# Epoch 29/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.4283 - accuracy: 0.1867
# Epoch 30/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.3287 - accuracy: 0.2000
# Epoch 31/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.1973 - accuracy: 0.2267
# Epoch 32/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.1384 - accuracy: 0.2133
# Epoch 33/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.0526 - accuracy: 0.2750
# Epoch 34/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.0408 - accuracy: 0.3067
# Epoch 35/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.8797 - accuracy: 0.3200
# Epoch 36/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.9320 - accuracy: 0.2625
# Epoch 37/100
# 5/5 [==============================] - 0s 53ms/step - loss: 1.7974 - accuracy: 0.4500
# Epoch 38/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6876 - accuracy: 0.3600
# Epoch 39/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.4813 - accuracy: 0.4125
# Epoch 40/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3898 - accuracy: 0.4533
# Epoch 41/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.1644 - accuracy: 0.5625
# Epoch 42/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.0447 - accuracy: 0.6533
# Epoch 43/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.0498 - accuracy: 0.5733
# Epoch 44/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.9189 - accuracy: 0.6667
# Epoch 45/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.8566 - accuracy: 0.6667
# Epoch 46/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6505 - accuracy: 0.7625
# Epoch 47/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.5445 - accuracy: 0.8133
# Epoch 48/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4412 - accuracy: 0.8667
# Epoch 49/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3042 - accuracy: 0.8933
# Epoch 50/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3279 - accuracy: 0.8800
# Epoch 51/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2198 - accuracy: 0.9200
# Epoch 52/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2105 - accuracy: 0.9333
# Epoch 53/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2037 - accuracy: 0.8933
# Epoch 54/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2421 - accuracy: 0.8800
# Epoch 55/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1687 - accuracy: 0.9333
# Epoch 56/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2590 - accuracy: 0.9067
# Epoch 57/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1025 - accuracy: 0.9875
# Epoch 58/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 44ms/step - loss: 9.2337e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 43ms/step - loss: 8.7913e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.4870e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 42ms/step - loss: 8.6693e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 39ms/step - loss: 9.0971e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 39ms/step - loss: 8.0188e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 40ms/step - loss: 8.1144e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 41ms/step - loss: 7.8459e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 51ms/step - loss: 7.9774e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 44ms/step - loss: 7.8219e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.9781e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 42ms/step - loss: 7.8779e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 40ms/step - loss: 6.7900e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.9392e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 40ms/step - loss: 6.8374e-04 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 39ms/step - loss: 6.4141e-04 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 40ms/step - loss: 6.6538e-04 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.2259e-04 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 43ms/step - loss: 6.3651e-04 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 41ms/step - loss: 5.7182e-04 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 42ms/step - loss: 5.5163e-04 - accuracy: 1.0000
# 6/6 [==============================] - 1s 13ms/step - loss: 5.7230e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 427ms/step - loss: 0.5343 - accuracy: 0.8462
# Fold 1:
# Train accuracy: 1.0, Validation accuracy: 0.8461538553237915
# Training time for fold 1: 34.966407775878906 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.6739e-04 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 43ms/step - loss: 5.7346e-04 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 0s 40ms/step - loss: 5.0900e-04 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 0s 41ms/step - loss: 5.0080e-04 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 0s 41ms/step - loss: 5.5351e-04 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 40ms/step - loss: 4.8790e-04 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 40ms/step - loss: 5.2111e-04 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 43ms/step - loss: 4.8827e-04 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 41ms/step - loss: 4.5327e-04 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 48ms/step - loss: 4.7418e-04 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 40ms/step - loss: 5.1070e-04 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 39ms/step - loss: 4.7179e-04 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 41ms/step - loss: 4.3551e-04 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 40ms/step - loss: 4.2843e-04 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 41ms/step - loss: 4.3671e-04 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.9172e-04 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 43ms/step - loss: 4.0908e-04 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 40ms/step - loss: 4.2091e-04 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 40ms/step - loss: 4.0325e-04 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 41ms/step - loss: 4.2187e-04 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.6065e-04 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 42ms/step - loss: 3.9146e-04 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 40ms/step - loss: 4.0228e-04 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 40ms/step - loss: 3.5754e-04 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 42ms/step - loss: 3.5216e-04 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 40ms/step - loss: 3.6667e-04 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 49ms/step - loss: 3.7128e-04 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 39ms/step - loss: 3.3678e-04 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 42ms/step - loss: 3.1485e-04 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.2787e-04 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.1237e-04 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 43ms/step - loss: 3.2772e-04 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 40ms/step - loss: 3.1399e-04 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 43ms/step - loss: 3.1857e-04 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 38ms/step - loss: 3.1428e-04 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 45ms/step - loss: 3.1991e-04 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 43ms/step - loss: 3.0172e-04 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.9753e-04 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 40ms/step - loss: 3.0461e-04 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.9032e-04 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.9671e-04 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.7044e-04 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.7979e-04 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 44ms/step - loss: 2.5384e-04 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5953e-04 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.7260e-04 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 45ms/step - loss: 2.5527e-04 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 51ms/step - loss: 2.6773e-04 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.5864e-04 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.5155e-04 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.4227e-04 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.2115e-04 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.5126e-04 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.4474e-04 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.2658e-04 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.1831e-04 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 44ms/step - loss: 2.4715e-04 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.3360e-04 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.3281e-04 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.2479e-04 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.1865e-04 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.1390e-04 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.9308e-04 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.9590e-04 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.1533e-04 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.9519e-04 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.0600e-04 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.9673e-04 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 50ms/step - loss: 1.9349e-04 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.9547e-04 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.9398e-04 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.7734e-04 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.8023e-04 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6912e-04 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.6119e-04 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.8351e-04 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.8990e-04 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.7820e-04 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.7335e-04 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.6120e-04 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.7206e-04 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.7328e-04 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.6646e-04 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.6328e-04 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.4360e-04 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.5598e-04 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.4055e-04 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.4248e-04 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1350e-04 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1344e-04 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1527e-04 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.0847e-04 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 45ms/step - loss: 1.0839e-04 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 44ms/step - loss: 9.2636e-05 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.6331e-05 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.6908e-05 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.4958e-05 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.2365e-05 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 39ms/step - loss: 8.2721e-05 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 41ms/step - loss: 8.7742e-05 - accuracy: 1.0000
# 6/6 [==============================] - 0s 14ms/step - loss: 8.0523e-05 - accuracy: 1.0000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6110 - accuracy: 0.8462
# Fold 2:
# Train accuracy: 1.0, Validation accuracy: 0.8461538553237915
# Training time for fold 2: 59.069093465805054 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.2279e-05 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 42ms/step - loss: 7.5434e-05 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 0s 40ms/step - loss: 7.2284e-05 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 0s 46ms/step - loss: 7.5807e-05 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 0s 39ms/step - loss: 7.4614e-05 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 42ms/step - loss: 7.2466e-05 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 41ms/step - loss: 6.9352e-05 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.6280e-05 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.8791e-05 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 42ms/step - loss: 5.9213e-05 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 44ms/step - loss: 5.3999e-05 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.2992e-05 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 40ms/step - loss: 5.6610e-05 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.1307e-05 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 40ms/step - loss: 5.6678e-05 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 41ms/step - loss: 5.3058e-05 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 41ms/step - loss: 5.0369e-05 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 44ms/step - loss: 5.4523e-05 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 41ms/step - loss: 5.2158e-05 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 41ms/step - loss: 5.3148e-05 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 48ms/step - loss: 5.1262e-05 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 41ms/step - loss: 5.0677e-05 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 41ms/step - loss: 4.9808e-05 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 39ms/step - loss: 5.0292e-05 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 43ms/step - loss: 4.7611e-05 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 41ms/step - loss: 4.6524e-05 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 41ms/step - loss: 4.7791e-05 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 43ms/step - loss: 4.4661e-05 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 44ms/step - loss: 4.3730e-05 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.8168e-05 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 41ms/step - loss: 4.2341e-05 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 39ms/step - loss: 3.8816e-05 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 39ms/step - loss: 4.0647e-05 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 39ms/step - loss: 4.1763e-05 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 40ms/step - loss: 3.7487e-05 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.8843e-05 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 50ms/step - loss: 3.7603e-05 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 40ms/step - loss: 3.7953e-05 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.6062e-05 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 39ms/step - loss: 3.3293e-05 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 41ms/step - loss: 3.7661e-05 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 52ms/step - loss: 3.2956e-05 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 59ms/step - loss: 3.3239e-05 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 69ms/step - loss: 3.2422e-05 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 60ms/step - loss: 3.7278e-05 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 59ms/step - loss: 2.9549e-05 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 57ms/step - loss: 3.1230e-05 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 58ms/step - loss: 3.4070e-05 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 57ms/step - loss: 3.0736e-05 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 52ms/step - loss: 3.2282e-05 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 66ms/step - loss: 2.9295e-05 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 40ms/step - loss: 3.0350e-05 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 39ms/step - loss: 3.0367e-05 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.8849e-05 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.8235e-05 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.5095e-05 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.8308e-05 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.7756e-05 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.8523e-05 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.3172e-05 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.7148e-05 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 38ms/step - loss: 2.7130e-05 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.6740e-05 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 47ms/step - loss: 2.7931e-05 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.6146e-05 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.6008e-05 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.6279e-05 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 38ms/step - loss: 2.4081e-05 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.6146e-05 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.4689e-05 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.3873e-05 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.3016e-05 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.2578e-05 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.4385e-05 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.4310e-05 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.3515e-05 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 42ms/step - loss: 2.2818e-05 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.1808e-05 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 46ms/step - loss: 2.4094e-05 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.1694e-05 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.2489e-05 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.1451e-05 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.0322e-05 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.0113e-05 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.8744e-05 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.1618e-05 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2.0664e-05 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 41ms/step - loss: 2.0170e-05 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.9914e-05 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 55ms/step - loss: 1.9826e-05 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 53ms/step - loss: 2.1549e-05 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 65ms/step - loss: 2.0681e-05 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 60ms/step - loss: 2.0211e-05 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 57ms/step - loss: 1.9888e-05 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 53ms/step - loss: 1.9267e-05 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 56ms/step - loss: 1.9149e-05 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 58ms/step - loss: 1.8550e-05 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 55ms/step - loss: 1.7508e-05 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 55ms/step - loss: 1.8544e-05 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 55ms/step - loss: 1.6794e-05 - accuracy: 1.0000
# 6/6 [==============================] - 0s 19ms/step - loss: 1.8296e-05 - accuracy: 1.0000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.5381 - accuracy: 0.8462
# Fold 3:
# Train accuracy: 1.0, Validation accuracy: 0.8461538553237915
# Training time for fold 3: 84.93345403671265 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.8100e-05 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.8450e-05 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6929e-05 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.8512e-05 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.8649e-05 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.8089e-05 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.7317e-05 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.7220e-05 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.7318e-05 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.7447e-05 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.8592e-05 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6893e-05 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.4276e-05 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5279e-05 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.5224e-05 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.6862e-05 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5382e-05 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.5958e-05 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6172e-05 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.5667e-05 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6074e-05 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.4682e-05 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.5802e-05 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5275e-05 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6002e-05 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.4383e-05 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.6083e-05 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.6379e-05 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5667e-05 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.5491e-05 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.5065e-05 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.4701e-05 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.4759e-05 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.4283e-05 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.5224e-05 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.4562e-05 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.5059e-05 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5193e-05 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.4821e-05 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.4529e-05 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.4493e-05 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.3671e-05 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.3159e-05 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3412e-05 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.5044e-05 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.4726e-05 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.4005e-05 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.4080e-05 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3812e-05 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2636e-05 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3977e-05 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2159e-05 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 49ms/step - loss: 1.2884e-05 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2495e-05 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.2577e-05 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3359e-05 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.3135e-05 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.3038e-05 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2213e-05 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1930e-05 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2134e-05 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2334e-05 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.0293e-05 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2456e-05 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.1946e-05 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.1490e-05 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2560e-05 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2175e-05 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2423e-05 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2062e-05 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.1846e-05 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.1077e-05 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0803e-05 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.1767e-05 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1829e-05 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1531e-05 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.0864e-05 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1668e-05 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0748e-05 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0514e-05 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0896e-05 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1310e-05 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 46ms/step - loss: 1.1392e-05 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0157e-05 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.6082e-06 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0333e-05 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.1170e-05 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.1342e-05 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.5970e-06 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 40ms/step - loss: 9.9054e-06 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.3602e-06 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.0730e-05 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0749e-05 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.0892e-05 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.0373e-05 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 40ms/step - loss: 9.1695e-06 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0452e-05 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.0060e-05 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0247e-05 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0463e-05 - accuracy: 1.0000
# 6/6 [==============================] - 0s 15ms/step - loss: 9.8275e-06 - accuracy: 1.0000
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4892 - accuracy: 0.8462
# Fold 4:
# Train accuracy: 1.0, Validation accuracy: 0.8461538553237915
# Training time for fold 4: 108.92176151275635 seconds
#
# Found 91 images belonging to 13 classes.
# Found 13 images belonging to 13 classes.
# Epoch 1/100
# 5/5 [==============================] - 0s 44ms/step - loss: 9.9737e-06 - accuracy: 1.0000
# Epoch 2/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.3825e-06 - accuracy: 1.0000
# Epoch 3/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.0548e-05 - accuracy: 1.0000
# Epoch 4/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.7512e-06 - accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0295e-05 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 40ms/step - loss: 9.8832e-06 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.9499e-06 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 39ms/step - loss: 9.9785e-06 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.4588e-06 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.6098e-06 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 47ms/step - loss: 9.3586e-06 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 40ms/step - loss: 9.9261e-06 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 39ms/step - loss: 9.7322e-06 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.6908e-06 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 41ms/step - loss: 8.7451e-06 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 43ms/step - loss: 9.6908e-06 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 43ms/step - loss: 8.9136e-06 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 43ms/step - loss: 8.7007e-06 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.1441e-06 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 41ms/step - loss: 9.4397e-06 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 39ms/step - loss: 9.0487e-06 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 39ms/step - loss: 8.4924e-06 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 41ms/step - loss: 8.1872e-06 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 40ms/step - loss: 8.3462e-06 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 43ms/step - loss: 9.0166e-06 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.2728e-06 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 41ms/step - loss: 7.8618e-06 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 38ms/step - loss: 8.8421e-06 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 44ms/step - loss: 8.9438e-06 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 41ms/step - loss: 8.6828e-06 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 42ms/step - loss: 8.5131e-06 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 42ms/step - loss: 8.1618e-06 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 60ms/step - loss: 8.7006e-06 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 52ms/step - loss: 8.2254e-06 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 45ms/step - loss: 8.0966e-06 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 43ms/step - loss: 7.2336e-06 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.2460e-06 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 56ms/step - loss: 8.2842e-06 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 40ms/step - loss: 8.3795e-06 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 50ms/step - loss: 7.9711e-06 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 41ms/step - loss: 8.5083e-06 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 48ms/step - loss: 7.8900e-06 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 54ms/step - loss: 8.2301e-06 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 49ms/step - loss: 7.9440e-06 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 41ms/step - loss: 8.0391e-06 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 49ms/step - loss: 8.0063e-06 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 43ms/step - loss: 7.9488e-06 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 53ms/step - loss: 8.3668e-06 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.9631e-06 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 57ms/step - loss: 7.9917e-06 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 40ms/step - loss: 7.6500e-06 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 66ms/step - loss: 7.7545e-06 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 43ms/step - loss: 7.9647e-06 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 41ms/step - loss: 7.8105e-06 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 39ms/step - loss: 7.6929e-06 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 55ms/step - loss: 7.5260e-06 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 41ms/step - loss: 7.6875e-06 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 39ms/step - loss: 7.9393e-06 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 37ms/step - loss: 7.4227e-06 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 44ms/step - loss: 7.2797e-06 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 41ms/step - loss: 6.9157e-06 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 39ms/step - loss: 8.1268e-06 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 41ms/step - loss: 7.8360e-06 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 40ms/step - loss: 7.7930e-06 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 40ms/step - loss: 7.1589e-06 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 40ms/step - loss: 7.4831e-06 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 60ms/step - loss: 7.2542e-06 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 53ms/step - loss: 7.3115e-06 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 61ms/step - loss: 6.8823e-06 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 54ms/step - loss: 6.5628e-06 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 42ms/step - loss: 7.4179e-06 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 53ms/step - loss: 7.7867e-06 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 67ms/step - loss: 7.3623e-06 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 51ms/step - loss: 6.5755e-06 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 50ms/step - loss: 6.4802e-06 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 48ms/step - loss: 6.3324e-06 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 41ms/step - loss: 7.1048e-06 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 46ms/step - loss: 6.7520e-06 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 54ms/step - loss: 7.3337e-06 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 40ms/step - loss: 7.1811e-06 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 57ms/step - loss: 7.4307e-06 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 42ms/step - loss: 7.1907e-06 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 44ms/step - loss: 7.1406e-06 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 48ms/step - loss: 6.6582e-06 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 47ms/step - loss: 6.1226e-06 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.6216e-06 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 45ms/step - loss: 6.6328e-06 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 44ms/step - loss: 7.0508e-06 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 64ms/step - loss: 6.1854e-06 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 58ms/step - loss: 6.6757e-06 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 53ms/step - loss: 6.9586e-06 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 56ms/step - loss: 6.8871e-06 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 41ms/step - loss: 6.6677e-06 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 50ms/step - loss: 7.0126e-06 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.0190e-06 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 41ms/step - loss: 6.5490e-06 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 50ms/step - loss: 6.5485e-06 - accuracy: 1.0000 0s - loss: 6.5485e-06 - accuracy: 1.00
# Epoch 98/100
# 5/5 [==============================] - 0s 43ms/step - loss: 6.5930e-06 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 40ms/step - loss: 6.4993e-06 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 42ms/step - loss: 6.2799e-06 - accuracy: 1.0000
# 6/6 [==============================] - 0s 14ms/step - loss: 6.4032e-06 - accuracy: 1.0000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4852 - accuracy: 0.8462
# Fold 5:
# Train accuracy: 1.0, Validation accuracy: 0.8461538553237915
# Training time for fold 5: 135.4645721912384 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 100.0 %
# Average Validation Accuracy: 84.61538553237915 %
# Average Training Time: 84.67105779647827
# Total Training Time: 135.60657167434692

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
#plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsCNN-RNNkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Metrics:
# +-------+---------------------+---------------------+---------------------+---------+
# | Class |      Precision      |        Recall       |       F1 Score      | Support |
# +-------+---------------------+---------------------+---------------------+---------+
# |   a   |         0.0         |         0.0         |         0.0         |    7    |
# |  bye  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  can  |         0.0         |         0.0         |         0.0         |    7    |
# |  cat  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  demo | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  dog  |         0.0         |         0.0         |         0.0         |    7    |
# | hello |         0.0         |         0.0         |         0.0         |    7    |
# |  here | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   is  | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  lips | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |   my  |         0.0         |         0.0         |         0.0         |    7    |
# |  read | 0.14285714285714285 | 0.14285714285714285 | 0.14285714285714285 |    7    |
# |  you  |         0.0         |         0.0         |         0.0         |    7    |
# +-------+---------------------+---------------------+---------------------+---------+
#
# Validation Metrics:
# +-------+-----------+--------+--------------------+---------+
# | Class | Precision | Recall |      F1 Score      | Support |
# +-------+-----------+--------+--------------------+---------+
# |   a   |    0.0    |  0.0   |        0.0         |    1    |
# |  bye  |    1.0    |  1.0   |        1.0         |    1    |
# |  can  |    1.0    |  1.0   |        1.0         |    1    |
# |  cat  |    1.0    |  1.0   |        1.0         |    1    |
# |  demo |    1.0    |  1.0   |        1.0         |    1    |
# |  dog  |    1.0    |  1.0   |        1.0         |    1    |
# | hello |    1.0    |  1.0   |        1.0         |    1    |
# |  here |    0.0    |  0.0   |        0.0         |    1    |
# |   is  |    1.0    |  1.0   |        1.0         |    1    |
# |  lips |    0.5    |  1.0   | 0.6666666666666666 |    1    |
# |   my  |    1.0    |  1.0   |        1.0         |    1    |
# |  read |    0.5    |  1.0   | 0.6666666666666666 |    1    |
# |  you  |    1.0    |  1.0   |        1.0         |    1    |
# +-------+-----------+--------+--------------------+---------+
# Combined metrics saved to combined_metricsCNN-RNNkfold5.xlsx

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'k_foldvalidation5cnn.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# # Create an ImageDataGenerator object
# datagen = ImageDataGenerator(rescale=1./255)

# # Create a generator
# generator = datagen.flow_from_directory(
#     'D:\\New Dataset Lip Movement Projec\\FINAL YEAR PROJECT\\output_denoised_image_folder',
#     target_size=(150, 150),
#     batch_size=16,
#     class_mode='binary'
# )

# print(generator.batch_size)
# Out:
# Found 298 images belonging to 17 classes.
# 16

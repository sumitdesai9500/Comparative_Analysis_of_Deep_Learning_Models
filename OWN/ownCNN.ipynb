# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # CNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
import time

# Define constants
# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Saquib\\output_denoised_image_folder"
K_FOLDS=5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Track start time
start_time = time.time()

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []
comp_times = []

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Define the CNN model
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Found 298 images belonging to 17 classes.
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.

# %% [markdown]
# # Model Summary

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
import time

# Define constants
# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Saquib\\output_denoised_image_folder"
K_FOLDS=5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []
comp_times = []

# Define the CNN model
model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax')
    ])

    # Compile the model
model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Found 298 images belonging to 17 classes.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 94, 70, 64)        1792
#
#  max_pooling2d_4 (MaxPooling  (None, 47, 35, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 33, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 16, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 20, 14, 128)       147584
#
#  max_pooling2d_6 (MaxPooling  (None, 10, 7, 128)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 5, 128)         147584
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 2, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 17)                8721
#
# =================================================================
# Total params: 904,337
# Trainable params: 904,337
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
import time

# Define constants
# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Saquib\\output_denoised_image_folder"
K_FOLDS=5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Track start time
start_time = time.time()

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []
comp_times = []

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Define the CNN model
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'cnn_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 298 images belonging to 17 classes.
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 10s 62ms/step - loss: 2.8556 - accuracy: 0.0696 - val_loss: 2.8313 - val_accuracy: 0.0833
# Epoch 2/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8322 - accuracy: 0.0739 - val_loss: 2.8240 - val_accuracy: 0.0833
# Epoch 3/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8172 - accuracy: 0.0826 - val_loss: 2.7470 - val_accuracy: 0.1458
# Epoch 4/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.5906 - accuracy: 0.1739 - val_loss: 2.5432 - val_accuracy: 0.2083
# Epoch 5/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.4158 - accuracy: 0.2043 - val_loss: 2.4793 - val_accuracy: 0.1458
# Epoch 6/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.1909 - accuracy: 0.2261 - val_loss: 2.1723 - val_accuracy: 0.2083
# Epoch 7/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.9864 - accuracy: 0.3217 - val_loss: 2.1686 - val_accuracy: 0.2500
# Epoch 8/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.7891 - accuracy: 0.4261 - val_loss: 2.0846 - val_accuracy: 0.3125
# Epoch 9/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.5381 - accuracy: 0.5087 - val_loss: 1.8875 - val_accuracy: 0.3542
# Epoch 10/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.3693 - accuracy: 0.5348 - val_loss: 1.8585 - val_accuracy: 0.4583
# Epoch 11/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.2654 - accuracy: 0.5783 - val_loss: 1.7339 - val_accuracy: 0.4375
# Epoch 12/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.0498 - accuracy: 0.6609 - val_loss: 1.3053 - val_accuracy: 0.5833
# Epoch 13/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.8805 - accuracy: 0.7174 - val_loss: 2.2503 - val_accuracy: 0.3958
# Epoch 14/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.9572 - accuracy: 0.7217 - val_loss: 1.1329 - val_accuracy: 0.6042
# Epoch 15/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5799 - accuracy: 0.8130 - val_loss: 1.3472 - val_accuracy: 0.5417
# Epoch 16/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5551 - accuracy: 0.8261 - val_loss: 0.9772 - val_accuracy: 0.6875
# Epoch 17/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6892 - accuracy: 0.8217 - val_loss: 1.3038 - val_accuracy: 0.5417
# Epoch 18/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5448 - accuracy: 0.8292 - val_loss: 1.0093 - val_accuracy: 0.6458
# Epoch 19/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5165 - accuracy: 0.8348 - val_loss: 0.6306 - val_accuracy: 0.7917
# Epoch 20/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.3239 - accuracy: 0.9130 - val_loss: 0.4241 - val_accuracy: 0.8333
# Epoch 21/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2219 - accuracy: 0.9391 - val_loss: 0.6293 - val_accuracy: 0.7500
# Epoch 22/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1786 - accuracy: 0.9391 - val_loss: 0.3183 - val_accuracy: 0.8750
# Epoch 23/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1770 - accuracy: 0.9522 - val_loss: 0.3990 - val_accuracy: 0.8542
# Epoch 24/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1059 - accuracy: 0.9609 - val_loss: 0.2021 - val_accuracy: 0.9375
# Epoch 25/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0847 - accuracy: 0.9739 - val_loss: 0.2062 - val_accuracy: 0.9375
# Epoch 26/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0723 - accuracy: 0.9783 - val_loss: 0.1192 - val_accuracy: 0.9375
# Epoch 27/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1067 - accuracy: 0.9652 - val_loss: 0.3240 - val_accuracy: 0.8958
# Epoch 28/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1084 - accuracy: 0.9696 - val_loss: 0.3318 - val_accuracy: 0.8750
# Epoch 29/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1213 - accuracy: 0.9652 - val_loss: 0.3348 - val_accuracy: 0.8958
# Epoch 30/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3664 - accuracy: 0.9174 - val_loss: 0.4951 - val_accuracy: 0.8333
# Epoch 31/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2169 - accuracy: 0.9391 - val_loss: 0.3964 - val_accuracy: 0.8333
# Epoch 32/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1608 - accuracy: 0.9522 - val_loss: 0.1403 - val_accuracy: 0.9792
# Epoch 33/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1503 - accuracy: 0.9783 - val_loss: 0.0877 - val_accuracy: 0.9792
# Epoch 34/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0880 - accuracy: 0.9739 - val_loss: 0.0692 - val_accuracy: 1.0000
# Epoch 35/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0263 - accuracy: 0.9917 - val_loss: 0.0389 - val_accuracy: 1.0000
# Epoch 36/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0532 - accuracy: 0.9783 - val_loss: 0.2829 - val_accuracy: 0.8958
# Epoch 37/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0924 - accuracy: 0.9739 - val_loss: 0.2583 - val_accuracy: 0.8750
# Epoch 38/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0631 - accuracy: 0.9696 - val_loss: 0.2849 - val_accuracy: 0.9167
# Epoch 39/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0720 - accuracy: 0.9826 - val_loss: 0.0639 - val_accuracy: 0.9583
# Epoch 40/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0313 - accuracy: 0.9913 - val_loss: 0.2083 - val_accuracy: 0.9375
# Epoch 41/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1257 - accuracy: 0.9652 - val_loss: 0.1512 - val_accuracy: 0.9583
# Epoch 42/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1047 - accuracy: 0.9696 - val_loss: 0.1354 - val_accuracy: 0.9583
# Epoch 43/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1068 - accuracy: 0.9783 - val_loss: 0.3603 - val_accuracy: 0.9375
# Epoch 44/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0858 - accuracy: 0.9826 - val_loss: 0.0685 - val_accuracy: 0.9792
# Epoch 45/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0501 - accuracy: 0.9870 - val_loss: 0.3509 - val_accuracy: 0.8958
# Epoch 46/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0393 - accuracy: 0.9957 - val_loss: 0.0427 - val_accuracy: 0.9792
# Epoch 47/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0624 - accuracy: 0.9783 - val_loss: 0.0655 - val_accuracy: 1.0000
# Epoch 48/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1133 - accuracy: 0.9696 - val_loss: 0.1205 - val_accuracy: 0.9375
# Epoch 49/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0724 - accuracy: 0.9783 - val_loss: 0.1385 - val_accuracy: 0.9583
# Epoch 50/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0998 - accuracy: 0.9783 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 51/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0457 - accuracy: 0.9957 - val_loss: 0.2501 - val_accuracy: 0.8958
# Epoch 52/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0978 - accuracy: 0.9696 - val_loss: 0.1112 - val_accuracy: 0.9583
# Epoch 53/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0652 - accuracy: 0.9826 - val_loss: 0.2057 - val_accuracy: 0.9167
# Epoch 54/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0778 - accuracy: 0.9696 - val_loss: 0.1495 - val_accuracy: 0.9792
# Epoch 55/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1043 - accuracy: 0.9652 - val_loss: 1.1418 - val_accuracy: 0.7083
# Epoch 56/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.3481 - accuracy: 0.9130 - val_loss: 0.4252 - val_accuracy: 0.8750
# Epoch 57/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.1457 - accuracy: 0.9652 - val_loss: 0.2525 - val_accuracy: 0.9167
# Epoch 58/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2663 - accuracy: 0.9478 - val_loss: 0.5082 - val_accuracy: 0.8333
# Epoch 59/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1958 - accuracy: 0.9652 - val_loss: 0.1932 - val_accuracy: 0.9583
# Epoch 60/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0360 - accuracy: 0.9870 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 61/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 62/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 63/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 64/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 65/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 66/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 67/100
# 15/15 [==============================] - 0s 18ms/step - loss: 9.9996e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 68/100
# 15/15 [==============================] - 0s 16ms/step - loss: 8.3611e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 69/100
# 15/15 [==============================] - 0s 16ms/step - loss: 7.6701e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 70/100
# 15/15 [==============================] - 0s 17ms/step - loss: 7.3601e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 71/100
# 15/15 [==============================] - 0s 17ms/step - loss: 7.4250e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 72/100
# 15/15 [==============================] - 0s 17ms/step - loss: 7.0062e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 73/100
# 15/15 [==============================] - 0s 17ms/step - loss: 5.9245e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 74/100
# 15/15 [==============================] - 0s 17ms/step - loss: 5.6959e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 75/100
# 15/15 [==============================] - 0s 16ms/step - loss: 5.6923e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 76/100
# 15/15 [==============================] - 0s 16ms/step - loss: 4.2216e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 77/100
# 15/15 [==============================] - 0s 15ms/step - loss: 5.1054e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 78/100
# 15/15 [==============================] - 0s 16ms/step - loss: 4.7903e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 79/100
# 15/15 [==============================] - 0s 17ms/step - loss: 4.5074e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 80/100
# 15/15 [==============================] - 0s 16ms/step - loss: 4.6172e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 81/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.2024e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 82/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.9218e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 83/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.6003e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 84/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.9789e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 85/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.4404e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 86/100
# 15/15 [==============================] - 0s 17ms/step - loss: 4.3700e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 87/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.4058e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 88/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.3385e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 89/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.0477e-04 - accuracy: 1.0000 - val_loss: 9.4905e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7552e-04 - accuracy: 1.0000 - val_loss: 9.1372e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 15/15 [==============================] - 0s 18ms/step - loss: 2.7135e-04 - accuracy: 1.0000 - val_loss: 8.9008e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6050e-04 - accuracy: 1.0000 - val_loss: 8.6332e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.9867e-04 - accuracy: 1.0000 - val_loss: 8.5789e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.4621e-04 - accuracy: 1.0000 - val_loss: 8.4363e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.4816e-04 - accuracy: 1.0000 - val_loss: 7.7398e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.2281e-04 - accuracy: 1.0000 - val_loss: 7.5478e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.2338e-04 - accuracy: 1.0000 - val_loss: 7.3631e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.1305e-04 - accuracy: 1.0000 - val_loss: 7.3181e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - 0s 15ms/step - loss: 2.2701e-04 - accuracy: 1.0000 - val_loss: 7.0260e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.0538e-04 - accuracy: 1.0000 - val_loss: 6.6926e-04 - val_accuracy: 1.0000
# 16/16 [==============================] - 0s 9ms/step - loss: 1.8916e-04 - accuracy: 1.0000
# 4/4 [==============================] - 0s 46ms/step - loss: 6.2017e-04 - accuracy: 1.0000
# Fold 1:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 1: 41.02516746520996 seconds
#
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 1s 24ms/step - loss: 2.8536 - accuracy: 0.0652 - val_loss: 2.8317 - val_accuracy: 0.0833
# Epoch 2/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8326 - accuracy: 0.0522 - val_loss: 2.8275 - val_accuracy: 0.1458
# Epoch 3/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8208 - accuracy: 0.1042 - val_loss: 2.7624 - val_accuracy: 0.0833
# Epoch 4/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6884 - accuracy: 0.1391 - val_loss: 2.4699 - val_accuracy: 0.2292
# Epoch 5/100
# 15/15 [==============================] - 0s 18ms/step - loss: 2.2896 - accuracy: 0.2348 - val_loss: 2.3000 - val_accuracy: 0.1250
# Epoch 6/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.1287 - accuracy: 0.2652 - val_loss: 2.0721 - val_accuracy: 0.3125
# Epoch 7/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.9589 - accuracy: 0.3125 - val_loss: 2.0697 - val_accuracy: 0.4167
# Epoch 8/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.7678 - accuracy: 0.4043 - val_loss: 2.0839 - val_accuracy: 0.2500
# Epoch 9/100
# 15/15 [==============================] - 0s 19ms/step - loss: 1.6482 - accuracy: 0.4957 - val_loss: 2.0300 - val_accuracy: 0.3542
# Epoch 10/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.6422 - accuracy: 0.4957 - val_loss: 1.7996 - val_accuracy: 0.3750
# Epoch 11/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.2502 - accuracy: 0.5826 - val_loss: 1.7299 - val_accuracy: 0.3958
# Epoch 12/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1405 - accuracy: 0.6522 - val_loss: 1.7106 - val_accuracy: 0.5000
# Epoch 13/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.0111 - accuracy: 0.6870 - val_loss: 1.4059 - val_accuracy: 0.5417
# Epoch 14/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.8235 - accuracy: 0.7391 - val_loss: 1.2042 - val_accuracy: 0.5625
# Epoch 15/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6015 - accuracy: 0.8043 - val_loss: 1.3583 - val_accuracy: 0.6250
# Epoch 16/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5329 - accuracy: 0.8609 - val_loss: 0.8626 - val_accuracy: 0.6875
# Epoch 17/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.4499 - accuracy: 0.8826 - val_loss: 0.9106 - val_accuracy: 0.7083
# Epoch 18/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.4584 - accuracy: 0.8375 - val_loss: 0.8731 - val_accuracy: 0.6458
# Epoch 19/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4101 - accuracy: 0.8565 - val_loss: 0.5595 - val_accuracy: 0.7500
# Epoch 20/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.4382 - accuracy: 0.8783 - val_loss: 0.5437 - val_accuracy: 0.7917
# Epoch 21/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2455 - accuracy: 0.9458 - val_loss: 0.4974 - val_accuracy: 0.8333
# Epoch 22/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1419 - accuracy: 0.9609 - val_loss: 0.4043 - val_accuracy: 0.8542
# Epoch 23/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0849 - accuracy: 0.9783 - val_loss: 0.3984 - val_accuracy: 0.8333
# Epoch 24/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0594 - accuracy: 0.9739 - val_loss: 0.1331 - val_accuracy: 0.9792
# Epoch 25/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0689 - accuracy: 0.9826 - val_loss: 0.4224 - val_accuracy: 0.8542
# Epoch 26/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.1170 - accuracy: 0.9565 - val_loss: 0.2017 - val_accuracy: 0.9167
# Epoch 27/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0813 - accuracy: 0.9783 - val_loss: 0.1120 - val_accuracy: 0.9792
# Epoch 28/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0495 - accuracy: 0.9870 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 29/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0218 - accuracy: 0.9913 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 30/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0213 - accuracy: 0.9957 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 31/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0203 - accuracy: 0.9957 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 32/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 33/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 34/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 35/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 36/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 37/100
# 15/15 [==============================] - 0s 16ms/step - loss: 9.5713e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 38/100
# 15/15 [==============================] - 0s 18ms/step - loss: 9.2561e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 39/100
# 15/15 [==============================] - 0s 16ms/step - loss: 8.2882e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 40/100
# 15/15 [==============================] - 0s 18ms/step - loss: 7.5707e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 41/100
# 15/15 [==============================] - 0s 17ms/step - loss: 6.5126e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 42/100
# 15/15 [==============================] - 0s 17ms/step - loss: 6.0602e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 43/100
# 15/15 [==============================] - 0s 17ms/step - loss: 5.7305e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 44/100
# 15/15 [==============================] - 0s 17ms/step - loss: 5.0311e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 45/100
# 15/15 [==============================] - 0s 18ms/step - loss: 5.1506e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 46/100
# 15/15 [==============================] - 0s 16ms/step - loss: 4.8692e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 47/100
# 15/15 [==============================] - 0s 16ms/step - loss: 4.2137e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 48/100
# 15/15 [==============================] - 0s 17ms/step - loss: 4.0106e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 49/100
# 15/15 [==============================] - ETA: 0s - loss: 3.9493e-04 - accuracy: 1.00 - 0s 16ms/step - loss: 3.9493e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 50/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.7256e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 51/100
# 15/15 [==============================] - 0s 18ms/step - loss: 3.3851e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 52/100
# 15/15 [==============================] - 0s 18ms/step - loss: 3.3469e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 53/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.3120e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 54/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.6687e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 55/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8791e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 56/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8371e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 57/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6790e-04 - accuracy: 1.0000 - val_loss: 9.6996e-04 - val_accuracy: 1.0000
# Epoch 58/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.5448e-04 - accuracy: 1.0000 - val_loss: 9.4469e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.4731e-04 - accuracy: 1.0000 - val_loss: 8.7957e-04 - val_accuracy: 1.0000
# Epoch 60/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.3151e-04 - accuracy: 1.0000 - val_loss: 8.4731e-04 - val_accuracy: 1.0000
# Epoch 61/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.3261e-04 - accuracy: 1.0000 - val_loss: 7.9226e-04 - val_accuracy: 1.0000
# Epoch 62/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.8683e-04 - accuracy: 1.0000 - val_loss: 8.6679e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.1518e-04 - accuracy: 1.0000 - val_loss: 7.9298e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.0434e-04 - accuracy: 1.0000 - val_loss: 7.7500e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.9471e-04 - accuracy: 1.0000 - val_loss: 7.0269e-04 - val_accuracy: 1.0000
# Epoch 66/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.8431e-04 - accuracy: 1.0000 - val_loss: 6.6845e-04 - val_accuracy: 1.0000
# Epoch 67/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.6651e-04 - accuracy: 1.0000 - val_loss: 6.3061e-04 - val_accuracy: 1.0000
# Epoch 68/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.7000e-04 - accuracy: 1.0000 - val_loss: 6.0262e-04 - val_accuracy: 1.0000
# Epoch 69/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.6965e-04 - accuracy: 1.0000 - val_loss: 6.1897e-04 - val_accuracy: 1.0000
# Epoch 70/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.6224e-04 - accuracy: 1.0000 - val_loss: 5.6267e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.4320e-04 - accuracy: 1.0000 - val_loss: 5.4980e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.4792e-04 - accuracy: 1.0000 - val_loss: 5.5849e-04 - val_accuracy: 1.0000
# Epoch 73/100
# 15/15 [==============================] - 0s 18ms/step - loss: 1.5196e-04 - accuracy: 1.0000 - val_loss: 5.7351e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.3335e-04 - accuracy: 1.0000 - val_loss: 5.6123e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.3777e-04 - accuracy: 1.0000 - val_loss: 5.1034e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.3857e-04 - accuracy: 1.0000 - val_loss: 5.0912e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.2721e-04 - accuracy: 1.0000 - val_loss: 4.7815e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 15/15 [==============================] - 0s 18ms/step - loss: 1.1889e-04 - accuracy: 1.0000 - val_loss: 4.7381e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1201e-04 - accuracy: 1.0000 - val_loss: 4.6485e-04 - val_accuracy: 1.0000
# Epoch 80/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1707e-04 - accuracy: 1.0000 - val_loss: 4.6590e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.1553e-04 - accuracy: 1.0000 - val_loss: 4.4827e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1409e-04 - accuracy: 1.0000 - val_loss: 4.2691e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.1136e-04 - accuracy: 1.0000 - val_loss: 4.4061e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.0379e-04 - accuracy: 1.0000 - val_loss: 4.1647e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 15/15 [==============================] - 0s 17ms/step - loss: 9.3332e-05 - accuracy: 1.0000 - val_loss: 3.8434e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.0225e-04 - accuracy: 1.0000 - val_loss: 3.9221e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.0411e-04 - accuracy: 1.0000 - val_loss: 3.7867e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 15/15 [==============================] - 0s 16ms/step - loss: 9.9636e-05 - accuracy: 1.0000 - val_loss: 3.8686e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 15/15 [==============================] - 0s 19ms/step - loss: 9.2340e-05 - accuracy: 1.0000 - val_loss: 3.6868e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 15/15 [==============================] - 0s 17ms/step - loss: 9.1643e-05 - accuracy: 1.0000 - val_loss: 3.6058e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 15/15 [==============================] - 0s 18ms/step - loss: 8.5141e-05 - accuracy: 1.0000 - val_loss: 3.5046e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 15/15 [==============================] - 0s 17ms/step - loss: 7.7619e-05 - accuracy: 1.0000 - val_loss: 3.3779e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 15/15 [==============================] - 0s 17ms/step - loss: 8.4457e-05 - accuracy: 1.0000 - val_loss: 3.3400e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 15/15 [==============================] - 0s 15ms/step - loss: 8.6747e-05 - accuracy: 1.0000 - val_loss: 3.2653e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 15/15 [==============================] - 0s 16ms/step - loss: 8.0732e-05 - accuracy: 1.0000 - val_loss: 3.2606e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 15/15 [==============================] - 0s 17ms/step - loss: 7.5321e-05 - accuracy: 1.0000 - val_loss: 3.1764e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 15/15 [==============================] - 0s 17ms/step - loss: 8.0342e-05 - accuracy: 1.0000 - val_loss: 3.0632e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 15/15 [==============================] - 0s 17ms/step - loss: 7.5189e-05 - accuracy: 1.0000 - val_loss: 3.1407e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - 0s 18ms/step - loss: 6.9959e-05 - accuracy: 1.0000 - val_loss: 2.9183e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - 0s 16ms/step - loss: 7.4047e-05 - accuracy: 1.0000 - val_loss: 3.0618e-04 - val_accuracy: 1.0000
# 16/16 [==============================] - 0s 11ms/step - loss: 6.9556e-05 - accuracy: 1.0000
# 4/4 [==============================] - 0s 10ms/step - loss: 2.8356e-04 - accuracy: 1.0000
# Fold 2:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 2: 70.590083360672 seconds
#
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 1s 28ms/step - loss: 2.8440 - accuracy: 0.0565 - val_loss: 2.8286 - val_accuracy: 0.1458
# Epoch 2/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8342 - accuracy: 0.0739 - val_loss: 2.8294 - val_accuracy: 0.0833
# Epoch 3/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8225 - accuracy: 0.0870 - val_loss: 2.7722 - val_accuracy: 0.1458
# Epoch 4/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.5947 - accuracy: 0.1478 - val_loss: 2.3248 - val_accuracy: 0.2292
# Epoch 5/100
# 15/15 [==============================] - 0s 15ms/step - loss: 2.3252 - accuracy: 0.1913 - val_loss: 2.1776 - val_accuracy: 0.2292
# Epoch 6/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.0754 - accuracy: 0.3522 - val_loss: 2.0884 - val_accuracy: 0.2292
# Epoch 7/100
# 15/15 [==============================] - 0s 15ms/step - loss: 1.8923 - accuracy: 0.3783 - val_loss: 2.1043 - val_accuracy: 0.2500
# Epoch 8/100
# 15/15 [==============================] - 0s 18ms/step - loss: 1.9048 - accuracy: 0.3522 - val_loss: 2.0493 - val_accuracy: 0.3125
# Epoch 9/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.6504 - accuracy: 0.4609 - val_loss: 1.6999 - val_accuracy: 0.4583
# Epoch 10/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.3395 - accuracy: 0.5913 - val_loss: 1.7543 - val_accuracy: 0.4792
# Epoch 11/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.2678 - accuracy: 0.5565 - val_loss: 1.5848 - val_accuracy: 0.4583
# Epoch 12/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.1680 - accuracy: 0.6130 - val_loss: 1.5018 - val_accuracy: 0.5417
# Epoch 13/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.0086 - accuracy: 0.7000 - val_loss: 1.2730 - val_accuracy: 0.5417
# Epoch 14/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.7040 - accuracy: 0.7875 - val_loss: 1.0606 - val_accuracy: 0.6458
# Epoch 15/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5112 - accuracy: 0.8565 - val_loss: 0.7774 - val_accuracy: 0.7917
# Epoch 16/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4333 - accuracy: 0.8783 - val_loss: 0.8274 - val_accuracy: 0.7292
# Epoch 17/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2712 - accuracy: 0.9304 - val_loss: 0.5320 - val_accuracy: 0.8125
# Epoch 18/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3600 - accuracy: 0.8783 - val_loss: 1.1475 - val_accuracy: 0.7500
# Epoch 19/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.5247 - accuracy: 0.8652 - val_loss: 0.5593 - val_accuracy: 0.7917
# Epoch 20/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2769 - accuracy: 0.9174 - val_loss: 0.5285 - val_accuracy: 0.8542
# Epoch 21/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2307 - accuracy: 0.9348 - val_loss: 0.4819 - val_accuracy: 0.8125
# Epoch 22/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1738 - accuracy: 0.9391 - val_loss: 0.4100 - val_accuracy: 0.8333
# Epoch 23/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1100 - accuracy: 0.9565 - val_loss: 0.2010 - val_accuracy: 0.9583
# Epoch 24/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1222 - accuracy: 0.9652 - val_loss: 0.3840 - val_accuracy: 0.8958
# Epoch 25/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1103 - accuracy: 0.9609 - val_loss: 0.4209 - val_accuracy: 0.8750
# Epoch 26/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1035 - accuracy: 0.9870 - val_loss: 0.1670 - val_accuracy: 0.9583
# Epoch 27/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0654 - accuracy: 0.9870 - val_loss: 0.1422 - val_accuracy: 0.9792
# Epoch 28/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.1094 - accuracy: 0.9739 - val_loss: 0.2165 - val_accuracy: 0.9583
# Epoch 29/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1103 - accuracy: 0.9783 - val_loss: 0.2024 - val_accuracy: 0.9375
# Epoch 30/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0673 - accuracy: 0.9783 - val_loss: 0.3477 - val_accuracy: 0.8958
# Epoch 31/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0976 - accuracy: 0.9792 - val_loss: 0.3150 - val_accuracy: 0.9375
# Epoch 32/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1404 - accuracy: 0.9783 - val_loss: 0.2393 - val_accuracy: 0.9167
# Epoch 33/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1317 - accuracy: 0.9652 - val_loss: 0.0827 - val_accuracy: 0.9792
# Epoch 34/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1482 - accuracy: 0.9435 - val_loss: 0.2137 - val_accuracy: 0.9583
# Epoch 35/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2520 - accuracy: 0.9261 - val_loss: 0.3225 - val_accuracy: 0.9167
# Epoch 36/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1047 - accuracy: 0.9750 - val_loss: 0.1503 - val_accuracy: 0.9375
# Epoch 37/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0389 - accuracy: 0.9870 - val_loss: 0.1311 - val_accuracy: 0.9375
# Epoch 38/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0395 - accuracy: 0.9826 - val_loss: 0.0597 - val_accuracy: 1.0000
# Epoch 39/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0408 - accuracy: 0.9826 - val_loss: 0.0516 - val_accuracy: 0.9792
# Epoch 40/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0201 - accuracy: 0.9957 - val_loss: 0.0985 - val_accuracy: 0.9792
# Epoch 41/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0276 - accuracy: 0.9957 - val_loss: 0.0738 - val_accuracy: 0.9792
# Epoch 42/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0235 - accuracy: 0.9870 - val_loss: 0.0911 - val_accuracy: 0.9792
# Epoch 43/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0770 - accuracy: 0.9870 - val_loss: 0.1213 - val_accuracy: 0.9375
# Epoch 44/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2066 - accuracy: 0.9609 - val_loss: 0.1902 - val_accuracy: 0.9167
# Epoch 45/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1204 - accuracy: 0.9609 - val_loss: 0.1187 - val_accuracy: 0.9792
# Epoch 46/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3385 - accuracy: 0.8870 - val_loss: 0.2587 - val_accuracy: 0.9375
# Epoch 47/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2583 - accuracy: 0.9348 - val_loss: 0.1565 - val_accuracy: 0.9792
# Epoch 48/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1226 - accuracy: 0.9609 - val_loss: 0.2399 - val_accuracy: 0.9167
# Epoch 49/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0647 - accuracy: 0.9826 - val_loss: 0.0611 - val_accuracy: 0.9792
# Epoch 50/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0316 - accuracy: 0.9913 - val_loss: 0.0813 - val_accuracy: 0.9792
# Epoch 51/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1135 - accuracy: 0.9826 - val_loss: 0.0960 - val_accuracy: 0.9792
# Epoch 52/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1121 - accuracy: 0.9739 - val_loss: 0.0645 - val_accuracy: 0.9792
# Epoch 53/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0416 - accuracy: 0.9957 - val_loss: 0.0933 - val_accuracy: 0.9792
# Epoch 54/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0305 - accuracy: 0.9957 - val_loss: 0.1175 - val_accuracy: 0.9583
# Epoch 55/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0203 - accuracy: 0.9917 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 56/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0265 - accuracy: 0.9957 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 57/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 58/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 59/100
# 15/15 [==============================] - 0s 16ms/step - loss: 9.8121e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 60/100
# 15/15 [==============================] - 0s 18ms/step - loss: 8.7406e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 61/100
# 15/15 [==============================] - 0s 17ms/step - loss: 7.7678e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 62/100
# 15/15 [==============================] - 0s 16ms/step - loss: 6.1477e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 63/100
# 15/15 [==============================] - 0s 16ms/step - loss: 5.7100e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 64/100
# 15/15 [==============================] - 0s 17ms/step - loss: 5.3069e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 65/100
# 15/15 [==============================] - 0s 17ms/step - loss: 4.7655e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 66/100
# 15/15 [==============================] - 0s 18ms/step - loss: 4.5928e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 67/100
# 15/15 [==============================] - 0s 17ms/step - loss: 4.1718e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 68/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.8452e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 69/100
# 15/15 [==============================] - 0s 18ms/step - loss: 3.6264e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 70/100
# 15/15 [==============================] - 0s 18ms/step - loss: 3.0622e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 71/100
# 15/15 [==============================] - 0s 18ms/step - loss: 3.3398e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 72/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.9748e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 73/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.9147e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 74/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.7689e-04 - accuracy: 1.0000 - val_loss: 9.7651e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.6510e-04 - accuracy: 1.0000 - val_loss: 9.2683e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.4807e-04 - accuracy: 1.0000 - val_loss: 8.8662e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 15/15 [==============================] - 0s 18ms/step - loss: 2.1990e-04 - accuracy: 1.0000 - val_loss: 8.6185e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.2799e-04 - accuracy: 1.0000 - val_loss: 8.3566e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.2276e-04 - accuracy: 1.0000 - val_loss: 8.0520e-04 - val_accuracy: 1.0000
# Epoch 80/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.9418e-04 - accuracy: 1.0000 - val_loss: 7.8143e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.9981e-04 - accuracy: 1.0000 - val_loss: 7.5630e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.9496e-04 - accuracy: 1.0000 - val_loss: 7.3405e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.9129e-04 - accuracy: 1.0000 - val_loss: 7.0434e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 15/15 [==============================] - 0s 15ms/step - loss: 1.8367e-04 - accuracy: 1.0000 - val_loss: 6.8464e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.7271e-04 - accuracy: 1.0000 - val_loss: 6.5516e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 15/15 [==============================] - 0s 18ms/step - loss: 1.7321e-04 - accuracy: 1.0000 - val_loss: 6.3235e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.6238e-04 - accuracy: 1.0000 - val_loss: 6.0566e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.6171e-04 - accuracy: 1.0000 - val_loss: 5.9425e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 15/15 [==============================] - 0s 15ms/step - loss: 1.5420e-04 - accuracy: 1.0000 - val_loss: 5.7482e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.4869e-04 - accuracy: 1.0000 - val_loss: 5.5551e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.4352e-04 - accuracy: 1.0000 - val_loss: 5.4389e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.3598e-04 - accuracy: 1.0000 - val_loss: 5.1951e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.3386e-04 - accuracy: 1.0000 - val_loss: 5.0235e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 15/15 [==============================] - 0s 15ms/step - loss: 1.3487e-04 - accuracy: 1.0000 - val_loss: 4.8952e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 15/15 [==============================] - 0s 19ms/step - loss: 1.2539e-04 - accuracy: 1.0000 - val_loss: 4.7534e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.2016e-04 - accuracy: 1.0000 - val_loss: 4.6417e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1464e-04 - accuracy: 1.0000 - val_loss: 4.6136e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.0645e-04 - accuracy: 1.0000 - val_loss: 4.6256e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.1422e-04 - accuracy: 1.0000 - val_loss: 4.4433e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.0952e-04 - accuracy: 1.0000 - val_loss: 4.2813e-04 - val_accuracy: 1.0000
# 16/16 [==============================] - 0s 9ms/step - loss: 1.0282e-04 - accuracy: 1.0000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.9589e-04 - accuracy: 1.0000
# Fold 3:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 3: 100.04006361961365 seconds
#
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 1s 24ms/step - loss: 2.8468 - accuracy: 0.0348 - val_loss: 2.8188 - val_accuracy: 0.1250
# Epoch 2/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8346 - accuracy: 0.0870 - val_loss: 2.8225 - val_accuracy: 0.1667
# Epoch 3/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8311 - accuracy: 0.0652 - val_loss: 2.8127 - val_accuracy: 0.1458
# Epoch 4/100
# 15/15 [==============================] - 0s 15ms/step - loss: 2.8022 - accuracy: 0.1261 - val_loss: 2.7159 - val_accuracy: 0.1458
# Epoch 5/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.5216 - accuracy: 0.1957 - val_loss: 2.4126 - val_accuracy: 0.1875
# Epoch 6/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.2249 - accuracy: 0.2739 - val_loss: 2.1105 - val_accuracy: 0.2500
# Epoch 7/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.9683 - accuracy: 0.3348 - val_loss: 2.0595 - val_accuracy: 0.2708
# Epoch 8/100
# 15/15 [==============================] - 0s 18ms/step - loss: 1.8316 - accuracy: 0.4087 - val_loss: 1.9789 - val_accuracy: 0.2917
# Epoch 9/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.5644 - accuracy: 0.4783 - val_loss: 1.7295 - val_accuracy: 0.4167
# Epoch 10/100
# 15/15 [==============================] - 0s 15ms/step - loss: 1.3822 - accuracy: 0.5435 - val_loss: 2.0513 - val_accuracy: 0.3333
# Epoch 11/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.1224 - accuracy: 0.6609 - val_loss: 1.5237 - val_accuracy: 0.4167
# Epoch 12/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.9823 - accuracy: 0.7130 - val_loss: 1.6808 - val_accuracy: 0.5000
# Epoch 13/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.9488 - accuracy: 0.7130 - val_loss: 1.5599 - val_accuracy: 0.5000
# Epoch 14/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.8367 - accuracy: 0.7565 - val_loss: 1.3622 - val_accuracy: 0.5833
# Epoch 15/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5204 - accuracy: 0.8304 - val_loss: 0.8925 - val_accuracy: 0.6875
# Epoch 16/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4140 - accuracy: 0.8739 - val_loss: 1.0635 - val_accuracy: 0.6875
# Epoch 17/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6595 - accuracy: 0.8217 - val_loss: 0.9221 - val_accuracy: 0.6667
# Epoch 18/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6216 - accuracy: 0.8375 - val_loss: 0.8870 - val_accuracy: 0.7083
# Epoch 19/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.3738 - accuracy: 0.8913 - val_loss: 0.8853 - val_accuracy: 0.6875
# Epoch 20/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2478 - accuracy: 0.9304 - val_loss: 0.7240 - val_accuracy: 0.7708
# Epoch 21/100
# ...
# Epoch 97/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.1950e-04 - accuracy: 1.0000 - val_loss: 5.7730e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.2420e-04 - accuracy: 1.0000 - val_loss: 5.5917e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1788e-04 - accuracy: 1.0000 - val_loss: 5.2164e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1893e-04 - accuracy: 1.0000 - val_loss: 5.1934e-04 - val_accuracy: 1.0000
# 16/16 [==============================] - 0s 8ms/step - loss: 1.1267e-04 - accuracy: 1.0000
# 4/4 [==============================] - 0s 5ms/step - loss: 4.8188e-04 - accuracy: 1.0000
# Fold 4:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 4: 128.93635439872742 seconds
#
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 1s 25ms/step - loss: 2.8526 - accuracy: 0.0435 - val_loss: 2.8293 - val_accuracy: 0.0833
# Epoch 2/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.8323 - accuracy: 0.0565 - val_loss: 2.8275 - val_accuracy: 0.0833
# Epoch 3/100
# 15/15 [==============================] - 0s 15ms/step - loss: 2.8218 - accuracy: 0.0783 - val_loss: 2.7850 - val_accuracy: 0.1458
# Epoch 4/100
# 15/15 [==============================] - 0s 15ms/step - loss: 2.7577 - accuracy: 0.1565 - val_loss: 2.4802 - val_accuracy: 0.2292
# Epoch 5/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.4099 - accuracy: 0.2435 - val_loss: 2.1975 - val_accuracy: 0.2292
# Epoch 6/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.1960 - accuracy: 0.2217 - val_loss: 2.1469 - val_accuracy: 0.2292
# Epoch 7/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.9783 - accuracy: 0.3913 - val_loss: 2.1024 - val_accuracy: 0.2500
# Epoch 8/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.8155 - accuracy: 0.4565 - val_loss: 1.9602 - val_accuracy: 0.3125
# Epoch 9/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.7069 - accuracy: 0.4565 - val_loss: 2.0107 - val_accuracy: 0.2708
# Epoch 10/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.6126 - accuracy: 0.4696 - val_loss: 1.9274 - val_accuracy: 0.2500
# Epoch 11/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.3368 - accuracy: 0.5652 - val_loss: 1.6489 - val_accuracy: 0.3542
# Epoch 12/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1790 - accuracy: 0.6043 - val_loss: 1.6363 - val_accuracy: 0.3958
# Epoch 13/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.1152 - accuracy: 0.6435 - val_loss: 1.5025 - val_accuracy: 0.5000
# Epoch 14/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.2306 - accuracy: 0.5913 - val_loss: 1.5961 - val_accuracy: 0.3542
# Epoch 15/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.0282 - accuracy: 0.6826 - val_loss: 1.2280 - val_accuracy: 0.4792
# Epoch 16/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6810 - accuracy: 0.7957 - val_loss: 1.2687 - val_accuracy: 0.5208
# Epoch 17/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6197 - accuracy: 0.7957 - val_loss: 1.3611 - val_accuracy: 0.5417
# Epoch 18/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.7014 - accuracy: 0.7913 - val_loss: 1.4784 - val_accuracy: 0.5833
# Epoch 19/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5779 - accuracy: 0.8043 - val_loss: 1.1945 - val_accuracy: 0.6250
# Epoch 20/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4171 - accuracy: 0.8696 - val_loss: 0.7699 - val_accuracy: 0.7083
# Epoch 21/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5135 - accuracy: 0.8417 - val_loss: 0.7212 - val_accuracy: 0.6875
# Epoch 22/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3790 - accuracy: 0.9000 - val_loss: 0.5884 - val_accuracy: 0.7500
# Epoch 23/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.2587 - accuracy: 0.9304 - val_loss: 0.4764 - val_accuracy: 0.8125
# Epoch 24/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3670 - accuracy: 0.8609 - val_loss: 0.5438 - val_accuracy: 0.7917
# Epoch 25/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4479 - accuracy: 0.8609 - val_loss: 0.6292 - val_accuracy: 0.7292
# Epoch 26/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2856 - accuracy: 0.9130 - val_loss: 0.6637 - val_accuracy: 0.7292
# Epoch 27/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2431 - accuracy: 0.9217 - val_loss: 0.4452 - val_accuracy: 0.8750
# Epoch 28/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1830 - accuracy: 0.9522 - val_loss: 0.2550 - val_accuracy: 0.9375
# Epoch 29/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0714 - accuracy: 0.9870 - val_loss: 0.2817 - val_accuracy: 0.8542
# Epoch 30/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0907 - accuracy: 0.9652 - val_loss: 0.1517 - val_accuracy: 0.9375
# Epoch 31/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0389 - accuracy: 0.9913 - val_loss: 0.1203 - val_accuracy: 0.9583
# Epoch 32/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0480 - accuracy: 0.9870 - val_loss: 0.1064 - val_accuracy: 0.9583
# Epoch 33/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0780 - accuracy: 0.9739 - val_loss: 0.2112 - val_accuracy: 0.9167
# Epoch 34/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0332 - accuracy: 0.9957 - val_loss: 0.1906 - val_accuracy: 0.9167
# Epoch 35/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0353 - accuracy: 0.9870 - val_loss: 0.2154 - val_accuracy: 0.9375
# Epoch 36/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0590 - accuracy: 0.9870 - val_loss: 0.2207 - val_accuracy: 0.9375
# Epoch 37/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1381 - accuracy: 0.9783 - val_loss: 0.2224 - val_accuracy: 0.9375
# Epoch 38/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1598 - accuracy: 0.9522 - val_loss: 0.3125 - val_accuracy: 0.8750
# Epoch 39/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1013 - accuracy: 0.9826 - val_loss: 0.0755 - val_accuracy: 1.0000
# Epoch 40/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1241 - accuracy: 0.9565 - val_loss: 0.5612 - val_accuracy: 0.8333
# Epoch 41/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1447 - accuracy: 0.9652 - val_loss: 0.0885 - val_accuracy: 0.9792
# Epoch 42/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0672 - accuracy: 0.9739 - val_loss: 0.0921 - val_accuracy: 0.9792
# Epoch 43/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0437 - accuracy: 0.9870 - val_loss: 0.1002 - val_accuracy: 0.9792
# Epoch 44/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0356 - accuracy: 0.9913 - val_loss: 0.1003 - val_accuracy: 0.9792
# Epoch 45/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0591 - accuracy: 0.9826 - val_loss: 0.0830 - val_accuracy: 0.9792
# Epoch 46/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2115 - accuracy: 0.9708 - val_loss: 0.5611 - val_accuracy: 0.9583
# Epoch 47/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1146 - accuracy: 0.9783 - val_loss: 0.1638 - val_accuracy: 0.9583
# Epoch 48/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0703 - accuracy: 0.9826 - val_loss: 0.2027 - val_accuracy: 0.9375
# Epoch 49/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0394 - accuracy: 0.9917 - val_loss: 0.1113 - val_accuracy: 0.9792
# Epoch 50/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0265 - accuracy: 0.9913 - val_loss: 0.0686 - val_accuracy: 0.9583
# Epoch 51/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0432 - accuracy: 0.9913 - val_loss: 0.2455 - val_accuracy: 0.8958
# Epoch 52/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0680 - accuracy: 0.9826 - val_loss: 0.1479 - val_accuracy: 0.9375
# Epoch 53/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0310 - accuracy: 0.9957 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 54/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0474 - accuracy: 0.9913 - val_loss: 0.1036 - val_accuracy: 0.9375
# Epoch 55/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0925 - accuracy: 0.9826 - val_loss: 0.1128 - val_accuracy: 0.9583
# Epoch 56/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0361 - accuracy: 0.9870 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 57/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 58/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 59/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 60/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 61/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 62/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 63/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 64/100
# 15/15 [==============================] - 0s 16ms/step - loss: 8.2195e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 65/100
# 15/15 [==============================] - 0s 19ms/step - loss: 8.3260e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 66/100
# 15/15 [==============================] - 0s 16ms/step - loss: 7.9817e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 67/100
# 15/15 [==============================] - 0s 16ms/step - loss: 7.6064e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 68/100
# 15/15 [==============================] - 0s 16ms/step - loss: 6.7970e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 69/100
# 15/15 [==============================] - 0s 16ms/step - loss: 6.5279e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 70/100
# 15/15 [==============================] - 0s 16ms/step - loss: 6.2317e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 71/100
# 15/15 [==============================] - 0s 18ms/step - loss: 5.7211e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 72/100
# 15/15 [==============================] - 0s 16ms/step - loss: 5.4095e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 73/100
# 15/15 [==============================] - 0s 16ms/step - loss: 5.8258e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 74/100
# 15/15 [==============================] - 0s 16ms/step - loss: 4.6731e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 75/100
# 15/15 [==============================] - 0s 17ms/step - loss: 4.4023e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 76/100
# 15/15 [==============================] - 0s 16ms/step - loss: 4.8505e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 77/100
# 15/15 [==============================] - 0s 18ms/step - loss: 4.3776e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 78/100
# 15/15 [==============================] - 0s 15ms/step - loss: 3.5005e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 79/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.8111e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 80/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.7982e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 81/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.7915e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 82/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.2302e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 83/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.6432e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 84/100
# 15/15 [==============================] - 0s 19ms/step - loss: 3.3053e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 85/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.2589e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 86/100
# 15/15 [==============================] - 0s 16ms/step - loss: 3.8673e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 87/100
# 15/15 [==============================] - 0s 17ms/step - loss: 3.0590e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 88/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.5581e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 89/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8135e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 90/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.3818e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 91/100
# 15/15 [==============================] - 0s 18ms/step - loss: 2.4574e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 92/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.6584e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 93/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.4325e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 94/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.3295e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 95/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.2814e-04 - accuracy: 1.0000 - val_loss: 9.9915e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 15/15 [==============================] - 0s 16ms/step - loss: 2.0810e-04 - accuracy: 1.0000 - val_loss: 9.9670e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 15/15 [==============================] - 0s 18ms/step - loss: 1.9955e-04 - accuracy: 1.0000 - val_loss: 9.8237e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 15/15 [==============================] - 0s 17ms/step - loss: 1.7348e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.9733e-04 - accuracy: 1.0000 - val_loss: 9.2572e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - 0s 16ms/step - loss: 1.9504e-04 - accuracy: 1.0000 - val_loss: 9.0006e-04 - val_accuracy: 1.0000
# 16/16 [==============================] - 0s 8ms/step - loss: 1.8438e-04 - accuracy: 1.0000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.3194e-04 - accuracy: 1.0000
# Fold 5:
# Train accuracy: 1.0, Validation accuracy: 1.0
# Training time for fold 5: 157.81299328804016 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 100.0 %
# Average Validation Accuracy: 100.0 %
# Average Training Time: 99.68093242645264
# Total Training Time: 157.85671663284302

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
import time

# Define constants
NUM_CLASSES = 17

# Load the models using K-fold cross-validation
model_paths = [

    ['D:\\FINAL MAJOR20-2\\CrossValidation\\CNN\\own\\cnn_kfold(1)_1.h5', 'D:\\FINAL MAJOR20-2\\CrossValidation\\CNN\\own\\cnn_kfold(1)_2.h5',
     'D:\\FINAL MAJOR20-2\\CrossValidation\\CNN\\own\\cnn_kfold(1)_3.h5', 'D:\\FINAL MAJOR20-2\\CrossValidation\\CNN\\own\\cnn_kfold(1)_4.h5',
     'D:\\FINAL MAJOR20-2\\CrossValidation\\CNN\\own\\cnn_kfold(1)_5.h5'],
    

]

models = []
for model_fold_paths in model_paths:
    model_fold = []
    for model_path in model_fold_paths:
        model = load_model(model_path)
        model_fold.append(model)
    models.append(model_fold)

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsCNNkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+---------------------+---------------------+---------------------+---------+
# | Class |      Precision      |        Recall       |       F1 Score      | Support |
# +-------+---------------------+---------------------+---------------------+---------+
# |   0   | 0.23076923076923078 | 0.23076923076923078 | 0.23076923076923078 |    13   |
# |   1   | 0.13333333333333333 | 0.13333333333333333 | 0.13333333333333333 |    15   |
# |   10  | 0.16666666666666666 | 0.16666666666666666 | 0.16666666666666666 |    12   |
# |   2   | 0.16666666666666666 | 0.16666666666666666 | 0.16666666666666666 |    18   |
# |   3   | 0.07692307692307693 | 0.07692307692307693 | 0.07692307692307693 |    13   |
# |   4   |         0.0         |         0.0         |         0.0         |    15   |
# |   5   |         0.0         |         0.0         |         0.0         |    12   |
# |   6   |         0.0         |         0.0         |         0.0         |    12   |
# |   7   | 0.08333333333333333 | 0.08333333333333333 | 0.08333333333333333 |    12   |
# |   8   |        0.0625       |        0.0625       |        0.0625       |    16   |
# |   9   | 0.07692307692307693 | 0.07692307692307693 | 0.07692307692307693 |    13   |
# |  box  | 0.06666666666666667 | 0.06666666666666667 | 0.06666666666666667 |    15   |
# |  fun  | 0.06666666666666667 | 0.06666666666666667 | 0.06666666666666667 |    15   |
# |  good |         0.0         |         0.0         |         0.0         |    18   |
# |  grow | 0.06666666666666667 | 0.06666666666666667 | 0.06666666666666667 |    15   |
# |  hero |         0.0         |         0.0         |         0.0         |    16   |
# | trust |        0.125        |        0.125        |        0.125        |    16   |
# +-------+---------------------+---------------------+---------------------+---------+
#
# Validation Metrics:
# +-------+-----------+--------+----------+---------+
# | Class | Precision | Recall | F1 Score | Support |
# +-------+-----------+--------+----------+---------+
# |   0   |    1.0    |  1.0   |   1.0    |    3    |
# |   1   |    1.0    |  1.0   |   1.0    |    3    |
# |   10  |    1.0    |  1.0   |   1.0    |    2    |
# |   2   |    1.0    |  1.0   |   1.0    |    4    |
# |   3   |    1.0    |  1.0   |   1.0    |    3    |
# |   4   |    1.0    |  1.0   |   1.0    |    3    |
# |   5   |    1.0    |  1.0   |   1.0    |    2    |
# |   6   |    1.0    |  1.0   |   1.0    |    2    |
# |   7   |    1.0    |  1.0   |   1.0    |    2    |
# |   8   |    1.0    |  1.0   |   1.0    |    4    |
# |   9   |    1.0    |  1.0   |   1.0    |    3    |
# |  box  |    1.0    |  1.0   |   1.0    |    3    |
# |  fun  |    1.0    |  1.0   |   1.0    |    3    |
# |  good |    1.0    |  1.0   |   1.0    |    4    |
# |  grow |    1.0    |  1.0   |   1.0    |    3    |
# |  hero |    1.0    |  1.0   |   1.0    |    4    |
# | trust |    1.0    |  1.0   |   1.0    |    4    |
# +-------+-----------+--------+----------+---------+
# Combined metrics saved to combined_metricsCNNkfold5.xlsx

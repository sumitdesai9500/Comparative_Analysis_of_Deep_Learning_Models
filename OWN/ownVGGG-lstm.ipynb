# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # VGG_lstm

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Input, Reshape
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2, VGG16
import time

# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Saquib\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Load pre-trained VGG-16 model, excluding the top classifier layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

# Freeze pre-trained layers to prevent them from being updated during training
for layer in base_model.layers:
    layer.trainable = False

# Define the model architecture
inputs = Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))  # Input layer for images

# Extract features using VGG-16
vgg_features = base_model(inputs)

# **Reshape features to ensure compatibility with LSTM (remove unnecessary dimension):**
# Adjust the shape based on the actual dimensions of `vgg_features` (e.g., if features are (None, 7, 7, 512), reshape to (None, 7, 512))
desired_feature_shape = (vgg_features.shape[1], vgg_features.shape[2] * vgg_features.shape[3])  # Calculate desired shape
reshaped_features = Reshape(desired_feature_shape)(vgg_features)

# Define the LSTM-based classifier
lstm_1 = LSTM(128, return_sequences=True)(reshaped_features)  # First LSTM layer
lstm_2 = LSTM(32)(lstm_1)                                     # Second LSTM layer

Dropout(0.7)
# Final dense layer for classification
predictions = Dense(NUM_CLASSES, activation='softmax')(lstm_2)

# Create the final model
model = tf.keras.Model(inputs=inputs, outputs=predictions)
# Compile the model
model.compile(optimizer=tf.keras.optimizers.SGD(clipnorm=1),  # Create Adam optimizer with clipnorm
              loss='categorical_crossentropy',
              metrics=['accuracy'],
              run_eagerly=True,  # Enables early stopping callbacks
              )

# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'VGG-lstm_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 298 images belonging to 17 classes.
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 10s 218ms/step - loss: 2.8523 - accuracy: 0.0696 - val_loss: 2.8357 - val_accuracy: 0.0625
# Epoch 2/100
# 15/15 [==============================] - 2s 116ms/step - loss: 2.8465 - accuracy: 0.0739 - val_loss: 2.8314 - val_accuracy: 0.0833
# Epoch 3/100
# 15/15 [==============================] - 2s 115ms/step - loss: 2.8427 - accuracy: 0.0739 - val_loss: 2.8306 - val_accuracy: 0.0833
# Epoch 4/100
# 15/15 [==============================] - 2s 113ms/step - loss: 2.8360 - accuracy: 0.0696 - val_loss: 2.8256 - val_accuracy: 0.0833
# Epoch 5/100
# 15/15 [==============================] - 2s 112ms/step - loss: 2.8322 - accuracy: 0.0739 - val_loss: 2.8241 - val_accuracy: 0.0833
# Epoch 6/100
# 15/15 [==============================] - 2s 113ms/step - loss: 2.8290 - accuracy: 0.0750 - val_loss: 2.8210 - val_accuracy: 0.1042
# Epoch 7/100
# 15/15 [==============================] - 2s 112ms/step - loss: 2.8283 - accuracy: 0.0913 - val_loss: 2.8207 - val_accuracy: 0.1042
# Epoch 8/100
# 15/15 [==============================] - 2s 110ms/step - loss: 2.8292 - accuracy: 0.0913 - val_loss: 2.8199 - val_accuracy: 0.1458
# Epoch 9/100
# 15/15 [==============================] - 2s 111ms/step - loss: 2.8243 - accuracy: 0.0870 - val_loss: 2.8199 - val_accuracy: 0.1458
# Epoch 10/100
# 15/15 [==============================] - 2s 111ms/step - loss: 2.8231 - accuracy: 0.1087 - val_loss: 2.8183 - val_accuracy: 0.1458
# Epoch 11/100
# 15/15 [==============================] - 2s 112ms/step - loss: 2.8235 - accuracy: 0.1304 - val_loss: 2.8180 - val_accuracy: 0.1042
# Epoch 12/100
# 15/15 [==============================] - 2s 112ms/step - loss: 2.8204 - accuracy: 0.1174 - val_loss: 2.8170 - val_accuracy: 0.1458
# Epoch 13/100
# 15/15 [==============================] - 2s 111ms/step - loss: 2.8148 - accuracy: 0.1304 - val_loss: 2.8159 - val_accuracy: 0.1667
# Epoch 14/100
# 15/15 [==============================] - 2s 120ms/step - loss: 2.8133 - accuracy: 0.1348 - val_loss: 2.8133 - val_accuracy: 0.1458
# Epoch 15/100
# 15/15 [==============================] - 2s 117ms/step - loss: 2.8145 - accuracy: 0.1217 - val_loss: 2.8111 - val_accuracy: 0.1667
# Epoch 16/100
# 15/15 [==============================] - 2s 115ms/step - loss: 2.8180 - accuracy: 0.1130 - val_loss: 2.8116 - val_accuracy: 0.1042
# Epoch 17/100
# 15/15 [==============================] - 2s 117ms/step - loss: 2.8138 - accuracy: 0.1000 - val_loss: 2.8095 - val_accuracy: 0.1667
# Epoch 18/100
# 15/15 [==============================] - 2s 117ms/step - loss: 2.8093 - accuracy: 0.1087 - val_loss: 2.8112 - val_accuracy: 0.1667
# Epoch 19/100
# 15/15 [==============================] - 2s 117ms/step - loss: 2.8067 - accuracy: 0.1261 - val_loss: 2.8076 - val_accuracy: 0.1458
# Epoch 20/100
# 15/15 [==============================] - 2s 115ms/step - loss: 2.8092 - accuracy: 0.1087 - val_loss: 2.8032 - val_accuracy: 0.1667
# Epoch 21/100
# 15/15 [==============================] - 2s 115ms/step - loss: 2.8065 - accuracy: 0.1348 - val_loss: 2.8020 - val_accuracy: 0.1458
# Epoch 22/100
# 15/15 [==============================] - 2s 113ms/step - loss: 2.8017 - accuracy: 0.1304 - val_loss: 2.8015 - val_accuracy: 0.1667
# Epoch 23/100
# 15/15 [==============================] - 2s 114ms/step - loss: 2.8009 - accuracy: 0.1304 - val_loss: 2.7987 - val_accuracy: 0.1458
# Epoch 24/100
# 15/15 [==============================] - 2s 116ms/step - loss: 2.7971 - accuracy: 0.1375 - val_loss: 2.7972 - val_accuracy: 0.1458
# Epoch 25/100
# 15/15 [==============================] - 2s 114ms/step - loss: 2.7943 - accuracy: 0.1348 - val_loss: 2.7952 - val_accuracy: 0.1458
# Epoch 26/100
# 15/15 [==============================] - 2s 115ms/step - loss: 2.7954 - accuracy: 0.1435 - val_loss: 2.7944 - val_accuracy: 0.1458
# Epoch 27/100
# 15/15 [==============================] - 2s 114ms/step - loss: 2.7918 - accuracy: 0.1435 - val_loss: 2.7934 - val_accuracy: 0.1458
# Epoch 28/100
# 15/15 [==============================] - 2s 114ms/step - loss: 2.7856 - accuracy: 0.1391 - val_loss: 2.7894 - val_accuracy: 0.1458
# Epoch 29/100
# 15/15 [==============================] - 2s 113ms/step - loss: 2.7870 - accuracy: 0.1304 - val_loss: 2.7864 - val_accuracy: 0.1458
# Epoch 30/100
# 15/15 [==============================] - 2s 119ms/step - loss: 2.7856 - accuracy: 0.1217 - val_loss: 2.7877 - val_accuracy: 0.1458
# Epoch 31/100
# 15/15 [==============================] - 2s 114ms/step - loss: 2.7835 - accuracy: 0.1292 - val_loss: 2.7838 - val_accuracy: 0.1458
# Epoch 32/100
# 15/15 [==============================] - 2s 113ms/step - loss: 2.7814 - accuracy: 0.1217 - val_loss: 2.7820 - val_accuracy: 0.1458
# Epoch 33/100
# 15/15 [==============================] - 2s 115ms/step - loss: 2.7740 - accuracy: 0.1174 - val_loss: 2.7822 - val_accuracy: 0.1667
# Epoch 34/100
# 15/15 [==============================] - 2s 113ms/step - loss: 2.7691 - accuracy: 0.1435 - val_loss: 2.7795 - val_accuracy: 0.1458
# Epoch 35/100
# 15/15 [==============================] - 2s 118ms/step - loss: 2.7695 - accuracy: 0.1500 - val_loss: 2.7767 - val_accuracy: 0.1667
# Epoch 36/100
# 15/15 [==============================] - 2s 116ms/step - loss: 2.7670 - accuracy: 0.1522 - val_loss: 2.7744 - val_accuracy: 0.1458
# Epoch 37/100
# 15/15 [==============================] - 2s 116ms/step - loss: 2.7650 - accuracy: 0.1435 - val_loss: 2.7698 - val_accuracy: 0.1458
# Epoch 38/100
# 15/15 [==============================] - 2s 116ms/step - loss: 2.7561 - accuracy: 0.1478 - val_loss: 2.7679 - val_accuracy: 0.1458
# Epoch 39/100
# 15/15 [==============================] - 2s 134ms/step - loss: 2.7606 - accuracy: 0.1174 - val_loss: 2.7697 - val_accuracy: 0.1458
# Epoch 40/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.7507 - accuracy: 0.1870 - val_loss: 2.7643 - val_accuracy: 0.1458
# Epoch 41/100
# 15/15 [==============================] - 2s 120ms/step - loss: 2.7545 - accuracy: 0.1609 - val_loss: 2.7601 - val_accuracy: 0.1667
# Epoch 42/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.7458 - accuracy: 0.1739 - val_loss: 2.7570 - val_accuracy: 0.1458
# Epoch 43/100
# 15/15 [==============================] - 2s 128ms/step - loss: 2.7418 - accuracy: 0.1826 - val_loss: 2.7533 - val_accuracy: 0.1667
# Epoch 44/100
# 15/15 [==============================] - 2s 116ms/step - loss: 2.7395 - accuracy: 0.1826 - val_loss: 2.7513 - val_accuracy: 0.1667
# Epoch 45/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.7283 - accuracy: 0.1783 - val_loss: 2.7524 - val_accuracy: 0.1667
# Epoch 46/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.7313 - accuracy: 0.2000 - val_loss: 2.7470 - val_accuracy: 0.1667
# Epoch 47/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.7305 - accuracy: 0.1957 - val_loss: 2.7424 - val_accuracy: 0.1667
# Epoch 48/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.7248 - accuracy: 0.2000 - val_loss: 2.7358 - val_accuracy: 0.1667
# Epoch 49/100
# 15/15 [==============================] - 2s 119ms/step - loss: 2.7157 - accuracy: 0.2043 - val_loss: 2.7329 - val_accuracy: 0.1875
# Epoch 50/100
# 15/15 [==============================] - 2s 120ms/step - loss: 2.7186 - accuracy: 0.1609 - val_loss: 2.7288 - val_accuracy: 0.1875
# Epoch 51/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.7089 - accuracy: 0.1826 - val_loss: 2.7261 - val_accuracy: 0.1875
# Epoch 52/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.7040 - accuracy: 0.1913 - val_loss: 2.7215 - val_accuracy: 0.1875
# Epoch 53/100
# 15/15 [==============================] - 2s 119ms/step - loss: 2.7028 - accuracy: 0.1913 - val_loss: 2.7228 - val_accuracy: 0.1667
# Epoch 54/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.6904 - accuracy: 0.2174 - val_loss: 2.7164 - val_accuracy: 0.1875
# Epoch 55/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.6823 - accuracy: 0.2087 - val_loss: 2.7106 - val_accuracy: 0.1875
# Epoch 56/100
# 15/15 [==============================] - 2s 119ms/step - loss: 2.6780 - accuracy: 0.2043 - val_loss: 2.7076 - val_accuracy: 0.1875
# Epoch 57/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.6708 - accuracy: 0.2174 - val_loss: 2.7078 - val_accuracy: 0.1875
# Epoch 58/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.6681 - accuracy: 0.2478 - val_loss: 2.7011 - val_accuracy: 0.2083
# Epoch 59/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.6682 - accuracy: 0.2174 - val_loss: 2.6959 - val_accuracy: 0.1875
# Epoch 60/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.6531 - accuracy: 0.2130 - val_loss: 2.6943 - val_accuracy: 0.1875
# Epoch 61/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.6578 - accuracy: 0.2130 - val_loss: 2.6902 - val_accuracy: 0.1875
# Epoch 62/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.6444 - accuracy: 0.2261 - val_loss: 2.6871 - val_accuracy: 0.2083
# Epoch 63/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.6392 - accuracy: 0.2304 - val_loss: 2.6901 - val_accuracy: 0.1875
# Epoch 64/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.6333 - accuracy: 0.2565 - val_loss: 2.6799 - val_accuracy: 0.1875
# Epoch 65/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.6244 - accuracy: 0.2522 - val_loss: 2.6751 - val_accuracy: 0.1875
# Epoch 66/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.6233 - accuracy: 0.2304 - val_loss: 2.6706 - val_accuracy: 0.1875
# Epoch 67/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.6112 - accuracy: 0.2261 - val_loss: 2.6711 - val_accuracy: 0.1875
# Epoch 68/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.6135 - accuracy: 0.2304 - val_loss: 2.6606 - val_accuracy: 0.1875
# Epoch 69/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.5932 - accuracy: 0.2478 - val_loss: 2.6585 - val_accuracy: 0.1875
# Epoch 70/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.5988 - accuracy: 0.2478 - val_loss: 2.6461 - val_accuracy: 0.2083
# Epoch 71/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.5832 - accuracy: 0.2348 - val_loss: 2.6485 - val_accuracy: 0.1875
# Epoch 72/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.5814 - accuracy: 0.2292 - val_loss: 2.6498 - val_accuracy: 0.1875
# Epoch 73/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.5782 - accuracy: 0.2304 - val_loss: 2.6368 - val_accuracy: 0.2083
# Epoch 74/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.5600 - accuracy: 0.2522 - val_loss: 2.6318 - val_accuracy: 0.2083
# Epoch 75/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.5598 - accuracy: 0.2522 - val_loss: 2.6303 - val_accuracy: 0.2083
# Epoch 76/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.5577 - accuracy: 0.2652 - val_loss: 2.6237 - val_accuracy: 0.2083
# Epoch 77/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.5218 - accuracy: 0.2696 - val_loss: 2.6331 - val_accuracy: 0.1875
# Epoch 78/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.5297 - accuracy: 0.2783 - val_loss: 2.6161 - val_accuracy: 0.2083
# Epoch 79/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.5240 - accuracy: 0.2478 - val_loss: 2.6164 - val_accuracy: 0.1875
# Epoch 80/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.5198 - accuracy: 0.2478 - val_loss: 2.6044 - val_accuracy: 0.2083
# Epoch 81/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.4974 - accuracy: 0.2783 - val_loss: 2.6075 - val_accuracy: 0.2083
# Epoch 82/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.4969 - accuracy: 0.2826 - val_loss: 2.5957 - val_accuracy: 0.1875
# Epoch 83/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.4998 - accuracy: 0.2826 - val_loss: 2.5893 - val_accuracy: 0.2083
# Epoch 84/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.4854 - accuracy: 0.2870 - val_loss: 2.5871 - val_accuracy: 0.2083
# Epoch 85/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.4660 - accuracy: 0.2826 - val_loss: 2.5820 - val_accuracy: 0.1875
# Epoch 86/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.4773 - accuracy: 0.2478 - val_loss: 2.5689 - val_accuracy: 0.2083
# Epoch 87/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.4602 - accuracy: 0.2870 - val_loss: 2.5657 - val_accuracy: 0.2083
# Epoch 88/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.4377 - accuracy: 0.3000 - val_loss: 2.5600 - val_accuracy: 0.2083
# Epoch 89/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.4469 - accuracy: 0.2913 - val_loss: 2.5477 - val_accuracy: 0.2292
# Epoch 90/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.4325 - accuracy: 0.2783 - val_loss: 2.5503 - val_accuracy: 0.2083
# Epoch 91/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.4198 - accuracy: 0.2826 - val_loss: 2.5344 - val_accuracy: 0.2292
# Epoch 92/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.4176 - accuracy: 0.3087 - val_loss: 2.5343 - val_accuracy: 0.2083
# Epoch 93/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.3928 - accuracy: 0.2957 - val_loss: 2.5405 - val_accuracy: 0.1875
# Epoch 94/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.3924 - accuracy: 0.3043 - val_loss: 2.5327 - val_accuracy: 0.2083
# Epoch 95/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.3782 - accuracy: 0.3087 - val_loss: 2.5230 - val_accuracy: 0.2083
# Epoch 96/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.3745 - accuracy: 0.2913 - val_loss: 2.5225 - val_accuracy: 0.2083
# Epoch 97/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.3571 - accuracy: 0.3000 - val_loss: 2.5140 - val_accuracy: 0.2083
# Epoch 98/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.3583 - accuracy: 0.2913 - val_loss: 2.5036 - val_accuracy: 0.2083
# Epoch 99/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.3317 - accuracy: 0.3348 - val_loss: 2.4848 - val_accuracy: 0.2292
# Epoch 100/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.3347 - accuracy: 0.2957 - val_loss: 2.4939 - val_accuracy: 0.2083
# 16/16 [==============================] - 1s 37ms/step - loss: 2.3173 - accuracy: 0.3008
# 4/4 [==============================] - 1s 257ms/step - loss: 2.4400 - accuracy: 0.2692
# Fold 1:
# Train accuracy: 0.3008130192756653, Validation accuracy: 0.26923078298568726
# Training time for fold 1: 192.17165088653564 seconds
#
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.3524 - accuracy: 0.2913 - val_loss: 2.4718 - val_accuracy: 0.2083
# Epoch 2/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.3184 - accuracy: 0.3391 - val_loss: 2.4913 - val_accuracy: 0.1875
# Epoch 3/100
# 15/15 [==============================] - 2s 128ms/step - loss: 2.2930 - accuracy: 0.3087 - val_loss: 2.4641 - val_accuracy: 0.2083
# Epoch 4/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.2948 - accuracy: 0.3174 - val_loss: 2.4680 - val_accuracy: 0.2083
# Epoch 5/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.2808 - accuracy: 0.3217 - val_loss: 2.4551 - val_accuracy: 0.2083
# Epoch 6/100
# 15/15 [==============================] - 2s 127ms/step - loss: 2.2810 - accuracy: 0.3522 - val_loss: 2.4506 - val_accuracy: 0.2083
# Epoch 7/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.2477 - accuracy: 0.3087 - val_loss: 2.4245 - val_accuracy: 0.2083
# Epoch 8/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.2431 - accuracy: 0.3304 - val_loss: 2.4386 - val_accuracy: 0.2083
# Epoch 9/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.2265 - accuracy: 0.3739 - val_loss: 2.4194 - val_accuracy: 0.2292
# Epoch 10/100
# 15/15 [==============================] - 2s 121ms/step - loss: 2.2373 - accuracy: 0.3478 - val_loss: 2.4219 - val_accuracy: 0.2083
# Epoch 11/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.2108 - accuracy: 0.3739 - val_loss: 2.4488 - val_accuracy: 0.1875
# Epoch 12/100
# 15/15 [==============================] - 2s 127ms/step - loss: 2.2116 - accuracy: 0.3458 - val_loss: 2.3829 - val_accuracy: 0.2500
# Epoch 13/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.1819 - accuracy: 0.3435 - val_loss: 2.3783 - val_accuracy: 0.2292
# Epoch 14/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.1914 - accuracy: 0.3826 - val_loss: 2.3914 - val_accuracy: 0.1875
# Epoch 15/100
# 15/15 [==============================] - 2s 126ms/step - loss: 2.1720 - accuracy: 0.3739 - val_loss: 2.3912 - val_accuracy: 0.2292
# Epoch 16/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.1532 - accuracy: 0.3609 - val_loss: 2.3885 - val_accuracy: 0.2083
# Epoch 17/100
# 15/15 [==============================] - 2s 129ms/step - loss: 2.1334 - accuracy: 0.3522 - val_loss: 2.3617 - val_accuracy: 0.2292
# Epoch 18/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.1430 - accuracy: 0.3957 - val_loss: 2.3875 - val_accuracy: 0.1875
# Epoch 19/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.1439 - accuracy: 0.3565 - val_loss: 2.3440 - val_accuracy: 0.2292
# Epoch 20/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.1381 - accuracy: 0.3913 - val_loss: 2.3297 - val_accuracy: 0.2083
# Epoch 21/100
# 15/15 [==============================] - 2s 127ms/step - loss: 2.1220 - accuracy: 0.3870 - val_loss: 2.3828 - val_accuracy: 0.1875
# Epoch 22/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.1278 - accuracy: 0.3565 - val_loss: 2.3231 - val_accuracy: 0.2292
# Epoch 23/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.0786 - accuracy: 0.4043 - val_loss: 2.3215 - val_accuracy: 0.2292
# Epoch 24/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.0744 - accuracy: 0.4217 - val_loss: 2.3030 - val_accuracy: 0.2292
# Epoch 25/100
# 15/15 [==============================] - 2s 122ms/step - loss: 2.0857 - accuracy: 0.3870 - val_loss: 2.3010 - val_accuracy: 0.2292
# Epoch 26/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.0418 - accuracy: 0.4130 - val_loss: 2.3088 - val_accuracy: 0.2500
# Epoch 27/100
# 15/15 [==============================] - 2s 123ms/step - loss: 2.0269 - accuracy: 0.4087 - val_loss: 2.3044 - val_accuracy: 0.2292
# Epoch 28/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.0376 - accuracy: 0.4130 - val_loss: 2.3019 - val_accuracy: 0.2500
# Epoch 29/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.0096 - accuracy: 0.4348 - val_loss: 2.2815 - val_accuracy: 0.2500
# Epoch 30/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.0060 - accuracy: 0.4348 - val_loss: 2.2630 - val_accuracy: 0.2292
# Epoch 31/100
# 15/15 [==============================] - 2s 125ms/step - loss: 2.0076 - accuracy: 0.4565 - val_loss: 2.2787 - val_accuracy: 0.2083
# Epoch 32/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.9822 - accuracy: 0.4261 - val_loss: 2.2900 - val_accuracy: 0.2292
# Epoch 33/100
# 15/15 [==============================] - 2s 124ms/step - loss: 2.0042 - accuracy: 0.4304 - val_loss: 2.2927 - val_accuracy: 0.2292
# Epoch 34/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.9775 - accuracy: 0.4391 - val_loss: 2.2338 - val_accuracy: 0.2083
# Epoch 35/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.9578 - accuracy: 0.4391 - val_loss: 2.2616 - val_accuracy: 0.2292
# Epoch 36/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.9524 - accuracy: 0.4609 - val_loss: 2.2415 - val_accuracy: 0.2500
# Epoch 37/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.9482 - accuracy: 0.4826 - val_loss: 2.2429 - val_accuracy: 0.2292
# Epoch 38/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.9509 - accuracy: 0.4696 - val_loss: 2.2166 - val_accuracy: 0.2292
# Epoch 39/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.9543 - accuracy: 0.4478 - val_loss: 2.2364 - val_accuracy: 0.2500
# Epoch 40/100
# 15/15 [==============================] - 2s 128ms/step - loss: 1.9099 - accuracy: 0.4958 - val_loss: 2.2629 - val_accuracy: 0.2292
# Epoch 41/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.9217 - accuracy: 0.4304 - val_loss: 2.1863 - val_accuracy: 0.2500
# Epoch 42/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.8864 - accuracy: 0.4696 - val_loss: 2.1919 - val_accuracy: 0.2292
# Epoch 43/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.8789 - accuracy: 0.4783 - val_loss: 2.1775 - val_accuracy: 0.2500
# Epoch 44/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.8813 - accuracy: 0.4739 - val_loss: 2.1697 - val_accuracy: 0.2083
# Epoch 45/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.8614 - accuracy: 0.4696 - val_loss: 2.2213 - val_accuracy: 0.2083
# Epoch 46/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.8882 - accuracy: 0.4478 - val_loss: 2.1625 - val_accuracy: 0.2500
# Epoch 47/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.8360 - accuracy: 0.4870 - val_loss: 2.1726 - val_accuracy: 0.2500
# Epoch 48/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.8160 - accuracy: 0.4783 - val_loss: 2.1541 - val_accuracy: 0.2500
# Epoch 49/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.8114 - accuracy: 0.4957 - val_loss: 2.1699 - val_accuracy: 0.2292
# Epoch 50/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.8177 - accuracy: 0.4913 - val_loss: 2.1338 - val_accuracy: 0.2917
# Epoch 51/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.8018 - accuracy: 0.4870 - val_loss: 2.1472 - val_accuracy: 0.2917
# Epoch 52/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.8013 - accuracy: 0.4958 - val_loss: 2.1195 - val_accuracy: 0.2500
# Epoch 53/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.7899 - accuracy: 0.4783 - val_loss: 2.1132 - val_accuracy: 0.2708
# Epoch 54/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.7751 - accuracy: 0.5174 - val_loss: 2.1214 - val_accuracy: 0.2500
# Epoch 55/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.7680 - accuracy: 0.4783 - val_loss: 2.1209 - val_accuracy: 0.2292
# Epoch 56/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.7655 - accuracy: 0.4957 - val_loss: 2.1259 - val_accuracy: 0.2917
# Epoch 57/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.7540 - accuracy: 0.5125 - val_loss: 2.1194 - val_accuracy: 0.2708
# Epoch 58/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.7543 - accuracy: 0.5130 - val_loss: 2.1182 - val_accuracy: 0.2917
# Epoch 59/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.7453 - accuracy: 0.5130 - val_loss: 2.1008 - val_accuracy: 0.2708
# Epoch 60/100
# 15/15 [==============================] - 2s 127ms/step - loss: 1.7243 - accuracy: 0.5435 - val_loss: 2.0787 - val_accuracy: 0.2917
# Epoch 61/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.7020 - accuracy: 0.5130 - val_loss: 2.1190 - val_accuracy: 0.2292
# Epoch 62/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.6825 - accuracy: 0.5043 - val_loss: 2.0713 - val_accuracy: 0.2708
# Epoch 63/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.7230 - accuracy: 0.5261 - val_loss: 2.0659 - val_accuracy: 0.2708
# Epoch 64/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.6981 - accuracy: 0.5217 - val_loss: 2.0934 - val_accuracy: 0.2500
# Epoch 65/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.6842 - accuracy: 0.5042 - val_loss: 2.0363 - val_accuracy: 0.2917
# Epoch 66/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.6809 - accuracy: 0.5000 - val_loss: 2.0399 - val_accuracy: 0.3542
# Epoch 67/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.6811 - accuracy: 0.5174 - val_loss: 2.0470 - val_accuracy: 0.2708
# Epoch 68/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.6163 - accuracy: 0.5391 - val_loss: 2.0821 - val_accuracy: 0.2708
# Epoch 69/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.6483 - accuracy: 0.5130 - val_loss: 2.0469 - val_accuracy: 0.2500
# Epoch 70/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.6686 - accuracy: 0.5174 - val_loss: 2.0093 - val_accuracy: 0.2917
# Epoch 71/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.6588 - accuracy: 0.5348 - val_loss: 2.0333 - val_accuracy: 0.2708
# Epoch 72/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.5805 - accuracy: 0.5391 - val_loss: 2.0143 - val_accuracy: 0.2917
# Epoch 73/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.6073 - accuracy: 0.5478 - val_loss: 2.0592 - val_accuracy: 0.2708
# Epoch 74/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.5936 - accuracy: 0.5391 - val_loss: 2.0542 - val_accuracy: 0.2292
# Epoch 75/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.5937 - accuracy: 0.5478 - val_loss: 2.0057 - val_accuracy: 0.3125
# Epoch 76/100
# 15/15 [==============================] - 2s 130ms/step - loss: 1.5849 - accuracy: 0.5435 - val_loss: 2.0539 - val_accuracy: 0.2917
# Epoch 77/100
# 15/15 [==============================] - 2s 135ms/step - loss: 1.5893 - accuracy: 0.5304 - val_loss: 2.0350 - val_accuracy: 0.2917
# Epoch 78/100
# 15/15 [==============================] - 2s 131ms/step - loss: 1.5757 - accuracy: 0.5609 - val_loss: 2.0506 - val_accuracy: 0.2500
# Epoch 79/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.5361 - accuracy: 0.5652 - val_loss: 1.9675 - val_accuracy: 0.3542
# Epoch 80/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.5648 - accuracy: 0.5565 - val_loss: 1.9578 - val_accuracy: 0.3542
# Epoch 81/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.5680 - accuracy: 0.5696 - val_loss: 1.9574 - val_accuracy: 0.3542
# Epoch 82/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.5321 - accuracy: 0.5696 - val_loss: 1.9860 - val_accuracy: 0.2917
# Epoch 83/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.5424 - accuracy: 0.5739 - val_loss: 1.9608 - val_accuracy: 0.2917
# Epoch 84/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.5180 - accuracy: 0.5783 - val_loss: 1.9926 - val_accuracy: 0.3125
# Epoch 85/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.5163 - accuracy: 0.5957 - val_loss: 1.9464 - val_accuracy: 0.3542
# Epoch 86/100
# 15/15 [==============================] - 2s 128ms/step - loss: 1.5163 - accuracy: 0.5783 - val_loss: 1.9527 - val_accuracy: 0.3542
# Epoch 87/100
# 15/15 [==============================] - 2s 140ms/step - loss: 1.5063 - accuracy: 0.5783 - val_loss: 1.9474 - val_accuracy: 0.3333
# Epoch 88/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.4661 - accuracy: 0.6087 - val_loss: 1.9257 - val_accuracy: 0.2917
# Epoch 89/100
# 15/15 [==============================] - 2s 146ms/step - loss: 1.4959 - accuracy: 0.5913 - val_loss: 1.9251 - val_accuracy: 0.3542
# Epoch 90/100
# 15/15 [==============================] - 2s 165ms/step - loss: 1.4881 - accuracy: 0.5826 - val_loss: 1.8980 - val_accuracy: 0.3750
# Epoch 91/100
# 15/15 [==============================] - 2s 144ms/step - loss: 1.4567 - accuracy: 0.5913 - val_loss: 1.9746 - val_accuracy: 0.3542
# Epoch 92/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.4524 - accuracy: 0.5739 - val_loss: 1.8885 - val_accuracy: 0.4167
# Epoch 93/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.4694 - accuracy: 0.5870 - val_loss: 1.9043 - val_accuracy: 0.3958
# Epoch 94/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.4288 - accuracy: 0.6042 - val_loss: 1.8945 - val_accuracy: 0.3958
# Epoch 95/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.4388 - accuracy: 0.6000 - val_loss: 1.9035 - val_accuracy: 0.2917
# Epoch 96/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.4702 - accuracy: 0.6000 - val_loss: 1.8719 - val_accuracy: 0.3750
# Epoch 97/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.4210 - accuracy: 0.6130 - val_loss: 1.8963 - val_accuracy: 0.3542
# Epoch 98/100
# 15/15 [==============================] - 2s 137ms/step - loss: 1.4354 - accuracy: 0.5870 - val_loss: 1.8664 - val_accuracy: 0.4375
# Epoch 99/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.3988 - accuracy: 0.6087 - val_loss: 1.8415 - val_accuracy: 0.4167
# Epoch 100/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.3879 - accuracy: 0.5870 - val_loss: 1.8700 - val_accuracy: 0.3750
# 16/16 [==============================] - 1s 40ms/step - loss: 1.3801 - accuracy: 0.6179
# 4/4 [==============================] - 0s 41ms/step - loss: 1.8024 - accuracy: 0.3654
# Fold 2:
# Train accuracy: 0.6178861856460571, Validation accuracy: 0.36538460850715637
# Training time for fold 2: 385.34623861312866 seconds
#
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.3793 - accuracy: 0.6087 - val_loss: 1.9141 - val_accuracy: 0.3542
# Epoch 2/100
# 15/15 [==============================] - 2s 140ms/step - loss: 1.3657 - accuracy: 0.6043 - val_loss: 1.8613 - val_accuracy: 0.3750
# Epoch 3/100
# 15/15 [==============================] - 2s 143ms/step - loss: 1.3902 - accuracy: 0.6261 - val_loss: 1.8557 - val_accuracy: 0.3542
# Epoch 4/100
# 15/15 [==============================] - 2s 122ms/step - loss: 1.3787 - accuracy: 0.6043 - val_loss: 1.8576 - val_accuracy: 0.3958
# Epoch 5/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.3536 - accuracy: 0.6261 - val_loss: 1.8298 - val_accuracy: 0.3958
# Epoch 6/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.3670 - accuracy: 0.6261 - val_loss: 1.8700 - val_accuracy: 0.3750
# Epoch 7/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.3494 - accuracy: 0.6391 - val_loss: 1.8229 - val_accuracy: 0.4375
# Epoch 8/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.3282 - accuracy: 0.6696 - val_loss: 1.8162 - val_accuracy: 0.3958
# Epoch 9/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.3381 - accuracy: 0.6696 - val_loss: 1.8461 - val_accuracy: 0.3333
# Epoch 10/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.3247 - accuracy: 0.6391 - val_loss: 1.8171 - val_accuracy: 0.4167
# Epoch 11/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.2959 - accuracy: 0.6826 - val_loss: 1.8575 - val_accuracy: 0.3542
# Epoch 12/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.3121 - accuracy: 0.6652 - val_loss: 1.8458 - val_accuracy: 0.3542
# Epoch 13/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.3036 - accuracy: 0.6826 - val_loss: 1.7855 - val_accuracy: 0.4375
# Epoch 14/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.3196 - accuracy: 0.6261 - val_loss: 1.8005 - val_accuracy: 0.4167
# Epoch 15/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.3020 - accuracy: 0.6565 - val_loss: 1.7933 - val_accuracy: 0.3750
# Epoch 16/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.3048 - accuracy: 0.6609 - val_loss: 1.8099 - val_accuracy: 0.3542
# Epoch 17/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.2898 - accuracy: 0.6391 - val_loss: 1.8130 - val_accuracy: 0.3958
# Epoch 18/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.2623 - accuracy: 0.6870 - val_loss: 1.9006 - val_accuracy: 0.2917
# Epoch 19/100
# 15/15 [==============================] - 2s 127ms/step - loss: 1.2917 - accuracy: 0.6565 - val_loss: 1.8027 - val_accuracy: 0.3750
# Epoch 20/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.2602 - accuracy: 0.6478 - val_loss: 1.7738 - val_accuracy: 0.5000
# Epoch 21/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.2823 - accuracy: 0.6739 - val_loss: 1.8172 - val_accuracy: 0.4167
# Epoch 22/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.2712 - accuracy: 0.6565 - val_loss: 1.7492 - val_accuracy: 0.4792
# Epoch 23/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.2602 - accuracy: 0.6913 - val_loss: 1.8198 - val_accuracy: 0.3750
# Epoch 24/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.2385 - accuracy: 0.6913 - val_loss: 1.7763 - val_accuracy: 0.4167
# Epoch 25/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.2628 - accuracy: 0.6391 - val_loss: 1.7292 - val_accuracy: 0.4375
# Epoch 26/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.2316 - accuracy: 0.6609 - val_loss: 1.7272 - val_accuracy: 0.4167
# Epoch 27/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.2123 - accuracy: 0.6609 - val_loss: 1.7203 - val_accuracy: 0.4583
# Epoch 28/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.2278 - accuracy: 0.6826 - val_loss: 1.7065 - val_accuracy: 0.5000
# Epoch 29/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.2021 - accuracy: 0.6870 - val_loss: 1.7263 - val_accuracy: 0.4375
# Epoch 30/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.1992 - accuracy: 0.6609 - val_loss: 1.7299 - val_accuracy: 0.4375
# Epoch 31/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.2104 - accuracy: 0.6696 - val_loss: 1.7482 - val_accuracy: 0.4167
# Epoch 32/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.2034 - accuracy: 0.6435 - val_loss: 1.6867 - val_accuracy: 0.5000
# Epoch 33/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.1751 - accuracy: 0.7348 - val_loss: 1.6858 - val_accuracy: 0.5208
# Epoch 34/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.1881 - accuracy: 0.6826 - val_loss: 1.7188 - val_accuracy: 0.4167
# Epoch 35/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.1781 - accuracy: 0.7043 - val_loss: 1.6872 - val_accuracy: 0.4792
# Epoch 36/100
# 15/15 [==============================] - 2s 133ms/step - loss: 1.1716 - accuracy: 0.7043 - val_loss: 1.7961 - val_accuracy: 0.3542
# Epoch 37/100
# 15/15 [==============================] - 2s 127ms/step - loss: 1.1307 - accuracy: 0.7130 - val_loss: 1.7180 - val_accuracy: 0.4583
# Epoch 38/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.1481 - accuracy: 0.6870 - val_loss: 1.7564 - val_accuracy: 0.3750
# Epoch 39/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.1469 - accuracy: 0.7087 - val_loss: 1.7348 - val_accuracy: 0.3542
# Epoch 40/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.1224 - accuracy: 0.7087 - val_loss: 1.6519 - val_accuracy: 0.5208
# Epoch 41/100
# 15/15 [==============================] - 2s 130ms/step - loss: 1.1499 - accuracy: 0.7042 - val_loss: 1.6788 - val_accuracy: 0.5000
# Epoch 42/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.1272 - accuracy: 0.7043 - val_loss: 1.6987 - val_accuracy: 0.4792
# Epoch 43/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.1101 - accuracy: 0.7043 - val_loss: 1.6545 - val_accuracy: 0.4583
# Epoch 44/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.1335 - accuracy: 0.7087 - val_loss: 1.6542 - val_accuracy: 0.4583
# Epoch 45/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.1311 - accuracy: 0.6957 - val_loss: 1.7737 - val_accuracy: 0.3542
# Epoch 46/100
# 15/15 [==============================] - 2s 127ms/step - loss: 1.1067 - accuracy: 0.6957 - val_loss: 1.6856 - val_accuracy: 0.3958
# Epoch 47/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.1008 - accuracy: 0.7174 - val_loss: 1.7031 - val_accuracy: 0.4375
# Epoch 48/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.1158 - accuracy: 0.7130 - val_loss: 1.7882 - val_accuracy: 0.4375
# Epoch 49/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.1216 - accuracy: 0.6870 - val_loss: 1.6487 - val_accuracy: 0.4792
# Epoch 50/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.0754 - accuracy: 0.7130 - val_loss: 1.6023 - val_accuracy: 0.5000
# Epoch 51/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.0696 - accuracy: 0.6913 - val_loss: 1.7020 - val_accuracy: 0.5000
# Epoch 52/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.1006 - accuracy: 0.7174 - val_loss: 1.6624 - val_accuracy: 0.4583
# Epoch 53/100
# 15/15 [==============================] - 2s 127ms/step - loss: 1.0875 - accuracy: 0.7087 - val_loss: 1.6911 - val_accuracy: 0.4583
# Epoch 54/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.0837 - accuracy: 0.7130 - val_loss: 1.6376 - val_accuracy: 0.5208
# Epoch 55/100
# 15/15 [==============================] - 2s 143ms/step - loss: 1.0646 - accuracy: 0.7478 - val_loss: 1.6238 - val_accuracy: 0.4375
# Epoch 56/100
# 15/15 [==============================] - 2s 129ms/step - loss: 1.0520 - accuracy: 0.7261 - val_loss: 1.8021 - val_accuracy: 0.4375
# Epoch 57/100
# 15/15 [==============================] - 2s 127ms/step - loss: 1.0713 - accuracy: 0.7348 - val_loss: 1.5826 - val_accuracy: 0.4792
# Epoch 58/100
# 15/15 [==============================] - 2s 123ms/step - loss: 1.0533 - accuracy: 0.7261 - val_loss: 1.5817 - val_accuracy: 0.5208
# Epoch 59/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.0398 - accuracy: 0.7478 - val_loss: 1.6044 - val_accuracy: 0.4375
# Epoch 60/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.0223 - accuracy: 0.7435 - val_loss: 1.5897 - val_accuracy: 0.5208
# Epoch 61/100
# 15/15 [==============================] - 2s 126ms/step - loss: 1.0167 - accuracy: 0.7435 - val_loss: 1.6416 - val_accuracy: 0.4375
# Epoch 62/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9989 - accuracy: 0.7696 - val_loss: 1.6371 - val_accuracy: 0.5208
# Epoch 63/100
# 15/15 [==============================] - 2s 124ms/step - loss: 1.0154 - accuracy: 0.7478 - val_loss: 1.5675 - val_accuracy: 0.4792
# Epoch 64/100
# 15/15 [==============================] - 2s 125ms/step - loss: 1.0070 - accuracy: 0.7565 - val_loss: 1.5923 - val_accuracy: 0.5208
# Epoch 65/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9893 - accuracy: 0.7913 - val_loss: 1.5815 - val_accuracy: 0.5000
# Epoch 66/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9822 - accuracy: 0.7783 - val_loss: 1.5336 - val_accuracy: 0.4375
# Epoch 67/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.9981 - accuracy: 0.7304 - val_loss: 1.5937 - val_accuracy: 0.5000
# Epoch 68/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.9698 - accuracy: 0.7652 - val_loss: 1.5598 - val_accuracy: 0.4792
# Epoch 69/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9847 - accuracy: 0.7565 - val_loss: 1.6810 - val_accuracy: 0.3958
# Epoch 70/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9773 - accuracy: 0.7565 - val_loss: 1.5366 - val_accuracy: 0.4792
# Epoch 71/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9786 - accuracy: 0.7435 - val_loss: 1.4930 - val_accuracy: 0.5000
# Epoch 72/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.9659 - accuracy: 0.7652 - val_loss: 1.4973 - val_accuracy: 0.5417
# Epoch 73/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.9533 - accuracy: 0.7870 - val_loss: 1.5254 - val_accuracy: 0.5000
# Epoch 74/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.9478 - accuracy: 0.7625 - val_loss: 1.5721 - val_accuracy: 0.4375
# Epoch 75/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9465 - accuracy: 0.7652 - val_loss: 1.5873 - val_accuracy: 0.4375
# Epoch 76/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9265 - accuracy: 0.7739 - val_loss: 1.5636 - val_accuracy: 0.5208
# Epoch 77/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.9336 - accuracy: 0.7708 - val_loss: 1.5106 - val_accuracy: 0.5000
# Epoch 78/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.9113 - accuracy: 0.7652 - val_loss: 1.5579 - val_accuracy: 0.4583
# Epoch 79/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.9036 - accuracy: 0.7957 - val_loss: 1.5052 - val_accuracy: 0.5000
# Epoch 80/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.9098 - accuracy: 0.7870 - val_loss: 1.4905 - val_accuracy: 0.5208
# Epoch 81/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.9384 - accuracy: 0.7870 - val_loss: 1.4898 - val_accuracy: 0.5208
# Epoch 82/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.9301 - accuracy: 0.7913 - val_loss: 1.4470 - val_accuracy: 0.5625
# Epoch 83/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.8873 - accuracy: 0.7792 - val_loss: 1.5609 - val_accuracy: 0.5417
# Epoch 84/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9114 - accuracy: 0.8043 - val_loss: 1.4466 - val_accuracy: 0.5417
# Epoch 85/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.8948 - accuracy: 0.7652 - val_loss: 1.4901 - val_accuracy: 0.5000
# Epoch 86/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.9002 - accuracy: 0.7739 - val_loss: 1.4612 - val_accuracy: 0.5417
# Epoch 87/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.9091 - accuracy: 0.7739 - val_loss: 1.4531 - val_accuracy: 0.5417
# Epoch 88/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.8629 - accuracy: 0.7957 - val_loss: 1.4101 - val_accuracy: 0.5417
# Epoch 89/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.9081 - accuracy: 0.7826 - val_loss: 1.4902 - val_accuracy: 0.5625
# Epoch 90/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.8550 - accuracy: 0.7957 - val_loss: 1.5710 - val_accuracy: 0.4583
# Epoch 91/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.8617 - accuracy: 0.8043 - val_loss: 1.4309 - val_accuracy: 0.5417
# Epoch 92/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.8575 - accuracy: 0.7957 - val_loss: 1.4789 - val_accuracy: 0.5000
# Epoch 93/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.8717 - accuracy: 0.7957 - val_loss: 1.4636 - val_accuracy: 0.5833
# Epoch 94/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.8685 - accuracy: 0.7652 - val_loss: 1.4302 - val_accuracy: 0.5833
# Epoch 95/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.8721 - accuracy: 0.7565 - val_loss: 1.4168 - val_accuracy: 0.5208
# Epoch 96/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.8727 - accuracy: 0.7957 - val_loss: 1.4192 - val_accuracy: 0.5625
# Epoch 97/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.8588 - accuracy: 0.8043 - val_loss: 1.4625 - val_accuracy: 0.5208
# Epoch 98/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.8117 - accuracy: 0.8261 - val_loss: 1.3960 - val_accuracy: 0.5625
# Epoch 99/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.8329 - accuracy: 0.8043 - val_loss: 1.4204 - val_accuracy: 0.5625
# Epoch 100/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.8199 - accuracy: 0.8348 - val_loss: 1.4051 - val_accuracy: 0.5833
# 16/16 [==============================] - 1s 40ms/step - loss: 0.8009 - accuracy: 0.8293
# 4/4 [==============================] - 0s 39ms/step - loss: 1.3280 - accuracy: 0.6154
# Fold 3:
# Train accuracy: 0.8292682766914368, Validation accuracy: 0.6153846383094788
# Training time for fold 3: 577.7202270030975 seconds
#
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.8236 - accuracy: 0.8043 - val_loss: 1.4216 - val_accuracy: 0.5208
# Epoch 2/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.8158 - accuracy: 0.8304 - val_loss: 1.3534 - val_accuracy: 0.5833
# Epoch 3/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.8179 - accuracy: 0.8174 - val_loss: 1.3914 - val_accuracy: 0.5625
# Epoch 4/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.8217 - accuracy: 0.8174 - val_loss: 1.4030 - val_accuracy: 0.5417
# Epoch 5/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.8106 - accuracy: 0.8000 - val_loss: 1.4063 - val_accuracy: 0.5625
# Epoch 6/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.8199 - accuracy: 0.8174 - val_loss: 1.3015 - val_accuracy: 0.6250
# Epoch 7/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.7811 - accuracy: 0.8217 - val_loss: 1.4138 - val_accuracy: 0.5208
# Epoch 8/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.8059 - accuracy: 0.8174 - val_loss: 1.3029 - val_accuracy: 0.6250
# Epoch 9/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.7913 - accuracy: 0.8217 - val_loss: 1.3256 - val_accuracy: 0.6042
# Epoch 10/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.7589 - accuracy: 0.8174 - val_loss: 1.3480 - val_accuracy: 0.6042
# Epoch 11/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.7791 - accuracy: 0.8304 - val_loss: 1.2994 - val_accuracy: 0.6458
# Epoch 12/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.7616 - accuracy: 0.8261 - val_loss: 1.3436 - val_accuracy: 0.5625
# Epoch 13/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.7553 - accuracy: 0.8478 - val_loss: 1.3469 - val_accuracy: 0.5625
# Epoch 14/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.7473 - accuracy: 0.8435 - val_loss: 1.4258 - val_accuracy: 0.5000
# Epoch 15/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.7885 - accuracy: 0.8261 - val_loss: 1.3250 - val_accuracy: 0.6458
# Epoch 16/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.7568 - accuracy: 0.8391 - val_loss: 1.2753 - val_accuracy: 0.5833
# Epoch 17/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.7677 - accuracy: 0.8043 - val_loss: 1.2981 - val_accuracy: 0.6667
# Epoch 18/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.7608 - accuracy: 0.8304 - val_loss: 1.4099 - val_accuracy: 0.5833
# Epoch 19/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.7429 - accuracy: 0.8304 - val_loss: 1.4464 - val_accuracy: 0.4583
# Epoch 20/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.7383 - accuracy: 0.8304 - val_loss: 1.2887 - val_accuracy: 0.5833
# Epoch 21/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.7267 - accuracy: 0.8217 - val_loss: 1.3651 - val_accuracy: 0.5625
# Epoch 22/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.7289 - accuracy: 0.8583 - val_loss: 1.2582 - val_accuracy: 0.6458
# Epoch 23/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.7048 - accuracy: 0.8565 - val_loss: 1.2795 - val_accuracy: 0.6250
# Epoch 24/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.7283 - accuracy: 0.8609 - val_loss: 1.2638 - val_accuracy: 0.6458
# Epoch 25/100
# ...
# Epoch 97/100
# 15/15 [==============================] - 2s 144ms/step - loss: 0.4877 - accuracy: 0.9000 - val_loss: 1.0183 - val_accuracy: 0.6250
# Epoch 98/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4774 - accuracy: 0.91 - 2s 142ms/step - loss: 0.4774 - accuracy: 0.9130 - val_loss: 1.0829 - val_accuracy: 0.6458
# Epoch 99/100
# 15/15 [==============================] - 2s 134ms/step - loss: 0.4750 - accuracy: 0.9174 - val_loss: 1.0365 - val_accuracy: 0.6667
# Epoch 100/100
# 15/15 [==============================] - 2s 139ms/step - loss: 0.4922 - accuracy: 0.8957 - val_loss: 0.9382 - val_accuracy: 0.7083
# 16/16 [==============================] - 1s 41ms/step - loss: 0.4327 - accuracy: 0.9268
# 4/4 [==============================] - 0s 41ms/step - loss: 0.9029 - accuracy: 0.7308
# Fold 4:
# Train accuracy: 0.9268292784690857, Validation accuracy: 0.7307692170143127
# Training time for fold 4: 777.8653898239136 seconds
#
# Found 246 images belonging to 17 classes.
# Found 52 images belonging to 17 classes.
# Epoch 1/100
# 15/15 [==============================] - 2s 132ms/step - loss: 0.4787 - accuracy: 0.9130 - val_loss: 0.9247 - val_accuracy: 0.6875
# Epoch 2/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.4490 - accuracy: 0.9087 - val_loss: 1.0750 - val_accuracy: 0.6042
# Epoch 3/100
# 15/15 [==============================] - 2s 129ms/step - loss: 0.4951 - accuracy: 0.9000 - val_loss: 1.0165 - val_accuracy: 0.6250
# Epoch 4/100
# 15/15 [==============================] - 2s 130ms/step - loss: 0.4744 - accuracy: 0.9174 - val_loss: 0.9240 - val_accuracy: 0.7292
# Epoch 5/100
# 15/15 [==============================] - 2s 129ms/step - loss: 0.4683 - accuracy: 0.9000 - val_loss: 0.9489 - val_accuracy: 0.6875
# Epoch 6/100
# 15/15 [==============================] - 2s 129ms/step - loss: 0.4624 - accuracy: 0.9130 - val_loss: 0.8885 - val_accuracy: 0.7917
# Epoch 7/100
# 15/15 [==============================] - 2s 132ms/step - loss: 0.4471 - accuracy: 0.8958 - val_loss: 0.9471 - val_accuracy: 0.7292
# Epoch 8/100
# 15/15 [==============================] - 2s 132ms/step - loss: 0.4269 - accuracy: 0.9304 - val_loss: 1.0573 - val_accuracy: 0.6250
# Epoch 9/100
# 15/15 [==============================] - 2s 128ms/step - loss: 0.4554 - accuracy: 0.9083 - val_loss: 0.9266 - val_accuracy: 0.7292
# Epoch 10/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.4368 - accuracy: 0.8913 - val_loss: 0.9406 - val_accuracy: 0.7500
# Epoch 11/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.4450 - accuracy: 0.9043 - val_loss: 0.9313 - val_accuracy: 0.6667
# Epoch 12/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.4161 - accuracy: 0.9217 - val_loss: 0.9102 - val_accuracy: 0.7708
# Epoch 13/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.4340 - accuracy: 0.9130 - val_loss: 0.9030 - val_accuracy: 0.6875
# Epoch 14/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.4323 - accuracy: 0.9130 - val_loss: 0.9498 - val_accuracy: 0.6458
# Epoch 15/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.4389 - accuracy: 0.9261 - val_loss: 0.9471 - val_accuracy: 0.7708
# Epoch 16/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.4288 - accuracy: 0.9174 - val_loss: 0.9131 - val_accuracy: 0.7708
# Epoch 17/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.4389 - accuracy: 0.9174 - val_loss: 0.9870 - val_accuracy: 0.6458
# Epoch 18/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.4229 - accuracy: 0.9217 - val_loss: 1.0392 - val_accuracy: 0.6250
# Epoch 19/100
# 15/15 [==============================] - 2s 127ms/step - loss: 0.4181 - accuracy: 0.9217 - val_loss: 1.1425 - val_accuracy: 0.6250
# Epoch 20/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.4367 - accuracy: 0.9130 - val_loss: 1.0725 - val_accuracy: 0.6875
# Epoch 21/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.4436 - accuracy: 0.9087 - val_loss: 0.9620 - val_accuracy: 0.7292
# Epoch 22/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.4152 - accuracy: 0.9348 - val_loss: 0.9448 - val_accuracy: 0.7083
# Epoch 23/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.4194 - accuracy: 0.9130 - val_loss: 0.8870 - val_accuracy: 0.7708
# Epoch 24/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.4292 - accuracy: 0.9174 - val_loss: 0.9115 - val_accuracy: 0.7083
# Epoch 25/100
# 15/15 [==============================] - 7s 464ms/step - loss: 0.4339 - accuracy: 0.9217 - val_loss: 0.8664 - val_accuracy: 0.7917
# Epoch 26/100
# 15/15 [==============================] - 3s 122ms/step - loss: 0.4111 - accuracy: 0.9304 - val_loss: 0.9109 - val_accuracy: 0.7292
# Epoch 27/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3951 - accuracy: 0.9348 - val_loss: 0.9192 - val_accuracy: 0.7500
# Epoch 28/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.4013 - accuracy: 0.9217 - val_loss: 0.8741 - val_accuracy: 0.7292
# Epoch 29/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.4159 - accuracy: 0.9174 - val_loss: 0.8574 - val_accuracy: 0.7292
# Epoch 30/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.4104 - accuracy: 0.9130 - val_loss: 0.9218 - val_accuracy: 0.7500
# Epoch 31/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.4028 - accuracy: 0.9087 - val_loss: 0.8557 - val_accuracy: 0.7917
# Epoch 32/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.4091 - accuracy: 0.9261 - val_loss: 0.8955 - val_accuracy: 0.7083
# Epoch 33/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.4054 - accuracy: 0.9130 - val_loss: 0.8686 - val_accuracy: 0.7292
# Epoch 34/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3850 - accuracy: 0.9522 - val_loss: 0.8616 - val_accuracy: 0.7917
# Epoch 35/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3893 - accuracy: 0.9250 - val_loss: 0.8201 - val_accuracy: 0.7708
# Epoch 36/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3942 - accuracy: 0.9217 - val_loss: 0.7960 - val_accuracy: 0.8333
# Epoch 37/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.4017 - accuracy: 0.9174 - val_loss: 0.8975 - val_accuracy: 0.6875
# Epoch 38/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3653 - accuracy: 0.9304 - val_loss: 0.8928 - val_accuracy: 0.6875
# Epoch 39/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3879 - accuracy: 0.9250 - val_loss: 0.9265 - val_accuracy: 0.6458
# Epoch 40/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3869 - accuracy: 0.9261 - val_loss: 0.8819 - val_accuracy: 0.7292
# Epoch 41/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3754 - accuracy: 0.9304 - val_loss: 0.8321 - val_accuracy: 0.7500
# Epoch 42/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.4053 - accuracy: 0.9000 - val_loss: 0.8134 - val_accuracy: 0.7708
# Epoch 43/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3805 - accuracy: 0.9391 - val_loss: 0.8228 - val_accuracy: 0.7500
# Epoch 44/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3482 - accuracy: 0.9478 - val_loss: 0.8333 - val_accuracy: 0.7917
# Epoch 45/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3790 - accuracy: 0.9217 - val_loss: 0.8523 - val_accuracy: 0.7917
# Epoch 46/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3804 - accuracy: 0.9391 - val_loss: 0.9747 - val_accuracy: 0.6042
# Epoch 47/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.3920 - accuracy: 0.9174 - val_loss: 0.7859 - val_accuracy: 0.8542
# Epoch 48/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3719 - accuracy: 0.9348 - val_loss: 0.8246 - val_accuracy: 0.7708
# Epoch 49/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3603 - accuracy: 0.9391 - val_loss: 0.9112 - val_accuracy: 0.6667
# Epoch 50/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3730 - accuracy: 0.9435 - val_loss: 0.9220 - val_accuracy: 0.6875
# Epoch 51/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3589 - accuracy: 0.9391 - val_loss: 0.8047 - val_accuracy: 0.7917
# Epoch 52/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3862 - accuracy: 0.9261 - val_loss: 0.7855 - val_accuracy: 0.7917
# Epoch 53/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3523 - accuracy: 0.9348 - val_loss: 0.8921 - val_accuracy: 0.7083
# Epoch 54/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3799 - accuracy: 0.9261 - val_loss: 0.7736 - val_accuracy: 0.7500
# Epoch 55/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3398 - accuracy: 0.9435 - val_loss: 0.8792 - val_accuracy: 0.6667
# Epoch 56/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3846 - accuracy: 0.9174 - val_loss: 0.7554 - val_accuracy: 0.8125
# Epoch 57/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3594 - accuracy: 0.9304 - val_loss: 0.8176 - val_accuracy: 0.7917
# Epoch 58/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3351 - accuracy: 0.9304 - val_loss: 0.8055 - val_accuracy: 0.7917
# Epoch 59/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3521 - accuracy: 0.9435 - val_loss: 0.7642 - val_accuracy: 0.7292
# Epoch 60/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3565 - accuracy: 0.9304 - val_loss: 0.8017 - val_accuracy: 0.7292
# Epoch 61/100
# 15/15 [==============================] - 2s 126ms/step - loss: 0.3384 - accuracy: 0.9375 - val_loss: 0.8377 - val_accuracy: 0.7500
# Epoch 62/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3362 - accuracy: 0.9391 - val_loss: 0.8650 - val_accuracy: 0.7292
# Epoch 63/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3373 - accuracy: 0.9478 - val_loss: 0.7257 - val_accuracy: 0.8125
# Epoch 64/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3328 - accuracy: 0.9391 - val_loss: 0.7955 - val_accuracy: 0.8125
# Epoch 65/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3348 - accuracy: 0.9348 - val_loss: 0.8284 - val_accuracy: 0.7500
# Epoch 66/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3221 - accuracy: 0.9304 - val_loss: 0.7365 - val_accuracy: 0.8333
# Epoch 67/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3255 - accuracy: 0.9478 - val_loss: 1.0206 - val_accuracy: 0.6250
# Epoch 68/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3305 - accuracy: 0.9435 - val_loss: 0.7689 - val_accuracy: 0.7917
# Epoch 69/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3335 - accuracy: 0.9348 - val_loss: 0.9817 - val_accuracy: 0.6250
# Epoch 70/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3158 - accuracy: 0.9391 - val_loss: 0.7813 - val_accuracy: 0.7708
# Epoch 71/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3043 - accuracy: 0.9565 - val_loss: 0.8697 - val_accuracy: 0.6875
# Epoch 72/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3123 - accuracy: 0.9435 - val_loss: 0.7618 - val_accuracy: 0.7292
# Epoch 73/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3407 - accuracy: 0.9391 - val_loss: 0.7271 - val_accuracy: 0.7917
# Epoch 74/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3232 - accuracy: 0.9522 - val_loss: 0.6943 - val_accuracy: 0.7917
# Epoch 75/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3264 - accuracy: 0.9391 - val_loss: 0.8909 - val_accuracy: 0.6875
# Epoch 76/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3239 - accuracy: 0.9435 - val_loss: 0.7622 - val_accuracy: 0.7500
# Epoch 77/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3200 - accuracy: 0.9478 - val_loss: 0.7780 - val_accuracy: 0.7292
# Epoch 78/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3171 - accuracy: 0.9391 - val_loss: 0.7098 - val_accuracy: 0.8125
# Epoch 79/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.3048 - accuracy: 0.9542 - val_loss: 0.7245 - val_accuracy: 0.8125
# Epoch 80/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3019 - accuracy: 0.9478 - val_loss: 0.7656 - val_accuracy: 0.7708
# Epoch 81/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2983 - accuracy: 0.9435 - val_loss: 0.7720 - val_accuracy: 0.7917
# Epoch 82/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3253 - accuracy: 0.9391 - val_loss: 0.7287 - val_accuracy: 0.7917
# Epoch 83/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2868 - accuracy: 0.9478 - val_loss: 0.7812 - val_accuracy: 0.7292
# Epoch 84/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3231 - accuracy: 0.9261 - val_loss: 0.7294 - val_accuracy: 0.7708
# Epoch 85/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3202 - accuracy: 0.9348 - val_loss: 0.6858 - val_accuracy: 0.8333
# Epoch 86/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2990 - accuracy: 0.9565 - val_loss: 0.8777 - val_accuracy: 0.6875
# Epoch 87/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3090 - accuracy: 0.9435 - val_loss: 0.7905 - val_accuracy: 0.7500
# Epoch 88/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.3136 - accuracy: 0.9304 - val_loss: 0.6741 - val_accuracy: 0.8750
# Epoch 89/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3125 - accuracy: 0.9435 - val_loss: 0.6356 - val_accuracy: 0.8333
# Epoch 90/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3202 - accuracy: 0.9478 - val_loss: 0.6917 - val_accuracy: 0.7917
# Epoch 91/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2917 - accuracy: 0.9565 - val_loss: 0.6742 - val_accuracy: 0.8125
# Epoch 92/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3185 - accuracy: 0.9478 - val_loss: 0.8455 - val_accuracy: 0.6875
# Epoch 93/100
# 15/15 [==============================] - 2s 123ms/step - loss: 0.2932 - accuracy: 0.9478 - val_loss: 0.6990 - val_accuracy: 0.8542
# Epoch 94/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2896 - accuracy: 0.9435 - val_loss: 0.7083 - val_accuracy: 0.7917
# Epoch 95/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3029 - accuracy: 0.9565 - val_loss: 0.6907 - val_accuracy: 0.7708
# Epoch 96/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.3029 - accuracy: 0.9478 - val_loss: 0.6965 - val_accuracy: 0.7708
# Epoch 97/100
# 15/15 [==============================] - 2s 124ms/step - loss: 0.2972 - accuracy: 0.9435 - val_loss: 0.7235 - val_accuracy: 0.8125
# Epoch 98/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.3078 - accuracy: 0.9304 - val_loss: 0.8107 - val_accuracy: 0.7292
# Epoch 99/100
# 15/15 [==============================] - 2s 122ms/step - loss: 0.2874 - accuracy: 0.9652 - val_loss: 0.6392 - val_accuracy: 0.8333
# Epoch 100/100
# 15/15 [==============================] - 2s 125ms/step - loss: 0.2819 - accuracy: 0.9542 - val_loss: 0.7276 - val_accuracy: 0.7708
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2900 - accuracy: 0.9472
# 4/4 [==============================] - 0s 37ms/step - loss: 0.6804 - accuracy: 0.7885
# Fold 5:
# Train accuracy: 0.9471544623374939, Validation accuracy: 0.7884615659713745
# Training time for fold 5: 973.9723012447357 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 72.43902444839478 %
# Average Validation Accuracy: 55.384616255760186 %
# Average Training Time: 581.4151615142822
# Total Training Time: 974.0977635383606

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsVGG-lstmkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+---------------------+---------------------+----------------------+---------+
# | Class |      Precision      |        Recall       |       F1 Score       | Support |
# +-------+---------------------+---------------------+----------------------+---------+
# |   0   |  0.2727272727272727 | 0.23076923076923078 |         0.25         |    13   |
# |   1   | 0.14285714285714285 | 0.13333333333333333 | 0.13793103448275862  |    15   |
# |   10  | 0.18181818181818182 | 0.16666666666666666 | 0.17391304347826086  |    12   |
# |   2   | 0.16666666666666666 | 0.16666666666666666 | 0.16666666666666666  |    18   |
# |   3   | 0.08333333333333333 | 0.07692307692307693 |         0.08         |    13   |
# |   4   |         0.0         |         0.0         |         0.0          |    15   |
# |   5   |         0.0         |         0.0         |         0.0          |    12   |
# |   6   | 0.07142857142857142 | 0.08333333333333333 | 0.07692307692307693  |    12   |
# |   7   | 0.08333333333333333 | 0.08333333333333333 | 0.08333333333333333  |    12   |
# |   8   | 0.05555555555555555 |        0.0625       | 0.058823529411764705 |    16   |
# |   9   | 0.21428571428571427 | 0.23076923076923078 |  0.2222222222222222  |    13   |
# |  box  |        0.0625       | 0.06666666666666667 | 0.06451612903225806  |    15   |
# |  fun  | 0.08333333333333333 | 0.06666666666666667 | 0.07407407407407407  |    15   |
# |  good |         0.0         |         0.0         |         0.0          |    18   |
# |  grow | 0.07142857142857142 | 0.06666666666666667 | 0.06896551724137931  |    15   |
# |  hero |         0.0         |         0.0         |         0.0          |    16   |
# | trust | 0.10526315789473684 |        0.125        | 0.11428571428571428  |    16   |
# +-------+---------------------+---------------------+----------------------+---------+
#
# Validation Metrics:
# +-------+--------------------+--------------------+--------------------+---------+
# | Class |     Precision      |       Recall       |      F1 Score      | Support |
# +-------+--------------------+--------------------+--------------------+---------+
# |   0   |        1.0         | 0.3333333333333333 |        0.5         |    3    |
# |   1   |        1.0         | 0.6666666666666666 |        0.8         |    3    |
# |   10  |        0.0         |        0.0         |        0.0         |    2    |
# |   2   |        0.75        |        0.75        |        0.75        |    4    |
# |   3   |        1.0         | 0.6666666666666666 |        0.8         |    3    |
# |   4   |        0.75        |        1.0         | 0.8571428571428571 |    3    |
# |   5   |        1.0         |        1.0         |        1.0         |    2    |
# |   6   |        0.5         |        1.0         | 0.6666666666666666 |    2    |
# |   7   |        1.0         |        1.0         |        1.0         |    2    |
# |   8   | 0.6666666666666666 |        1.0         |        0.8         |    4    |
# |   9   |        0.5         | 0.6666666666666666 | 0.5714285714285714 |    3    |
# |  box  |        0.75        |        1.0         | 0.8571428571428571 |    3    |
# |  fun  |        1.0         | 0.6666666666666666 |        0.8         |    3    |
# |  good |        1.0         |        1.0         |        1.0         |    4    |
# |  grow |        1.0         | 0.6666666666666666 |        0.8         |    3    |
# |  hero |        1.0         |        0.75        | 0.8571428571428571 |    4    |
# | trust |        0.8         |        1.0         | 0.8888888888888888 |    4    |
# +-------+--------------------+--------------------+--------------------+---------+
# Combined metrics saved to combined_metricsVGG-lstmkfold5.xlsx

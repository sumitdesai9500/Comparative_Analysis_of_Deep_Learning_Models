# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # Resnet

# %% [markdown]
# # Model Summmary

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
from tensorflow.keras.applications import ResNet50
import time

# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Noise reduction 2\\output_denoised_image_folder"
K_FOLDS=5


# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the ResNet50 model
model = ResNet50(include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))


# Add new layers to the model
x = model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

# Combine the original model with the new layers
model = tf.keras.models.Model(inputs=model.input, outputs=predictions)


    # Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Found 417 images belonging to 17 classes.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 72, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 102, 78, 3)   0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 48, 36, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 48, 36, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 48, 36, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 50, 38, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 24, 18, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 24, 18, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 24, 18, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 24, 18, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 24, 18, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 24, 18, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 24, 18, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 24, 18, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 24, 18, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 24, 18, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 24, 18, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 24, 18, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 24, 18, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 24, 18, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 24, 18, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 24, 18, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 24, 18, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 24, 18, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 24, 18, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 24, 18, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 24, 18, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 24, 18, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 24, 18, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 24, 18, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 24, 18, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 24, 18, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 24, 18, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 24, 18, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 24, 18, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 24, 18, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 24, 18, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 24, 18, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 24, 18, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 12, 9, 128)   32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 12, 9, 128)  512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 12, 9, 128)  0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 12, 9, 128)   147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 12, 9, 128)  512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 12, 9, 128)  0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 12, 9, 512)   131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 12, 9, 512)   66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 12, 9, 512)  2048        ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 12, 9, 512)  2048        ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 12, 9, 512)   0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 12, 9, 512)   0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 12, 9, 128)   65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 12, 9, 128)  512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 12, 9, 128)  0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 12, 9, 128)   147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 12, 9, 128)  512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 12, 9, 128)  0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 12, 9, 512)   66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 12, 9, 512)  2048        ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 12, 9, 512)   0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 12, 9, 512)   0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 12, 9, 128)   65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 12, 9, 128)  512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 12, 9, 128)  0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 12, 9, 128)   147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 12, 9, 128)  512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 12, 9, 128)  0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 12, 9, 512)   66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 12, 9, 512)  2048        ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 12, 9, 512)   0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 12, 9, 512)   0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 12, 9, 128)   65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 12, 9, 128)  512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 12, 9, 128)  0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 9, 128)   147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 12, 9, 128)  512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 12, 9, 128)  0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 12, 9, 512)   66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 12, 9, 512)  2048        ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 12, 9, 512)   0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 12, 9, 512)   0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 6, 5, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 6, 5, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 6, 5, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 6, 5, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 6, 5, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 6, 5, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 6, 5, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 6, 5, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 6, 5, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 6, 5, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 6, 5, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 6, 5, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 6, 5, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 6, 5, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 6, 5, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 6, 5, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 6, 5, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 6, 5, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 6, 5, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 6, 5, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 6, 5, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 6, 5, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 6, 5, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 6, 5, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 6, 5, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 6, 5, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 6, 5, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 6, 5, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 6, 5, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 6, 5, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 6, 5, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 6, 5, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 6, 5, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 6, 5, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 6, 5, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 6, 5, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 6, 5, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 6, 5, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 6, 5, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 6, 5, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 3, 3, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 3, 3, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 3, 3, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 3, 3, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 3, 3, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 3, 3, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 3, 3, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 3, 3, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 3, 3, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 3, 3, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 3, 3, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 3, 3, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 3, 3, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 3, 3, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 3, 3, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 3, 3, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 3, 3, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 3, 3, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 3, 3, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 3, 3, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten (Flatten)              (None, 18432)        0           ['conv5_block3_out[0][0]']
#
#  dense (Dense)                  (None, 128)          2359424     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 17)           2193        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 25,949,329
# Trainable params: 25,896,209
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
from tensorflow.keras.applications import ResNet50
import time

# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Noise reduction 2\\output_denoised_image_folder"
K_FOLDS=5


# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the ResNet50 model
model = ResNet50(include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))


# Add new layers to the model
x = model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

# Combine the original model with the new layers
model = tf.keras.models.Model(inputs=model.input, outputs=predictions)


    # Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'resnet_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 417 images belonging to 17 classes.
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 10s 177ms/step - loss: 3.8430 - accuracy: 0.1238 - val_loss: 3.9451 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 21/21 [==============================] - 2s 89ms/step - loss: 2.7342 - accuracy: 0.1455 - val_loss: 2.8326 - val_accuracy: 0.0781
# Epoch 3/100
# 21/21 [==============================] - 2s 90ms/step - loss: 2.6134 - accuracy: 0.1300 - val_loss: 2.8320 - val_accuracy: 0.0781
# Epoch 4/100
# 21/21 [==============================] - 2s 92ms/step - loss: 2.4938 - accuracy: 0.2105 - val_loss: 2.8317 - val_accuracy: 0.0781
# Epoch 5/100
# 21/21 [==============================] - 2s 108ms/step - loss: 2.3271 - accuracy: 0.2693 - val_loss: 2.8549 - val_accuracy: 0.0625
# Epoch 6/100
# 21/21 [==============================] - 2s 90ms/step - loss: 2.1592 - accuracy: 0.3622 - val_loss: 2.8595 - val_accuracy: 0.0625
# Epoch 7/100
# 21/21 [==============================] - 2s 91ms/step - loss: 1.9663 - accuracy: 0.3932 - val_loss: 3.0474 - val_accuracy: 0.0625
# Epoch 8/100
# 21/21 [==============================] - 2s 92ms/step - loss: 1.5547 - accuracy: 0.5387 - val_loss: 4.6623 - val_accuracy: 0.0625
# Epoch 9/100
# 21/21 [==============================] - 2s 90ms/step - loss: 1.0671 - accuracy: 0.6718 - val_loss: 3.5157 - val_accuracy: 0.0625
# Epoch 10/100
# 21/21 [==============================] - 2s 91ms/step - loss: 1.3411 - accuracy: 0.6502 - val_loss: 4.2224 - val_accuracy: 0.0625
# Epoch 11/100
# 21/21 [==============================] - 2s 91ms/step - loss: 2.0060 - accuracy: 0.4427 - val_loss: 3.4060 - val_accuracy: 0.0781
# Epoch 12/100
# 21/21 [==============================] - 2s 94ms/step - loss: 1.8060 - accuracy: 0.4551 - val_loss: 2.8306 - val_accuracy: 0.0781
# Epoch 13/100
# 21/21 [==============================] - 2s 90ms/step - loss: 1.4346 - accuracy: 0.5325 - val_loss: 5.4781 - val_accuracy: 0.0625
# Epoch 14/100
# 21/21 [==============================] - 2s 90ms/step - loss: 1.4436 - accuracy: 0.5666 - val_loss: 4.3557 - val_accuracy: 0.0625
# Epoch 15/100
# 21/21 [==============================] - 2s 90ms/step - loss: 1.3905 - accuracy: 0.5573 - val_loss: 4.7261 - val_accuracy: 0.1094
# Epoch 16/100
# 21/21 [==============================] - 2s 91ms/step - loss: 1.7545 - accuracy: 0.4737 - val_loss: 2.8302 - val_accuracy: 0.0781
# Epoch 17/100
# 21/21 [==============================] - 2s 90ms/step - loss: 1.5302 - accuracy: 0.5851 - val_loss: 2.8301 - val_accuracy: 0.0781
# Epoch 18/100
# 21/21 [==============================] - 2s 90ms/step - loss: 1.0014 - accuracy: 0.7059 - val_loss: 4.8208 - val_accuracy: 0.0781
# Epoch 19/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.8908 - accuracy: 0.7121 - val_loss: 7.1555 - val_accuracy: 0.0781
# Epoch 20/100
# 21/21 [==============================] - 2s 90ms/step - loss: 0.7791 - accuracy: 0.7554 - val_loss: 5.7950 - val_accuracy: 0.0781
# Epoch 21/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.7041 - accuracy: 0.7895 - val_loss: 3.0510 - val_accuracy: 0.0781
# Epoch 22/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.4728 - accuracy: 0.8576 - val_loss: 3.1337 - val_accuracy: 0.0781
# Epoch 23/100
# 21/21 [==============================] - 2s 90ms/step - loss: 0.4628 - accuracy: 0.8576 - val_loss: 3.1537 - val_accuracy: 0.0781
# Epoch 24/100
# 21/21 [==============================] - 2s 90ms/step - loss: 0.8691 - accuracy: 0.7709 - val_loss: 6.7395 - val_accuracy: 0.0625
# Epoch 25/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.6382 - accuracy: 0.7957 - val_loss: 3.0810 - val_accuracy: 0.0938
# Epoch 26/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.7846 - accuracy: 0.7895 - val_loss: 3.3649 - val_accuracy: 0.0156
# Epoch 27/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.6661 - accuracy: 0.8173 - val_loss: 6.1178 - val_accuracy: 0.0625
# Epoch 28/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.6290 - accuracy: 0.8111 - val_loss: 5.6989 - val_accuracy: 0.0625
# Epoch 29/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.4911 - accuracy: 0.8452 - val_loss: 5.0074 - val_accuracy: 0.0625
# Epoch 30/100
# 21/21 [==============================] - 2s 90ms/step - loss: 0.4406 - accuracy: 0.8824 - val_loss: 5.9688 - val_accuracy: 0.0781
# Epoch 31/100
# 21/21 [==============================] - 2s 90ms/step - loss: 0.5207 - accuracy: 0.8359 - val_loss: 4.5326 - val_accuracy: 0.0938
# Epoch 32/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.9123 - accuracy: 0.7183 - val_loss: 4.2533 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.9619 - accuracy: 0.6873 - val_loss: 3.0351 - val_accuracy: 0.0938
# Epoch 34/100
# 21/21 [==============================] - 2s 92ms/step - loss: 1.0467 - accuracy: 0.6780 - val_loss: 4.0971 - val_accuracy: 0.0625
# Epoch 35/100
# 21/21 [==============================] - 2s 93ms/step - loss: 1.1866 - accuracy: 0.6625 - val_loss: 3.3813 - val_accuracy: 0.1406
# Epoch 36/100
# 21/21 [==============================] - 2s 92ms/step - loss: 0.7356 - accuracy: 0.7523 - val_loss: 3.3946 - val_accuracy: 0.0781
# Epoch 37/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.8018 - accuracy: 0.7957 - val_loss: 2.8923 - val_accuracy: 0.1406
# Epoch 38/100
# 21/21 [==============================] - 2s 92ms/step - loss: 0.7420 - accuracy: 0.8235 - val_loss: 3.8063 - val_accuracy: 0.1250
# Epoch 39/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.7038 - accuracy: 0.8050 - val_loss: 4.5081 - val_accuracy: 0.1406
# Epoch 40/100
# 21/21 [==============================] - 2s 93ms/step - loss: 0.5539 - accuracy: 0.8095 - val_loss: 4.5628 - val_accuracy: 0.1094
# Epoch 41/100
# 21/21 [==============================] - 2s 92ms/step - loss: 0.4511 - accuracy: 0.8669 - val_loss: 4.3577 - val_accuracy: 0.1250
# Epoch 42/100
# 21/21 [==============================] - 2s 93ms/step - loss: 0.3965 - accuracy: 0.8899 - val_loss: 5.0063 - val_accuracy: 0.0938
# Epoch 43/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.4195 - accuracy: 0.8669 - val_loss: 7.4862 - val_accuracy: 0.0938
# Epoch 44/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.4511 - accuracy: 0.8638 - val_loss: 5.2082 - val_accuracy: 0.1250
# Epoch 45/100
# 21/21 [==============================] - 2s 91ms/step - loss: 0.5654 - accuracy: 0.8669 - val_loss: 4.2139 - val_accuracy: 0.0781
# Epoch 46/100
# 21/21 [==============================] - 2s 92ms/step - loss: 0.5122 - accuracy: 0.8576 - val_loss: 5.0927 - val_accuracy: 0.0938
# Epoch 47/100
# 21/21 [==============================] - 2s 95ms/step - loss: 0.4837 - accuracy: 0.8661 - val_loss: 4.2243 - val_accuracy: 0.2188
# Epoch 48/100
# 21/21 [==============================] - 2s 93ms/step - loss: 0.4014 - accuracy: 0.8762 - val_loss: 4.2693 - val_accuracy: 0.2188
# Epoch 49/100
# 21/21 [==============================] - 2s 93ms/step - loss: 0.2875 - accuracy: 0.9257 - val_loss: 4.0671 - val_accuracy: 0.2812
# Epoch 50/100
# 21/21 [==============================] - 2s 93ms/step - loss: 0.3680 - accuracy: 0.9009 - val_loss: 4.4592 - val_accuracy: 0.2344
# Epoch 51/100
# 21/21 [==============================] - 2s 95ms/step - loss: 0.2874 - accuracy: 0.9040 - val_loss: 3.7711 - val_accuracy: 0.4062
# Epoch 52/100
# 21/21 [==============================] - 2s 95ms/step - loss: 0.3069 - accuracy: 0.9164 - val_loss: 3.9351 - val_accuracy: 0.4062
# Epoch 53/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.3907 - accuracy: 0.8824 - val_loss: 4.1823 - val_accuracy: 0.4219
# Epoch 54/100
# 21/21 [==============================] - 2s 97ms/step - loss: 0.3209 - accuracy: 0.9040 - val_loss: 3.3934 - val_accuracy: 0.4531
# Epoch 55/100
# 21/21 [==============================] - 2s 98ms/step - loss: 0.2868 - accuracy: 0.9009 - val_loss: 4.2196 - val_accuracy: 0.4531
# Epoch 56/100
# 21/21 [==============================] - 2s 96ms/step - loss: 0.2864 - accuracy: 0.9133 - val_loss: 3.6122 - val_accuracy: 0.5156
# Epoch 57/100
# 21/21 [==============================] - 2s 100ms/step - loss: 0.3356 - accuracy: 0.8947 - val_loss: 3.3370 - val_accuracy: 0.5156
# Epoch 58/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.2888 - accuracy: 0.9350 - val_loss: 2.9703 - val_accuracy: 0.5781
# Epoch 59/100
# 21/21 [==============================] - 2s 101ms/step - loss: 0.2281 - accuracy: 0.9350 - val_loss: 3.0436 - val_accuracy: 0.4844
# Epoch 60/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.2548 - accuracy: 0.9226 - val_loss: 2.9539 - val_accuracy: 0.5938
# Epoch 61/100
# 21/21 [==============================] - 2s 100ms/step - loss: 0.2167 - accuracy: 0.9381 - val_loss: 3.1641 - val_accuracy: 0.6250
# Epoch 62/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.2619 - accuracy: 0.9319 - val_loss: 3.8123 - val_accuracy: 0.5469
# Epoch 63/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.2522 - accuracy: 0.9319 - val_loss: 3.8019 - val_accuracy: 0.5781
# Epoch 64/100
# 21/21 [==============================] - 2s 101ms/step - loss: 0.2373 - accuracy: 0.9256 - val_loss: 3.9009 - val_accuracy: 0.2031
# Epoch 65/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.6149 - accuracy: 0.8266 - val_loss: 4.2735 - val_accuracy: 0.0781
# Epoch 66/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.6237 - accuracy: 0.8125 - val_loss: 7.3380 - val_accuracy: 0.1094
# Epoch 67/100
# 21/21 [==============================] - 2s 100ms/step - loss: 0.7097 - accuracy: 0.8204 - val_loss: 5.9621 - val_accuracy: 0.0312
# Epoch 68/100
# 21/21 [==============================] - 2s 101ms/step - loss: 1.6924 - accuracy: 0.5108 - val_loss: 4.1829 - val_accuracy: 0.1406
# Epoch 69/100
# 21/21 [==============================] - 2s 103ms/step - loss: 1.1774 - accuracy: 0.6316 - val_loss: 4.0987 - val_accuracy: 0.0781
# Epoch 70/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.8485 - accuracy: 0.7245 - val_loss: 7.4360 - val_accuracy: 0.1562
# Epoch 71/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.7666 - accuracy: 0.7802 - val_loss: 3.5650 - val_accuracy: 0.1719
# Epoch 72/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5688 - accuracy: 0.8266 - val_loss: 3.3766 - val_accuracy: 0.3125
# Epoch 73/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5555 - accuracy: 0.8390 - val_loss: 3.5948 - val_accuracy: 0.4062
# Epoch 74/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3129 - accuracy: 0.9009 - val_loss: 3.5141 - val_accuracy: 0.4531
# Epoch 75/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3125 - accuracy: 0.9009 - val_loss: 3.4443 - val_accuracy: 0.5312
# Epoch 76/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5080 - accuracy: 0.8483 - val_loss: 3.7041 - val_accuracy: 0.3906
# Epoch 77/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.6334 - accuracy: 0.7895 - val_loss: 4.4749 - val_accuracy: 0.1719
# Epoch 78/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5563 - accuracy: 0.8452 - val_loss: 4.3210 - val_accuracy: 0.2812
# Epoch 79/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.4456 - accuracy: 0.8720 - val_loss: 3.8470 - val_accuracy: 0.5156
# Epoch 80/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3288 - accuracy: 0.9133 - val_loss: 4.1966 - val_accuracy: 0.3906
# Epoch 81/100
# 21/21 [==============================] - 5s 246ms/step - loss: 0.3083 - accuracy: 0.9071 - val_loss: 4.0897 - val_accuracy: 0.4375
# Epoch 82/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2520 - accuracy: 0.9319 - val_loss: 4.2749 - val_accuracy: 0.5781
# Epoch 83/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2243 - accuracy: 0.9381 - val_loss: 4.4082 - val_accuracy: 0.5625
# Epoch 84/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.4303 - accuracy: 0.9107 - val_loss: 4.7592 - val_accuracy: 0.5469
# Epoch 85/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2384 - accuracy: 0.9350 - val_loss: 4.5264 - val_accuracy: 0.6094
# Epoch 86/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2044 - accuracy: 0.9381 - val_loss: 4.3911 - val_accuracy: 0.6094
# Epoch 87/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.4187 - accuracy: 0.8700 - val_loss: 2.6402 - val_accuracy: 0.5312
# Epoch 88/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3295 - accuracy: 0.8947 - val_loss: 3.2608 - val_accuracy: 0.5625
# Epoch 89/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3631 - accuracy: 0.8885 - val_loss: 4.0502 - val_accuracy: 0.3281
# Epoch 90/100
# 21/21 [==============================] - 5s 245ms/step - loss: 0.3335 - accuracy: 0.9009 - val_loss: 3.8275 - val_accuracy: 0.4219
# Epoch 91/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3654 - accuracy: 0.9164 - val_loss: 4.3178 - val_accuracy: 0.5000
# Epoch 92/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2210 - accuracy: 0.9257 - val_loss: 3.8299 - val_accuracy: 0.5625
# Epoch 93/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2056 - accuracy: 0.9319 - val_loss: 3.6750 - val_accuracy: 0.5625
# Epoch 94/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2456 - accuracy: 0.9319 - val_loss: 3.6312 - val_accuracy: 0.5938
# Epoch 95/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.1918 - accuracy: 0.9381 - val_loss: 3.6341 - val_accuracy: 0.5781
# Epoch 96/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.1847 - accuracy: 0.9412 - val_loss: 3.5940 - val_accuracy: 0.6094
# Epoch 97/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.1921 - accuracy: 0.9443 - val_loss: 3.5570 - val_accuracy: 0.6250
# Epoch 98/100
# 21/21 [==============================] - 6s 292ms/step - loss: 0.2004 - accuracy: 0.9381 - val_loss: 3.5640 - val_accuracy: 0.6250
# Epoch 99/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.1881 - accuracy: 0.9412 - val_loss: 4.0887 - val_accuracy: 0.5938
# Epoch 100/100
# 21/21 [==============================] - 2s 101ms/step - loss: 0.2121 - accuracy: 0.9443 - val_loss: 4.2640 - val_accuracy: 0.5312
# 22/22 [==============================] - 1s 30ms/step - loss: 0.1860 - accuracy: 0.9587
# 5/5 [==============================] - 1s 170ms/step - loss: 3.6049 - accuracy: 0.6026
# Fold 1:
# Train accuracy: 0.9587020874023438, Validation accuracy: 0.6025640964508057
# Training time for fold 1: 222.95398664474487 seconds
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2285 - accuracy: 0.9350 - val_loss: 5.0817 - val_accuracy: 0.5625
# Epoch 2/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3142 - accuracy: 0.9195 - val_loss: 4.2097 - val_accuracy: 0.5469
# Epoch 3/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2646 - accuracy: 0.9288 - val_loss: 4.5497 - val_accuracy: 0.5469
# Epoch 4/100
# 21/21 [==============================] - 2s 107ms/step - loss: 0.2624 - accuracy: 0.9412 - val_loss: 4.1057 - val_accuracy: 0.6094
# Epoch 5/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2358 - accuracy: 0.9319 - val_loss: 4.0132 - val_accuracy: 0.5938
# Epoch 6/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2347 - accuracy: 0.9226 - val_loss: 4.0617 - val_accuracy: 0.5469
# Epoch 7/100
# 21/21 [==============================] - 6s 294ms/step - loss: 0.7497 - accuracy: 0.7585 - val_loss: 4.1236 - val_accuracy: 0.1094
# Epoch 8/100
# 21/21 [==============================] - 2s 103ms/step - loss: 1.0234 - accuracy: 0.6656 - val_loss: 3.0609 - val_accuracy: 0.1094
# Epoch 9/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.9217 - accuracy: 0.7337 - val_loss: 3.0852 - val_accuracy: 0.1250
# Epoch 10/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.7072 - accuracy: 0.8080 - val_loss: 3.6538 - val_accuracy: 0.0625
# Epoch 11/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.7099 - accuracy: 0.7988 - val_loss: 4.4532 - val_accuracy: 0.2500
# Epoch 12/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.5988 - accuracy: 0.8607 - val_loss: 5.3112 - val_accuracy: 0.3438
# Epoch 13/100
# 21/21 [==============================] - 4s 196ms/step - loss: 0.3995 - accuracy: 0.8824 - val_loss: 5.3343 - val_accuracy: 0.3906
# Epoch 14/100
# 21/21 [==============================] - 4s 133ms/step - loss: 0.3586 - accuracy: 0.8947 - val_loss: 4.6425 - val_accuracy: 0.4375
# Epoch 15/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3450 - accuracy: 0.8916 - val_loss: 4.7234 - val_accuracy: 0.2812
# Epoch 16/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5032 - accuracy: 0.8607 - val_loss: 5.1960 - val_accuracy: 0.3594
# Epoch 17/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.4427 - accuracy: 0.8731 - val_loss: 5.8379 - val_accuracy: 0.2188
# Epoch 18/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.4784 - accuracy: 0.8421 - val_loss: 3.7579 - val_accuracy: 0.4375
# Epoch 19/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3937 - accuracy: 0.8638 - val_loss: 4.0575 - val_accuracy: 0.4062
# Epoch 20/100
# 21/21 [==============================] - 6s 291ms/step - loss: 0.3851 - accuracy: 0.8824 - val_loss: 4.6890 - val_accuracy: 0.4844
# Epoch 21/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.5061 - accuracy: 0.8452 - val_loss: 3.4133 - val_accuracy: 0.6094
# Epoch 22/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.5789 - accuracy: 0.8173 - val_loss: 4.6239 - val_accuracy: 0.5000
# Epoch 23/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5197 - accuracy: 0.8328 - val_loss: 4.6894 - val_accuracy: 0.4531
# Epoch 24/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.4220 - accuracy: 0.8885 - val_loss: 4.4047 - val_accuracy: 0.5469
# Epoch 25/100
# 21/21 [==============================] - 6s 301ms/step - loss: 0.2343 - accuracy: 0.9256 - val_loss: 4.4932 - val_accuracy: 0.4844
# Epoch 26/100
# 21/21 [==============================] - 2s 101ms/step - loss: 0.5275 - accuracy: 0.8669 - val_loss: 4.2614 - val_accuracy: 0.4219
# Epoch 27/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.4187 - accuracy: 0.8607 - val_loss: 3.6132 - val_accuracy: 0.3594
# Epoch 28/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5193 - accuracy: 0.8297 - val_loss: 3.6435 - val_accuracy: 0.5000
# Epoch 29/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.4088 - accuracy: 0.8762 - val_loss: 3.4837 - val_accuracy: 0.4219
# Epoch 30/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3896 - accuracy: 0.8793 - val_loss: 3.8524 - val_accuracy: 0.4531
# Epoch 31/100
# 21/21 [==============================] - 6s 295ms/step - loss: 0.4857 - accuracy: 0.8731 - val_loss: 4.4869 - val_accuracy: 0.5312
# Epoch 32/100
# 21/21 [==============================] - 2s 101ms/step - loss: 0.3107 - accuracy: 0.9102 - val_loss: 3.9546 - val_accuracy: 0.6094
# Epoch 33/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2137 - accuracy: 0.9319 - val_loss: 3.7382 - val_accuracy: 0.6250
# Epoch 34/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2174 - accuracy: 0.9319 - val_loss: 3.5800 - val_accuracy: 0.6250
# Epoch 35/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2995 - accuracy: 0.9319 - val_loss: 3.4809 - val_accuracy: 0.5938
# Epoch 36/100
# 21/21 [==============================] - 6s 296ms/step - loss: 0.2266 - accuracy: 0.9288 - val_loss: 3.4179 - val_accuracy: 0.5938
# Epoch 37/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2065 - accuracy: 0.9288 - val_loss: 3.4453 - val_accuracy: 0.6094
# Epoch 38/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2227 - accuracy: 0.9288 - val_loss: 3.4285 - val_accuracy: 0.5938
# Epoch 39/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3512 - accuracy: 0.9009 - val_loss: 4.2657 - val_accuracy: 0.3906
# Epoch 40/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3939 - accuracy: 0.8854 - val_loss: 3.9836 - val_accuracy: 0.5938
# Epoch 41/100
# 21/21 [==============================] - 6s 293ms/step - loss: 0.3140 - accuracy: 0.9009 - val_loss: 4.4557 - val_accuracy: 0.5156
# Epoch 42/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.3552 - accuracy: 0.8885 - val_loss: 3.3734 - val_accuracy: 0.3906
# Epoch 43/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2818 - accuracy: 0.9133 - val_loss: 3.7204 - val_accuracy: 0.4219
# Epoch 44/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2701 - accuracy: 0.9102 - val_loss: 4.1255 - val_accuracy: 0.4688
# Epoch 45/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.5472 - accuracy: 0.8638 - val_loss: 4.1989 - val_accuracy: 0.4531
# Epoch 46/100
# 21/21 [==============================] - 6s 292ms/step - loss: 0.3317 - accuracy: 0.9009 - val_loss: 3.9710 - val_accuracy: 0.4375
# Epoch 47/100
# 21/21 [==============================] - 2s 99ms/step - loss: 0.3034 - accuracy: 0.9040 - val_loss: 4.1791 - val_accuracy: 0.4375
# Epoch 48/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2495 - accuracy: 0.9226 - val_loss: 4.7086 - val_accuracy: 0.2656
# Epoch 49/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.5420 - accuracy: 0.8266 - val_loss: 4.0828 - val_accuracy: 0.2344
# Epoch 50/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.6990 - accuracy: 0.8204 - val_loss: 5.4827 - val_accuracy: 0.1562
# Epoch 51/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5032 - accuracy: 0.8483 - val_loss: 4.8469 - val_accuracy: 0.2188
# Epoch 52/100
# 21/21 [==============================] - 3s 120ms/step - loss: 0.4006 - accuracy: 0.8731 - val_loss: 4.0957 - val_accuracy: 0.4219
# Epoch 53/100
# 21/21 [==============================] - 4s 161ms/step - loss: 0.2891 - accuracy: 0.9102 - val_loss: 4.3198 - val_accuracy: 0.4375
# Epoch 54/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3086 - accuracy: 0.9009 - val_loss: 4.7839 - val_accuracy: 0.3906
# Epoch 55/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.4701 - accuracy: 0.8669 - val_loss: 3.9559 - val_accuracy: 0.4531
# Epoch 56/100
# 21/21 [==============================] - 5s 253ms/step - loss: 0.3186 - accuracy: 0.8978 - val_loss: 4.0610 - val_accuracy: 0.5312
# Epoch 57/100
# 21/21 [==============================] - 3s 104ms/step - loss: 0.2457 - accuracy: 0.9164 - val_loss: 4.1043 - val_accuracy: 0.5781
# Epoch 58/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2668 - accuracy: 0.9102 - val_loss: 4.0727 - val_accuracy: 0.5625
# Epoch 59/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2709 - accuracy: 0.9133 - val_loss: 4.5341 - val_accuracy: 0.4375
# Epoch 60/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3369 - accuracy: 0.8916 - val_loss: 4.2940 - val_accuracy: 0.5000
# Epoch 61/100
# 21/21 [==============================] - 6s 292ms/step - loss: 0.2452 - accuracy: 0.9164 - val_loss: 4.6007 - val_accuracy: 0.5469
# Epoch 62/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2337 - accuracy: 0.9319 - val_loss: 5.1279 - val_accuracy: 0.5469
# Epoch 63/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2388 - accuracy: 0.9381 - val_loss: 5.1893 - val_accuracy: 0.5312
# Epoch 64/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2736 - accuracy: 0.9133 - val_loss: 5.2286 - val_accuracy: 0.5156
# Epoch 65/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3652 - accuracy: 0.8947 - val_loss: 2.8359 - val_accuracy: 0.0781
# Epoch 66/100
# 21/21 [==============================] - 6s 293ms/step - loss: 1.2737 - accuracy: 0.6192 - val_loss: 2.8372 - val_accuracy: 0.0781
# Epoch 67/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5737 - accuracy: 0.8235 - val_loss: 3.9576 - val_accuracy: 0.1094
# Epoch 68/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.6111 - accuracy: 0.8111 - val_loss: 5.0824 - val_accuracy: 0.2031
# Epoch 69/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.5081 - accuracy: 0.8483 - val_loss: 5.4425 - val_accuracy: 0.2500
# Epoch 70/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.3981 - accuracy: 0.8669 - val_loss: 5.4498 - val_accuracy: 0.1875
# Epoch 71/100
# 21/21 [==============================] - 6s 292ms/step - loss: 0.3645 - accuracy: 0.8700 - val_loss: 4.5670 - val_accuracy: 0.2969
# Epoch 72/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2919 - accuracy: 0.9164 - val_loss: 3.2961 - val_accuracy: 0.2031
# Epoch 73/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.3598 - accuracy: 0.9137 - val_loss: 3.1254 - val_accuracy: 0.2656
# Epoch 74/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3343 - accuracy: 0.9133 - val_loss: 4.1093 - val_accuracy: 0.4531
# Epoch 75/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2698 - accuracy: 0.9164 - val_loss: 3.5619 - val_accuracy: 0.4531
# Epoch 76/100
# 21/21 [==============================] - 6s 292ms/step - loss: 0.3371 - accuracy: 0.9164 - val_loss: 4.3659 - val_accuracy: 0.4219
# Epoch 77/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2465 - accuracy: 0.9195 - val_loss: 4.0462 - val_accuracy: 0.6250
# Epoch 78/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2340 - accuracy: 0.9288 - val_loss: 4.4427 - val_accuracy: 0.5469
# Epoch 79/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2895 - accuracy: 0.9018 - val_loss: 4.7670 - val_accuracy: 0.4688
# Epoch 80/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3287 - accuracy: 0.9009 - val_loss: 5.1756 - val_accuracy: 0.3125
# Epoch 81/100
# 21/21 [==============================] - 6s 282ms/step - loss: 0.3055 - accuracy: 0.9195 - val_loss: 3.8308 - val_accuracy: 0.4219
# Epoch 82/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3832 - accuracy: 0.8720 - val_loss: 3.0808 - val_accuracy: 0.3906
# Epoch 83/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3718 - accuracy: 0.8854 - val_loss: 3.4618 - val_accuracy: 0.5156
# Epoch 84/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3019 - accuracy: 0.9009 - val_loss: 4.2973 - val_accuracy: 0.5781
# Epoch 85/100
# 21/21 [==============================] - 6s 296ms/step - loss: 0.4476 - accuracy: 0.8669 - val_loss: 4.6781 - val_accuracy: 0.2812
# Epoch 86/100
# 21/21 [==============================] - 2s 111ms/step - loss: 0.4781 - accuracy: 0.8638 - val_loss: 4.2612 - val_accuracy: 0.4219
# Epoch 87/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3241 - accuracy: 0.9040 - val_loss: 3.7965 - val_accuracy: 0.5625
# Epoch 88/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3824 - accuracy: 0.9133 - val_loss: 4.0961 - val_accuracy: 0.5781
# Epoch 89/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3869 - accuracy: 0.8916 - val_loss: 3.1410 - val_accuracy: 0.0781
# Epoch 90/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.5408 - accuracy: 0.8669 - val_loss: 3.2566 - val_accuracy: 0.2656
# Epoch 91/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.6047 - accuracy: 0.8576 - val_loss: 4.4064 - val_accuracy: 0.3906
# Epoch 92/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3884 - accuracy: 0.8885 - val_loss: 4.2339 - val_accuracy: 0.5156
# Epoch 93/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2706 - accuracy: 0.9288 - val_loss: 3.9930 - val_accuracy: 0.5625
# Epoch 94/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2379 - accuracy: 0.9350 - val_loss: 3.8505 - val_accuracy: 0.4688
# Epoch 95/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2224 - accuracy: 0.9381 - val_loss: 4.0161 - val_accuracy: 0.4688
# Epoch 96/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2182 - accuracy: 0.9350 - val_loss: 4.4473 - val_accuracy: 0.5312
# Epoch 97/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2774 - accuracy: 0.9102 - val_loss: 4.3458 - val_accuracy: 0.4531
# Epoch 98/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2728 - accuracy: 0.9195 - val_loss: 5.0005 - val_accuracy: 0.4531
# Epoch 99/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2292 - accuracy: 0.9350 - val_loss: 4.8610 - val_accuracy: 0.5000
# Epoch 100/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2469 - accuracy: 0.9288 - val_loss: 4.7316 - val_accuracy: 0.5156
# 22/22 [==============================] - 1s 31ms/step - loss: 0.4599 - accuracy: 0.8584
# 5/5 [==============================] - 0s 31ms/step - loss: 3.9026 - accuracy: 0.5897
# Fold 2:
# Train accuracy: 0.8584070801734924, Validation accuracy: 0.5897436141967773
# Training time for fold 2: 503.30604791641235 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2194 - accuracy: 0.9412 - val_loss: 4.3765 - val_accuracy: 0.5312
# Epoch 2/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.1964 - accuracy: 0.9474 - val_loss: 4.1393 - val_accuracy: 0.6094
# Epoch 3/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2042 - accuracy: 0.9381 - val_loss: 4.3311 - val_accuracy: 0.6250
# Epoch 4/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2112 - accuracy: 0.9412 - val_loss: 4.2614 - val_accuracy: 0.6250
# Epoch 5/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.1934 - accuracy: 0.9443 - val_loss: 4.2307 - val_accuracy: 0.6406
# Epoch 6/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2004 - accuracy: 0.9443 - val_loss: 4.3061 - val_accuracy: 0.6250
# Epoch 7/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.1907 - accuracy: 0.9524 - val_loss: 4.2778 - val_accuracy: 0.6250
# Epoch 8/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.1894 - accuracy: 0.9536 - val_loss: 4.3343 - val_accuracy: 0.5781
# Epoch 9/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2567 - accuracy: 0.9350 - val_loss: 4.5639 - val_accuracy: 0.5781
# Epoch 10/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2544 - accuracy: 0.9345 - val_loss: 4.2170 - val_accuracy: 0.5781
# Epoch 11/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3328 - accuracy: 0.9009 - val_loss: 4.4782 - val_accuracy: 0.5938
# Epoch 12/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2336 - accuracy: 0.9288 - val_loss: 4.5950 - val_accuracy: 0.5938
# Epoch 13/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2926 - accuracy: 0.9257 - val_loss: 4.3095 - val_accuracy: 0.5781
# Epoch 14/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2972 - accuracy: 0.9164 - val_loss: 4.6667 - val_accuracy: 0.5781
# Epoch 15/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.4287 - accuracy: 0.8638 - val_loss: 8.8324 - val_accuracy: 0.1875
# Epoch 16/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3755 - accuracy: 0.8885 - val_loss: 7.5970 - val_accuracy: 0.3750
# Epoch 17/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3421 - accuracy: 0.9164 - val_loss: 6.5928 - val_accuracy: 0.4375
# Epoch 18/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3129 - accuracy: 0.9226 - val_loss: 7.4168 - val_accuracy: 0.1406
# Epoch 19/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2617 - accuracy: 0.9412 - val_loss: 6.8874 - val_accuracy: 0.2500
# Epoch 20/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2541 - accuracy: 0.9350 - val_loss: 6.2820 - val_accuracy: 0.3594
# Epoch 21/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2426 - accuracy: 0.9319 - val_loss: 6.3549 - val_accuracy: 0.3906
# Epoch 22/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3559 - accuracy: 0.9133 - val_loss: 6.2001 - val_accuracy: 0.4219
# Epoch 23/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3002 - accuracy: 0.9195 - val_loss: 5.3124 - val_accuracy: 0.4688
# Epoch 24/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3050 - accuracy: 0.9133 - val_loss: 5.3530 - val_accuracy: 0.5000
# Epoch 25/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.3861 - accuracy: 0.8988 - val_loss: 5.2675 - val_accuracy: 0.5312
# Epoch 26/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3153 - accuracy: 0.9040 - val_loss: 4.9498 - val_accuracy: 0.5625
# Epoch 27/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2211 - accuracy: 0.9257 - val_loss: 4.9003 - val_accuracy: 0.5781
# Epoch 28/100
# 21/21 [==============================] - 9s 431ms/step - loss: 0.3233 - accuracy: 0.8978 - val_loss: 5.9422 - val_accuracy: 0.2031
# Epoch 29/100
# 21/21 [==============================] - 2s 101ms/step - loss: 0.3267 - accuracy: 0.8885 - val_loss: 5.6729 - val_accuracy: 0.2656
# Epoch 30/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.4416 - accuracy: 0.8885 - val_loss: 6.0146 - val_accuracy: 0.1562
# Epoch 31/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.4135 - accuracy: 0.8916 - val_loss: 4.5158 - val_accuracy: 0.3438
# Epoch 32/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3777 - accuracy: 0.8929 - val_loss: 4.1028 - val_accuracy: 0.6250
# Epoch 33/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3566 - accuracy: 0.9071 - val_loss: 4.1533 - val_accuracy: 0.5625
# Epoch 34/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3336 - accuracy: 0.8916 - val_loss: 4.2518 - val_accuracy: 0.5938
# Epoch 35/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2686 - accuracy: 0.9164 - val_loss: 5.9844 - val_accuracy: 0.2500
# Epoch 36/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2145 - accuracy: 0.9350 - val_loss: 5.5079 - val_accuracy: 0.1406
# Epoch 37/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2748 - accuracy: 0.9164 - val_loss: 5.0697 - val_accuracy: 0.1875
# Epoch 38/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2024 - accuracy: 0.9381 - val_loss: 5.4787 - val_accuracy: 0.1562
# Epoch 39/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2121 - accuracy: 0.9257 - val_loss: 5.5005 - val_accuracy: 0.2969
# Epoch 40/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2169 - accuracy: 0.9381 - val_loss: 6.0280 - val_accuracy: 0.2344
# Epoch 41/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2393 - accuracy: 0.9350 - val_loss: 6.6315 - val_accuracy: 0.1406
# Epoch 42/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2723 - accuracy: 0.9164 - val_loss: 5.6340 - val_accuracy: 0.1406
# Epoch 43/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2776 - accuracy: 0.9102 - val_loss: 5.3842 - val_accuracy: 0.2812
# Epoch 44/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2403 - accuracy: 0.9226 - val_loss: 5.1678 - val_accuracy: 0.3750
# Epoch 45/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2456 - accuracy: 0.9164 - val_loss: 5.4143 - val_accuracy: 0.3906
# Epoch 46/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2194 - accuracy: 0.9195 - val_loss: 5.6190 - val_accuracy: 0.4375
# Epoch 47/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2433 - accuracy: 0.9226 - val_loss: 5.7851 - val_accuracy: 0.4688
# Epoch 48/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2697 - accuracy: 0.9102 - val_loss: 5.4343 - val_accuracy: 0.5156
# Epoch 49/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2567 - accuracy: 0.9133 - val_loss: 5.6158 - val_accuracy: 0.5000
# Epoch 50/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2422 - accuracy: 0.9133 - val_loss: 5.7374 - val_accuracy: 0.5312
# Epoch 51/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2652 - accuracy: 0.9102 - val_loss: 5.7672 - val_accuracy: 0.5000
# Epoch 52/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2506 - accuracy: 0.9164 - val_loss: 6.4491 - val_accuracy: 0.4531
# Epoch 53/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2396 - accuracy: 0.9195 - val_loss: 6.3872 - val_accuracy: 0.4844
# Epoch 54/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2967 - accuracy: 0.9133 - val_loss: 6.5948 - val_accuracy: 0.5625
# Epoch 55/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2845 - accuracy: 0.9257 - val_loss: 6.3597 - val_accuracy: 0.4844
# Epoch 56/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2293 - accuracy: 0.9226 - val_loss: 5.8269 - val_accuracy: 0.5312
# Epoch 57/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2364 - accuracy: 0.9195 - val_loss: 7.2286 - val_accuracy: 0.2188
# Epoch 58/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3748 - accuracy: 0.8947 - val_loss: 6.0378 - val_accuracy: 0.1875
# Epoch 59/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3213 - accuracy: 0.9164 - val_loss: 6.1572 - val_accuracy: 0.1719
# Epoch 60/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3035 - accuracy: 0.9195 - val_loss: 5.6066 - val_accuracy: 0.3750
# Epoch 61/100
# 21/21 [==============================] - 2s 111ms/step - loss: 0.2645 - accuracy: 0.9412 - val_loss: 5.9412 - val_accuracy: 0.4062
# Epoch 62/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2323 - accuracy: 0.9443 - val_loss: 5.5857 - val_accuracy: 0.5000
# Epoch 63/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.1945 - accuracy: 0.9505 - val_loss: 5.1392 - val_accuracy: 0.4531
# Epoch 64/100
# 21/21 [==============================] - 10s 488ms/step - loss: 0.2615 - accuracy: 0.9226 - val_loss: 5.0089 - val_accuracy: 0.5469
# Epoch 65/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2347 - accuracy: 0.9257 - val_loss: 4.9181 - val_accuracy: 0.5625
# Epoch 66/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3203 - accuracy: 0.9040 - val_loss: 4.3112 - val_accuracy: 0.5156
# Epoch 67/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2841 - accuracy: 0.9226 - val_loss: 4.1563 - val_accuracy: 0.5625
# Epoch 68/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2725 - accuracy: 0.9164 - val_loss: 4.3313 - val_accuracy: 0.5781
# Epoch 69/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2364 - accuracy: 0.9226 - val_loss: 4.3619 - val_accuracy: 0.6406
# Epoch 70/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2311 - accuracy: 0.9226 - val_loss: 4.4683 - val_accuracy: 0.6406
# Epoch 71/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2071 - accuracy: 0.9288 - val_loss: 4.6245 - val_accuracy: 0.6406
# Epoch 72/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2770 - accuracy: 0.9257 - val_loss: 4.5861 - val_accuracy: 0.6250
# Epoch 73/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.4467 - accuracy: 0.8793 - val_loss: 5.8468 - val_accuracy: 0.2188
# Epoch 74/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2733 - accuracy: 0.9040 - val_loss: 5.7870 - val_accuracy: 0.2188
# Epoch 75/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2531 - accuracy: 0.9102 - val_loss: 5.5377 - val_accuracy: 0.2812
# Epoch 76/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2435 - accuracy: 0.9195 - val_loss: 5.1554 - val_accuracy: 0.3594
# Epoch 77/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3388 - accuracy: 0.9257 - val_loss: 5.3561 - val_accuracy: 0.3906
# Epoch 78/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2406 - accuracy: 0.9164 - val_loss: 4.8249 - val_accuracy: 0.4844
# Epoch 79/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2285 - accuracy: 0.9164 - val_loss: 4.7174 - val_accuracy: 0.5469
# Epoch 80/100
# 21/21 [==============================] - 2s 108ms/step - loss: 0.2247 - accuracy: 0.9164 - val_loss: 4.7277 - val_accuracy: 0.5625
# Epoch 81/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2128 - accuracy: 0.9226 - val_loss: 4.6581 - val_accuracy: 0.5938
# Epoch 82/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.1943 - accuracy: 0.9350 - val_loss: 4.6415 - val_accuracy: 0.5938
# Epoch 83/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.1791 - accuracy: 0.9350 - val_loss: 4.6471 - val_accuracy: 0.5938
# Epoch 84/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2119 - accuracy: 0.9257 - val_loss: 4.8460 - val_accuracy: 0.5625
# Epoch 85/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2365 - accuracy: 0.9195 - val_loss: 5.1345 - val_accuracy: 0.5938
# Epoch 86/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2021 - accuracy: 0.9319 - val_loss: 5.0677 - val_accuracy: 0.5938
# Epoch 87/100
# 21/21 [==============================] - 11s 565ms/step - loss: 0.2242 - accuracy: 0.9257 - val_loss: 5.2030 - val_accuracy: 0.5781
# Epoch 88/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2364 - accuracy: 0.9257 - val_loss: 5.1816 - val_accuracy: 0.5469
# Epoch 89/100
# 21/21 [==============================] - 2s 109ms/step - loss: 0.2358 - accuracy: 0.9164 - val_loss: 5.9322 - val_accuracy: 0.3594
# Epoch 90/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.4581 - accuracy: 0.8854 - val_loss: 5.7478 - val_accuracy: 0.3594
# Epoch 91/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2503 - accuracy: 0.9137 - val_loss: 5.2696 - val_accuracy: 0.4531
# Epoch 92/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2024 - accuracy: 0.9288 - val_loss: 4.6856 - val_accuracy: 0.5781
# Epoch 93/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.1885 - accuracy: 0.9319 - val_loss: 4.6497 - val_accuracy: 0.5625
# Epoch 94/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2724 - accuracy: 0.9164 - val_loss: 4.5598 - val_accuracy: 0.5625
# Epoch 95/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2491 - accuracy: 0.9102 - val_loss: 4.3050 - val_accuracy: 0.5469
# Epoch 96/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2283 - accuracy: 0.9288 - val_loss: 4.3392 - val_accuracy: 0.5781
# Epoch 97/100
# 21/21 [==============================] - 2s 115ms/step - loss: 0.1701 - accuracy: 0.9405 - val_loss: 4.3155 - val_accuracy: 0.5938
# Epoch 98/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2101 - accuracy: 0.9288 - val_loss: 4.2870 - val_accuracy: 0.6250
# Epoch 99/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2335 - accuracy: 0.9226 - val_loss: 4.1194 - val_accuracy: 0.6094
# Epoch 100/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2223 - accuracy: 0.9257 - val_loss: 4.4017 - val_accuracy: 0.5000
# 22/22 [==============================] - 1s 38ms/step - loss: 0.4494 - accuracy: 0.8496
# 5/5 [==============================] - 0s 32ms/step - loss: 3.8540 - accuracy: 0.5256
# Fold 3:
# Train accuracy: 0.8495575189590454, Validation accuracy: 0.5256410241127014
# Training time for fold 3: 748.3964240550995 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2211 - accuracy: 0.9350 - val_loss: 4.4906 - val_accuracy: 0.5469
# Epoch 2/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2444 - accuracy: 0.9474 - val_loss: 4.5081 - val_accuracy: 0.6094
# Epoch 3/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.1823 - accuracy: 0.9443 - val_loss: 4.3389 - val_accuracy: 0.6406
# Epoch 4/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2054 - accuracy: 0.9412 - val_loss: 4.3838 - val_accuracy: 0.6406
# Epoch 5/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2063 - accuracy: 0.9381 - val_loss: 4.3732 - val_accuracy: 0.6094
# Epoch 6/100
# 21/21 [==============================] - 2s 115ms/step - loss: 0.2720 - accuracy: 0.9195 - val_loss: 4.4119 - val_accuracy: 0.5625
# Epoch 7/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.4496 - accuracy: 0.9133 - val_loss: 4.1583 - val_accuracy: 0.6406
# Epoch 8/100
# 21/21 [==============================] - 2s 107ms/step - loss: 0.2726 - accuracy: 0.9257 - val_loss: 4.2095 - val_accuracy: 0.6562
# Epoch 9/100
# 21/21 [==============================] - 10s 500ms/step - loss: 0.2101 - accuracy: 0.9505 - val_loss: 4.3544 - val_accuracy: 0.6094
# Epoch 10/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2005 - accuracy: 0.9435 - val_loss: 4.3433 - val_accuracy: 0.6094
# Epoch 11/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2143 - accuracy: 0.9381 - val_loss: 4.2188 - val_accuracy: 0.6094
# Epoch 12/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.1749 - accuracy: 0.9598 - val_loss: 4.2310 - val_accuracy: 0.6250
# Epoch 13/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2013 - accuracy: 0.9412 - val_loss: 4.3291 - val_accuracy: 0.6094
# Epoch 14/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2008 - accuracy: 0.9536 - val_loss: 4.2890 - val_accuracy: 0.5781
# Epoch 15/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2579 - accuracy: 0.9319 - val_loss: 4.5873 - val_accuracy: 0.5781
# Epoch 16/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2798 - accuracy: 0.9381 - val_loss: 4.7565 - val_accuracy: 0.5781
# Epoch 17/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2643 - accuracy: 0.9195 - val_loss: 5.2004 - val_accuracy: 0.5938
# Epoch 18/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2554 - accuracy: 0.9257 - val_loss: 4.8337 - val_accuracy: 0.5625
# Epoch 19/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2441 - accuracy: 0.9350 - val_loss: 4.7868 - val_accuracy: 0.5938
# Epoch 20/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2334 - accuracy: 0.9195 - val_loss: 4.9507 - val_accuracy: 0.5625
# Epoch 21/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2299 - accuracy: 0.9164 - val_loss: 5.4238 - val_accuracy: 0.5469
# Epoch 22/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2934 - accuracy: 0.9102 - val_loss: 4.5454 - val_accuracy: 0.5781
# Epoch 23/100
# ...
# Epoch 97/100
# 21/21 [==============================] - 7s 308ms/step - loss: 0.2433 - accuracy: 0.9164 - val_loss: 5.4134 - val_accuracy: 0.4531
# Epoch 98/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2960 - accuracy: 0.9164 - val_loss: 5.6160 - val_accuracy: 0.4844
# Epoch 99/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2997 - accuracy: 0.9195 - val_loss: 5.8735 - val_accuracy: 0.5312
# Epoch 100/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2985 - accuracy: 0.9009 - val_loss: 5.7126 - val_accuracy: 0.5938
# 22/22 [==============================] - 1s 31ms/step - loss: 0.2182 - accuracy: 0.9322
# 5/5 [==============================] - 0s 34ms/step - loss: 4.7098 - accuracy: 0.6538
# Fold 4:
# Train accuracy: 0.9321534037590027, Validation accuracy: 0.6538461446762085
# Training time for fold 4: 1008.2182352542877 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2403 - accuracy: 0.9164 - val_loss: 5.8613 - val_accuracy: 0.6094
# Epoch 2/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3043 - accuracy: 0.8947 - val_loss: 6.5364 - val_accuracy: 0.5625
# Epoch 3/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.3317 - accuracy: 0.9009 - val_loss: 4.8426 - val_accuracy: 0.5625
# Epoch 4/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2323 - accuracy: 0.9350 - val_loss: 4.3522 - val_accuracy: 0.5469
# Epoch 5/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2702 - accuracy: 0.9195 - val_loss: 4.4302 - val_accuracy: 0.5781
# Epoch 6/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2072 - accuracy: 0.9319 - val_loss: 4.7354 - val_accuracy: 0.5938
# Epoch 7/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3081 - accuracy: 0.9195 - val_loss: 5.3261 - val_accuracy: 0.6094
# Epoch 8/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2338 - accuracy: 0.9257 - val_loss: 5.6424 - val_accuracy: 0.5781
# Epoch 9/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3234 - accuracy: 0.9009 - val_loss: 6.0703 - val_accuracy: 0.5938
# Epoch 10/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2813 - accuracy: 0.9195 - val_loss: 5.8429 - val_accuracy: 0.6250
# Epoch 11/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2045 - accuracy: 0.9412 - val_loss: 5.9761 - val_accuracy: 0.5938
# Epoch 12/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2234 - accuracy: 0.9226 - val_loss: 6.1163 - val_accuracy: 0.6094
# Epoch 13/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.1945 - accuracy: 0.9412 - val_loss: 6.5462 - val_accuracy: 0.6250
# Epoch 14/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.1947 - accuracy: 0.9412 - val_loss: 6.4419 - val_accuracy: 0.6094
# Epoch 15/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.1909 - accuracy: 0.9412 - val_loss: 6.2500 - val_accuracy: 0.5938
# Epoch 16/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2228 - accuracy: 0.9381 - val_loss: 6.6485 - val_accuracy: 0.6094
# Epoch 17/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2115 - accuracy: 0.9319 - val_loss: 6.6201 - val_accuracy: 0.6094
# Epoch 18/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2003 - accuracy: 0.9443 - val_loss: 6.8237 - val_accuracy: 0.6094
# Epoch 19/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.1892 - accuracy: 0.9443 - val_loss: 6.8619 - val_accuracy: 0.6094
# Epoch 20/100
# 21/21 [==============================] - 9s 407ms/step - loss: 0.2184 - accuracy: 0.9443 - val_loss: 6.4250 - val_accuracy: 0.6094
# Epoch 21/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.1936 - accuracy: 0.9443 - val_loss: 6.0287 - val_accuracy: 0.5781
# Epoch 22/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.1866 - accuracy: 0.9412 - val_loss: 5.3456 - val_accuracy: 0.5938
# Epoch 23/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.1857 - accuracy: 0.9443 - val_loss: 5.0859 - val_accuracy: 0.6094
# Epoch 24/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2424 - accuracy: 0.9195 - val_loss: 4.9749 - val_accuracy: 0.6250
# Epoch 25/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3440 - accuracy: 0.8916 - val_loss: 4.8637 - val_accuracy: 0.6094
# Epoch 26/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3598 - accuracy: 0.8947 - val_loss: 5.5349 - val_accuracy: 0.5938
# Epoch 27/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3342 - accuracy: 0.8978 - val_loss: 6.0480 - val_accuracy: 0.6094
# Epoch 28/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3763 - accuracy: 0.8854 - val_loss: 7.0162 - val_accuracy: 0.5781
# Epoch 29/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3418 - accuracy: 0.9009 - val_loss: 6.4005 - val_accuracy: 0.6250
# Epoch 30/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3160 - accuracy: 0.9040 - val_loss: 6.0913 - val_accuracy: 0.6406
# Epoch 31/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.3255 - accuracy: 0.8899 - val_loss: 5.6858 - val_accuracy: 0.6406
# Epoch 32/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2642 - accuracy: 0.9195 - val_loss: 6.3608 - val_accuracy: 0.6250
# Epoch 33/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2005 - accuracy: 0.9288 - val_loss: 6.5761 - val_accuracy: 0.6250
# Epoch 34/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2464 - accuracy: 0.9226 - val_loss: 5.5019 - val_accuracy: 0.5781
# Epoch 35/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2361 - accuracy: 0.9164 - val_loss: 2.9185 - val_accuracy: 0.0625
# Epoch 36/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3079 - accuracy: 0.8978 - val_loss: 2.7676 - val_accuracy: 0.0938
# Epoch 37/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2328 - accuracy: 0.9257 - val_loss: 3.3663 - val_accuracy: 0.3125
# Epoch 38/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2364 - accuracy: 0.9195 - val_loss: 2.7487 - val_accuracy: 0.4688
# Epoch 39/100
# 21/21 [==============================] - 10s 477ms/step - loss: 0.2408 - accuracy: 0.9226 - val_loss: 2.5624 - val_accuracy: 0.6406
# Epoch 40/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2237 - accuracy: 0.9226 - val_loss: 3.0662 - val_accuracy: 0.5938
# Epoch 41/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2108 - accuracy: 0.9257 - val_loss: 3.0336 - val_accuracy: 0.5625
# Epoch 42/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2102 - accuracy: 0.9319 - val_loss: 3.4823 - val_accuracy: 0.5469
# Epoch 43/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2100 - accuracy: 0.9319 - val_loss: 5.1004 - val_accuracy: 0.6406
# Epoch 44/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2592 - accuracy: 0.9164 - val_loss: 5.1602 - val_accuracy: 0.6406
# Epoch 45/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3302 - accuracy: 0.9009 - val_loss: 5.3336 - val_accuracy: 0.6719
# Epoch 46/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3178 - accuracy: 0.9009 - val_loss: 5.7118 - val_accuracy: 0.6406
# Epoch 47/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3050 - accuracy: 0.9071 - val_loss: 5.1573 - val_accuracy: 0.6250
# Epoch 48/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2997 - accuracy: 0.9102 - val_loss: 5.5203 - val_accuracy: 0.6406
# Epoch 49/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2274 - accuracy: 0.9257 - val_loss: 6.0442 - val_accuracy: 0.6406
# Epoch 50/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2536 - accuracy: 0.9102 - val_loss: 5.0879 - val_accuracy: 0.6250
# Epoch 51/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2623 - accuracy: 0.9133 - val_loss: 4.6253 - val_accuracy: 0.6094
# Epoch 52/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2730 - accuracy: 0.9133 - val_loss: 4.0622 - val_accuracy: 0.5781
# Epoch 53/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.3231 - accuracy: 0.9009 - val_loss: 4.5312 - val_accuracy: 0.6406
# Epoch 54/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2594 - accuracy: 0.9133 - val_loss: 3.6341 - val_accuracy: 0.5938
# Epoch 55/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2610 - accuracy: 0.9133 - val_loss: 3.8197 - val_accuracy: 0.6250
# Epoch 56/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2607 - accuracy: 0.9257 - val_loss: 5.1593 - val_accuracy: 0.5781
# Epoch 57/100
# 21/21 [==============================] - 2s 107ms/step - loss: 0.2200 - accuracy: 0.9257 - val_loss: 5.7910 - val_accuracy: 0.5469
# Epoch 58/100
# 21/21 [==============================] - 2s 112ms/step - loss: 0.2460 - accuracy: 0.9133 - val_loss: 5.4000 - val_accuracy: 0.5781
# Epoch 59/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.1915 - accuracy: 0.9350 - val_loss: 5.3808 - val_accuracy: 0.6406
# Epoch 60/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2102 - accuracy: 0.9319 - val_loss: 5.9113 - val_accuracy: 0.5312
# Epoch 61/100
# 21/21 [==============================] - 11s 545ms/step - loss: 0.4562 - accuracy: 0.8824 - val_loss: 6.1203 - val_accuracy: 0.2188
# Epoch 62/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3101 - accuracy: 0.9040 - val_loss: 5.5752 - val_accuracy: 0.4219
# Epoch 63/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3393 - accuracy: 0.8916 - val_loss: 5.5343 - val_accuracy: 0.5938
# Epoch 64/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3354 - accuracy: 0.8978 - val_loss: 5.3395 - val_accuracy: 0.5938
# Epoch 65/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2493 - accuracy: 0.9164 - val_loss: 5.4545 - val_accuracy: 0.5938
# Epoch 66/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2731 - accuracy: 0.9071 - val_loss: 5.3783 - val_accuracy: 0.6250
# Epoch 67/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2210 - accuracy: 0.9257 - val_loss: 5.2026 - val_accuracy: 0.6406
# Epoch 68/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2351 - accuracy: 0.9256 - val_loss: 3.9134 - val_accuracy: 0.6094
# Epoch 69/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2920 - accuracy: 0.9071 - val_loss: 3.2990 - val_accuracy: 0.6250
# Epoch 70/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2325 - accuracy: 0.9257 - val_loss: 3.8189 - val_accuracy: 0.6406
# Epoch 71/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2274 - accuracy: 0.9288 - val_loss: 4.4685 - val_accuracy: 0.6250
# Epoch 72/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2249 - accuracy: 0.9412 - val_loss: 4.4571 - val_accuracy: 0.6250
# Epoch 73/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2548 - accuracy: 0.9226 - val_loss: 4.5774 - val_accuracy: 0.6406
# Epoch 74/100
# 21/21 [==============================] - 2s 105ms/step - loss: 0.2325 - accuracy: 0.9381 - val_loss: 4.8106 - val_accuracy: 0.6250
# Epoch 75/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2216 - accuracy: 0.9350 - val_loss: 5.3734 - val_accuracy: 0.6094
# Epoch 76/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2345 - accuracy: 0.9319 - val_loss: 4.6510 - val_accuracy: 0.5625
# Epoch 77/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2951 - accuracy: 0.9288 - val_loss: 5.0135 - val_accuracy: 0.6094
# Epoch 78/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3644 - accuracy: 0.9226 - val_loss: 4.3077 - val_accuracy: 0.5938
# Epoch 79/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2846 - accuracy: 0.9226 - val_loss: 5.4853 - val_accuracy: 0.6250
# Epoch 80/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3747 - accuracy: 0.9164 - val_loss: 5.4001 - val_accuracy: 0.6094
# Epoch 81/100
# 21/21 [==============================] - 9s 436ms/step - loss: 0.3112 - accuracy: 0.9133 - val_loss: 5.3096 - val_accuracy: 0.6250
# Epoch 82/100
# 21/21 [==============================] - 2s 104ms/step - loss: 0.2800 - accuracy: 0.9288 - val_loss: 5.0928 - val_accuracy: 0.6094
# Epoch 83/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.3404 - accuracy: 0.9319 - val_loss: 5.7124 - val_accuracy: 0.5938
# Epoch 84/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2485 - accuracy: 0.9288 - val_loss: 5.7632 - val_accuracy: 0.5938
# Epoch 85/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2004 - accuracy: 0.9381 - val_loss: 5.7456 - val_accuracy: 0.5938
# Epoch 86/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2356 - accuracy: 0.9288 - val_loss: 5.5712 - val_accuracy: 0.6250
# Epoch 87/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2310 - accuracy: 0.9288 - val_loss: 4.8102 - val_accuracy: 0.5938
# Epoch 88/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2130 - accuracy: 0.9319 - val_loss: 4.7750 - val_accuracy: 0.6094
# Epoch 89/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2807 - accuracy: 0.9288 - val_loss: 4.6989 - val_accuracy: 0.6250
# Epoch 90/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2369 - accuracy: 0.9288 - val_loss: 4.8849 - val_accuracy: 0.6250
# Epoch 91/100
# 21/21 [==============================] - 2s 102ms/step - loss: 0.2007 - accuracy: 0.9381 - val_loss: 5.1069 - val_accuracy: 0.6406
# Epoch 92/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2305 - accuracy: 0.9288 - val_loss: 5.0610 - val_accuracy: 0.6250
# Epoch 93/100
# 21/21 [==============================] - 2s 112ms/step - loss: 0.2185 - accuracy: 0.9319 - val_loss: 5.0732 - val_accuracy: 0.6250
# Epoch 94/100
# 21/21 [==============================] - 2s 106ms/step - loss: 0.2164 - accuracy: 0.9319 - val_loss: 5.1847 - val_accuracy: 0.6250
# Epoch 95/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.3380 - accuracy: 0.9102 - val_loss: 3.6938 - val_accuracy: 0.6250
# Epoch 96/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2546 - accuracy: 0.9040 - val_loss: 4.2622 - val_accuracy: 0.6250
# Epoch 97/100
# 21/21 [==============================] - 2s 103ms/step - loss: 0.2267 - accuracy: 0.9319 - val_loss: 3.1706 - val_accuracy: 0.5781
# Epoch 98/100
# 21/21 [==============================] - 8s 397ms/step - loss: 0.2552 - accuracy: 0.9040 - val_loss: 3.8769 - val_accuracy: 0.5625
# Epoch 99/100
# 21/21 [==============================] - 3s 113ms/step - loss: 0.2696 - accuracy: 0.9137 - val_loss: 4.4876 - val_accuracy: 0.5781
# Epoch 100/100
# 21/21 [==============================] - 2s 107ms/step - loss: 0.3107 - accuracy: 0.8978 - val_loss: 3.5875 - val_accuracy: 0.5938
# 22/22 [==============================] - 1s 32ms/step - loss: 0.6801 - accuracy: 0.7965
# 5/5 [==============================] - 0s 42ms/step - loss: 3.0313 - accuracy: 0.6538
# Fold 5:
# Train accuracy: 0.7964601516723633, Validation accuracy: 0.6538461446762085
# Training time for fold 5: 1267.6872317790985 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 87.90560483932495 %
# Average Validation Accuracy: 60.51282048225403 %
# Average Training Time: 750.1123851299286
# Total Training Time: 1270.1591951847076

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsResnetkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+----------------------+----------------------+----------------------+---------+
# | Class |      Precision       |        Recall        |       F1 Score       | Support |
# +-------+----------------------+----------------------+----------------------+---------+
# |   0   |        0.125         | 0.10526315789473684  | 0.11428571428571428  |    19   |
# |   1   |         0.0          |         0.0          |         0.0          |    20   |
# |   10  | 0.08333333333333333  | 0.058823529411764705 | 0.06896551724137931  |    17   |
# |   2   | 0.047619047619047616 | 0.041666666666666664 | 0.044444444444444446 |    24   |
# |   3   | 0.07142857142857142  | 0.05263157894736842  | 0.06060606060606061  |    19   |
# |   4   |         0.0          |         0.0          |         0.0          |    20   |
# |   5   |         0.2          | 0.17647058823529413  |        0.1875        |    17   |
# |   6   | 0.14285714285714285  | 0.11764705882352941  | 0.12903225806451613  |    17   |
# |   7   | 0.06666666666666667  | 0.058823529411764705 |        0.0625        |    17   |
# |   8   | 0.05263157894736842  | 0.045454545454545456 | 0.04878048780487805  |    22   |
# |   9   | 0.11764705882352941  | 0.10526315789473684  |  0.1111111111111111  |    19   |
# |  box  | 0.05555555555555555  |         0.05         | 0.05263157894736842  |    20   |
# |  fun  |        0.0625        |         0.05         | 0.05555555555555555  |    20   |
# |  good | 0.05555555555555555  | 0.041666666666666664 | 0.047619047619047616 |    24   |
# |  grow |         0.0          |         0.0          |         0.0          |    20   |
# |  hero | 0.06329113924050633  | 0.22727272727272727  | 0.09900990099009901  |    22   |
# | trust | 0.05555555555555555  | 0.045454545454545456 |         0.05         |    22   |
# +-------+----------------------+----------------------+----------------------+---------+
#
# Validation Metrics:
# +-------+--------------------+--------+---------------------+---------+
# | Class |     Precision      | Recall |       F1 Score      | Support |
# +-------+--------------------+--------+---------------------+---------+
# |   0   |        1.0         |  0.5   |  0.6666666666666666 |    4    |
# |   1   |        1.0         |  0.6   |         0.75        |    5    |
# |   10  |        0.5         |  0.25  |  0.3333333333333333 |    4    |
# |   2   |        0.75        |  0.6   |  0.6666666666666666 |    5    |
# |   3   |        1.0         |  0.5   |  0.6666666666666666 |    4    |
# |   4   |        1.0         |  0.6   |         0.75        |    5    |
# |   5   |        0.25        |  0.25  |         0.25        |    4    |
# |   6   |        1.0         |  0.25  |         0.4         |    4    |
# |   7   |        1.0         |  0.25  |         0.4         |    4    |
# |   8   | 0.6666666666666666 |  0.8   |  0.7272727272727273 |    5    |
# |   9   |        0.75        |  0.75  |         0.75        |    4    |
# |  box  |        1.0         |  0.6   |         0.75        |    5    |
# |  fun  | 0.7142857142857143 |  1.0   |  0.8333333333333334 |    5    |
# |  good | 0.8333333333333334 |  1.0   |  0.9090909090909091 |    5    |
# |  grow | 0.8333333333333334 |  1.0   |  0.9090909090909091 |    5    |
# |  hero | 0.2777777777777778 |  1.0   | 0.43478260869565216 |    5    |
# | trust | 0.6666666666666666 |  0.8   |  0.7272727272727273 |    5    |
# +-------+--------------------+--------+---------------------+---------+
# Combined metrics saved to combined_metricsResnetkfold5.xlsx

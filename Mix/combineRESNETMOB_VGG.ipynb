# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # ResnetMobile_VGG

# %% [markdown]
# # Model Summary

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Concatenate
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2, VGG16
import time

# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Noise reduction 2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the MobileNetV2 model
mobilenet_model = MobileNetV2(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                              include_top=False,
                              weights='imagenet')

# Define the VGG16 model
vgg16_model = VGG16(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                    include_top=False,
                    weights='imagenet')

# Freeze the layers in both base models
mobilenet_model.trainable = False
vgg16_model.trainable = False

# Define input layer
input_layer = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

# Obtain outputs from both models
mobilenet_output = mobilenet_model(input_layer)
vgg16_output = vgg16_model(input_layer)

# Flatten the outputs
mobilenet_flatten = Flatten()(mobilenet_output)
vgg16_flatten = Flatten()(vgg16_output)

# Concatenate the outputs
concatenated = Concatenate()([mobilenet_flatten, vgg16_flatten])

# Add dense layers for classification
x = Dense(128, activation='relu')(concatenated)
output_layer = Dense(NUM_CLASSES, activation='softmax')(x)

# Create the model
combined_model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
combined_model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Found 417 images belonging to 17 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
combined_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 96, 72, 3)]  0           []
#
#  mobilenetv2_1.00_224 (Function  (None, 3, 3, 1280)  2257984     ['input_3[0][0]']
#  al)
#
#  vgg16 (Functional)             (None, 3, 2, 512)    14714688    ['input_3[0][0]']
#
#  flatten (Flatten)              (None, 11520)        0           ['mobilenetv2_1.00_224[0][0]']
#
#  flatten_1 (Flatten)            (None, 3072)         0           ['vgg16[0][0]']
#
#  concatenate (Concatenate)      (None, 14592)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense (Dense)                  (None, 128)          1867904     ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 17)           2193        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 18,842,769
# Trainable params: 1,870,097
# Non-trainable params: 16,972,672
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = datagen.flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = datagen.flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = combined_model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = combined_model.evaluate(train_generator)
    val_loss, val_acc = combined_model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    combined_model.save(f'resnetmobile_vgg_kfold({K_FOLDS})_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 8s 131ms/step - loss: 10.5673 - accuracy: 0.1269 - val_loss: 3.5803 - val_accuracy: 0.1719
# Epoch 2/100
# 21/21 [==============================] - 1s 41ms/step - loss: 2.7689 - accuracy: 0.1579 - val_loss: 2.7620 - val_accuracy: 0.1562
# Epoch 3/100
# 21/21 [==============================] - 1s 40ms/step - loss: 2.4763 - accuracy: 0.1765 - val_loss: 2.5016 - val_accuracy: 0.1875
# Epoch 4/100
# 21/21 [==============================] - 1s 40ms/step - loss: 2.2510 - accuracy: 0.2879 - val_loss: 2.4205 - val_accuracy: 0.2344
# Epoch 5/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.1027 - accuracy: 0.3251 - val_loss: 2.3835 - val_accuracy: 0.2188
# Epoch 6/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.9421 - accuracy: 0.3870 - val_loss: 2.1583 - val_accuracy: 0.3594
# Epoch 7/100
# 21/21 [==============================] - 1s 41ms/step - loss: 1.7361 - accuracy: 0.4830 - val_loss: 2.1872 - val_accuracy: 0.3438
# Epoch 8/100
# 21/21 [==============================] - 1s 41ms/step - loss: 1.5834 - accuracy: 0.4737 - val_loss: 2.2388 - val_accuracy: 0.3750
# Epoch 9/100
# 21/21 [==============================] - 1s 41ms/step - loss: 1.4736 - accuracy: 0.5511 - val_loss: 2.1101 - val_accuracy: 0.3125
# Epoch 10/100
# 21/21 [==============================] - 1s 39ms/step - loss: 1.1984 - accuracy: 0.6471 - val_loss: 2.1988 - val_accuracy: 0.4219
# Epoch 11/100
# 21/21 [==============================] - 1s 39ms/step - loss: 1.0117 - accuracy: 0.6656 - val_loss: 2.2511 - val_accuracy: 0.3906
# Epoch 12/100
# 21/21 [==============================] - 1s 39ms/step - loss: 1.0835 - accuracy: 0.6440 - val_loss: 1.9755 - val_accuracy: 0.4219
# Epoch 13/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.9362 - accuracy: 0.7152 - val_loss: 2.1146 - val_accuracy: 0.4844
# Epoch 14/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.7684 - accuracy: 0.7647 - val_loss: 2.3602 - val_accuracy: 0.4219
# Epoch 15/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.7089 - accuracy: 0.7771 - val_loss: 2.1467 - val_accuracy: 0.5156
# Epoch 16/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.5420 - accuracy: 0.8638 - val_loss: 2.0031 - val_accuracy: 0.5000
# Epoch 17/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.4432 - accuracy: 0.8899 - val_loss: 1.9588 - val_accuracy: 0.5781
# Epoch 18/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.4137 - accuracy: 0.9009 - val_loss: 2.3836 - val_accuracy: 0.4844
# Epoch 19/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3405 - accuracy: 0.9257 - val_loss: 1.9465 - val_accuracy: 0.5312
# Epoch 20/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.3025 - accuracy: 0.9381 - val_loss: 2.3301 - val_accuracy: 0.5781
# Epoch 21/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.2522 - accuracy: 0.9598 - val_loss: 1.9493 - val_accuracy: 0.5625
# Epoch 22/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2004 - accuracy: 0.9598 - val_loss: 2.0469 - val_accuracy: 0.5781
# Epoch 23/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.1809 - accuracy: 0.9690 - val_loss: 2.2664 - val_accuracy: 0.5781
# Epoch 24/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1586 - accuracy: 0.9783 - val_loss: 2.4198 - val_accuracy: 0.5938
# Epoch 25/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1376 - accuracy: 0.9814 - val_loss: 2.2765 - val_accuracy: 0.5781
# Epoch 26/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1446 - accuracy: 0.9783 - val_loss: 2.3211 - val_accuracy: 0.5625
# Epoch 27/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.1403 - accuracy: 0.9876 - val_loss: 2.5599 - val_accuracy: 0.5625
# Epoch 28/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1068 - accuracy: 0.9907 - val_loss: 2.2178 - val_accuracy: 0.6250
# Epoch 29/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1134 - accuracy: 0.9845 - val_loss: 2.3823 - val_accuracy: 0.6250
# Epoch 30/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0836 - accuracy: 0.9876 - val_loss: 2.2899 - val_accuracy: 0.5938
# Epoch 31/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0674 - accuracy: 0.9907 - val_loss: 2.4329 - val_accuracy: 0.5938
# Epoch 32/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0577 - accuracy: 0.9969 - val_loss: 2.5259 - val_accuracy: 0.6094
# Epoch 33/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0467 - accuracy: 0.9969 - val_loss: 2.5839 - val_accuracy: 0.5938
# Epoch 34/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0432 - accuracy: 0.9969 - val_loss: 2.5680 - val_accuracy: 0.5781
# Epoch 35/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0393 - accuracy: 0.9969 - val_loss: 2.6237 - val_accuracy: 0.5938
# Epoch 36/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0379 - accuracy: 0.9969 - val_loss: 2.6124 - val_accuracy: 0.5938
# Epoch 37/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0335 - accuracy: 0.9969 - val_loss: 2.6411 - val_accuracy: 0.5781
# Epoch 38/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0340 - accuracy: 0.9969 - val_loss: 2.7352 - val_accuracy: 0.6094
# Epoch 39/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0327 - accuracy: 0.9970 - val_loss: 2.5854 - val_accuracy: 0.6250
# Epoch 40/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0302 - accuracy: 0.9969 - val_loss: 2.8095 - val_accuracy: 0.5938
# Epoch 41/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0282 - accuracy: 0.9969 - val_loss: 2.7886 - val_accuracy: 0.5938
# Epoch 42/100
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 2.6926 - val_accuracy: 0.6094
# Epoch 43/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0228 - accuracy: 0.9969 - val_loss: 2.6714 - val_accuracy: 0.6094
# Epoch 44/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 2.8323 - val_accuracy: 0.5938
# Epoch 45/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0205 - accuracy: 0.9969 - val_loss: 2.7250 - val_accuracy: 0.5938
# Epoch 46/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0197 - accuracy: 0.9969 - val_loss: 2.7438 - val_accuracy: 0.5938
# Epoch 47/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 2.8564 - val_accuracy: 0.6094
# Epoch 48/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 2.8623 - val_accuracy: 0.6094
# Epoch 49/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 2.9184 - val_accuracy: 0.5938
# Epoch 50/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 2.8882 - val_accuracy: 0.6094
# Epoch 51/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 2.8721 - val_accuracy: 0.6094
# Epoch 52/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 2.9860 - val_accuracy: 0.5938
# Epoch 53/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 2.9050 - val_accuracy: 0.6094
# Epoch 54/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 2.9839 - val_accuracy: 0.6094
# Epoch 55/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 3.0133 - val_accuracy: 0.5938
# Epoch 56/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 3.0454 - val_accuracy: 0.6250
# Epoch 57/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 3.0377 - val_accuracy: 0.6094
# Epoch 58/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 3.0054 - val_accuracy: 0.5938
# Epoch 59/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 3.0344 - val_accuracy: 0.6094
# Epoch 60/100
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 2.9989 - val_accuracy: 0.6094
# Epoch 61/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 3.1006 - val_accuracy: 0.6094
# Epoch 62/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 3.0388 - val_accuracy: 0.6094
# Epoch 63/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 3.0818 - val_accuracy: 0.6094
# Epoch 64/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 3.0843 - val_accuracy: 0.6094
# Epoch 65/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 3.0978 - val_accuracy: 0.6094
# Epoch 66/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 3.1017 - val_accuracy: 0.6094
# Epoch 67/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 3.1221 - val_accuracy: 0.6094
# Epoch 68/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.1362 - val_accuracy: 0.6094
# Epoch 69/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 3.1373 - val_accuracy: 0.6094
# Epoch 70/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.1596 - val_accuracy: 0.6094
# Epoch 71/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 3.1263 - val_accuracy: 0.6094
# Epoch 72/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 3.1658 - val_accuracy: 0.6094
# Epoch 73/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 3.1413 - val_accuracy: 0.6094
# Epoch 74/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 3.1613 - val_accuracy: 0.6094
# Epoch 75/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.1461 - val_accuracy: 0.6094
# Epoch 76/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.1678 - val_accuracy: 0.6094
# Epoch 77/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 3.1966 - val_accuracy: 0.6094
# Epoch 78/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.1891 - val_accuracy: 0.6094
# Epoch 79/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.2637 - val_accuracy: 0.6094
# Epoch 80/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 3.2774 - val_accuracy: 0.6094
# Epoch 81/100
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.2724 - val_accuracy: 0.6094
# Epoch 82/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.2669 - val_accuracy: 0.6094
# Epoch 83/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.2071 - val_accuracy: 0.6094
# Epoch 84/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.2518 - val_accuracy: 0.6094
# Epoch 85/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 3.2471 - val_accuracy: 0.6094
# Epoch 86/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.2660 - val_accuracy: 0.6094
# Epoch 87/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.2481 - val_accuracy: 0.6094
# Epoch 88/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.2863 - val_accuracy: 0.6094
# Epoch 89/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.2815 - val_accuracy: 0.6094
# Epoch 90/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.2991 - val_accuracy: 0.6094
# Epoch 91/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.2969 - val_accuracy: 0.6094
# Epoch 92/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.2819 - val_accuracy: 0.6094
# Epoch 93/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.3196 - val_accuracy: 0.6094
# Epoch 94/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.3019 - val_accuracy: 0.6094
# Epoch 95/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.3119 - val_accuracy: 0.6094
# Epoch 96/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.3117 - val_accuracy: 0.6094
# Epoch 97/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.3433 - val_accuracy: 0.6094
# Epoch 98/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.3104 - val_accuracy: 0.6094
# Epoch 99/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.3404 - val_accuracy: 0.6094
# Epoch 100/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.3191 - val_accuracy: 0.6094
# 22/22 [==============================] - 1s 33ms/step - loss: 0.0022 - accuracy: 1.0000
# 5/5 [==============================] - 1s 330ms/step - loss: 2.7673 - accuracy: 0.6667
# Fold 1:
# Train accuracy: 1.0, Validation accuracy: 0.6666666865348816
# Training time for fold 1: 95.94812655448914 seconds
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.3497 - val_accuracy: 0.6094
# Epoch 2/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.3507 - val_accuracy: 0.6094
# Epoch 3/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.3532 - val_accuracy: 0.6094
# Epoch 4/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.3494 - val_accuracy: 0.6094
# Epoch 5/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.3597 - val_accuracy: 0.6094
# Epoch 6/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.3564 - val_accuracy: 0.6094
# Epoch 7/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.3985 - val_accuracy: 0.6094
# Epoch 8/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.3700 - val_accuracy: 0.6094
# Epoch 9/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.3756 - val_accuracy: 0.6094
# Epoch 10/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.3822 - val_accuracy: 0.6094
# Epoch 11/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.4083 - val_accuracy: 0.6094
# Epoch 12/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.4081 - val_accuracy: 0.6094
# Epoch 13/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.4005 - val_accuracy: 0.6094
# Epoch 14/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.4041 - val_accuracy: 0.6094
# Epoch 15/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.4217 - val_accuracy: 0.6094
# Epoch 16/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.4192 - val_accuracy: 0.6094
# Epoch 17/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.4118 - val_accuracy: 0.6094
# Epoch 18/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.4660 - val_accuracy: 0.6094
# Epoch 19/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.4345 - val_accuracy: 0.6094
# Epoch 20/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.4457 - val_accuracy: 0.6094
# Epoch 21/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.4658 - val_accuracy: 0.6094
# Epoch 22/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.4553 - val_accuracy: 0.6094
# Epoch 23/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.4504 - val_accuracy: 0.6094
# Epoch 24/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.4579 - val_accuracy: 0.6094
# Epoch 25/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.4828 - val_accuracy: 0.6094
# Epoch 26/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.4956 - val_accuracy: 0.6094
# Epoch 27/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.4592 - val_accuracy: 0.6094
# Epoch 28/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.5076 - val_accuracy: 0.6094
# Epoch 29/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.4833 - val_accuracy: 0.6094
# Epoch 30/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.4722 - val_accuracy: 0.6094
# Epoch 31/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.4936 - val_accuracy: 0.6094
# Epoch 32/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.4904 - val_accuracy: 0.6094
# Epoch 33/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.5140 - val_accuracy: 0.6094
# Epoch 34/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.4994 - val_accuracy: 0.6094
# Epoch 35/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.5335 - val_accuracy: 0.6094
# Epoch 36/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.5155 - val_accuracy: 0.6094
# Epoch 37/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.5293 - val_accuracy: 0.6094
# Epoch 38/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.5260 - val_accuracy: 0.6094
# Epoch 39/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.5436 - val_accuracy: 0.6094
# Epoch 40/100
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.5557 - val_accuracy: 0.6094
# Epoch 41/100
# 21/21 [==============================] - 1s 46ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.5277 - val_accuracy: 0.6094
# Epoch 42/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.9686e-04 - accuracy: 1.0000 - val_loss: 3.5539 - val_accuracy: 0.6094
# Epoch 43/100
# 21/21 [==============================] - 1s 44ms/step - loss: 9.4627e-04 - accuracy: 1.0000 - val_loss: 3.5603 - val_accuracy: 0.6094
# Epoch 44/100
# 21/21 [==============================] - 1s 44ms/step - loss: 9.4997e-04 - accuracy: 1.0000 - val_loss: 3.5529 - val_accuracy: 0.6094
# Epoch 45/100
# 21/21 [==============================] - 1s 44ms/step - loss: 9.3435e-04 - accuracy: 1.0000 - val_loss: 3.5571 - val_accuracy: 0.6094
# Epoch 46/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.3985e-04 - accuracy: 1.0000 - val_loss: 3.5758 - val_accuracy: 0.6094
# Epoch 47/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.1589e-04 - accuracy: 1.0000 - val_loss: 3.5678 - val_accuracy: 0.6094
# Epoch 48/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.7981e-04 - accuracy: 1.0000 - val_loss: 3.5734 - val_accuracy: 0.6094
# Epoch 49/100
# 21/21 [==============================] - 1s 44ms/step - loss: 8.7813e-04 - accuracy: 1.0000 - val_loss: 3.5812 - val_accuracy: 0.6094
# Epoch 50/100
# 21/21 [==============================] - 1s 46ms/step - loss: 8.3340e-04 - accuracy: 1.0000 - val_loss: 3.6019 - val_accuracy: 0.6094
# Epoch 51/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.7225e-04 - accuracy: 1.0000 - val_loss: 3.5980 - val_accuracy: 0.6094
# Epoch 52/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.2273e-04 - accuracy: 1.0000 - val_loss: 3.6022 - val_accuracy: 0.6094
# Epoch 53/100
# 21/21 [==============================] - 1s 47ms/step - loss: 8.1369e-04 - accuracy: 1.0000 - val_loss: 3.5885 - val_accuracy: 0.6094
# Epoch 54/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.3150e-04 - accuracy: 1.0000 - val_loss: 3.6046 - val_accuracy: 0.6094
# Epoch 55/100
# 21/21 [==============================] - 1s 48ms/step - loss: 7.9207e-04 - accuracy: 1.0000 - val_loss: 3.6091 - val_accuracy: 0.6094
# Epoch 56/100
# 21/21 [==============================] - 1s 48ms/step - loss: 7.8342e-04 - accuracy: 1.0000 - val_loss: 3.6108 - val_accuracy: 0.6094
# Epoch 57/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.8559e-04 - accuracy: 1.0000 - val_loss: 3.6273 - val_accuracy: 0.6094
# Epoch 58/100
# 21/21 [==============================] - 1s 52ms/step - loss: 7.3606e-04 - accuracy: 1.0000 - val_loss: 3.6293 - val_accuracy: 0.6094
# Epoch 59/100
# 21/21 [==============================] - 1s 53ms/step - loss: 7.3802e-04 - accuracy: 1.0000 - val_loss: 3.6325 - val_accuracy: 0.6094
# Epoch 60/100
# 21/21 [==============================] - 1s 45ms/step - loss: 7.4559e-04 - accuracy: 1.0000 - val_loss: 3.6127 - val_accuracy: 0.6094
# Epoch 61/100
# 21/21 [==============================] - 1s 45ms/step - loss: 7.2492e-04 - accuracy: 1.0000 - val_loss: 3.6265 - val_accuracy: 0.6094
# Epoch 62/100
# 21/21 [==============================] - 1s 45ms/step - loss: 7.0838e-04 - accuracy: 1.0000 - val_loss: 3.6289 - val_accuracy: 0.6094
# Epoch 63/100
# 21/21 [==============================] - 1s 45ms/step - loss: 6.8172e-04 - accuracy: 1.0000 - val_loss: 3.6209 - val_accuracy: 0.6094
# Epoch 64/100
# 21/21 [==============================] - 1s 45ms/step - loss: 6.7993e-04 - accuracy: 1.0000 - val_loss: 3.6440 - val_accuracy: 0.6094
# Epoch 65/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.7852e-04 - accuracy: 1.0000 - val_loss: 3.6499 - val_accuracy: 0.6094
# Epoch 66/100
# 21/21 [==============================] - 1s 46ms/step - loss: 6.7564e-04 - accuracy: 1.0000 - val_loss: 3.6588 - val_accuracy: 0.6094
# Epoch 67/100
# 21/21 [==============================] - 1s 46ms/step - loss: 6.5164e-04 - accuracy: 1.0000 - val_loss: 3.6503 - val_accuracy: 0.6094
# Epoch 68/100
# 21/21 [==============================] - 1s 46ms/step - loss: 6.4155e-04 - accuracy: 1.0000 - val_loss: 3.6710 - val_accuracy: 0.6094
# Epoch 69/100
# 21/21 [==============================] - 1s 45ms/step - loss: 6.3490e-04 - accuracy: 1.0000 - val_loss: 3.6636 - val_accuracy: 0.6094
# Epoch 70/100
# 21/21 [==============================] - 1s 45ms/step - loss: 6.3451e-04 - accuracy: 1.0000 - val_loss: 3.6985 - val_accuracy: 0.6094
# Epoch 71/100
# 21/21 [==============================] - 1s 46ms/step - loss: 6.0418e-04 - accuracy: 1.0000 - val_loss: 3.6569 - val_accuracy: 0.6094
# Epoch 72/100
# 21/21 [==============================] - 1s 44ms/step - loss: 6.1153e-04 - accuracy: 1.0000 - val_loss: 3.6937 - val_accuracy: 0.6094
# Epoch 73/100
# 21/21 [==============================] - 1s 46ms/step - loss: 6.0300e-04 - accuracy: 1.0000 - val_loss: 3.6654 - val_accuracy: 0.6094
# Epoch 74/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.8771e-04 - accuracy: 1.0000 - val_loss: 3.6864 - val_accuracy: 0.6094
# Epoch 75/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.8130e-04 - accuracy: 1.0000 - val_loss: 3.6784 - val_accuracy: 0.6094
# Epoch 76/100
# 21/21 [==============================] - 1s 46ms/step - loss: 5.6904e-04 - accuracy: 1.0000 - val_loss: 3.6880 - val_accuracy: 0.6094
# Epoch 77/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.5820e-04 - accuracy: 1.0000 - val_loss: 3.7168 - val_accuracy: 0.6094
# Epoch 78/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.5125e-04 - accuracy: 1.0000 - val_loss: 3.6966 - val_accuracy: 0.6094
# Epoch 79/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.4844e-04 - accuracy: 1.0000 - val_loss: 3.7284 - val_accuracy: 0.6094
# Epoch 80/100
# 21/21 [==============================] - 1s 46ms/step - loss: 5.3011e-04 - accuracy: 1.0000 - val_loss: 3.7402 - val_accuracy: 0.6094
# Epoch 81/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.3210e-04 - accuracy: 1.0000 - val_loss: 3.7434 - val_accuracy: 0.6094
# Epoch 82/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.1909e-04 - accuracy: 1.0000 - val_loss: 3.7527 - val_accuracy: 0.6094
# Epoch 83/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.1020e-04 - accuracy: 1.0000 - val_loss: 3.7331 - val_accuracy: 0.6094
# Epoch 84/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.0154e-04 - accuracy: 1.0000 - val_loss: 3.7298 - val_accuracy: 0.6094
# Epoch 85/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.9852e-04 - accuracy: 1.0000 - val_loss: 3.7494 - val_accuracy: 0.6094
# Epoch 86/100
# 21/21 [==============================] - 1s 46ms/step - loss: 4.9358e-04 - accuracy: 1.0000 - val_loss: 3.7358 - val_accuracy: 0.6094
# Epoch 87/100
# 21/21 [==============================] - 1s 44ms/step - loss: 4.7685e-04 - accuracy: 1.0000 - val_loss: 3.7634 - val_accuracy: 0.6094
# Epoch 88/100
# 21/21 [==============================] - 1s 46ms/step - loss: 4.7446e-04 - accuracy: 1.0000 - val_loss: 3.7509 - val_accuracy: 0.6094
# Epoch 89/100
# 21/21 [==============================] - 1s 44ms/step - loss: 4.7228e-04 - accuracy: 1.0000 - val_loss: 3.7569 - val_accuracy: 0.6094
# Epoch 90/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.6229e-04 - accuracy: 1.0000 - val_loss: 3.7625 - val_accuracy: 0.6094
# Epoch 91/100
# 21/21 [==============================] - 1s 46ms/step - loss: 4.5487e-04 - accuracy: 1.0000 - val_loss: 3.7667 - val_accuracy: 0.6094
# Epoch 92/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.4089e-04 - accuracy: 1.0000 - val_loss: 3.7721 - val_accuracy: 0.6094
# Epoch 93/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.4185e-04 - accuracy: 1.0000 - val_loss: 3.7701 - val_accuracy: 0.6094
# Epoch 94/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.3857e-04 - accuracy: 1.0000 - val_loss: 3.7927 - val_accuracy: 0.6094
# Epoch 95/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.3088e-04 - accuracy: 1.0000 - val_loss: 3.7608 - val_accuracy: 0.6094
# Epoch 96/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.2203e-04 - accuracy: 1.0000 - val_loss: 3.8039 - val_accuracy: 0.6094
# Epoch 97/100
# 21/21 [==============================] - 1s 46ms/step - loss: 4.1760e-04 - accuracy: 1.0000 - val_loss: 3.7844 - val_accuracy: 0.6094
# Epoch 98/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.1157e-04 - accuracy: 1.0000 - val_loss: 3.7934 - val_accuracy: 0.6094
# Epoch 99/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.0523e-04 - accuracy: 1.0000 - val_loss: 3.7996 - val_accuracy: 0.6094
# Epoch 100/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.0368e-04 - accuracy: 1.0000 - val_loss: 3.8063 - val_accuracy: 0.6094
# 22/22 [==============================] - 1s 35ms/step - loss: 3.8758e-04 - accuracy: 1.0000
# 5/5 [==============================] - 0s 37ms/step - loss: 3.1621 - accuracy: 0.6667
# Fold 2:
# Train accuracy: 1.0, Validation accuracy: 0.6666666865348816
# Training time for fold 2: 193.46087646484375 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 1s 46ms/step - loss: 3.9154e-04 - accuracy: 1.0000 - val_loss: 3.8119 - val_accuracy: 0.6094
# Epoch 2/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.9684e-04 - accuracy: 1.0000 - val_loss: 3.8115 - val_accuracy: 0.6094
# Epoch 3/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.8245e-04 - accuracy: 1.0000 - val_loss: 3.8033 - val_accuracy: 0.6094
# Epoch 4/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.6588e-04 - accuracy: 1.0000 - val_loss: 3.8127 - val_accuracy: 0.6094
# Epoch 5/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.7955e-04 - accuracy: 1.0000 - val_loss: 3.8335 - val_accuracy: 0.6094
# Epoch 6/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.5207e-04 - accuracy: 1.0000 - val_loss: 3.8299 - val_accuracy: 0.6094
# Epoch 7/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.6004e-04 - accuracy: 1.0000 - val_loss: 3.8423 - val_accuracy: 0.6094
# Epoch 8/100
# 21/21 [==============================] - 1s 46ms/step - loss: 3.5229e-04 - accuracy: 1.0000 - val_loss: 3.8267 - val_accuracy: 0.6094
# Epoch 9/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.3779e-04 - accuracy: 1.0000 - val_loss: 3.8372 - val_accuracy: 0.6094
# Epoch 10/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.5365e-04 - accuracy: 1.0000 - val_loss: 3.8516 - val_accuracy: 0.6094
# Epoch 11/100
# 21/21 [==============================] - 1s 46ms/step - loss: 3.4827e-04 - accuracy: 1.0000 - val_loss: 3.8293 - val_accuracy: 0.6094
# Epoch 12/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.3678e-04 - accuracy: 1.0000 - val_loss: 3.8547 - val_accuracy: 0.6094
# Epoch 13/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.3579e-04 - accuracy: 1.0000 - val_loss: 3.8574 - val_accuracy: 0.6094
# Epoch 14/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.2195e-04 - accuracy: 1.0000 - val_loss: 3.8650 - val_accuracy: 0.6094
# Epoch 15/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.2217e-04 - accuracy: 1.0000 - val_loss: 3.8733 - val_accuracy: 0.6094
# Epoch 16/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.2603e-04 - accuracy: 1.0000 - val_loss: 3.8774 - val_accuracy: 0.6094
# Epoch 17/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.1969e-04 - accuracy: 1.0000 - val_loss: 3.8731 - val_accuracy: 0.6094
# Epoch 18/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.0810e-04 - accuracy: 1.0000 - val_loss: 3.8818 - val_accuracy: 0.6094
# Epoch 19/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.1093e-04 - accuracy: 1.0000 - val_loss: 3.8668 - val_accuracy: 0.6094
# Epoch 20/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.9983e-04 - accuracy: 1.0000 - val_loss: 3.8859 - val_accuracy: 0.6094
# Epoch 21/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.8868e-04 - accuracy: 1.0000 - val_loss: 3.8929 - val_accuracy: 0.6094
# Epoch 22/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.9108e-04 - accuracy: 1.0000 - val_loss: 3.8861 - val_accuracy: 0.6094
# Epoch 23/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.8456e-04 - accuracy: 1.0000 - val_loss: 3.8989 - val_accuracy: 0.6094
# Epoch 24/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.8541e-04 - accuracy: 1.0000 - val_loss: 3.8938 - val_accuracy: 0.6094
# Epoch 25/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.7954e-04 - accuracy: 1.0000 - val_loss: 3.9007 - val_accuracy: 0.6094
# Epoch 26/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.7557e-04 - accuracy: 1.0000 - val_loss: 3.9111 - val_accuracy: 0.6094
# Epoch 27/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.7533e-04 - accuracy: 1.0000 - val_loss: 3.9044 - val_accuracy: 0.6094
# Epoch 28/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.7427e-04 - accuracy: 1.0000 - val_loss: 3.9224 - val_accuracy: 0.6094
# Epoch 29/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.6911e-04 - accuracy: 1.0000 - val_loss: 3.9423 - val_accuracy: 0.6094
# Epoch 30/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.5627e-04 - accuracy: 1.0000 - val_loss: 3.9254 - val_accuracy: 0.6094
# Epoch 31/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.6003e-04 - accuracy: 1.0000 - val_loss: 3.9172 - val_accuracy: 0.6094
# Epoch 32/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.5569e-04 - accuracy: 1.0000 - val_loss: 3.9340 - val_accuracy: 0.6094
# Epoch 33/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.4382e-04 - accuracy: 1.0000 - val_loss: 3.9358 - val_accuracy: 0.6094
# Epoch 34/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.4744e-04 - accuracy: 1.0000 - val_loss: 3.9292 - val_accuracy: 0.6094
# Epoch 35/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.4564e-04 - accuracy: 1.0000 - val_loss: 3.9518 - val_accuracy: 0.6094
# Epoch 36/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.4743e-04 - accuracy: 1.0000 - val_loss: 3.9399 - val_accuracy: 0.6094
# Epoch 37/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.3874e-04 - accuracy: 1.0000 - val_loss: 3.9462 - val_accuracy: 0.6094
# Epoch 38/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.2870e-04 - accuracy: 1.0000 - val_loss: 3.9425 - val_accuracy: 0.6094
# Epoch 39/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.3418e-04 - accuracy: 1.0000 - val_loss: 3.9549 - val_accuracy: 0.6094
# Epoch 40/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.2999e-04 - accuracy: 1.0000 - val_loss: 3.9612 - val_accuracy: 0.6094
# Epoch 41/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.3046e-04 - accuracy: 1.0000 - val_loss: 3.9724 - val_accuracy: 0.6094
# Epoch 42/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1571e-04 - accuracy: 1.0000 - val_loss: 3.9664 - val_accuracy: 0.6094
# Epoch 43/100
# 21/21 [==============================] - 1s 44ms/step - loss: 2.2337e-04 - accuracy: 1.0000 - val_loss: 3.9806 - val_accuracy: 0.6094
# Epoch 44/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1764e-04 - accuracy: 1.0000 - val_loss: 3.9777 - val_accuracy: 0.6094
# Epoch 45/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1526e-04 - accuracy: 1.0000 - val_loss: 3.9729 - val_accuracy: 0.6094
# Epoch 46/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1434e-04 - accuracy: 1.0000 - val_loss: 3.9982 - val_accuracy: 0.6094
# Epoch 47/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1070e-04 - accuracy: 1.0000 - val_loss: 3.9788 - val_accuracy: 0.6094
# Epoch 48/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1099e-04 - accuracy: 1.0000 - val_loss: 4.0036 - val_accuracy: 0.6094
# Epoch 49/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.0786e-04 - accuracy: 1.0000 - val_loss: 3.9863 - val_accuracy: 0.6094
# Epoch 50/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.0332e-04 - accuracy: 1.0000 - val_loss: 4.0062 - val_accuracy: 0.6094
# Epoch 51/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.9354e-04 - accuracy: 1.0000 - val_loss: 4.0199 - val_accuracy: 0.6094
# Epoch 52/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.9713e-04 - accuracy: 1.0000 - val_loss: 3.9990 - val_accuracy: 0.6094
# Epoch 53/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.9688e-04 - accuracy: 1.0000 - val_loss: 4.0161 - val_accuracy: 0.6094
# Epoch 54/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.9247e-04 - accuracy: 1.0000 - val_loss: 4.0122 - val_accuracy: 0.6094
# Epoch 55/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.9143e-04 - accuracy: 1.0000 - val_loss: 4.0175 - val_accuracy: 0.6094
# Epoch 56/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.8732e-04 - accuracy: 1.0000 - val_loss: 4.0177 - val_accuracy: 0.6094
# Epoch 57/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.7906e-04 - accuracy: 1.0000 - val_loss: 4.0146 - val_accuracy: 0.6094
# Epoch 58/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.8139e-04 - accuracy: 1.0000 - val_loss: 4.0249 - val_accuracy: 0.6094
# Epoch 59/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.7857e-04 - accuracy: 1.0000 - val_loss: 4.0386 - val_accuracy: 0.6094
# Epoch 60/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.7796e-04 - accuracy: 1.0000 - val_loss: 4.0252 - val_accuracy: 0.6094
# Epoch 61/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.7475e-04 - accuracy: 1.0000 - val_loss: 4.0411 - val_accuracy: 0.6094
# Epoch 62/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.7018e-04 - accuracy: 1.0000 - val_loss: 4.0337 - val_accuracy: 0.6094
# Epoch 63/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.7365e-04 - accuracy: 1.0000 - val_loss: 4.0385 - val_accuracy: 0.6094
# Epoch 64/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.6889e-04 - accuracy: 1.0000 - val_loss: 4.0503 - val_accuracy: 0.6094
# Epoch 65/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.6788e-04 - accuracy: 1.0000 - val_loss: 4.0547 - val_accuracy: 0.6094
# Epoch 66/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.6376e-04 - accuracy: 1.0000 - val_loss: 4.0607 - val_accuracy: 0.6094
# Epoch 67/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.6172e-04 - accuracy: 1.0000 - val_loss: 4.0682 - val_accuracy: 0.6094
# Epoch 68/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.5538e-04 - accuracy: 1.0000 - val_loss: 4.0795 - val_accuracy: 0.6094
# Epoch 69/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.5719e-04 - accuracy: 1.0000 - val_loss: 4.0654 - val_accuracy: 0.6094
# Epoch 70/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.6148e-04 - accuracy: 1.0000 - val_loss: 4.0684 - val_accuracy: 0.6094
# Epoch 71/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.5327e-04 - accuracy: 1.0000 - val_loss: 4.0798 - val_accuracy: 0.6094
# Epoch 72/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.5304e-04 - accuracy: 1.0000 - val_loss: 4.0741 - val_accuracy: 0.6094
# Epoch 73/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.5161e-04 - accuracy: 1.0000 - val_loss: 4.0729 - val_accuracy: 0.6094
# Epoch 74/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.5022e-04 - accuracy: 1.0000 - val_loss: 4.0865 - val_accuracy: 0.6094
# Epoch 75/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.4557e-04 - accuracy: 1.0000 - val_loss: 4.0801 - val_accuracy: 0.6094
# Epoch 76/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.4723e-04 - accuracy: 1.0000 - val_loss: 4.0852 - val_accuracy: 0.6094
# Epoch 77/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.4393e-04 - accuracy: 1.0000 - val_loss: 4.1047 - val_accuracy: 0.6094
# Epoch 78/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.4422e-04 - accuracy: 1.0000 - val_loss: 4.0859 - val_accuracy: 0.6094
# Epoch 79/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.4291e-04 - accuracy: 1.0000 - val_loss: 4.0926 - val_accuracy: 0.6094
# Epoch 80/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.3975e-04 - accuracy: 1.0000 - val_loss: 4.1479 - val_accuracy: 0.6094
# Epoch 81/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.3771e-04 - accuracy: 1.0000 - val_loss: 4.1100 - val_accuracy: 0.6094
# Epoch 82/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.3395e-04 - accuracy: 1.0000 - val_loss: 4.1444 - val_accuracy: 0.6094
# Epoch 83/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.3353e-04 - accuracy: 1.0000 - val_loss: 4.1259 - val_accuracy: 0.6094
# Epoch 84/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.3127e-04 - accuracy: 1.0000 - val_loss: 4.1202 - val_accuracy: 0.6094
# Epoch 85/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2726e-04 - accuracy: 1.0000 - val_loss: 4.1364 - val_accuracy: 0.6094
# Epoch 86/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2798e-04 - accuracy: 1.0000 - val_loss: 4.1431 - val_accuracy: 0.6094
# Epoch 87/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.2277e-04 - accuracy: 1.0000 - val_loss: 4.1466 - val_accuracy: 0.6094
# Epoch 88/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2570e-04 - accuracy: 1.0000 - val_loss: 4.1405 - val_accuracy: 0.6094
# Epoch 89/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2300e-04 - accuracy: 1.0000 - val_loss: 4.1527 - val_accuracy: 0.6094
# Epoch 90/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.1748e-04 - accuracy: 1.0000 - val_loss: 4.1488 - val_accuracy: 0.6094
# Epoch 91/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.1420e-04 - accuracy: 1.0000 - val_loss: 4.1544 - val_accuracy: 0.6094
# Epoch 92/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.1947e-04 - accuracy: 1.0000 - val_loss: 4.1599 - val_accuracy: 0.6094
# Epoch 93/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.1598e-04 - accuracy: 1.0000 - val_loss: 4.1638 - val_accuracy: 0.6094
# Epoch 94/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.1404e-04 - accuracy: 1.0000 - val_loss: 4.1694 - val_accuracy: 0.6094
# Epoch 95/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.1416e-04 - accuracy: 1.0000 - val_loss: 4.1543 - val_accuracy: 0.6094
# Epoch 96/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.1094e-04 - accuracy: 1.0000 - val_loss: 4.1709 - val_accuracy: 0.6094
# Epoch 97/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0978e-04 - accuracy: 1.0000 - val_loss: 4.1857 - val_accuracy: 0.6094
# Epoch 98/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0752e-04 - accuracy: 1.0000 - val_loss: 4.1806 - val_accuracy: 0.6094
# Epoch 99/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0860e-04 - accuracy: 1.0000 - val_loss: 4.1895 - val_accuracy: 0.6094
# Epoch 100/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.0466e-04 - accuracy: 1.0000 - val_loss: 4.1819 - val_accuracy: 0.6094
# 22/22 [==============================] - 1s 36ms/step - loss: 1.0266e-04 - accuracy: 1.0000
# 5/5 [==============================] - 0s 37ms/step - loss: 3.4703 - accuracy: 0.6667
# Fold 3:
# Train accuracy: 1.0, Validation accuracy: 0.6666666865348816
# Training time for fold 3: 292.06776237487793 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.0363e-04 - accuracy: 1.0000 - val_loss: 4.1881 - val_accuracy: 0.6094
# Epoch 2/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0457e-04 - accuracy: 1.0000 - val_loss: 4.1912 - val_accuracy: 0.6094
# Epoch 3/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0046e-04 - accuracy: 1.0000 - val_loss: 4.1913 - val_accuracy: 0.6094
# Epoch 4/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0103e-04 - accuracy: 1.0000 - val_loss: 4.1931 - val_accuracy: 0.6094
# Epoch 5/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.0085e-04 - accuracy: 1.0000 - val_loss: 4.1956 - val_accuracy: 0.6094
# Epoch 6/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.6681e-05 - accuracy: 1.0000 - val_loss: 4.1970 - val_accuracy: 0.6094
# Epoch 7/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.7740e-05 - accuracy: 1.0000 - val_loss: 4.2318 - val_accuracy: 0.6094
# Epoch 8/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.4260e-05 - accuracy: 1.0000 - val_loss: 4.2064 - val_accuracy: 0.6094
# Epoch 9/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.3424e-05 - accuracy: 1.0000 - val_loss: 4.2149 - val_accuracy: 0.6094
# Epoch 10/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.2711e-05 - accuracy: 1.0000 - val_loss: 4.2265 - val_accuracy: 0.6094
# Epoch 11/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.0797e-05 - accuracy: 1.0000 - val_loss: 4.2312 - val_accuracy: 0.6094
# Epoch 12/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.0314e-05 - accuracy: 1.0000 - val_loss: 4.2122 - val_accuracy: 0.6094
# Epoch 13/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.8874e-05 - accuracy: 1.0000 - val_loss: 4.2250 - val_accuracy: 0.6094
# Epoch 14/100
# 21/21 [==============================] - 1s 46ms/step - loss: 8.6525e-05 - accuracy: 1.0000 - val_loss: 4.2217 - val_accuracy: 0.6094
# Epoch 15/100
# 21/21 [==============================] - 1s 46ms/step - loss: 8.7099e-05 - accuracy: 1.0000 - val_loss: 4.2368 - val_accuracy: 0.6094
# Epoch 16/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.7024e-05 - accuracy: 1.0000 - val_loss: 4.2432 - val_accuracy: 0.6094
# Epoch 17/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.6261e-05 - accuracy: 1.0000 - val_loss: 4.2370 - val_accuracy: 0.6094
# Epoch 18/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.2923e-05 - accuracy: 1.0000 - val_loss: 4.2503 - val_accuracy: 0.6094
# Epoch 19/100
# 21/21 [==============================] - 1s 46ms/step - loss: 8.3494e-05 - accuracy: 1.0000 - val_loss: 4.2393 - val_accuracy: 0.6094
# Epoch 20/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.1596e-05 - accuracy: 1.0000 - val_loss: 4.2526 - val_accuracy: 0.6094
# Epoch 21/100
# ...
# Epoch 99/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.9191e-05 - accuracy: 1.0000 - val_loss: 4.4922 - val_accuracy: 0.6094
# Epoch 100/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.8736e-05 - accuracy: 1.0000 - val_loss: 4.5058 - val_accuracy: 0.6094
# 22/22 [==============================] - 1s 36ms/step - loss: 2.8075e-05 - accuracy: 1.0000
# 5/5 [==============================] - 0s 39ms/step - loss: 3.7321 - accuracy: 0.6667
# Fold 4:
# Train accuracy: 1.0, Validation accuracy: 0.6666666865348816
# Training time for fold 4: 397.3203773498535 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.8211e-05 - accuracy: 1.0000 - val_loss: 4.5110 - val_accuracy: 0.6094
# Epoch 2/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.7928e-05 - accuracy: 1.0000 - val_loss: 4.5189 - val_accuracy: 0.6094
# Epoch 3/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.7076e-05 - accuracy: 1.0000 - val_loss: 4.5118 - val_accuracy: 0.6094
# Epoch 4/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.7661e-05 - accuracy: 1.0000 - val_loss: 4.5138 - val_accuracy: 0.6094
# Epoch 5/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.7484e-05 - accuracy: 1.0000 - val_loss: 4.5269 - val_accuracy: 0.6094
# Epoch 6/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.6631e-05 - accuracy: 1.0000 - val_loss: 4.5271 - val_accuracy: 0.6094
# Epoch 7/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.6912e-05 - accuracy: 1.0000 - val_loss: 4.5407 - val_accuracy: 0.6094
# Epoch 8/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.5889e-05 - accuracy: 1.0000 - val_loss: 4.5397 - val_accuracy: 0.6094
# Epoch 9/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.5579e-05 - accuracy: 1.0000 - val_loss: 4.5350 - val_accuracy: 0.6094
# Epoch 10/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.4952e-05 - accuracy: 1.0000 - val_loss: 4.5437 - val_accuracy: 0.6094
# Epoch 11/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.4507e-05 - accuracy: 1.0000 - val_loss: 4.5390 - val_accuracy: 0.6094
# Epoch 12/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.4017e-05 - accuracy: 1.0000 - val_loss: 4.5444 - val_accuracy: 0.6094
# Epoch 13/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.4504e-05 - accuracy: 1.0000 - val_loss: 4.5404 - val_accuracy: 0.6094
# Epoch 14/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.4141e-05 - accuracy: 1.0000 - val_loss: 4.5606 - val_accuracy: 0.6094
# Epoch 15/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.4066e-05 - accuracy: 1.0000 - val_loss: 4.5463 - val_accuracy: 0.6094
# Epoch 16/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.3511e-05 - accuracy: 1.0000 - val_loss: 4.5699 - val_accuracy: 0.6094
# Epoch 17/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.3159e-05 - accuracy: 1.0000 - val_loss: 4.5585 - val_accuracy: 0.6094
# Epoch 18/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.2618e-05 - accuracy: 1.0000 - val_loss: 4.5520 - val_accuracy: 0.6094
# Epoch 19/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.3205e-05 - accuracy: 1.0000 - val_loss: 4.5728 - val_accuracy: 0.6094
# Epoch 20/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.2808e-05 - accuracy: 1.0000 - val_loss: 4.5672 - val_accuracy: 0.6094
# Epoch 21/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.2278e-05 - accuracy: 1.0000 - val_loss: 4.5839 - val_accuracy: 0.6094
# Epoch 22/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.2230e-05 - accuracy: 1.0000 - val_loss: 4.5735 - val_accuracy: 0.6094
# Epoch 23/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1721e-05 - accuracy: 1.0000 - val_loss: 4.5721 - val_accuracy: 0.6094
# Epoch 24/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1745e-05 - accuracy: 1.0000 - val_loss: 4.5831 - val_accuracy: 0.6094
# Epoch 25/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.1197e-05 - accuracy: 1.0000 - val_loss: 4.5758 - val_accuracy: 0.6094
# Epoch 26/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.0819e-05 - accuracy: 1.0000 - val_loss: 4.6129 - val_accuracy: 0.6094
# Epoch 27/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.1247e-05 - accuracy: 1.0000 - val_loss: 4.5834 - val_accuracy: 0.6094
# Epoch 28/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.0796e-05 - accuracy: 1.0000 - val_loss: 4.6210 - val_accuracy: 0.6094
# Epoch 29/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.0824e-05 - accuracy: 1.0000 - val_loss: 4.6122 - val_accuracy: 0.6094
# Epoch 30/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.0266e-05 - accuracy: 1.0000 - val_loss: 4.6034 - val_accuracy: 0.6094
# Epoch 31/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.9654e-05 - accuracy: 1.0000 - val_loss: 4.6007 - val_accuracy: 0.6094
# Epoch 32/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.9767e-05 - accuracy: 1.0000 - val_loss: 4.6007 - val_accuracy: 0.6094
# Epoch 33/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.9598e-05 - accuracy: 1.0000 - val_loss: 4.6104 - val_accuracy: 0.6094
# Epoch 34/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.8663e-05 - accuracy: 1.0000 - val_loss: 4.6227 - val_accuracy: 0.6094
# Epoch 35/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.9000e-05 - accuracy: 1.0000 - val_loss: 4.6150 - val_accuracy: 0.6094
# Epoch 36/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.8983e-05 - accuracy: 1.0000 - val_loss: 4.6224 - val_accuracy: 0.6094
# Epoch 37/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.8796e-05 - accuracy: 1.0000 - val_loss: 4.6164 - val_accuracy: 0.6094
# Epoch 38/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.8296e-05 - accuracy: 1.0000 - val_loss: 4.6351 - val_accuracy: 0.6094
# Epoch 39/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.8207e-05 - accuracy: 1.0000 - val_loss: 4.6366 - val_accuracy: 0.6094
# Epoch 40/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.7847e-05 - accuracy: 1.0000 - val_loss: 4.6343 - val_accuracy: 0.6094
# Epoch 41/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.8067e-05 - accuracy: 1.0000 - val_loss: 4.6528 - val_accuracy: 0.6094
# Epoch 42/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.6985e-05 - accuracy: 1.0000 - val_loss: 4.6189 - val_accuracy: 0.6094
# Epoch 43/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.7077e-05 - accuracy: 1.0000 - val_loss: 4.6468 - val_accuracy: 0.6094
# Epoch 44/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.6914e-05 - accuracy: 1.0000 - val_loss: 4.6570 - val_accuracy: 0.6094
# Epoch 45/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.6900e-05 - accuracy: 1.0000 - val_loss: 4.6501 - val_accuracy: 0.6094
# Epoch 46/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.6366e-05 - accuracy: 1.0000 - val_loss: 4.6641 - val_accuracy: 0.6094
# Epoch 47/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.6479e-05 - accuracy: 1.0000 - val_loss: 4.6606 - val_accuracy: 0.6094
# Epoch 48/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.6473e-05 - accuracy: 1.0000 - val_loss: 4.6570 - val_accuracy: 0.6094
# Epoch 49/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.5842e-05 - accuracy: 1.0000 - val_loss: 4.6772 - val_accuracy: 0.6094
# Epoch 50/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.5621e-05 - accuracy: 1.0000 - val_loss: 4.6480 - val_accuracy: 0.6094
# Epoch 51/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.5968e-05 - accuracy: 1.0000 - val_loss: 4.6843 - val_accuracy: 0.6094
# Epoch 52/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.5686e-05 - accuracy: 1.0000 - val_loss: 4.6800 - val_accuracy: 0.6094
# Epoch 53/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.5524e-05 - accuracy: 1.0000 - val_loss: 4.6699 - val_accuracy: 0.6094
# Epoch 54/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.4855e-05 - accuracy: 1.0000 - val_loss: 4.6856 - val_accuracy: 0.6094
# Epoch 55/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.5081e-05 - accuracy: 1.0000 - val_loss: 4.6852 - val_accuracy: 0.6094
# Epoch 56/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.4234e-05 - accuracy: 1.0000 - val_loss: 4.6781 - val_accuracy: 0.6094
# Epoch 57/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.5008e-05 - accuracy: 1.0000 - val_loss: 4.6880 - val_accuracy: 0.6094
# Epoch 58/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.4456e-05 - accuracy: 1.0000 - val_loss: 4.6836 - val_accuracy: 0.6094
# Epoch 59/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.4405e-05 - accuracy: 1.0000 - val_loss: 4.6965 - val_accuracy: 0.6094
# Epoch 60/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.4312e-05 - accuracy: 1.0000 - val_loss: 4.6942 - val_accuracy: 0.6094
# Epoch 61/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.3750e-05 - accuracy: 1.0000 - val_loss: 4.6920 - val_accuracy: 0.6094
# Epoch 62/100
# 21/21 [==============================] - 5s 268ms/step - loss: 1.3766e-05 - accuracy: 1.0000 - val_loss: 4.7048 - val_accuracy: 0.6094
# Epoch 63/100
# 21/21 [==============================] - 2s 92ms/step - loss: 1.3855e-05 - accuracy: 1.0000 - val_loss: 4.6889 - val_accuracy: 0.6094
# Epoch 64/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.3806e-05 - accuracy: 1.0000 - val_loss: 4.7088 - val_accuracy: 0.6094
# Epoch 65/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.3291e-05 - accuracy: 1.0000 - val_loss: 4.7324 - val_accuracy: 0.6094
# Epoch 66/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.3189e-05 - accuracy: 1.0000 - val_loss: 4.7073 - val_accuracy: 0.6094
# Epoch 67/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2584e-05 - accuracy: 1.0000 - val_loss: 4.7151 - val_accuracy: 0.6094
# Epoch 68/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.2591e-05 - accuracy: 1.0000 - val_loss: 4.7183 - val_accuracy: 0.6094
# Epoch 69/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2781e-05 - accuracy: 1.0000 - val_loss: 4.7232 - val_accuracy: 0.6094
# Epoch 70/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2461e-05 - accuracy: 1.0000 - val_loss: 4.7341 - val_accuracy: 0.6094
# Epoch 71/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.2556e-05 - accuracy: 1.0000 - val_loss: 4.7441 - val_accuracy: 0.6094
# Epoch 72/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.2301e-05 - accuracy: 1.0000 - val_loss: 4.7294 - val_accuracy: 0.6094
# Epoch 73/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2077e-05 - accuracy: 1.0000 - val_loss: 4.7402 - val_accuracy: 0.6094
# Epoch 74/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.1963e-05 - accuracy: 1.0000 - val_loss: 4.7340 - val_accuracy: 0.6094
# Epoch 75/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2214e-05 - accuracy: 1.0000 - val_loss: 4.7169 - val_accuracy: 0.6094
# Epoch 76/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.2020e-05 - accuracy: 1.0000 - val_loss: 4.7593 - val_accuracy: 0.6094
# Epoch 77/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.1709e-05 - accuracy: 1.0000 - val_loss: 4.7467 - val_accuracy: 0.6094
# Epoch 78/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.1489e-05 - accuracy: 1.0000 - val_loss: 4.7509 - val_accuracy: 0.6094
# Epoch 79/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.1472e-05 - accuracy: 1.0000 - val_loss: 4.7666 - val_accuracy: 0.6094
# Epoch 80/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.1526e-05 - accuracy: 1.0000 - val_loss: 4.7794 - val_accuracy: 0.6094
# Epoch 81/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.1288e-05 - accuracy: 1.0000 - val_loss: 4.7643 - val_accuracy: 0.6094
# Epoch 82/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.0879e-05 - accuracy: 1.0000 - val_loss: 4.7782 - val_accuracy: 0.6094
# Epoch 83/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.0727e-05 - accuracy: 1.0000 - val_loss: 4.7634 - val_accuracy: 0.6094
# Epoch 84/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.0667e-05 - accuracy: 1.0000 - val_loss: 4.7780 - val_accuracy: 0.6094
# Epoch 85/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0323e-05 - accuracy: 1.0000 - val_loss: 4.7798 - val_accuracy: 0.6094
# Epoch 86/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0439e-05 - accuracy: 1.0000 - val_loss: 4.7859 - val_accuracy: 0.6094
# Epoch 87/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0205e-05 - accuracy: 1.0000 - val_loss: 4.7945 - val_accuracy: 0.6094
# Epoch 88/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0246e-05 - accuracy: 1.0000 - val_loss: 4.7918 - val_accuracy: 0.6094
# Epoch 89/100
# 21/21 [==============================] - 1s 46ms/step - loss: 9.9917e-06 - accuracy: 1.0000 - val_loss: 4.7934 - val_accuracy: 0.6094
# Epoch 90/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.9544e-06 - accuracy: 1.0000 - val_loss: 4.7864 - val_accuracy: 0.6094
# Epoch 91/100
# 21/21 [==============================] - 1s 45ms/step - loss: 1.0019e-05 - accuracy: 1.0000 - val_loss: 4.8023 - val_accuracy: 0.6094
# Epoch 92/100
# 21/21 [==============================] - 1s 46ms/step - loss: 9.6714e-06 - accuracy: 1.0000 - val_loss: 4.8137 - val_accuracy: 0.6094
# Epoch 93/100
# 21/21 [==============================] - 1s 46ms/step - loss: 9.6444e-06 - accuracy: 1.0000 - val_loss: 4.8125 - val_accuracy: 0.6094
# Epoch 94/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.6799e-06 - accuracy: 1.0000 - val_loss: 4.8105 - val_accuracy: 0.6094
# Epoch 95/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.5319e-06 - accuracy: 1.0000 - val_loss: 4.8117 - val_accuracy: 0.6094
# Epoch 96/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.4038e-06 - accuracy: 1.0000 - val_loss: 4.8237 - val_accuracy: 0.6094
# Epoch 97/100
# 21/21 [==============================] - 1s 45ms/step - loss: 9.1602e-06 - accuracy: 1.0000 - val_loss: 4.8304 - val_accuracy: 0.6094
# Epoch 98/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.1661e-06 - accuracy: 1.0000 - val_loss: 4.8218 - val_accuracy: 0.6094
# Epoch 99/100
# 21/21 [==============================] - 1s 46ms/step - loss: 8.9923e-06 - accuracy: 1.0000 - val_loss: 4.8311 - val_accuracy: 0.6094
# Epoch 100/100
# 21/21 [==============================] - 1s 45ms/step - loss: 8.9417e-06 - accuracy: 1.0000 - val_loss: 4.8182 - val_accuracy: 0.6094
# 22/22 [==============================] - 1s 36ms/step - loss: 8.7757e-06 - accuracy: 1.0000
# 5/5 [==============================] - 0s 37ms/step - loss: 3.9877 - accuracy: 0.6667
# Fold 5:
# Train accuracy: 1.0, Validation accuracy: 0.6666666865348816
# Training time for fold 5: 503.50607800483704 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 100.0 %
# Average Validation Accuracy: 66.66666865348816 %
# Average Training Time: 296.46064414978025
# Total Training Time: 503.775771856308

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = combined_model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = combined_model.predict(train_generator)
validation_predictions = combined_model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsResnetMObile-Vggkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+----------------------+----------------------+----------------------+---------+
# | Class |      Precision       |        Recall        |       F1 Score       | Support |
# +-------+----------------------+----------------------+----------------------+---------+
# |   0   | 0.15789473684210525  | 0.15789473684210525  | 0.15789473684210525  |    19   |
# |   1   |         0.0          |         0.0          |         0.0          |    20   |
# |   10  | 0.058823529411764705 | 0.058823529411764705 | 0.058823529411764705 |    17   |
# |   2   | 0.041666666666666664 | 0.041666666666666664 | 0.041666666666666664 |    24   |
# |   3   | 0.05263157894736842  | 0.05263157894736842  | 0.05263157894736842  |    19   |
# |   4   |         0.0          |         0.0          |         0.0          |    20   |
# |   5   | 0.17647058823529413  | 0.17647058823529413  | 0.17647058823529413  |    17   |
# |   6   | 0.11764705882352941  | 0.11764705882352941  | 0.11764705882352941  |    17   |
# |   7   | 0.058823529411764705 | 0.058823529411764705 | 0.058823529411764705 |    17   |
# |   8   | 0.045454545454545456 | 0.045454545454545456 | 0.045454545454545456 |    22   |
# |   9   | 0.15789473684210525  | 0.15789473684210525  | 0.15789473684210525  |    19   |
# |  box  |         0.05         |         0.05         |         0.05         |    20   |
# |  fun  |         0.05         |         0.05         |         0.05         |    20   |
# |  good | 0.08333333333333333  | 0.08333333333333333  | 0.08333333333333333  |    24   |
# |  grow |         0.0          |         0.0          |         0.0          |    20   |
# |  hero |         0.0          |         0.0          |         0.0          |    22   |
# | trust | 0.045454545454545456 | 0.045454545454545456 | 0.045454545454545456 |    22   |
# +-------+----------------------+----------------------+----------------------+---------+
#
# Validation Metrics:
# +-------+--------------------+--------+--------------------+---------+
# | Class |     Precision      | Recall |      F1 Score      | Support |
# +-------+--------------------+--------+--------------------+---------+
# |   0   |        0.6         |  0.75  | 0.6666666666666666 |    4    |
# |   1   |        0.75        |  0.6   | 0.6666666666666666 |    5    |
# |   10  |        0.25        |  0.25  |        0.25        |    4    |
# |   2   |        0.75        |  0.6   | 0.6666666666666666 |    5    |
# |   3   | 0.6666666666666666 |  0.5   | 0.5714285714285714 |    4    |
# |   4   |        0.8         |  0.8   |        0.8         |    5    |
# |   5   |        0.4         |  0.5   | 0.4444444444444444 |    4    |
# |   6   |        0.5         |  0.5   |        0.5         |    4    |
# |   7   |        0.5         |  0.25  | 0.3333333333333333 |    4    |
# |   8   |        1.0         |  0.6   |        0.75        |    5    |
# |   9   | 0.6666666666666666 |  0.5   | 0.5714285714285714 |    4    |
# |  box  |        0.75        |  0.6   | 0.6666666666666666 |    5    |
# |  fun  | 0.8333333333333334 |  1.0   | 0.9090909090909091 |    5    |
# |  good |        0.5         |  0.8   | 0.6153846153846154 |    5    |
# |  grow |        1.0         |  1.0   |        1.0         |    5    |
# |  hero |        0.8         |  0.8   |        0.8         |    5    |
# | trust |       0.625        |  1.0   | 0.7692307692307693 |    5    |
# +-------+--------------------+--------+--------------------+---------+
# Combined metrics saved to combined_metricsResnetMObile-Vggkfold5.xlsx

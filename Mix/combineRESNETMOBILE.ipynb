# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # ResnetMobile

# %% [markdown]
# # Model Summary

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2
import time

# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Noise reduction 2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the MobileNetV2 model
base_model = MobileNetV2(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                         include_top=False,
                         weights='imagenet')

# Freeze the layers in the base model
base_model.trainable = False

# Create new model on top
model = Sequential([
    base_model,
    Flatten(),
    Dense(128, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Found 417 images belonging to 17 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 3, 3, 1280)       2257984
#  ional)
#
#  flatten (Flatten)           (None, 11520)             0
#
#  dense (Dense)               (None, 128)               1474688
#
#  dense_1 (Dense)             (None, 17)                2193
#
# =================================================================
# Total params: 3,734,865
# Trainable params: 1,476,881
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2
import time

# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Noise reduction 2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Define the MobileNetV2 model
base_model = MobileNetV2(input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                         include_top=False,
                         weights='imagenet')

# Freeze the layers in the base model
base_model.trainable = False

# Create new model on top
model = Sequential([
    base_model,
    Flatten(),
    Dense(128, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'resnetMobile_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 417 images belonging to 17 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 6s 74ms/step - loss: 10.9860 - accuracy: 0.1146 - val_loss: 3.9056 - val_accuracy: 0.1719
# Epoch 2/100
# 21/21 [==============================] - 0s 20ms/step - loss: 2.8667 - accuracy: 0.1548 - val_loss: 2.9715 - val_accuracy: 0.1250
# Epoch 3/100
# 21/21 [==============================] - 0s 24ms/step - loss: 2.5573 - accuracy: 0.1641 - val_loss: 2.8566 - val_accuracy: 0.0781
# Epoch 4/100
# 21/21 [==============================] - 0s 23ms/step - loss: 2.4839 - accuracy: 0.1827 - val_loss: 2.9635 - val_accuracy: 0.1094
# Epoch 5/100
# 21/21 [==============================] - 1s 24ms/step - loss: 2.3425 - accuracy: 0.2167 - val_loss: 3.0621 - val_accuracy: 0.0625
# Epoch 6/100
# 21/21 [==============================] - 0s 23ms/step - loss: 2.3330 - accuracy: 0.2353 - val_loss: 2.9171 - val_accuracy: 0.1094
# Epoch 7/100
# 21/21 [==============================] - 0s 19ms/step - loss: 2.2131 - accuracy: 0.2601 - val_loss: 2.8319 - val_accuracy: 0.1562
# Epoch 8/100
# 21/21 [==============================] - 0s 20ms/step - loss: 2.1838 - accuracy: 0.2786 - val_loss: 2.9022 - val_accuracy: 0.1406
# Epoch 9/100
# 21/21 [==============================] - 0s 19ms/step - loss: 2.1864 - accuracy: 0.2798 - val_loss: 2.8856 - val_accuracy: 0.1562
# Epoch 10/100
# 21/21 [==============================] - 0s 20ms/step - loss: 2.0690 - accuracy: 0.3251 - val_loss: 2.9707 - val_accuracy: 0.1562
# Epoch 11/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.9923 - accuracy: 0.3127 - val_loss: 2.9993 - val_accuracy: 0.1562
# Epoch 12/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.9937 - accuracy: 0.3034 - val_loss: 2.8546 - val_accuracy: 0.1406
# Epoch 13/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.9104 - accuracy: 0.3251 - val_loss: 2.9286 - val_accuracy: 0.1562
# Epoch 14/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.8942 - accuracy: 0.3591 - val_loss: 2.8590 - val_accuracy: 0.1875
# Epoch 15/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.8194 - accuracy: 0.3715 - val_loss: 2.8336 - val_accuracy: 0.1875
# Epoch 16/100
# 21/21 [==============================] - 0s 20ms/step - loss: 1.7502 - accuracy: 0.4149 - val_loss: 2.7458 - val_accuracy: 0.1719
# Epoch 17/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.7475 - accuracy: 0.3839 - val_loss: 2.8041 - val_accuracy: 0.1719
# Epoch 18/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.6978 - accuracy: 0.4077 - val_loss: 2.9694 - val_accuracy: 0.1875
# Epoch 19/100
# 21/21 [==============================] - 0s 22ms/step - loss: 1.6522 - accuracy: 0.4211 - val_loss: 3.0108 - val_accuracy: 0.1406
# Epoch 20/100
# 21/21 [==============================] - 0s 20ms/step - loss: 1.6153 - accuracy: 0.4365 - val_loss: 2.8306 - val_accuracy: 0.1875
# Epoch 21/100
# 21/21 [==============================] - 0s 21ms/step - loss: 1.6112 - accuracy: 0.4211 - val_loss: 2.9225 - val_accuracy: 0.2031
# Epoch 22/100
# 21/21 [==============================] - 0s 20ms/step - loss: 1.5644 - accuracy: 0.4551 - val_loss: 2.8761 - val_accuracy: 0.1875
# Epoch 23/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.5596 - accuracy: 0.4892 - val_loss: 2.8502 - val_accuracy: 0.2500
# Epoch 24/100
# 21/21 [==============================] - 0s 21ms/step - loss: 1.6076 - accuracy: 0.4799 - val_loss: 2.8465 - val_accuracy: 0.2188
# Epoch 25/100
# 21/21 [==============================] - 0s 23ms/step - loss: 1.4896 - accuracy: 0.4954 - val_loss: 3.0037 - val_accuracy: 0.2188
# Epoch 26/100
# 21/21 [==============================] - 1s 28ms/step - loss: 1.4695 - accuracy: 0.4768 - val_loss: 2.8608 - val_accuracy: 0.2031
# Epoch 27/100
# 21/21 [==============================] - 1s 26ms/step - loss: 1.4285 - accuracy: 0.5263 - val_loss: 2.9144 - val_accuracy: 0.2188
# Epoch 28/100
# 21/21 [==============================] - 1s 23ms/step - loss: 1.4342 - accuracy: 0.4923 - val_loss: 2.9972 - val_accuracy: 0.2344
# Epoch 29/100
# 21/21 [==============================] - 1s 26ms/step - loss: 1.4037 - accuracy: 0.5139 - val_loss: 2.9982 - val_accuracy: 0.2031
# Epoch 30/100
# 21/21 [==============================] - 0s 22ms/step - loss: 1.3479 - accuracy: 0.5449 - val_loss: 2.9030 - val_accuracy: 0.1875
# Epoch 31/100
# 21/21 [==============================] - 0s 20ms/step - loss: 1.3090 - accuracy: 0.5728 - val_loss: 2.8974 - val_accuracy: 0.2344
# Epoch 32/100
# 21/21 [==============================] - 0s 23ms/step - loss: 1.2318 - accuracy: 0.6006 - val_loss: 2.9551 - val_accuracy: 0.2344
# Epoch 33/100
# 21/21 [==============================] - 1s 35ms/step - loss: 1.2236 - accuracy: 0.6223 - val_loss: 3.1525 - val_accuracy: 0.2500
# Epoch 34/100
# 21/21 [==============================] - 1s 25ms/step - loss: 1.3726 - accuracy: 0.5325 - val_loss: 3.4776 - val_accuracy: 0.2031
# Epoch 35/100
# 21/21 [==============================] - 1s 25ms/step - loss: 1.2298 - accuracy: 0.5789 - val_loss: 3.1330 - val_accuracy: 0.2969
# Epoch 36/100
# 21/21 [==============================] - 0s 22ms/step - loss: 1.1992 - accuracy: 0.6223 - val_loss: 2.9908 - val_accuracy: 0.2812
# Epoch 37/100
# 21/21 [==============================] - 0s 21ms/step - loss: 1.1805 - accuracy: 0.6254 - val_loss: 2.9627 - val_accuracy: 0.2969
# Epoch 38/100
# 21/21 [==============================] - 0s 22ms/step - loss: 1.2191 - accuracy: 0.6068 - val_loss: 2.9801 - val_accuracy: 0.2188
# Epoch 39/100
# 21/21 [==============================] - 0s 21ms/step - loss: 1.3113 - accuracy: 0.5697 - val_loss: 2.9952 - val_accuracy: 0.3125
# Epoch 40/100
# 21/21 [==============================] - 0s 23ms/step - loss: 1.1427 - accuracy: 0.6285 - val_loss: 2.8778 - val_accuracy: 0.3281
# Epoch 41/100
# 21/21 [==============================] - 0s 20ms/step - loss: 1.2177 - accuracy: 0.5728 - val_loss: 3.0706 - val_accuracy: 0.2656
# Epoch 42/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.2098 - accuracy: 0.6037 - val_loss: 3.2484 - val_accuracy: 0.2812
# Epoch 43/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.1326 - accuracy: 0.6471 - val_loss: 3.0744 - val_accuracy: 0.3125
# Epoch 44/100
# 21/21 [==============================] - 0s 20ms/step - loss: 1.1215 - accuracy: 0.6563 - val_loss: 3.1763 - val_accuracy: 0.3281
# Epoch 45/100
# 21/21 [==============================] - 0s 19ms/step - loss: 1.0879 - accuracy: 0.6749 - val_loss: 3.2219 - val_accuracy: 0.3281
# Epoch 46/100
# 21/21 [==============================] - 0s 20ms/step - loss: 1.0085 - accuracy: 0.7152 - val_loss: 2.8765 - val_accuracy: 0.3750
# Epoch 47/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.9513 - accuracy: 0.7307 - val_loss: 2.8704 - val_accuracy: 0.3594
# Epoch 48/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.8955 - accuracy: 0.7430 - val_loss: 2.8745 - val_accuracy: 0.3750
# Epoch 49/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.8649 - accuracy: 0.7245 - val_loss: 2.7649 - val_accuracy: 0.4062
# Epoch 50/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.8308 - accuracy: 0.7946 - val_loss: 2.7373 - val_accuracy: 0.4375
# Epoch 51/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7820 - accuracy: 0.7957 - val_loss: 2.9851 - val_accuracy: 0.3750
# Epoch 52/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.8038 - accuracy: 0.7988 - val_loss: 2.8621 - val_accuracy: 0.4219
# Epoch 53/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7794 - accuracy: 0.7957 - val_loss: 2.8413 - val_accuracy: 0.4375
# Epoch 54/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7140 - accuracy: 0.8235 - val_loss: 3.2204 - val_accuracy: 0.4375
# Epoch 55/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7004 - accuracy: 0.8080 - val_loss: 3.1118 - val_accuracy: 0.4062
# Epoch 56/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.6460 - accuracy: 0.8204 - val_loss: 2.9390 - val_accuracy: 0.4375
# Epoch 57/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.8395 - accuracy: 0.7523 - val_loss: 3.2150 - val_accuracy: 0.4219
# Epoch 58/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.6904 - accuracy: 0.8173 - val_loss: 3.0644 - val_accuracy: 0.4531
# Epoch 59/100
# 21/21 [==============================] - 0s 23ms/step - loss: 0.5859 - accuracy: 0.8576 - val_loss: 2.9611 - val_accuracy: 0.5000
# Epoch 60/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.5409 - accuracy: 0.8762 - val_loss: 3.1516 - val_accuracy: 0.4688
# Epoch 61/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4879 - accuracy: 0.8916 - val_loss: 3.2033 - val_accuracy: 0.4688
# Epoch 62/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4952 - accuracy: 0.8854 - val_loss: 2.8588 - val_accuracy: 0.5000
# Epoch 63/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.5917 - accuracy: 0.8204 - val_loss: 3.0887 - val_accuracy: 0.5000
# Epoch 64/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4840 - accuracy: 0.8810 - val_loss: 3.2790 - val_accuracy: 0.4688
# Epoch 65/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4541 - accuracy: 0.9009 - val_loss: 3.2768 - val_accuracy: 0.4531
# Epoch 66/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4229 - accuracy: 0.9009 - val_loss: 3.4417 - val_accuracy: 0.5000
# Epoch 67/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4168 - accuracy: 0.9071 - val_loss: 3.2299 - val_accuracy: 0.5156
# Epoch 68/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.3981 - accuracy: 0.9257 - val_loss: 3.1587 - val_accuracy: 0.5312
# Epoch 69/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.3959 - accuracy: 0.9071 - val_loss: 3.3942 - val_accuracy: 0.4844
# Epoch 70/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.3617 - accuracy: 0.9319 - val_loss: 3.4891 - val_accuracy: 0.4844
# Epoch 71/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.3887 - accuracy: 0.9288 - val_loss: 3.7164 - val_accuracy: 0.4531
# Epoch 72/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4390 - accuracy: 0.9071 - val_loss: 3.3584 - val_accuracy: 0.5000
# Epoch 73/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.3133 - accuracy: 0.9474 - val_loss: 3.2585 - val_accuracy: 0.5000
# Epoch 74/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.2984 - accuracy: 0.9536 - val_loss: 3.1740 - val_accuracy: 0.5625
# Epoch 75/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.3011 - accuracy: 0.9598 - val_loss: 3.1921 - val_accuracy: 0.5312
# Epoch 76/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4183 - accuracy: 0.9133 - val_loss: 3.3837 - val_accuracy: 0.5312
# Epoch 77/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.3297 - accuracy: 0.9505 - val_loss: 3.6611 - val_accuracy: 0.5312
# Epoch 78/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.3240 - accuracy: 0.9412 - val_loss: 3.7727 - val_accuracy: 0.4375
# Epoch 79/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.2711 - accuracy: 0.9505 - val_loss: 3.4349 - val_accuracy: 0.5469
# Epoch 80/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.2530 - accuracy: 0.9598 - val_loss: 3.5337 - val_accuracy: 0.5312
# Epoch 81/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.2185 - accuracy: 0.9659 - val_loss: 3.4522 - val_accuracy: 0.5312
# Epoch 82/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.2012 - accuracy: 0.9659 - val_loss: 3.5576 - val_accuracy: 0.5312
# Epoch 83/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1857 - accuracy: 0.9721 - val_loss: 3.4308 - val_accuracy: 0.5469
# Epoch 84/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1894 - accuracy: 0.9628 - val_loss: 3.3150 - val_accuracy: 0.5469
# Epoch 85/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1878 - accuracy: 0.9721 - val_loss: 3.5285 - val_accuracy: 0.5469
# Epoch 86/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1686 - accuracy: 0.9752 - val_loss: 3.6916 - val_accuracy: 0.5312
# Epoch 87/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1663 - accuracy: 0.9752 - val_loss: 3.7325 - val_accuracy: 0.5312
# Epoch 88/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1604 - accuracy: 0.9783 - val_loss: 3.7772 - val_accuracy: 0.5312
# Epoch 89/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1563 - accuracy: 0.9721 - val_loss: 3.6583 - val_accuracy: 0.5625
# Epoch 90/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1540 - accuracy: 0.9721 - val_loss: 3.8701 - val_accuracy: 0.5312
# Epoch 91/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1537 - accuracy: 0.9721 - val_loss: 3.8565 - val_accuracy: 0.5312
# Epoch 92/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1487 - accuracy: 0.9721 - val_loss: 3.8498 - val_accuracy: 0.5469
# Epoch 93/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1502 - accuracy: 0.9752 - val_loss: 3.9078 - val_accuracy: 0.5469
# Epoch 94/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.1455 - accuracy: 0.9783 - val_loss: 3.8579 - val_accuracy: 0.5312
# Epoch 95/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1274 - accuracy: 0.9845 - val_loss: 3.8292 - val_accuracy: 0.5312
# Epoch 96/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1305 - accuracy: 0.9783 - val_loss: 3.8989 - val_accuracy: 0.5312
# Epoch 97/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1381 - accuracy: 0.9721 - val_loss: 3.9663 - val_accuracy: 0.5469
# Epoch 98/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1393 - accuracy: 0.9721 - val_loss: 3.8050 - val_accuracy: 0.5312
# Epoch 99/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1386 - accuracy: 0.9721 - val_loss: 4.0432 - val_accuracy: 0.5625
# Epoch 100/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1396 - accuracy: 0.9721 - val_loss: 3.9952 - val_accuracy: 0.5625
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1290 - accuracy: 0.9735
# 5/5 [==============================] - 1s 115ms/step - loss: 3.3684 - accuracy: 0.6282
# Fold 1:
# Train accuracy: 0.9734513163566589, Validation accuracy: 0.6282051205635071
# Training time for fold 1: 52.59787154197693 seconds
# c:\Users\sumit\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1324 - accuracy: 0.9721 - val_loss: 4.1173 - val_accuracy: 0.5312
# Epoch 2/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1305 - accuracy: 0.9690 - val_loss: 3.9605 - val_accuracy: 0.5312
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.1322 - accuracy: 0.9721 - val_loss: 4.2343 - val_accuracy: 0.5312
# Epoch 4/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1218 - accuracy: 0.9690 - val_loss: 4.0932 - val_accuracy: 0.5625
# Epoch 5/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1228 - accuracy: 0.9752 - val_loss: 4.1560 - val_accuracy: 0.5312
# Epoch 6/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1124 - accuracy: 0.9752 - val_loss: 4.2379 - val_accuracy: 0.5469
# Epoch 7/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1225 - accuracy: 0.9721 - val_loss: 4.3768 - val_accuracy: 0.5312
# Epoch 8/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1127 - accuracy: 0.9752 - val_loss: 4.0946 - val_accuracy: 0.5469
# Epoch 9/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1126 - accuracy: 0.9721 - val_loss: 4.1994 - val_accuracy: 0.5469
# Epoch 10/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1139 - accuracy: 0.9752 - val_loss: 4.2079 - val_accuracy: 0.5312
# Epoch 11/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1166 - accuracy: 0.9690 - val_loss: 4.1602 - val_accuracy: 0.5312
# Epoch 12/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1009 - accuracy: 0.9752 - val_loss: 4.2467 - val_accuracy: 0.5625
# Epoch 13/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1134 - accuracy: 0.9721 - val_loss: 4.1277 - val_accuracy: 0.5625
# Epoch 14/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1026 - accuracy: 0.9721 - val_loss: 4.3353 - val_accuracy: 0.5469
# Epoch 15/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1118 - accuracy: 0.9721 - val_loss: 4.3184 - val_accuracy: 0.5625
# Epoch 16/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1095 - accuracy: 0.9721 - val_loss: 4.3516 - val_accuracy: 0.5469
# Epoch 17/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1074 - accuracy: 0.9690 - val_loss: 4.3037 - val_accuracy: 0.5312
# Epoch 18/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1083 - accuracy: 0.9721 - val_loss: 4.4902 - val_accuracy: 0.5469
# Epoch 19/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1054 - accuracy: 0.9721 - val_loss: 4.3717 - val_accuracy: 0.5469
# Epoch 20/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.1199 - accuracy: 0.9690 - val_loss: 4.3213 - val_accuracy: 0.5312
# Epoch 21/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1149 - accuracy: 0.9783 - val_loss: 4.5599 - val_accuracy: 0.5625
# Epoch 22/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0992 - accuracy: 0.9783 - val_loss: 4.5229 - val_accuracy: 0.5469
# Epoch 23/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.1021 - accuracy: 0.9721 - val_loss: 4.5879 - val_accuracy: 0.5312
# Epoch 24/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0894 - accuracy: 0.9783 - val_loss: 4.5616 - val_accuracy: 0.5312
# Epoch 25/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1003 - accuracy: 0.9721 - val_loss: 4.6406 - val_accuracy: 0.5312
# Epoch 26/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.1497 - accuracy: 0.9536 - val_loss: 4.3755 - val_accuracy: 0.5312
# Epoch 27/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.1159 - accuracy: 0.9752 - val_loss: 4.4073 - val_accuracy: 0.5625
# Epoch 28/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.1107 - accuracy: 0.9752 - val_loss: 4.6984 - val_accuracy: 0.5312
# Epoch 29/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0885 - accuracy: 0.9821 - val_loss: 4.5108 - val_accuracy: 0.5625
# Epoch 30/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0900 - accuracy: 0.9783 - val_loss: 4.5245 - val_accuracy: 0.5312
# Epoch 31/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0863 - accuracy: 0.9783 - val_loss: 4.6895 - val_accuracy: 0.5625
# Epoch 32/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0865 - accuracy: 0.9783 - val_loss: 4.5779 - val_accuracy: 0.5625
# Epoch 33/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0721 - accuracy: 0.9814 - val_loss: 4.7385 - val_accuracy: 0.5469
# Epoch 34/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0908 - accuracy: 0.9783 - val_loss: 4.7612 - val_accuracy: 0.5469
# Epoch 35/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0939 - accuracy: 0.9814 - val_loss: 4.7271 - val_accuracy: 0.5625
# Epoch 36/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0806 - accuracy: 0.9876 - val_loss: 4.7037 - val_accuracy: 0.5625
# Epoch 37/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0816 - accuracy: 0.9845 - val_loss: 4.5870 - val_accuracy: 0.5625
# Epoch 38/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0643 - accuracy: 0.9938 - val_loss: 4.7977 - val_accuracy: 0.5625
# Epoch 39/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0618 - accuracy: 0.9938 - val_loss: 4.5819 - val_accuracy: 0.5781
# Epoch 40/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0608 - accuracy: 0.9911 - val_loss: 4.5290 - val_accuracy: 0.5781
# Epoch 41/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0631 - accuracy: 0.9938 - val_loss: 5.2947 - val_accuracy: 0.5469
# Epoch 42/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0639 - accuracy: 0.9938 - val_loss: 4.9242 - val_accuracy: 0.5781
# Epoch 43/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0621 - accuracy: 0.9938 - val_loss: 4.6164 - val_accuracy: 0.5625
# Epoch 44/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0699 - accuracy: 0.9876 - val_loss: 5.0573 - val_accuracy: 0.5469
# Epoch 45/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0556 - accuracy: 0.9938 - val_loss: 4.9820 - val_accuracy: 0.5625
# Epoch 46/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0487 - accuracy: 0.9938 - val_loss: 4.7994 - val_accuracy: 0.5781
# Epoch 47/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0309 - accuracy: 0.9969 - val_loss: 5.0510 - val_accuracy: 0.5781
# Epoch 48/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0472 - accuracy: 0.9907 - val_loss: 4.8668 - val_accuracy: 0.5781
# Epoch 49/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0312 - accuracy: 0.9938 - val_loss: 5.2009 - val_accuracy: 0.5781
# Epoch 50/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0395 - accuracy: 0.9907 - val_loss: 4.8379 - val_accuracy: 0.5781
# Epoch 51/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0451 - accuracy: 0.9907 - val_loss: 5.3323 - val_accuracy: 0.5781
# Epoch 52/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0354 - accuracy: 0.9938 - val_loss: 5.1315 - val_accuracy: 0.5781
# Epoch 53/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0363 - accuracy: 0.9938 - val_loss: 4.8488 - val_accuracy: 0.5625
# Epoch 54/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0244 - accuracy: 0.9969 - val_loss: 5.2520 - val_accuracy: 0.5781
# Epoch 55/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0292 - accuracy: 0.9938 - val_loss: 5.2159 - val_accuracy: 0.5625
# Epoch 56/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0268 - accuracy: 0.9938 - val_loss: 5.0581 - val_accuracy: 0.5781
# Epoch 57/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0221 - accuracy: 0.9938 - val_loss: 5.0191 - val_accuracy: 0.5781
# Epoch 58/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0209 - accuracy: 0.9938 - val_loss: 5.1185 - val_accuracy: 0.5781
# Epoch 59/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 5.0658 - val_accuracy: 0.5781
# Epoch 60/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 5.0782 - val_accuracy: 0.5781
# Epoch 61/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 5.1099 - val_accuracy: 0.5781
# Epoch 62/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 5.1213 - val_accuracy: 0.5781
# Epoch 63/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 5.1704 - val_accuracy: 0.5781
# Epoch 64/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 5.1920 - val_accuracy: 0.5781
# Epoch 65/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 5.1727 - val_accuracy: 0.5781
# Epoch 66/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 5.2312 - val_accuracy: 0.5781
# Epoch 67/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 5.2046 - val_accuracy: 0.5781
# Epoch 68/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 5.1422 - val_accuracy: 0.5781
# Epoch 69/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 5.2320 - val_accuracy: 0.5781
# Epoch 70/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 5.2433 - val_accuracy: 0.5781
# Epoch 71/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 5.1900 - val_accuracy: 0.5781
# Epoch 72/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 5.2311 - val_accuracy: 0.5781
# Epoch 73/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 5.2093 - val_accuracy: 0.5781
# Epoch 74/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 5.2744 - val_accuracy: 0.5781
# Epoch 75/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 5.2521 - val_accuracy: 0.5781
# Epoch 76/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 5.2192 - val_accuracy: 0.5781
# Epoch 77/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 5.3240 - val_accuracy: 0.5781
# Epoch 78/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 5.3065 - val_accuracy: 0.5781
# Epoch 79/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 5.3477 - val_accuracy: 0.5781
# Epoch 80/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 5.3038 - val_accuracy: 0.5781
# Epoch 81/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 5.2719 - val_accuracy: 0.5781
# Epoch 82/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 5.3413 - val_accuracy: 0.5781
# Epoch 83/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 5.3086 - val_accuracy: 0.5781
# Epoch 84/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 5.2798 - val_accuracy: 0.5781
# Epoch 85/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 5.3625 - val_accuracy: 0.5781
# Epoch 86/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 5.4036 - val_accuracy: 0.5781
# Epoch 87/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 5.3867 - val_accuracy: 0.5781
# Epoch 88/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 5.4610 - val_accuracy: 0.5781
# Epoch 89/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 5.3702 - val_accuracy: 0.5781
# Epoch 90/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 5.4119 - val_accuracy: 0.5781
# Epoch 91/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 5.4316 - val_accuracy: 0.5781
# Epoch 92/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 5.5032 - val_accuracy: 0.5781
# Epoch 93/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 5.4895 - val_accuracy: 0.5781
# Epoch 94/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 5.4429 - val_accuracy: 0.5781
# Epoch 95/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 5.4807 - val_accuracy: 0.5781
# Epoch 96/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 5.4771 - val_accuracy: 0.5781
# Epoch 97/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 5.5087 - val_accuracy: 0.5781
# Epoch 98/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 5.5130 - val_accuracy: 0.5781
# Epoch 99/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 5.5243 - val_accuracy: 0.5781
# Epoch 100/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 5.4092 - val_accuracy: 0.5781
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0138 - accuracy: 1.0000
# 5/5 [==============================] - 0s 14ms/step - loss: 4.4999 - accuracy: 0.6410
# Fold 2:
# Train accuracy: 1.0, Validation accuracy: 0.6410256624221802
# Training time for fold 2: 94.84978246688843 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 5.5072 - val_accuracy: 0.5781
# Epoch 2/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 5.4819 - val_accuracy: 0.5781
# Epoch 3/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 5.5289 - val_accuracy: 0.5781
# Epoch 4/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 5.5646 - val_accuracy: 0.5781
# Epoch 5/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 5.5405 - val_accuracy: 0.5781
# Epoch 6/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 5.5320 - val_accuracy: 0.5781
# Epoch 7/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 5.6021 - val_accuracy: 0.5781
# Epoch 8/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 5.5764 - val_accuracy: 0.5781
# Epoch 9/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 5.6087 - val_accuracy: 0.5781
# Epoch 10/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 5.6369 - val_accuracy: 0.5781
# Epoch 11/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 5.5956 - val_accuracy: 0.5781
# Epoch 12/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 5.5978 - val_accuracy: 0.5781
# Epoch 13/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 5.6286 - val_accuracy: 0.5781
# Epoch 14/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 5.6065 - val_accuracy: 0.5781
# Epoch 15/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 5.6436 - val_accuracy: 0.5781
# Epoch 16/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 5.6584 - val_accuracy: 0.5781
# Epoch 17/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 5.6172 - val_accuracy: 0.5781
# Epoch 18/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 5.6567 - val_accuracy: 0.5781
# Epoch 19/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 5.6741 - val_accuracy: 0.5781
# Epoch 20/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 5.6934 - val_accuracy: 0.5781
# Epoch 21/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 5.6945 - val_accuracy: 0.5781
# Epoch 22/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 5.7221 - val_accuracy: 0.5781
# Epoch 23/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 5.6860 - val_accuracy: 0.5781
# Epoch 24/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 5.7286 - val_accuracy: 0.5781
# Epoch 25/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 5.7642 - val_accuracy: 0.5781
# Epoch 26/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 5.7552 - val_accuracy: 0.5781
# Epoch 27/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 5.5909 - val_accuracy: 0.5625
# Epoch 28/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 6.1315 - val_accuracy: 0.5625
# Epoch 29/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 5.8380 - val_accuracy: 0.5625
# Epoch 30/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 5.9211 - val_accuracy: 0.5625
# Epoch 31/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 5.8682 - val_accuracy: 0.5625
# Epoch 32/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 5.8543 - val_accuracy: 0.5625
# Epoch 33/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 5.8792 - val_accuracy: 0.5625
# Epoch 34/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 5.9324 - val_accuracy: 0.5625
# Epoch 35/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 5.8838 - val_accuracy: 0.5625
# Epoch 36/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 5.9032 - val_accuracy: 0.5625
# Epoch 37/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 5.8899 - val_accuracy: 0.5625
# Epoch 38/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 5.8706 - val_accuracy: 0.5625
# Epoch 39/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 5.9383 - val_accuracy: 0.5625
# Epoch 40/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 5.9205 - val_accuracy: 0.5625
# Epoch 41/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 5.9097 - val_accuracy: 0.5625
# Epoch 42/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 5.9305 - val_accuracy: 0.5625
# Epoch 43/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 5.9702 - val_accuracy: 0.5625
# Epoch 44/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 5.9632 - val_accuracy: 0.5781
# Epoch 45/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 5.9593 - val_accuracy: 0.5781
# Epoch 46/100
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 5.9717 - val_accuracy: 0.5625
# Epoch 47/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 5.9838 - val_accuracy: 0.5625
# Epoch 48/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 6.0024 - val_accuracy: 0.5781
# Epoch 49/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 5.9630 - val_accuracy: 0.5781
# Epoch 50/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 5.9922 - val_accuracy: 0.5625
# Epoch 51/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 5.9923 - val_accuracy: 0.5625
# Epoch 52/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 5.9882 - val_accuracy: 0.5781
# Epoch 53/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 6.0552 - val_accuracy: 0.5625
# Epoch 54/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 5.8851 - val_accuracy: 0.5781
# Epoch 55/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 6.1200 - val_accuracy: 0.5625
# Epoch 56/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 6.0320 - val_accuracy: 0.5781
# Epoch 57/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 5.9966 - val_accuracy: 0.5781
# Epoch 58/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 6.0597 - val_accuracy: 0.5781
# Epoch 59/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 6.0620 - val_accuracy: 0.5625
# Epoch 60/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 6.0260 - val_accuracy: 0.5781
# Epoch 61/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 6.0736 - val_accuracy: 0.5625
# Epoch 62/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 6.0946 - val_accuracy: 0.5625
# Epoch 63/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 6.1334 - val_accuracy: 0.5625
# Epoch 64/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 6.0876 - val_accuracy: 0.5625
# Epoch 65/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 6.0961 - val_accuracy: 0.5625
# Epoch 66/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 6.0854 - val_accuracy: 0.5625
# Epoch 67/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 6.1151 - val_accuracy: 0.5781
# Epoch 68/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 6.1364 - val_accuracy: 0.5625
# Epoch 69/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 6.1334 - val_accuracy: 0.5781
# Epoch 70/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 6.1436 - val_accuracy: 0.5625
# Epoch 71/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 6.0946 - val_accuracy: 0.5781
# Epoch 72/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 6.1518 - val_accuracy: 0.5625
# Epoch 73/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 6.1549 - val_accuracy: 0.5781
# Epoch 74/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 6.1987 - val_accuracy: 0.5625
# Epoch 75/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 6.1766 - val_accuracy: 0.5781
# Epoch 76/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 6.2115 - val_accuracy: 0.5625
# Epoch 77/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 6.1960 - val_accuracy: 0.5625
# Epoch 78/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 6.2144 - val_accuracy: 0.5625
# Epoch 79/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 6.2011 - val_accuracy: 0.5781
# Epoch 80/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 6.2834 - val_accuracy: 0.5625
# Epoch 81/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 6.2150 - val_accuracy: 0.5781
# Epoch 82/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 6.2427 - val_accuracy: 0.5625
# Epoch 83/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 6.2301 - val_accuracy: 0.5781
# Epoch 84/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 6.2379 - val_accuracy: 0.5781
# Epoch 85/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 6.2784 - val_accuracy: 0.5781
# Epoch 86/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 6.2930 - val_accuracy: 0.5781
# Epoch 87/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 6.3062 - val_accuracy: 0.5781
# Epoch 88/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 6.2562 - val_accuracy: 0.5781
# Epoch 89/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 6.3189 - val_accuracy: 0.5781
# Epoch 90/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 6.3205 - val_accuracy: 0.5781
# Epoch 91/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 6.2782 - val_accuracy: 0.5781
# Epoch 92/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 6.3509 - val_accuracy: 0.5781
# Epoch 93/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 6.3078 - val_accuracy: 0.5781
# Epoch 94/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 6.3677 - val_accuracy: 0.5625
# Epoch 95/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 6.3333 - val_accuracy: 0.5625
# Epoch 96/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 6.3331 - val_accuracy: 0.5781
# Epoch 97/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 6.3864 - val_accuracy: 0.5625
# Epoch 98/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 6.3942 - val_accuracy: 0.5781
# Epoch 99/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 6.3840 - val_accuracy: 0.5781
# Epoch 100/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 6.3976 - val_accuracy: 0.5625
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0083 - accuracy: 1.0000
# 5/5 [==============================] - 0s 16ms/step - loss: 5.3198 - accuracy: 0.6154
# Fold 3:
# Train accuracy: 1.0, Validation accuracy: 0.6153846383094788
# Training time for fold 3: 137.57202816009521 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 6.4187 - val_accuracy: 0.5781
# Epoch 2/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 6.4415 - val_accuracy: 0.5625
# Epoch 3/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 6.4129 - val_accuracy: 0.5781
# Epoch 4/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 6.4243 - val_accuracy: 0.5781
# Epoch 5/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 6.4019 - val_accuracy: 0.5781
# Epoch 6/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 6.4296 - val_accuracy: 0.5781
# Epoch 7/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 6.4694 - val_accuracy: 0.5781
# Epoch 8/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 6.4366 - val_accuracy: 0.5781
# Epoch 9/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 6.4948 - val_accuracy: 0.5781
# Epoch 10/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 6.4797 - val_accuracy: 0.5781
# Epoch 11/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 6.4825 - val_accuracy: 0.5781
# Epoch 12/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 6.4854 - val_accuracy: 0.5781
# Epoch 13/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 6.5146 - val_accuracy: 0.5781
# Epoch 14/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 6.5261 - val_accuracy: 0.5625
# Epoch 15/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 6.5100 - val_accuracy: 0.5781
# Epoch 16/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 6.5351 - val_accuracy: 0.5781
# Epoch 17/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 6.5509 - val_accuracy: 0.5625
# Epoch 18/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 6.5330 - val_accuracy: 0.5781
# Epoch 19/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 6.5430 - val_accuracy: 0.5781
# Epoch 20/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 6.5576 - val_accuracy: 0.5781
# Epoch 21/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 6.5603 - val_accuracy: 0.5781
# Epoch 22/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 6.5769 - val_accuracy: 0.5781
# Epoch 23/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 6.5843 - val_accuracy: 0.5781
# Epoch 24/100
# ...
# Epoch 96/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.8436 - accuracy: 0.6594 - val_loss: 5.7640 - val_accuracy: 0.4219
# Epoch 97/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.8275 - accuracy: 0.6718 - val_loss: 6.1329 - val_accuracy: 0.4375
# Epoch 98/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7851 - accuracy: 0.6935 - val_loss: 5.9657 - val_accuracy: 0.4062
# Epoch 99/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.7867 - accuracy: 0.7121 - val_loss: 6.5389 - val_accuracy: 0.3906
# Epoch 100/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7827 - accuracy: 0.7214 - val_loss: 5.8011 - val_accuracy: 0.4062
# 22/22 [==============================] - 0s 15ms/step - loss: 0.7587 - accuracy: 0.7404
# 5/5 [==============================] - 0s 18ms/step - loss: 4.8906 - accuracy: 0.4744
# Fold 4:
# Train accuracy: 0.7404129505157471, Validation accuracy: 0.4743589758872986
# Training time for fold 4: 180.7881736755371 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.7711 - accuracy: 0.7276 - val_loss: 5.8069 - val_accuracy: 0.4062
# Epoch 2/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.8057 - accuracy: 0.7461 - val_loss: 6.5971 - val_accuracy: 0.4531
# Epoch 3/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7639 - accuracy: 0.7926 - val_loss: 6.7461 - val_accuracy: 0.4531
# Epoch 4/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.7539 - accuracy: 0.7895 - val_loss: 7.0359 - val_accuracy: 0.4531
# Epoch 5/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7311 - accuracy: 0.7833 - val_loss: 6.5302 - val_accuracy: 0.4375
# Epoch 6/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7355 - accuracy: 0.7833 - val_loss: 6.2104 - val_accuracy: 0.4375
# Epoch 7/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7969 - accuracy: 0.7616 - val_loss: 6.9977 - val_accuracy: 0.3750
# Epoch 8/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7484 - accuracy: 0.7988 - val_loss: 6.4205 - val_accuracy: 0.4844
# Epoch 9/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.7322 - accuracy: 0.8142 - val_loss: 7.0786 - val_accuracy: 0.4219
# Epoch 10/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7192 - accuracy: 0.8019 - val_loss: 6.5941 - val_accuracy: 0.4688
# Epoch 11/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7226 - accuracy: 0.8235 - val_loss: 6.7590 - val_accuracy: 0.4844
# Epoch 12/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.7209 - accuracy: 0.8080 - val_loss: 6.1163 - val_accuracy: 0.4531
# Epoch 13/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7066 - accuracy: 0.8204 - val_loss: 7.4895 - val_accuracy: 0.4375
# Epoch 14/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6817 - accuracy: 0.8514 - val_loss: 7.2933 - val_accuracy: 0.4531
# Epoch 15/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7335 - accuracy: 0.7895 - val_loss: 7.1682 - val_accuracy: 0.4531
# Epoch 16/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7212 - accuracy: 0.8019 - val_loss: 6.5319 - val_accuracy: 0.5000
# Epoch 17/100
# 21/21 [==============================] - 0s 22ms/step - loss: 0.6858 - accuracy: 0.8328 - val_loss: 7.1024 - val_accuracy: 0.4375
# Epoch 18/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7011 - accuracy: 0.8173 - val_loss: 7.3193 - val_accuracy: 0.4844
# Epoch 19/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6885 - accuracy: 0.8359 - val_loss: 7.2825 - val_accuracy: 0.4531
# Epoch 20/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6701 - accuracy: 0.8514 - val_loss: 6.9589 - val_accuracy: 0.5000
# Epoch 21/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6792 - accuracy: 0.8266 - val_loss: 6.6721 - val_accuracy: 0.4688
# Epoch 22/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6585 - accuracy: 0.8638 - val_loss: 7.5645 - val_accuracy: 0.4688
# Epoch 23/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7383 - accuracy: 0.7926 - val_loss: 8.2123 - val_accuracy: 0.4062
# Epoch 24/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6879 - accuracy: 0.8297 - val_loss: 6.9710 - val_accuracy: 0.4688
# Epoch 25/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6577 - accuracy: 0.8483 - val_loss: 7.0632 - val_accuracy: 0.4844
# Epoch 26/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6528 - accuracy: 0.8452 - val_loss: 7.5020 - val_accuracy: 0.4375
# Epoch 27/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.7128 - accuracy: 0.8006 - val_loss: 7.3143 - val_accuracy: 0.4062
# Epoch 28/100
# 21/21 [==============================] - 0s 17ms/step - loss: 1.1005 - accuracy: 0.6316 - val_loss: 7.5894 - val_accuracy: 0.4375
# Epoch 29/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.8494 - accuracy: 0.6780 - val_loss: 7.6231 - val_accuracy: 0.4219
# Epoch 30/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6747 - accuracy: 0.8142 - val_loss: 7.2572 - val_accuracy: 0.4375
# Epoch 31/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6970 - accuracy: 0.7957 - val_loss: 7.3360 - val_accuracy: 0.4062
# Epoch 32/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6506 - accuracy: 0.8328 - val_loss: 7.9786 - val_accuracy: 0.3906
# Epoch 33/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6661 - accuracy: 0.8173 - val_loss: 8.1587 - val_accuracy: 0.4375
# Epoch 34/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6589 - accuracy: 0.8297 - val_loss: 7.7111 - val_accuracy: 0.4688
# Epoch 35/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6262 - accuracy: 0.8421 - val_loss: 7.8376 - val_accuracy: 0.4688
# Epoch 36/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5873 - accuracy: 0.8669 - val_loss: 7.5277 - val_accuracy: 0.4844
# Epoch 37/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5732 - accuracy: 0.8824 - val_loss: 7.5976 - val_accuracy: 0.4375
# Epoch 38/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5709 - accuracy: 0.8793 - val_loss: 7.9025 - val_accuracy: 0.4531
# Epoch 39/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5938 - accuracy: 0.8638 - val_loss: 7.6154 - val_accuracy: 0.4531
# Epoch 40/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5716 - accuracy: 0.8793 - val_loss: 7.8934 - val_accuracy: 0.4531
# Epoch 41/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.5604 - accuracy: 0.8929 - val_loss: 7.9584 - val_accuracy: 0.4688
# Epoch 42/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5541 - accuracy: 0.8824 - val_loss: 8.0374 - val_accuracy: 0.4375
# Epoch 43/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5445 - accuracy: 0.8854 - val_loss: 8.5106 - val_accuracy: 0.4375
# Epoch 44/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6707 - accuracy: 0.7926 - val_loss: 8.3300 - val_accuracy: 0.4375
# Epoch 45/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.5941 - accuracy: 0.8359 - val_loss: 7.7446 - val_accuracy: 0.4688
# Epoch 46/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5868 - accuracy: 0.8545 - val_loss: 8.3188 - val_accuracy: 0.4531
# Epoch 47/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6279 - accuracy: 0.8328 - val_loss: 8.4120 - val_accuracy: 0.4375
# Epoch 48/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5824 - accuracy: 0.8542 - val_loss: 8.0396 - val_accuracy: 0.4531
# Epoch 49/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5625 - accuracy: 0.8793 - val_loss: 8.1891 - val_accuracy: 0.5000
# Epoch 50/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5754 - accuracy: 0.8669 - val_loss: 8.2199 - val_accuracy: 0.4219
# Epoch 51/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6056 - accuracy: 0.8514 - val_loss: 8.7130 - val_accuracy: 0.4219
# Epoch 52/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5570 - accuracy: 0.8731 - val_loss: 8.3146 - val_accuracy: 0.5000
# Epoch 53/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5361 - accuracy: 0.8854 - val_loss: 8.6379 - val_accuracy: 0.4688
# Epoch 54/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.5958 - accuracy: 0.8421 - val_loss: 8.2615 - val_accuracy: 0.4531
# Epoch 55/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.7842 - accuracy: 0.7276 - val_loss: 9.3940 - val_accuracy: 0.4531
# Epoch 56/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.6761 - accuracy: 0.7709 - val_loss: 9.6115 - val_accuracy: 0.4219
# Epoch 57/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.6482 - accuracy: 0.7864 - val_loss: 9.0084 - val_accuracy: 0.4531
# Epoch 58/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.5748 - accuracy: 0.8452 - val_loss: 8.9391 - val_accuracy: 0.4062
# Epoch 59/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5845 - accuracy: 0.8204 - val_loss: 8.8474 - val_accuracy: 0.4531
# Epoch 60/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5441 - accuracy: 0.8885 - val_loss: 8.6062 - val_accuracy: 0.4688
# Epoch 61/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5403 - accuracy: 0.8824 - val_loss: 8.7037 - val_accuracy: 0.4844
# Epoch 62/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5306 - accuracy: 0.8824 - val_loss: 8.4916 - val_accuracy: 0.4375
# Epoch 63/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5097 - accuracy: 0.9102 - val_loss: 8.8350 - val_accuracy: 0.4844
# Epoch 64/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5142 - accuracy: 0.8978 - val_loss: 8.8358 - val_accuracy: 0.5000
# Epoch 65/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5130 - accuracy: 0.8916 - val_loss: 9.1741 - val_accuracy: 0.4375
# Epoch 66/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5141 - accuracy: 0.8731 - val_loss: 9.2591 - val_accuracy: 0.4531
# Epoch 67/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5087 - accuracy: 0.8885 - val_loss: 9.0748 - val_accuracy: 0.4688
# Epoch 68/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5157 - accuracy: 0.8854 - val_loss: 8.7188 - val_accuracy: 0.4844
# Epoch 69/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5102 - accuracy: 0.8854 - val_loss: 8.9097 - val_accuracy: 0.4531
# Epoch 70/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.5076 - accuracy: 0.8762 - val_loss: 9.0774 - val_accuracy: 0.5000
# Epoch 71/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4901 - accuracy: 0.9040 - val_loss: 8.9139 - val_accuracy: 0.5156
# Epoch 72/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4787 - accuracy: 0.9071 - val_loss: 9.4232 - val_accuracy: 0.4844
# Epoch 73/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4812 - accuracy: 0.9009 - val_loss: 9.5102 - val_accuracy: 0.5312
# Epoch 74/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4651 - accuracy: 0.9195 - val_loss: 9.1440 - val_accuracy: 0.5312
# Epoch 75/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4766 - accuracy: 0.9226 - val_loss: 9.6583 - val_accuracy: 0.4219
# Epoch 76/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4697 - accuracy: 0.9009 - val_loss: 9.0750 - val_accuracy: 0.5312
# Epoch 77/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4807 - accuracy: 0.9071 - val_loss: 9.0205 - val_accuracy: 0.5469
# Epoch 78/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4658 - accuracy: 0.9133 - val_loss: 9.3726 - val_accuracy: 0.5156
# Epoch 79/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4609 - accuracy: 0.9009 - val_loss: 9.5595 - val_accuracy: 0.4844
# Epoch 80/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4646 - accuracy: 0.9009 - val_loss: 9.4167 - val_accuracy: 0.5312
# Epoch 81/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4566 - accuracy: 0.9102 - val_loss: 9.5750 - val_accuracy: 0.5312
# Epoch 82/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4573 - accuracy: 0.9164 - val_loss: 9.3620 - val_accuracy: 0.5156
# Epoch 83/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4558 - accuracy: 0.9164 - val_loss: 10.1370 - val_accuracy: 0.4844
# Epoch 84/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4972 - accuracy: 0.8824 - val_loss: 9.1080 - val_accuracy: 0.4844
# Epoch 85/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4796 - accuracy: 0.9009 - val_loss: 9.8133 - val_accuracy: 0.5000
# Epoch 86/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4708 - accuracy: 0.9009 - val_loss: 9.6887 - val_accuracy: 0.5156
# Epoch 87/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.5021 - accuracy: 0.8916 - val_loss: 9.9623 - val_accuracy: 0.4688
# Epoch 88/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5802 - accuracy: 0.8638 - val_loss: 8.3617 - val_accuracy: 0.5156
# Epoch 89/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6293 - accuracy: 0.8235 - val_loss: 9.7926 - val_accuracy: 0.4688
# Epoch 90/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.7760 - accuracy: 0.7307 - val_loss: 10.5142 - val_accuracy: 0.3906
# Epoch 91/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.5551 - accuracy: 0.8328 - val_loss: 9.2879 - val_accuracy: 0.5000
# Epoch 92/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.5503 - accuracy: 0.8700 - val_loss: 10.1908 - val_accuracy: 0.4688
# Epoch 93/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4782 - accuracy: 0.8916 - val_loss: 10.4776 - val_accuracy: 0.4688
# Epoch 94/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4469 - accuracy: 0.9195 - val_loss: 9.5790 - val_accuracy: 0.4844
# Epoch 95/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.4414 - accuracy: 0.9164 - val_loss: 10.0384 - val_accuracy: 0.5000
# Epoch 96/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4553 - accuracy: 0.8947 - val_loss: 9.7276 - val_accuracy: 0.4531
# Epoch 97/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4496 - accuracy: 0.9040 - val_loss: 10.1445 - val_accuracy: 0.4688
# Epoch 98/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.4643 - accuracy: 0.9133 - val_loss: 9.8813 - val_accuracy: 0.4688
# Epoch 99/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4356 - accuracy: 0.9102 - val_loss: 9.7924 - val_accuracy: 0.4844
# Epoch 100/100
# 21/21 [==============================] - 0s 19ms/step - loss: 0.4281 - accuracy: 0.9133 - val_loss: 9.9657 - val_accuracy: 0.5000
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4178 - accuracy: 0.9204
# 5/5 [==============================] - 0s 16ms/step - loss: 8.3491 - accuracy: 0.5385
# Fold 5:
# Train accuracy: 0.9203540086746216, Validation accuracy: 0.5384615659713745
# Training time for fold 5: 223.85223412513733 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 92.68436551094055 %
# Average Validation Accuracy: 57.94871926307679 %
# Average Training Time: 137.932017993927
# Total Training Time: 224.0515649318695

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsResnetMObilekfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+----------------------+----------------------+----------------------+---------+
# | Class |      Precision       |        Recall        |       F1 Score       | Support |
# +-------+----------------------+----------------------+----------------------+---------+
# |   0   | 0.13793103448275862  | 0.21052631578947367  | 0.16666666666666666  |    19   |
# |   1   |         0.0          |         0.0          |         0.0          |    20   |
# |   10  | 0.058823529411764705 | 0.058823529411764705 | 0.058823529411764705 |    17   |
# |   2   | 0.041666666666666664 | 0.041666666666666664 | 0.041666666666666664 |    24   |
# |   3   | 0.05263157894736842  | 0.05263157894736842  | 0.05263157894736842  |    19   |
# |   4   |         0.0          |         0.0          |         0.0          |    20   |
# |   5   | 0.16666666666666666  | 0.17647058823529413  | 0.17142857142857143  |    17   |
# |   6   | 0.13333333333333333  | 0.11764705882352941  |        0.125         |    17   |
# |   7   | 0.06666666666666667  | 0.058823529411764705 |        0.0625        |    17   |
# |   8   | 0.045454545454545456 | 0.045454545454545456 | 0.045454545454545456 |    22   |
# |   9   | 0.16129032258064516  |  0.2631578947368421  |         0.2          |    19   |
# |  box  |         0.1          |         0.05         | 0.06666666666666667  |    20   |
# |  fun  |         0.05         |         0.05         |         0.05         |    20   |
# |  good | 0.08333333333333333  | 0.08333333333333333  | 0.08333333333333333  |    24   |
# |  grow |         0.0          |         0.0          |         0.0          |    20   |
# |  hero |         0.0          |         0.0          |         0.0          |    22   |
# | trust | 0.045454545454545456 | 0.045454545454545456 | 0.045454545454545456 |    22   |
# +-------+----------------------+----------------------+----------------------+---------+
#
# Validation Metrics:
# +-------+--------------------+--------+---------------------+---------+
# | Class |     Precision      | Recall |       F1 Score      | Support |
# +-------+--------------------+--------+---------------------+---------+
# |   0   |        0.6         |  0.75  |  0.6666666666666666 |    4    |
# |   1   |        0.25        |  0.2   |  0.2222222222222222 |    5    |
# |   10  |        0.4         |  1.0   |  0.5714285714285714 |    4    |
# |   2   |        1.0         |  0.6   |         0.75        |    5    |
# |   3   |        1.0         |  0.5   |  0.6666666666666666 |    4    |
# |   4   |        1.0         |  0.4   |  0.5714285714285714 |    5    |
# |   5   | 0.3333333333333333 |  0.25  |  0.2857142857142857 |    4    |
# |   6   |        0.25        |  0.25  |         0.25        |    4    |
# |   7   |        0.0         |  0.0   |         0.0         |    4    |
# |   8   |        0.6         |  0.6   |         0.6         |    5    |
# |   9   | 0.6666666666666666 |  0.5   |  0.5714285714285714 |    4    |
# |  box  |        1.0         |  0.2   |  0.3333333333333333 |    5    |
# |  fun  |        0.5         |  1.0   |  0.6666666666666666 |    5    |
# |  good | 0.6666666666666666 |  0.8   |  0.7272727272727273 |    5    |
# |  grow |        0.75        |  0.6   |  0.6666666666666666 |    5    |
# |  hero | 0.6666666666666666 |  0.8   |  0.7272727272727273 |    5    |
# | trust |       0.375        |  0.6   | 0.46153846153846156 |    5    |
# +-------+--------------------+--------+---------------------+---------+
# Combined metrics saved to combined_metricsResnetMObilekfold5.xlsx

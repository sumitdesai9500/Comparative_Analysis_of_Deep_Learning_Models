# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt

import time

# %% [markdown]
# # VGG

# %% [markdown]
# # Model Summary

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Concatenate
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2, VGG16
import time

# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Noise reduction 2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Load pre-trained VGG-16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Define the CNN model with VGG-16 base
model = Sequential([
    base_model,
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')
])
# Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# Found 417 images belonging to 17 classes.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 3, 2, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 3072)              0
#
#  dense_3 (Dense)             (None, 4096)              12587008
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dense_5 (Dense)             (None, 17)                69649
#
# =================================================================
# Total params: 44,152,657
# Trainable params: 29,437,969
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Concatenate
from sklearn.model_selection import KFold
from tensorflow.keras.applications import MobileNetV2, VGG16
import time

# Define constants
IMAGE_SIZE = (96, 72)
BATCH_SIZE = 16
EPOCHS = 100
NUM_CLASSES = 17  # Update this to the correct number of classes in your dataset
TRAIN_DATA_DIR = "C:\\Users\\sumit\\Downloads\\Noise reduction 2\\output_denoised_image_folder"
K_FOLDS = 5

# Load the data
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

data_generator = datagen.flow_from_directory(
    TRAIN_DATA_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Initialize KFold
kf = KFold(n_splits=K_FOLDS, shuffle=True)

# Initialize arrays to store accuracies and computational times
train_accuracies = []
val_accuracies = []

comp_times = []

# Load pre-trained VGG-16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Define the CNN model with VGG-16 base
model = Sequential([
    base_model,
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')
])
# Compile the model
model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# Track start time
start_time = time.time()

# K-fold cross-validation loop
for fold, (train_index, val_index) in enumerate(kf.split(data_generator), 1):
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        subset='training',
        seed=42
    )

    validation_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2
    ).flow_from_directory(
        TRAIN_DATA_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False,
        subset='validation',
        seed=42
    )

    # Train the model
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples // BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model
    train_loss, train_acc = model.evaluate(train_generator)
    val_loss, val_acc = model.evaluate(validation_generator)

    print(f"Fold {fold}:")
    print(f"Train accuracy: {train_acc}, Validation accuracy: {val_acc}")
    print(f"Training time for fold {fold}: {time.time() - start_time} seconds\n")

    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    comp_times.append(time.time() - start_time)

    # Save the model for this fold
    model.save(f'VGG_kfold(1)_{fold}.h5')

# Track end time
end_time = time.time()

print("K-Fold Cross Validation Complete.")
# Print average accuracies and computational time
print("Average Training Accuracy:", np.mean(train_accuracies)*100,"%")
print("Average Validation Accuracy:", np.mean(val_accuracies)*100,"%")
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# Found 417 images belonging to 17 classes.
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 5s 80ms/step - loss: 3.9861 - accuracy: 0.0743 - val_loss: 2.7924 - val_accuracy: 0.0938
# Epoch 2/100
# 21/21 [==============================] - 1s 41ms/step - loss: 2.6822 - accuracy: 0.1548 - val_loss: 2.6255 - val_accuracy: 0.0938
# Epoch 3/100
# 21/21 [==============================] - 1s 41ms/step - loss: 2.3737 - accuracy: 0.1920 - val_loss: 2.3163 - val_accuracy: 0.2812
# Epoch 4/100
# 21/21 [==============================] - 1s 42ms/step - loss: 2.0911 - accuracy: 0.3220 - val_loss: 2.4862 - val_accuracy: 0.2188
# Epoch 5/100
# 21/21 [==============================] - 1s 43ms/step - loss: 1.8020 - accuracy: 0.4056 - val_loss: 2.6192 - val_accuracy: 0.1875
# Epoch 6/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.7521 - accuracy: 0.4365 - val_loss: 2.0438 - val_accuracy: 0.3594
# Epoch 7/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.3804 - accuracy: 0.5655 - val_loss: 2.2224 - val_accuracy: 0.3281
# Epoch 8/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.2535 - accuracy: 0.5714 - val_loss: 2.0744 - val_accuracy: 0.3750
# Epoch 9/100
# 21/21 [==============================] - 1s 42ms/step - loss: 1.0301 - accuracy: 0.6749 - val_loss: 1.9453 - val_accuracy: 0.4219
# Epoch 10/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.9856 - accuracy: 0.6687 - val_loss: 2.1424 - val_accuracy: 0.4531
# Epoch 11/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.8868 - accuracy: 0.7121 - val_loss: 1.8473 - val_accuracy: 0.5469
# Epoch 12/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.7195 - accuracy: 0.7771 - val_loss: 2.1318 - val_accuracy: 0.4688
# Epoch 13/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.6756 - accuracy: 0.7802 - val_loss: 2.2789 - val_accuracy: 0.5000
# Epoch 14/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.6147 - accuracy: 0.8235 - val_loss: 2.5008 - val_accuracy: 0.5000
# Epoch 15/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.5504 - accuracy: 0.8173 - val_loss: 2.0867 - val_accuracy: 0.5312
# Epoch 16/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.4375 - accuracy: 0.8824 - val_loss: 2.0236 - val_accuracy: 0.5625
# Epoch 17/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.5078 - accuracy: 0.8173 - val_loss: 2.0481 - val_accuracy: 0.5938
# Epoch 18/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.4603 - accuracy: 0.8421 - val_loss: 2.7353 - val_accuracy: 0.4844
# Epoch 19/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.4687 - accuracy: 0.8545 - val_loss: 2.8472 - val_accuracy: 0.3750
# Epoch 20/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.5810 - accuracy: 0.7864 - val_loss: 2.0873 - val_accuracy: 0.5469
# Epoch 21/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.3503 - accuracy: 0.8916 - val_loss: 2.4527 - val_accuracy: 0.5625
# Epoch 22/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.3485 - accuracy: 0.8916 - val_loss: 2.3080 - val_accuracy: 0.5938
# Epoch 23/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.2596 - accuracy: 0.9164 - val_loss: 3.0383 - val_accuracy: 0.4688
# Epoch 24/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.4134 - accuracy: 0.8669 - val_loss: 3.1554 - val_accuracy: 0.5156
# Epoch 25/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.3532 - accuracy: 0.8854 - val_loss: 2.8413 - val_accuracy: 0.5312
# Epoch 26/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.2205 - accuracy: 0.9350 - val_loss: 2.9960 - val_accuracy: 0.5312
# Epoch 27/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.2607 - accuracy: 0.8885 - val_loss: 2.5636 - val_accuracy: 0.5781
# Epoch 28/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.2501 - accuracy: 0.9288 - val_loss: 2.8598 - val_accuracy: 0.5625
# Epoch 29/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.1754 - accuracy: 0.9319 - val_loss: 3.3185 - val_accuracy: 0.5469
# Epoch 30/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.1693 - accuracy: 0.9412 - val_loss: 3.0958 - val_accuracy: 0.5938
# Epoch 31/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.1426 - accuracy: 0.9505 - val_loss: 3.2292 - val_accuracy: 0.5469
# Epoch 32/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.2503 - accuracy: 0.9133 - val_loss: 2.8186 - val_accuracy: 0.6094
# Epoch 33/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.1922 - accuracy: 0.9350 - val_loss: 2.7232 - val_accuracy: 0.6094
# Epoch 34/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.1008 - accuracy: 0.9721 - val_loss: 2.7681 - val_accuracy: 0.6406
# Epoch 35/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0914 - accuracy: 0.9598 - val_loss: 2.9596 - val_accuracy: 0.5938
# Epoch 36/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0982 - accuracy: 0.9690 - val_loss: 2.9911 - val_accuracy: 0.5781
# Epoch 37/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.1068 - accuracy: 0.9536 - val_loss: 3.7476 - val_accuracy: 0.5781
# Epoch 38/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.1999 - accuracy: 0.9381 - val_loss: 3.1815 - val_accuracy: 0.6094
# Epoch 39/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.1427 - accuracy: 0.9536 - val_loss: 3.2696 - val_accuracy: 0.5938
# Epoch 40/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0697 - accuracy: 0.9821 - val_loss: 3.3232 - val_accuracy: 0.5781
# Epoch 41/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0439 - accuracy: 0.9907 - val_loss: 3.3369 - val_accuracy: 0.5938
# Epoch 42/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0742 - accuracy: 0.9752 - val_loss: 3.8350 - val_accuracy: 0.6250
# Epoch 43/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0403 - accuracy: 0.9907 - val_loss: 3.7451 - val_accuracy: 0.6094
# Epoch 44/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.1374 - accuracy: 0.9536 - val_loss: 3.2906 - val_accuracy: 0.5781
# Epoch 45/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0606 - accuracy: 0.9821 - val_loss: 3.5581 - val_accuracy: 0.6094
# Epoch 46/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0279 - accuracy: 0.9938 - val_loss: 3.5599 - val_accuracy: 0.5781
# Epoch 47/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0201 - accuracy: 0.9969 - val_loss: 3.6745 - val_accuracy: 0.5781
# Epoch 48/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 3.8643 - val_accuracy: 0.6094
# Epoch 49/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 3.7357 - val_accuracy: 0.6094
# Epoch 50/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 3.9536 - val_accuracy: 0.5938
# Epoch 51/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 4.0735 - val_accuracy: 0.5938
# Epoch 52/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 4.0774 - val_accuracy: 0.5781
# Epoch 53/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 4.0985 - val_accuracy: 0.5781
# Epoch 54/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 4.0832 - val_accuracy: 0.5781
# Epoch 55/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 4.0627 - val_accuracy: 0.5938
# Epoch 56/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0123 - accuracy: 0.9969 - val_loss: 4.0606 - val_accuracy: 0.5781
# Epoch 57/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0168 - accuracy: 0.9969 - val_loss: 4.1931 - val_accuracy: 0.5469
# Epoch 58/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0379 - accuracy: 0.9876 - val_loss: 3.8766 - val_accuracy: 0.5938
# Epoch 59/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.3158 - accuracy: 0.9164 - val_loss: 2.8033 - val_accuracy: 0.6406
# Epoch 60/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.3858 - accuracy: 0.8854 - val_loss: 3.0601 - val_accuracy: 0.6094
# Epoch 61/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.4961 - accuracy: 0.8421 - val_loss: 2.8815 - val_accuracy: 0.5000
# Epoch 62/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.2079 - accuracy: 0.9195 - val_loss: 3.3974 - val_accuracy: 0.5312
# Epoch 63/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.1196 - accuracy: 0.9567 - val_loss: 3.2903 - val_accuracy: 0.5938
# Epoch 64/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.3349 - accuracy: 0.8793 - val_loss: 2.4011 - val_accuracy: 0.6094
# Epoch 65/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.1258 - accuracy: 0.9628 - val_loss: 2.8489 - val_accuracy: 0.5156
# Epoch 66/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.1244 - accuracy: 0.9628 - val_loss: 3.3957 - val_accuracy: 0.5781
# Epoch 67/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0813 - accuracy: 0.9783 - val_loss: 3.0621 - val_accuracy: 0.6094
# Epoch 68/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 3.3167 - val_accuracy: 0.6094
# Epoch 69/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0207 - accuracy: 0.9969 - val_loss: 3.1878 - val_accuracy: 0.6094
# Epoch 70/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0177 - accuracy: 0.9969 - val_loss: 3.1916 - val_accuracy: 0.6250
# Epoch 71/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 3.2055 - val_accuracy: 0.5625
# Epoch 72/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 3.4036 - val_accuracy: 0.5781
# Epoch 73/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.3771 - val_accuracy: 0.5781
# Epoch 74/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.4437 - val_accuracy: 0.5781
# Epoch 75/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.4661 - val_accuracy: 0.5781
# Epoch 76/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.5221 - val_accuracy: 0.5781
# Epoch 77/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.5595 - val_accuracy: 0.5781
# Epoch 78/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.6162 - val_accuracy: 0.5781
# Epoch 79/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.6530 - val_accuracy: 0.5781
# Epoch 80/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.7062 - val_accuracy: 0.5781
# Epoch 81/100
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.7402 - val_accuracy: 0.5781
# Epoch 82/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.7535 - val_accuracy: 0.5781
# Epoch 83/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.7771 - val_accuracy: 0.5781
# Epoch 84/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.7836 - val_accuracy: 0.5781
# Epoch 85/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.8443 - val_accuracy: 0.5781
# Epoch 86/100
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.8588 - val_accuracy: 0.5781
# Epoch 87/100
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.8755 - val_accuracy: 0.5781
# Epoch 88/100
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.9026 - val_accuracy: 0.5781
# Epoch 89/100
# 21/21 [==============================] - 1s 43ms/step - loss: 9.5695e-04 - accuracy: 1.0000 - val_loss: 3.9270 - val_accuracy: 0.5781
# Epoch 90/100
# 21/21 [==============================] - 1s 42ms/step - loss: 9.2449e-04 - accuracy: 1.0000 - val_loss: 3.9292 - val_accuracy: 0.5781
# Epoch 91/100
# 21/21 [==============================] - 1s 42ms/step - loss: 9.1239e-04 - accuracy: 1.0000 - val_loss: 3.9581 - val_accuracy: 0.5781
# Epoch 92/100
# 21/21 [==============================] - 1s 42ms/step - loss: 8.8263e-04 - accuracy: 1.0000 - val_loss: 3.9731 - val_accuracy: 0.5781
# Epoch 93/100
# 21/21 [==============================] - 1s 44ms/step - loss: 8.1890e-04 - accuracy: 1.0000 - val_loss: 3.9945 - val_accuracy: 0.5781
# Epoch 94/100
# 21/21 [==============================] - 1s 42ms/step - loss: 8.0376e-04 - accuracy: 1.0000 - val_loss: 4.0115 - val_accuracy: 0.5625
# Epoch 95/100
# 21/21 [==============================] - 1s 44ms/step - loss: 6.9303e-04 - accuracy: 1.0000 - val_loss: 4.0388 - val_accuracy: 0.5625
# Epoch 96/100
# 21/21 [==============================] - 1s 43ms/step - loss: 7.3540e-04 - accuracy: 1.0000 - val_loss: 4.0380 - val_accuracy: 0.5625
# Epoch 97/100
# 21/21 [==============================] - 1s 43ms/step - loss: 7.0597e-04 - accuracy: 1.0000 - val_loss: 4.0354 - val_accuracy: 0.5781
# Epoch 98/100
# 21/21 [==============================] - 1s 44ms/step - loss: 7.1865e-04 - accuracy: 1.0000 - val_loss: 4.0567 - val_accuracy: 0.5625
# Epoch 99/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.6557e-04 - accuracy: 1.0000 - val_loss: 4.0553 - val_accuracy: 0.5625
# Epoch 100/100
# 21/21 [==============================] - 1s 43ms/step - loss: 6.5427e-04 - accuracy: 1.0000 - val_loss: 4.0818 - val_accuracy: 0.5625
# 22/22 [==============================] - 1s 29ms/step - loss: 6.2168e-04 - accuracy: 1.0000
# 5/5 [==============================] - 1s 211ms/step - loss: 3.4095 - accuracy: 0.6282
# Fold 1:
# Train accuracy: 1.0, Validation accuracy: 0.6282051205635071
# Training time for fold 1: 95.8461606502533 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 1s 44ms/step - loss: 6.3366e-04 - accuracy: 1.0000 - val_loss: 4.1163 - val_accuracy: 0.5625
# Epoch 2/100
# 21/21 [==============================] - 1s 44ms/step - loss: 6.1628e-04 - accuracy: 1.0000 - val_loss: 4.1045 - val_accuracy: 0.5625
# Epoch 3/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.9258e-04 - accuracy: 1.0000 - val_loss: 4.1342 - val_accuracy: 0.5625
# Epoch 4/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.3704e-04 - accuracy: 1.0000 - val_loss: 4.1517 - val_accuracy: 0.5625
# Epoch 5/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.4650e-04 - accuracy: 1.0000 - val_loss: 4.1481 - val_accuracy: 0.5625
# Epoch 6/100
# 21/21 [==============================] - 1s 43ms/step - loss: 5.7982e-04 - accuracy: 1.0000 - val_loss: 4.1688 - val_accuracy: 0.5625
# Epoch 7/100
# 21/21 [==============================] - 1s 44ms/step - loss: 5.5845e-04 - accuracy: 1.0000 - val_loss: 4.1681 - val_accuracy: 0.5625
# Epoch 8/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.3332e-04 - accuracy: 1.0000 - val_loss: 4.1778 - val_accuracy: 0.5625
# Epoch 9/100
# 21/21 [==============================] - 1s 44ms/step - loss: 5.2235e-04 - accuracy: 1.0000 - val_loss: 4.1768 - val_accuracy: 0.5625
# Epoch 10/100
# 21/21 [==============================] - 1s 44ms/step - loss: 5.0779e-04 - accuracy: 1.0000 - val_loss: 4.2108 - val_accuracy: 0.5625
# Epoch 11/100
# 21/21 [==============================] - 1s 45ms/step - loss: 5.1690e-04 - accuracy: 1.0000 - val_loss: 4.2088 - val_accuracy: 0.5781
# Epoch 12/100
# 21/21 [==============================] - 1s 44ms/step - loss: 4.9917e-04 - accuracy: 1.0000 - val_loss: 4.2311 - val_accuracy: 0.5625
# Epoch 13/100
# 21/21 [==============================] - 1s 44ms/step - loss: 4.9387e-04 - accuracy: 1.0000 - val_loss: 4.2448 - val_accuracy: 0.5781
# Epoch 14/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.8626e-04 - accuracy: 1.0000 - val_loss: 4.2830 - val_accuracy: 0.5781
# Epoch 15/100
# 21/21 [==============================] - 1s 43ms/step - loss: 4.7598e-04 - accuracy: 1.0000 - val_loss: 4.2565 - val_accuracy: 0.5781
# Epoch 16/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.4943e-04 - accuracy: 1.0000 - val_loss: 4.2658 - val_accuracy: 0.5781
# Epoch 17/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.3251e-04 - accuracy: 1.0000 - val_loss: 4.2816 - val_accuracy: 0.5625
# Epoch 18/100
# 21/21 [==============================] - 1s 44ms/step - loss: 4.1631e-04 - accuracy: 1.0000 - val_loss: 4.2854 - val_accuracy: 0.5781
# Epoch 19/100
# 21/21 [==============================] - 1s 44ms/step - loss: 4.2936e-04 - accuracy: 1.0000 - val_loss: 4.3087 - val_accuracy: 0.5781
# Epoch 20/100
# 21/21 [==============================] - 1s 46ms/step - loss: 4.1800e-04 - accuracy: 1.0000 - val_loss: 4.3116 - val_accuracy: 0.5781
# Epoch 21/100
# 21/21 [==============================] - 1s 45ms/step - loss: 4.0767e-04 - accuracy: 1.0000 - val_loss: 4.3367 - val_accuracy: 0.5781
# Epoch 22/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.9261e-04 - accuracy: 1.0000 - val_loss: 4.3246 - val_accuracy: 0.5781
# Epoch 23/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.9413e-04 - accuracy: 1.0000 - val_loss: 4.3336 - val_accuracy: 0.5781
# Epoch 24/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.7255e-04 - accuracy: 1.0000 - val_loss: 4.3442 - val_accuracy: 0.5781
# Epoch 25/100
# 21/21 [==============================] - 1s 44ms/step - loss: 3.7151e-04 - accuracy: 1.0000 - val_loss: 4.3515 - val_accuracy: 0.5781
# Epoch 26/100
# 21/21 [==============================] - 1s 46ms/step - loss: 3.5363e-04 - accuracy: 1.0000 - val_loss: 4.3731 - val_accuracy: 0.5781
# Epoch 27/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.7759e-04 - accuracy: 1.0000 - val_loss: 4.3702 - val_accuracy: 0.5781
# Epoch 28/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.3376e-04 - accuracy: 1.0000 - val_loss: 4.3930 - val_accuracy: 0.5781
# Epoch 29/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.3024e-04 - accuracy: 1.0000 - val_loss: 4.4032 - val_accuracy: 0.5781
# Epoch 30/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.2560e-04 - accuracy: 1.0000 - val_loss: 4.3993 - val_accuracy: 0.5781
# Epoch 31/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.0397e-04 - accuracy: 1.0000 - val_loss: 4.3936 - val_accuracy: 0.5781
# Epoch 32/100
# 21/21 [==============================] - 1s 46ms/step - loss: 3.1824e-04 - accuracy: 1.0000 - val_loss: 4.4178 - val_accuracy: 0.5781
# Epoch 33/100
# 21/21 [==============================] - 1s 46ms/step - loss: 3.0628e-04 - accuracy: 1.0000 - val_loss: 4.4173 - val_accuracy: 0.5781
# Epoch 34/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.9245e-04 - accuracy: 1.0000 - val_loss: 4.4173 - val_accuracy: 0.5781
# Epoch 35/100
# 21/21 [==============================] - 1s 45ms/step - loss: 3.0274e-04 - accuracy: 1.0000 - val_loss: 4.4325 - val_accuracy: 0.5781
# Epoch 36/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.9206e-04 - accuracy: 1.0000 - val_loss: 4.4288 - val_accuracy: 0.5781
# Epoch 37/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.6546e-04 - accuracy: 1.0000 - val_loss: 4.4488 - val_accuracy: 0.5781
# Epoch 38/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.8456e-04 - accuracy: 1.0000 - val_loss: 4.4535 - val_accuracy: 0.5781
# Epoch 39/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.8968e-04 - accuracy: 1.0000 - val_loss: 4.5083 - val_accuracy: 0.5781
# Epoch 40/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.8592e-04 - accuracy: 1.0000 - val_loss: 4.4810 - val_accuracy: 0.5938
# Epoch 41/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.8754e-04 - accuracy: 1.0000 - val_loss: 4.5127 - val_accuracy: 0.5781
# Epoch 42/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.5578e-04 - accuracy: 1.0000 - val_loss: 4.5044 - val_accuracy: 0.5781
# Epoch 43/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.6089e-04 - accuracy: 1.0000 - val_loss: 4.5053 - val_accuracy: 0.5781
# Epoch 44/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.5307e-04 - accuracy: 1.0000 - val_loss: 4.5123 - val_accuracy: 0.5781
# Epoch 45/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.4360e-04 - accuracy: 1.0000 - val_loss: 4.5043 - val_accuracy: 0.5781
# Epoch 46/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.3656e-04 - accuracy: 1.0000 - val_loss: 4.5263 - val_accuracy: 0.5781
# Epoch 47/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.3243e-04 - accuracy: 1.0000 - val_loss: 4.5323 - val_accuracy: 0.5781
# Epoch 48/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.2633e-04 - accuracy: 1.0000 - val_loss: 4.5376 - val_accuracy: 0.5781
# Epoch 49/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.3547e-04 - accuracy: 1.0000 - val_loss: 4.5391 - val_accuracy: 0.5781
# Epoch 50/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.2408e-04 - accuracy: 1.0000 - val_loss: 4.5494 - val_accuracy: 0.5781
# Epoch 51/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.2246e-04 - accuracy: 1.0000 - val_loss: 4.5516 - val_accuracy: 0.5781
# Epoch 52/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.1647e-04 - accuracy: 1.0000 - val_loss: 4.5639 - val_accuracy: 0.5781
# Epoch 53/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.1004e-04 - accuracy: 1.0000 - val_loss: 4.5656 - val_accuracy: 0.5781
# Epoch 54/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.0171e-04 - accuracy: 1.0000 - val_loss: 4.5603 - val_accuracy: 0.5781
# Epoch 55/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.1382e-04 - accuracy: 1.0000 - val_loss: 4.5939 - val_accuracy: 0.5781
# Epoch 56/100
# 21/21 [==============================] - 1s 46ms/step - loss: 2.0753e-04 - accuracy: 1.0000 - val_loss: 4.6102 - val_accuracy: 0.5781
# Epoch 57/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.9932e-04 - accuracy: 1.0000 - val_loss: 4.6173 - val_accuracy: 0.5781
# Epoch 58/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.9526e-04 - accuracy: 1.0000 - val_loss: 4.6142 - val_accuracy: 0.5781
# Epoch 59/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.8195e-04 - accuracy: 1.0000 - val_loss: 4.6327 - val_accuracy: 0.5781
# Epoch 60/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.8715e-04 - accuracy: 1.0000 - val_loss: 4.6376 - val_accuracy: 0.5781
# Epoch 61/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.8858e-04 - accuracy: 1.0000 - val_loss: 4.6447 - val_accuracy: 0.5781
# Epoch 62/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.8072e-04 - accuracy: 1.0000 - val_loss: 4.6476 - val_accuracy: 0.5781
# Epoch 63/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.7331e-04 - accuracy: 1.0000 - val_loss: 4.6469 - val_accuracy: 0.5781
# Epoch 64/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.6969e-04 - accuracy: 1.0000 - val_loss: 4.6504 - val_accuracy: 0.5781
# Epoch 65/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.7442e-04 - accuracy: 1.0000 - val_loss: 4.6627 - val_accuracy: 0.5781
# Epoch 66/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.6137e-04 - accuracy: 1.0000 - val_loss: 4.6652 - val_accuracy: 0.5781
# Epoch 67/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.6837e-04 - accuracy: 1.0000 - val_loss: 4.6763 - val_accuracy: 0.5781
# Epoch 68/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.6526e-04 - accuracy: 1.0000 - val_loss: 4.6794 - val_accuracy: 0.5781
# Epoch 69/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.5721e-04 - accuracy: 1.0000 - val_loss: 4.6992 - val_accuracy: 0.5781
# Epoch 70/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.4282e-04 - accuracy: 1.0000 - val_loss: 4.6961 - val_accuracy: 0.5781
# Epoch 71/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.5369e-04 - accuracy: 1.0000 - val_loss: 4.6906 - val_accuracy: 0.5781
# Epoch 72/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.4980e-04 - accuracy: 1.0000 - val_loss: 4.7114 - val_accuracy: 0.5781
# Epoch 73/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.4841e-04 - accuracy: 1.0000 - val_loss: 4.7094 - val_accuracy: 0.5781
# Epoch 74/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.4811e-04 - accuracy: 1.0000 - val_loss: 4.7193 - val_accuracy: 0.5781
# Epoch 75/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.4648e-04 - accuracy: 1.0000 - val_loss: 4.7341 - val_accuracy: 0.5781
# Epoch 76/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.4925e-04 - accuracy: 1.0000 - val_loss: 4.7201 - val_accuracy: 0.5781
# Epoch 77/100
# 21/21 [==============================] - 1s 46ms/step - loss: 1.3737e-04 - accuracy: 1.0000 - val_loss: 4.7335 - val_accuracy: 0.5781
# Epoch 78/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.3897e-04 - accuracy: 1.0000 - val_loss: 4.7365 - val_accuracy: 0.5781
# Epoch 79/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.3969e-04 - accuracy: 1.0000 - val_loss: 4.7483 - val_accuracy: 0.5781
# Epoch 80/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.3753e-04 - accuracy: 1.0000 - val_loss: 4.7588 - val_accuracy: 0.5781
# Epoch 81/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.3718e-04 - accuracy: 1.0000 - val_loss: 4.7644 - val_accuracy: 0.5781
# Epoch 82/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.3382e-04 - accuracy: 1.0000 - val_loss: 4.7675 - val_accuracy: 0.5781
# Epoch 83/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.2801e-04 - accuracy: 1.0000 - val_loss: 4.7694 - val_accuracy: 0.5781
# Epoch 84/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.3034e-04 - accuracy: 1.0000 - val_loss: 4.7880 - val_accuracy: 0.5781
# Epoch 85/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.2495e-04 - accuracy: 1.0000 - val_loss: 4.7822 - val_accuracy: 0.5781
# Epoch 86/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.1992e-04 - accuracy: 1.0000 - val_loss: 4.7931 - val_accuracy: 0.5781
# Epoch 87/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.1877e-04 - accuracy: 1.0000 - val_loss: 4.7965 - val_accuracy: 0.5781
# Epoch 88/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.1817e-04 - accuracy: 1.0000 - val_loss: 4.8238 - val_accuracy: 0.5781
# Epoch 89/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.1554e-04 - accuracy: 1.0000 - val_loss: 4.8135 - val_accuracy: 0.5781
# Epoch 90/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.1405e-04 - accuracy: 1.0000 - val_loss: 4.8270 - val_accuracy: 0.5781
# Epoch 91/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.1677e-04 - accuracy: 1.0000 - val_loss: 4.8245 - val_accuracy: 0.5781
# Epoch 92/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.1113e-04 - accuracy: 1.0000 - val_loss: 4.8369 - val_accuracy: 0.5781
# Epoch 93/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.0461e-04 - accuracy: 1.0000 - val_loss: 4.8383 - val_accuracy: 0.5781
# Epoch 94/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.1221e-04 - accuracy: 1.0000 - val_loss: 4.8352 - val_accuracy: 0.5781
# Epoch 95/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.0694e-04 - accuracy: 1.0000 - val_loss: 4.8536 - val_accuracy: 0.5781
# Epoch 96/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.0346e-04 - accuracy: 1.0000 - val_loss: 4.8473 - val_accuracy: 0.5781
# Epoch 97/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.0660e-04 - accuracy: 1.0000 - val_loss: 4.8547 - val_accuracy: 0.5781
# Epoch 98/100
# 21/21 [==============================] - 1s 48ms/step - loss: 9.9717e-05 - accuracy: 1.0000 - val_loss: 4.8666 - val_accuracy: 0.5781
# Epoch 99/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.5450e-05 - accuracy: 1.0000 - val_loss: 4.8619 - val_accuracy: 0.5781
# Epoch 100/100
# 21/21 [==============================] - 1s 49ms/step - loss: 9.8994e-05 - accuracy: 1.0000 - val_loss: 4.8752 - val_accuracy: 0.5781
# 22/22 [==============================] - 1s 31ms/step - loss: 9.2967e-05 - accuracy: 1.0000
# 5/5 [==============================] - 0s 30ms/step - loss: 4.0772 - accuracy: 0.6410
# Fold 2:
# Train accuracy: 1.0, Validation accuracy: 0.6410256624221802
# Training time for fold 2: 196.18467664718628 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.7591e-05 - accuracy: 1.0000 - val_loss: 4.8961 - val_accuracy: 0.5781
# Epoch 2/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.9351e-05 - accuracy: 1.0000 - val_loss: 4.8973 - val_accuracy: 0.5781
# Epoch 3/100
# 21/21 [==============================] - 1s 48ms/step - loss: 9.6103e-05 - accuracy: 1.0000 - val_loss: 4.9055 - val_accuracy: 0.5781
# Epoch 4/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.4034e-05 - accuracy: 1.0000 - val_loss: 4.9086 - val_accuracy: 0.5781
# Epoch 5/100
# 21/21 [==============================] - 1s 47ms/step - loss: 9.2052e-05 - accuracy: 1.0000 - val_loss: 4.9125 - val_accuracy: 0.5781
# Epoch 6/100
# 21/21 [==============================] - 1s 48ms/step - loss: 8.4423e-05 - accuracy: 1.0000 - val_loss: 4.9075 - val_accuracy: 0.5781
# Epoch 7/100
# 21/21 [==============================] - 1s 47ms/step - loss: 8.8747e-05 - accuracy: 1.0000 - val_loss: 4.9291 - val_accuracy: 0.5781
# Epoch 8/100
# 21/21 [==============================] - 1s 48ms/step - loss: 8.8932e-05 - accuracy: 1.0000 - val_loss: 4.9303 - val_accuracy: 0.5781
# Epoch 9/100
# 21/21 [==============================] - 1s 47ms/step - loss: 8.7676e-05 - accuracy: 1.0000 - val_loss: 4.9290 - val_accuracy: 0.5781
# Epoch 10/100
# 21/21 [==============================] - 1s 47ms/step - loss: 8.3432e-05 - accuracy: 1.0000 - val_loss: 4.9315 - val_accuracy: 0.5781
# Epoch 11/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.7884e-05 - accuracy: 1.0000 - val_loss: 4.9460 - val_accuracy: 0.5781
# Epoch 12/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.6577e-05 - accuracy: 1.0000 - val_loss: 4.9478 - val_accuracy: 0.5781
# Epoch 13/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.7445e-05 - accuracy: 1.0000 - val_loss: 4.9507 - val_accuracy: 0.5781
# Epoch 14/100
# 21/21 [==============================] - 1s 47ms/step - loss: 8.1697e-05 - accuracy: 1.0000 - val_loss: 4.9760 - val_accuracy: 0.5781
# Epoch 15/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.6748e-05 - accuracy: 1.0000 - val_loss: 4.9677 - val_accuracy: 0.5781
# Epoch 16/100
# 21/21 [==============================] - 1s 48ms/step - loss: 7.7069e-05 - accuracy: 1.0000 - val_loss: 4.9581 - val_accuracy: 0.5781
# Epoch 17/100
# 21/21 [==============================] - 1s 48ms/step - loss: 7.4606e-05 - accuracy: 1.0000 - val_loss: 4.9936 - val_accuracy: 0.5781
# Epoch 18/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.4429e-05 - accuracy: 1.0000 - val_loss: 4.9679 - val_accuracy: 0.5781
# Epoch 19/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.4765e-05 - accuracy: 1.0000 - val_loss: 4.9765 - val_accuracy: 0.5781
# Epoch 20/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.2625e-05 - accuracy: 1.0000 - val_loss: 4.9975 - val_accuracy: 0.5781
# Epoch 21/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.0302e-05 - accuracy: 1.0000 - val_loss: 5.0093 - val_accuracy: 0.5781
# Epoch 22/100
# 21/21 [==============================] - 1s 49ms/step - loss: 6.8457e-05 - accuracy: 1.0000 - val_loss: 5.0055 - val_accuracy: 0.5781
# Epoch 23/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.7395e-05 - accuracy: 1.0000 - val_loss: 5.0143 - val_accuracy: 0.5781
# Epoch 24/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.6117e-05 - accuracy: 1.0000 - val_loss: 5.0119 - val_accuracy: 0.5781
# Epoch 25/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.9533e-05 - accuracy: 1.0000 - val_loss: 5.0068 - val_accuracy: 0.5781
# Epoch 26/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.5995e-05 - accuracy: 1.0000 - val_loss: 5.0241 - val_accuracy: 0.5781
# Epoch 27/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.5736e-05 - accuracy: 1.0000 - val_loss: 5.0281 - val_accuracy: 0.5781
# Epoch 28/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.5781e-05 - accuracy: 1.0000 - val_loss: 5.0458 - val_accuracy: 0.5781
# Epoch 29/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.3456e-05 - accuracy: 1.0000 - val_loss: 5.0353 - val_accuracy: 0.5781
# Epoch 30/100
# 21/21 [==============================] - 1s 49ms/step - loss: 6.4185e-05 - accuracy: 1.0000 - val_loss: 5.0389 - val_accuracy: 0.5781
# Epoch 31/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.2401e-05 - accuracy: 1.0000 - val_loss: 5.0489 - val_accuracy: 0.5781
# Epoch 32/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.4143e-05 - accuracy: 1.0000 - val_loss: 5.0487 - val_accuracy: 0.5781
# Epoch 33/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.0493e-05 - accuracy: 1.0000 - val_loss: 5.0453 - val_accuracy: 0.5781
# Epoch 34/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.0379e-05 - accuracy: 1.0000 - val_loss: 5.0586 - val_accuracy: 0.5781
# Epoch 35/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.6357e-05 - accuracy: 1.0000 - val_loss: 5.0585 - val_accuracy: 0.5781
# Epoch 36/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.8719e-05 - accuracy: 1.0000 - val_loss: 5.0678 - val_accuracy: 0.5781
# Epoch 37/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.7801e-05 - accuracy: 1.0000 - val_loss: 5.0642 - val_accuracy: 0.5781
# Epoch 38/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.3550e-05 - accuracy: 1.0000 - val_loss: 5.0711 - val_accuracy: 0.5781
# Epoch 39/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.7990e-05 - accuracy: 1.0000 - val_loss: 5.1098 - val_accuracy: 0.5781
# Epoch 40/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.5540e-05 - accuracy: 1.0000 - val_loss: 5.0956 - val_accuracy: 0.5781
# Epoch 41/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.6506e-05 - accuracy: 1.0000 - val_loss: 5.0914 - val_accuracy: 0.5781
# Epoch 42/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.1518e-05 - accuracy: 1.0000 - val_loss: 5.1136 - val_accuracy: 0.5781
# Epoch 43/100
# 21/21 [==============================] - 1s 48ms/step - loss: 5.1639e-05 - accuracy: 1.0000 - val_loss: 5.1180 - val_accuracy: 0.5781
# Epoch 44/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.2235e-05 - accuracy: 1.0000 - val_loss: 5.1159 - val_accuracy: 0.5781
# Epoch 45/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.9404e-05 - accuracy: 1.0000 - val_loss: 5.1077 - val_accuracy: 0.5781
# Epoch 46/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.9951e-05 - accuracy: 1.0000 - val_loss: 5.1195 - val_accuracy: 0.5781
# Epoch 47/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.8367e-05 - accuracy: 1.0000 - val_loss: 5.1335 - val_accuracy: 0.5781
# Epoch 48/100
# 21/21 [==============================] - 1s 48ms/step - loss: 5.0192e-05 - accuracy: 1.0000 - val_loss: 5.1242 - val_accuracy: 0.5781
# Epoch 49/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.7245e-05 - accuracy: 1.0000 - val_loss: 5.1330 - val_accuracy: 0.5781
# Epoch 50/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.4597e-05 - accuracy: 1.0000 - val_loss: 5.1379 - val_accuracy: 0.5781
# Epoch 51/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.8594e-05 - accuracy: 1.0000 - val_loss: 5.1375 - val_accuracy: 0.5781
# Epoch 52/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.6198e-05 - accuracy: 1.0000 - val_loss: 5.1422 - val_accuracy: 0.5781
# Epoch 53/100
# 21/21 [==============================] - 1s 49ms/step - loss: 4.5464e-05 - accuracy: 1.0000 - val_loss: 5.1487 - val_accuracy: 0.5781
# Epoch 54/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.4861e-05 - accuracy: 1.0000 - val_loss: 5.1459 - val_accuracy: 0.5781
# Epoch 55/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.3456e-05 - accuracy: 1.0000 - val_loss: 5.1624 - val_accuracy: 0.5781
# Epoch 56/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.5649e-05 - accuracy: 1.0000 - val_loss: 5.1841 - val_accuracy: 0.5781
# Epoch 57/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.2779e-05 - accuracy: 1.0000 - val_loss: 5.1777 - val_accuracy: 0.5781
# Epoch 58/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.2274e-05 - accuracy: 1.0000 - val_loss: 5.1778 - val_accuracy: 0.5781
# Epoch 59/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.2723e-05 - accuracy: 1.0000 - val_loss: 5.1865 - val_accuracy: 0.5781
# Epoch 60/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.1385e-05 - accuracy: 1.0000 - val_loss: 5.1908 - val_accuracy: 0.5781
# Epoch 61/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.0296e-05 - accuracy: 1.0000 - val_loss: 5.2091 - val_accuracy: 0.5781
# Epoch 62/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.1596e-05 - accuracy: 1.0000 - val_loss: 5.1958 - val_accuracy: 0.5781
# Epoch 63/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.7655e-05 - accuracy: 1.0000 - val_loss: 5.2088 - val_accuracy: 0.5781
# Epoch 64/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.9293e-05 - accuracy: 1.0000 - val_loss: 5.1995 - val_accuracy: 0.5781
# Epoch 65/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.8464e-05 - accuracy: 1.0000 - val_loss: 5.2103 - val_accuracy: 0.5781
# Epoch 66/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.7186e-05 - accuracy: 1.0000 - val_loss: 5.2153 - val_accuracy: 0.5781
# Epoch 67/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.7592e-05 - accuracy: 1.0000 - val_loss: 5.2262 - val_accuracy: 0.5781
# Epoch 68/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.8570e-05 - accuracy: 1.0000 - val_loss: 5.2241 - val_accuracy: 0.5781
# Epoch 69/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.6466e-05 - accuracy: 1.0000 - val_loss: 5.2347 - val_accuracy: 0.5781
# Epoch 70/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.6315e-05 - accuracy: 1.0000 - val_loss: 5.2458 - val_accuracy: 0.5781
# Epoch 71/100
# 21/21 [==============================] - 1s 46ms/step - loss: 3.5046e-05 - accuracy: 1.0000 - val_loss: 5.2403 - val_accuracy: 0.5781
# Epoch 72/100
# 21/21 [==============================] - 1s 49ms/step - loss: 3.6342e-05 - accuracy: 1.0000 - val_loss: 5.2482 - val_accuracy: 0.5781
# Epoch 73/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.5998e-05 - accuracy: 1.0000 - val_loss: 5.2551 - val_accuracy: 0.5781
# Epoch 74/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.5264e-05 - accuracy: 1.0000 - val_loss: 5.2552 - val_accuracy: 0.5781
# Epoch 75/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.2117e-05 - accuracy: 1.0000 - val_loss: 5.2647 - val_accuracy: 0.5781
# Epoch 76/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.4116e-05 - accuracy: 1.0000 - val_loss: 5.2685 - val_accuracy: 0.5781
# Epoch 77/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.2312e-05 - accuracy: 1.0000 - val_loss: 5.2824 - val_accuracy: 0.5781
# Epoch 78/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.3962e-05 - accuracy: 1.0000 - val_loss: 5.2764 - val_accuracy: 0.5781
# Epoch 79/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.2665e-05 - accuracy: 1.0000 - val_loss: 5.2817 - val_accuracy: 0.5781
# Epoch 80/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.1317e-05 - accuracy: 1.0000 - val_loss: 5.3008 - val_accuracy: 0.5781
# Epoch 81/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.1764e-05 - accuracy: 1.0000 - val_loss: 5.2934 - val_accuracy: 0.5781
# Epoch 82/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.1104e-05 - accuracy: 1.0000 - val_loss: 5.3014 - val_accuracy: 0.5781
# Epoch 83/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.1283e-05 - accuracy: 1.0000 - val_loss: 5.3078 - val_accuracy: 0.5781
# Epoch 84/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.1115e-05 - accuracy: 1.0000 - val_loss: 5.3017 - val_accuracy: 0.5781
# Epoch 85/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.8818e-05 - accuracy: 1.0000 - val_loss: 5.3155 - val_accuracy: 0.5781
# Epoch 86/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.9935e-05 - accuracy: 1.0000 - val_loss: 5.3249 - val_accuracy: 0.5781
# Epoch 87/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.0115e-05 - accuracy: 1.0000 - val_loss: 5.3285 - val_accuracy: 0.5781
# Epoch 88/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.9248e-05 - accuracy: 1.0000 - val_loss: 5.3494 - val_accuracy: 0.5781
# Epoch 89/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.8594e-05 - accuracy: 1.0000 - val_loss: 5.3425 - val_accuracy: 0.5781
# Epoch 90/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.8308e-05 - accuracy: 1.0000 - val_loss: 5.3415 - val_accuracy: 0.5781
# Epoch 91/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.8422e-05 - accuracy: 1.0000 - val_loss: 5.3473 - val_accuracy: 0.5781
# Epoch 92/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.6263e-05 - accuracy: 1.0000 - val_loss: 5.3519 - val_accuracy: 0.5781
# Epoch 93/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.6013e-05 - accuracy: 1.0000 - val_loss: 5.3474 - val_accuracy: 0.5781
# Epoch 94/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.5959e-05 - accuracy: 1.0000 - val_loss: 5.3647 - val_accuracy: 0.5781
# Epoch 95/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.4687e-05 - accuracy: 1.0000 - val_loss: 5.3676 - val_accuracy: 0.5781
# Epoch 96/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.4944e-05 - accuracy: 1.0000 - val_loss: 5.3564 - val_accuracy: 0.5781
# Epoch 97/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.6292e-05 - accuracy: 1.0000 - val_loss: 5.3695 - val_accuracy: 0.5781
# Epoch 98/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.5756e-05 - accuracy: 1.0000 - val_loss: 5.3784 - val_accuracy: 0.5781
# Epoch 99/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.4508e-05 - accuracy: 1.0000 - val_loss: 5.3820 - val_accuracy: 0.5781
# Epoch 100/100
# 21/21 [==============================] - 1s 49ms/step - loss: 2.2935e-05 - accuracy: 1.0000 - val_loss: 5.3745 - val_accuracy: 0.5781
# 22/22 [==============================] - 1s 31ms/step - loss: 2.3533e-05 - accuracy: 1.0000
# 5/5 [==============================] - 0s 32ms/step - loss: 4.4976 - accuracy: 0.6410
# Fold 3:
# Train accuracy: 1.0, Validation accuracy: 0.6410256624221802
# Training time for fold 3: 299.5348479747772 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 1s 49ms/step - loss: 2.3503e-05 - accuracy: 1.0000 - val_loss: 5.3980 - val_accuracy: 0.5781
# Epoch 2/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.4871e-05 - accuracy: 1.0000 - val_loss: 5.4141 - val_accuracy: 0.5781
# Epoch 3/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.4062e-05 - accuracy: 1.0000 - val_loss: 5.4122 - val_accuracy: 0.5781
# Epoch 4/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.2794e-05 - accuracy: 1.0000 - val_loss: 5.4188 - val_accuracy: 0.5781
# Epoch 5/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.1818e-05 - accuracy: 1.0000 - val_loss: 5.4169 - val_accuracy: 0.5781
# Epoch 6/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.3233e-05 - accuracy: 1.0000 - val_loss: 5.4097 - val_accuracy: 0.5781
# Epoch 7/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.2400e-05 - accuracy: 1.0000 - val_loss: 5.4305 - val_accuracy: 0.5781
# Epoch 8/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.1562e-05 - accuracy: 1.0000 - val_loss: 5.4328 - val_accuracy: 0.5781
# Epoch 9/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.1553e-05 - accuracy: 1.0000 - val_loss: 5.4428 - val_accuracy: 0.5781
# Epoch 10/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.1513e-05 - accuracy: 1.0000 - val_loss: 5.4467 - val_accuracy: 0.5781
# Epoch 11/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.1412e-05 - accuracy: 1.0000 - val_loss: 5.4474 - val_accuracy: 0.5781
# Epoch 12/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.1062e-05 - accuracy: 1.0000 - val_loss: 5.4452 - val_accuracy: 0.5781
# Epoch 13/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.0355e-05 - accuracy: 1.0000 - val_loss: 5.4427 - val_accuracy: 0.5781
# Epoch 14/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.0388e-05 - accuracy: 1.0000 - val_loss: 5.4695 - val_accuracy: 0.5781
# Epoch 15/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.0928e-05 - accuracy: 1.0000 - val_loss: 5.4695 - val_accuracy: 0.5781
# Epoch 16/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.9257e-05 - accuracy: 1.0000 - val_loss: 5.4744 - val_accuracy: 0.5781
# Epoch 17/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.0155e-05 - accuracy: 1.0000 - val_loss: 5.4862 - val_accuracy: 0.5781
# Epoch 18/100
# 21/21 [==============================] - 1s 47ms/step - loss: 1.8768e-05 - accuracy: 1.0000 - val_loss: 5.4822 - val_accuracy: 0.5781
# Epoch 19/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.0036e-05 - accuracy: 1.0000 - val_loss: 5.4676 - val_accuracy: 0.5781
# Epoch 20/100
# 21/21 [==============================] - 1s 48ms/step - loss: 1.9157e-05 - accuracy: 1.0000 - val_loss: 5.4837 - val_accuracy: 0.5781
# Epoch 21/100
# ...
# Epoch 99/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.7705e-06 - accuracy: 1.0000 - val_loss: 5.8756 - val_accuracy: 0.5781
# Epoch 100/100
# 21/21 [==============================] - 1s 47ms/step - loss: 7.0347e-06 - accuracy: 1.0000 - val_loss: 5.8751 - val_accuracy: 0.5781
# 22/22 [==============================] - 1s 30ms/step - loss: 6.7589e-06 - accuracy: 1.0000
# 5/5 [==============================] - 0s 31ms/step - loss: 4.9154 - accuracy: 0.6410
# Fold 4:
# Train accuracy: 1.0, Validation accuracy: 0.6410256624221802
# Training time for fold 4: 408.92422580718994 seconds
#
# Found 339 images belonging to 17 classes.
# Found 78 images belonging to 17 classes.
# Epoch 1/100
# 21/21 [==============================] - 1s 48ms/step - loss: 7.0646e-06 - accuracy: 1.0000 - val_loss: 5.8921 - val_accuracy: 0.5781
# Epoch 2/100
# 21/21 [==============================] - 1s 49ms/step - loss: 7.0107e-06 - accuracy: 1.0000 - val_loss: 5.8961 - val_accuracy: 0.5781
# Epoch 3/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.8520e-06 - accuracy: 1.0000 - val_loss: 5.9039 - val_accuracy: 0.5781
# Epoch 4/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.5324e-06 - accuracy: 1.0000 - val_loss: 5.9049 - val_accuracy: 0.5781
# Epoch 5/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.5331e-06 - accuracy: 1.0000 - val_loss: 5.9015 - val_accuracy: 0.5781
# Epoch 6/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.6656e-06 - accuracy: 1.0000 - val_loss: 5.9054 - val_accuracy: 0.5781
# Epoch 7/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.4413e-06 - accuracy: 1.0000 - val_loss: 5.9111 - val_accuracy: 0.5781
# Epoch 8/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.3885e-06 - accuracy: 1.0000 - val_loss: 5.9178 - val_accuracy: 0.5781
# Epoch 9/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.4102e-06 - accuracy: 1.0000 - val_loss: 5.9213 - val_accuracy: 0.5781
# Epoch 10/100
# 21/21 [==============================] - 1s 48ms/step - loss: 6.1006e-06 - accuracy: 1.0000 - val_loss: 5.9206 - val_accuracy: 0.5781
# Epoch 11/100
# 21/21 [==============================] - 1s 47ms/step - loss: 6.1696e-06 - accuracy: 1.0000 - val_loss: 5.9274 - val_accuracy: 0.5781
# Epoch 12/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.9500e-06 - accuracy: 1.0000 - val_loss: 5.9389 - val_accuracy: 0.5781
# Epoch 13/100
# 21/21 [==============================] - 1s 48ms/step - loss: 5.7733e-06 - accuracy: 1.0000 - val_loss: 5.9327 - val_accuracy: 0.5781
# Epoch 14/100
# 21/21 [==============================] - 1s 48ms/step - loss: 5.8460e-06 - accuracy: 1.0000 - val_loss: 5.9537 - val_accuracy: 0.5781
# Epoch 15/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.7341e-06 - accuracy: 1.0000 - val_loss: 5.9544 - val_accuracy: 0.5781
# Epoch 16/100
# 21/21 [==============================] - 1s 48ms/step - loss: 5.6592e-06 - accuracy: 1.0000 - val_loss: 5.9619 - val_accuracy: 0.5781
# Epoch 17/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.8973e-06 - accuracy: 1.0000 - val_loss: 5.9626 - val_accuracy: 0.5781
# Epoch 18/100
# 21/21 [==============================] - 3s 144ms/step - loss: 5.6470e-06 - accuracy: 1.0000 - val_loss: 5.9583 - val_accuracy: 0.5781
# Epoch 19/100
# 21/21 [==============================] - 4s 198ms/step - loss: 5.3728e-06 - accuracy: 1.0000 - val_loss: 5.9666 - val_accuracy: 0.5781
# Epoch 20/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.0960e-06 - accuracy: 1.0000 - val_loss: 5.9671 - val_accuracy: 0.5781
# Epoch 21/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.5131e-06 - accuracy: 1.0000 - val_loss: 5.9874 - val_accuracy: 0.5781
# Epoch 22/100
# 21/21 [==============================] - 1s 48ms/step - loss: 5.5275e-06 - accuracy: 1.0000 - val_loss: 5.9870 - val_accuracy: 0.5781
# Epoch 23/100
# 21/21 [==============================] - 1s 49ms/step - loss: 4.9528e-06 - accuracy: 1.0000 - val_loss: 5.9859 - val_accuracy: 0.5781
# Epoch 24/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.3931e-06 - accuracy: 1.0000 - val_loss: 5.9945 - val_accuracy: 0.5781
# Epoch 25/100
# 21/21 [==============================] - 1s 49ms/step - loss: 5.1419e-06 - accuracy: 1.0000 - val_loss: 5.9915 - val_accuracy: 0.5781
# Epoch 26/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.2411e-06 - accuracy: 1.0000 - val_loss: 6.0021 - val_accuracy: 0.5781
# Epoch 27/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.9337e-06 - accuracy: 1.0000 - val_loss: 6.0045 - val_accuracy: 0.5781
# Epoch 28/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.0831e-06 - accuracy: 1.0000 - val_loss: 6.0040 - val_accuracy: 0.5781
# Epoch 29/100
# 21/21 [==============================] - 1s 47ms/step - loss: 5.0396e-06 - accuracy: 1.0000 - val_loss: 6.0163 - val_accuracy: 0.5781
# Epoch 30/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.6823e-06 - accuracy: 1.0000 - val_loss: 6.0241 - val_accuracy: 0.5781
# Epoch 31/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.7130e-06 - accuracy: 1.0000 - val_loss: 6.0318 - val_accuracy: 0.5781
# Epoch 32/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.6417e-06 - accuracy: 1.0000 - val_loss: 6.0346 - val_accuracy: 0.5781
# Epoch 33/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.7871e-06 - accuracy: 1.0000 - val_loss: 6.0394 - val_accuracy: 0.5781
# Epoch 34/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.4638e-06 - accuracy: 1.0000 - val_loss: 6.0371 - val_accuracy: 0.5781
# Epoch 35/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.4941e-06 - accuracy: 1.0000 - val_loss: 6.0479 - val_accuracy: 0.5781
# Epoch 36/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.5937e-06 - accuracy: 1.0000 - val_loss: 6.0423 - val_accuracy: 0.5781
# Epoch 37/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.3343e-06 - accuracy: 1.0000 - val_loss: 6.0534 - val_accuracy: 0.5781
# Epoch 38/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.4174e-06 - accuracy: 1.0000 - val_loss: 6.0585 - val_accuracy: 0.5781
# Epoch 39/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.4114e-06 - accuracy: 1.0000 - val_loss: 6.0922 - val_accuracy: 0.5781
# Epoch 40/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.3384e-06 - accuracy: 1.0000 - val_loss: 6.0766 - val_accuracy: 0.5781
# Epoch 41/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.0630e-06 - accuracy: 1.0000 - val_loss: 6.0789 - val_accuracy: 0.5781
# Epoch 42/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.1815e-06 - accuracy: 1.0000 - val_loss: 6.0831 - val_accuracy: 0.5781
# Epoch 43/100
# 21/21 [==============================] - 1s 48ms/step - loss: 4.1760e-06 - accuracy: 1.0000 - val_loss: 6.0969 - val_accuracy: 0.5781
# Epoch 44/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.1276e-06 - accuracy: 1.0000 - val_loss: 6.0859 - val_accuracy: 0.5781
# Epoch 45/100
# 21/21 [==============================] - 1s 49ms/step - loss: 4.1025e-06 - accuracy: 1.0000 - val_loss: 6.0938 - val_accuracy: 0.5781
# Epoch 46/100
# 21/21 [==============================] - 1s 47ms/step - loss: 4.0811e-06 - accuracy: 1.0000 - val_loss: 6.0940 - val_accuracy: 0.5781
# Epoch 47/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.8922e-06 - accuracy: 1.0000 - val_loss: 6.0966 - val_accuracy: 0.5781
# Epoch 48/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.8276e-06 - accuracy: 1.0000 - val_loss: 6.1071 - val_accuracy: 0.5781
# Epoch 49/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.8933e-06 - accuracy: 1.0000 - val_loss: 6.1081 - val_accuracy: 0.5781
# Epoch 50/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.5574e-06 - accuracy: 1.0000 - val_loss: 6.1177 - val_accuracy: 0.5781
# Epoch 51/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.6338e-06 - accuracy: 1.0000 - val_loss: 6.1220 - val_accuracy: 0.5781
# Epoch 52/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.7401e-06 - accuracy: 1.0000 - val_loss: 6.1184 - val_accuracy: 0.5781
# Epoch 53/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.7183e-06 - accuracy: 1.0000 - val_loss: 6.1138 - val_accuracy: 0.5781
# Epoch 54/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.4825e-06 - accuracy: 1.0000 - val_loss: 6.1168 - val_accuracy: 0.5781
# Epoch 55/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.6275e-06 - accuracy: 1.0000 - val_loss: 6.1335 - val_accuracy: 0.5781
# Epoch 56/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.5021e-06 - accuracy: 1.0000 - val_loss: 6.1557 - val_accuracy: 0.5781
# Epoch 57/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.3626e-06 - accuracy: 1.0000 - val_loss: 6.1508 - val_accuracy: 0.5781
# Epoch 58/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.5010e-06 - accuracy: 1.0000 - val_loss: 6.1488 - val_accuracy: 0.5781
# Epoch 59/100
# 21/21 [==============================] - 1s 49ms/step - loss: 3.3691e-06 - accuracy: 1.0000 - val_loss: 6.1610 - val_accuracy: 0.5781
# Epoch 60/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.2611e-06 - accuracy: 1.0000 - val_loss: 6.1621 - val_accuracy: 0.5781
# Epoch 61/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.2677e-06 - accuracy: 1.0000 - val_loss: 6.1673 - val_accuracy: 0.5781
# Epoch 62/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.2862e-06 - accuracy: 1.0000 - val_loss: 6.1745 - val_accuracy: 0.5781
# Epoch 63/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.2422e-06 - accuracy: 1.0000 - val_loss: 6.1859 - val_accuracy: 0.5781
# Epoch 64/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.2275e-06 - accuracy: 1.0000 - val_loss: 6.1885 - val_accuracy: 0.5781
# Epoch 65/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.0858e-06 - accuracy: 1.0000 - val_loss: 6.1980 - val_accuracy: 0.5781
# Epoch 66/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.9839e-06 - accuracy: 1.0000 - val_loss: 6.2022 - val_accuracy: 0.5781
# Epoch 67/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.9197e-06 - accuracy: 1.0000 - val_loss: 6.2117 - val_accuracy: 0.5781
# Epoch 68/100
# 21/21 [==============================] - 1s 47ms/step - loss: 3.0337e-06 - accuracy: 1.0000 - val_loss: 6.2086 - val_accuracy: 0.5781
# Epoch 69/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.9961e-06 - accuracy: 1.0000 - val_loss: 6.2233 - val_accuracy: 0.5781
# Epoch 70/100
# 21/21 [==============================] - 1s 48ms/step - loss: 3.0038e-06 - accuracy: 1.0000 - val_loss: 6.2297 - val_accuracy: 0.5781
# Epoch 71/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.9821e-06 - accuracy: 1.0000 - val_loss: 6.2259 - val_accuracy: 0.5781
# Epoch 72/100
# 21/21 [==============================] - 1s 49ms/step - loss: 2.9706e-06 - accuracy: 1.0000 - val_loss: 6.2265 - val_accuracy: 0.5781
# Epoch 73/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.8293e-06 - accuracy: 1.0000 - val_loss: 6.2258 - val_accuracy: 0.5781
# Epoch 74/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.8304e-06 - accuracy: 1.0000 - val_loss: 6.2410 - val_accuracy: 0.5781
# Epoch 75/100
# 21/21 [==============================] - 3s 126ms/step - loss: 2.7913e-06 - accuracy: 1.0000 - val_loss: 6.2404 - val_accuracy: 0.5781
# Epoch 76/100
# 21/21 [==============================] - 5s 253ms/step - loss: 2.7706e-06 - accuracy: 1.0000 - val_loss: 6.2464 - val_accuracy: 0.5781
# Epoch 77/100
# 21/21 [==============================] - 1s 45ms/step - loss: 2.7123e-06 - accuracy: 1.0000 - val_loss: 6.2485 - val_accuracy: 0.5781
# Epoch 78/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.7750e-06 - accuracy: 1.0000 - val_loss: 6.2508 - val_accuracy: 0.5781
# Epoch 79/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.5606e-06 - accuracy: 1.0000 - val_loss: 6.2662 - val_accuracy: 0.5781
# Epoch 80/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.6861e-06 - accuracy: 1.0000 - val_loss: 6.2716 - val_accuracy: 0.5781
# Epoch 81/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.6155e-06 - accuracy: 1.0000 - val_loss: 6.2651 - val_accuracy: 0.5781
# Epoch 82/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.5617e-06 - accuracy: 1.0000 - val_loss: 6.2816 - val_accuracy: 0.5781
# Epoch 83/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.5676e-06 - accuracy: 1.0000 - val_loss: 6.2843 - val_accuracy: 0.5781
# Epoch 84/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.5303e-06 - accuracy: 1.0000 - val_loss: 6.2836 - val_accuracy: 0.5781
# Epoch 85/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.5381e-06 - accuracy: 1.0000 - val_loss: 6.2957 - val_accuracy: 0.5781
# Epoch 86/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.3797e-06 - accuracy: 1.0000 - val_loss: 6.2899 - val_accuracy: 0.5781
# Epoch 87/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.4041e-06 - accuracy: 1.0000 - val_loss: 6.3140 - val_accuracy: 0.5781
# Epoch 88/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.4318e-06 - accuracy: 1.0000 - val_loss: 6.3154 - val_accuracy: 0.5781
# Epoch 89/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.4502e-06 - accuracy: 1.0000 - val_loss: 6.3319 - val_accuracy: 0.5781
# Epoch 90/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.3521e-06 - accuracy: 1.0000 - val_loss: 6.3248 - val_accuracy: 0.5781
# Epoch 91/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.3417e-06 - accuracy: 1.0000 - val_loss: 6.3245 - val_accuracy: 0.5781
# Epoch 92/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.2801e-06 - accuracy: 1.0000 - val_loss: 6.3269 - val_accuracy: 0.5781
# Epoch 93/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.3270e-06 - accuracy: 1.0000 - val_loss: 6.3306 - val_accuracy: 0.5781
# Epoch 94/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.2664e-06 - accuracy: 1.0000 - val_loss: 6.3515 - val_accuracy: 0.5781
# Epoch 95/100
# 21/21 [==============================] - 1s 49ms/step - loss: 2.1912e-06 - accuracy: 1.0000 - val_loss: 6.3536 - val_accuracy: 0.5781
# Epoch 96/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.1860e-06 - accuracy: 1.0000 - val_loss: 6.3479 - val_accuracy: 0.5781
# Epoch 97/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.2937e-06 - accuracy: 1.0000 - val_loss: 6.3464 - val_accuracy: 0.5781
# Epoch 98/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.0723e-06 - accuracy: 1.0000 - val_loss: 6.3463 - val_accuracy: 0.5781
# Epoch 99/100
# 21/21 [==============================] - 1s 47ms/step - loss: 2.0454e-06 - accuracy: 1.0000 - val_loss: 6.3622 - val_accuracy: 0.5781
# Epoch 100/100
# 21/21 [==============================] - 1s 48ms/step - loss: 2.0716e-06 - accuracy: 1.0000 - val_loss: 6.3655 - val_accuracy: 0.5781
# 22/22 [==============================] - 1s 31ms/step - loss: 1.9945e-06 - accuracy: 1.0000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.3194 - accuracy: 0.6410
# Fold 5:
# Train accuracy: 1.0, Validation accuracy: 0.6410256624221802
# Training time for fold 5: 524.7179119586945 seconds
#
# K-Fold Cross Validation Complete.
# Average Training Accuracy: 100.0 %
# Average Validation Accuracy: 63.846155405044556 %
# Average Training Time: 305.0415646076202
# Total Training Time: 526.0242750644684

# %% [markdown]
# # Training accuracy

# %%
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
y_pred = model.predict(validation_generator)
y_true = validation_generator.classes
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()

# %% [markdown]
# # F1 score support

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import time

# Assuming you already have the necessary variables defined in your code
train_predictions = model.predict(train_generator)
validation_predictions = model.predict(validation_generator)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
validation_pred_labels = np.argmax(validation_predictions, axis=1)

# True labels for training and validation sets
train_true_labels = train_generator.classes
validation_true_labels = validation_generator.classes

# Calculate metrics
train_report = classification_report(train_true_labels, train_pred_labels, target_names=train_generator.class_indices)
validation_report = classification_report(validation_true_labels, validation_pred_labels, target_names=validation_generator.class_indices)

# Additional metrics using confusion matrix
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
validation_conf_matrix = confusion_matrix(validation_true_labels, validation_pred_labels)

# Calculate precision, recall, F1 score, and support
train_precision, train_recall, train_f1_score, train_support = precision_recall_fscore_support(train_true_labels, train_pred_labels)
validation_precision, validation_recall, validation_f1_score, validation_support = precision_recall_fscore_support(validation_true_labels, validation_pred_labels)

# Create PrettyTable for training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with training metrics
for class_name, precision, recall, f1_score, support in zip(
        train_generator.class_indices.keys(),
        train_precision,
        train_recall,
        train_f1_score,
        train_support
):
    train_table.add_row([class_name, precision, recall, f1_score, support])

# Create PrettyTable for validation metrics
validation_table = PrettyTable()
validation_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]

# Populate the table with validation metrics
for class_name, precision, recall, f1_score, support in zip(
        validation_generator.class_indices.keys(),
        validation_precision,
        validation_recall,
        validation_f1_score,
        validation_support
):
    validation_table.add_row([class_name, precision, recall, f1_score, support])

# Print tables
print("Training Metrics:")
print(train_table)

print("\nValidation Metrics:")
print(validation_table)

# ... (your existing code)

# Create DataFrames for training and validation metrics
train_df = pd.DataFrame({
    'Dataset': 'Training',
    'Class': list(train_generator.class_indices.keys()),
    'Precision': train_precision,
    'Recall': train_recall,
    'F1 Score': train_f1_score,
    'Support': train_support
})

validation_df = pd.DataFrame({
    'Dataset': 'Validation',
    'Class': list(validation_generator.class_indices.keys()),
    'Precision': validation_precision,
    'Recall': validation_recall,
    'F1 Score': validation_f1_score,
    'Support': validation_support
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, validation_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'combined_metricsVGGkfold5.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Combined metrics saved to {combined_excel_path}")
# Out:
# Training Metrics:
# +-------+----------------------+----------------------+----------------------+---------+
# | Class |      Precision       |        Recall        |       F1 Score       | Support |
# +-------+----------------------+----------------------+----------------------+---------+
# |   0   | 0.15789473684210525  | 0.15789473684210525  | 0.15789473684210525  |    19   |
# |   1   |         0.0          |         0.0          |         0.0          |    20   |
# |   10  | 0.058823529411764705 | 0.058823529411764705 | 0.058823529411764705 |    17   |
# |   2   | 0.041666666666666664 | 0.041666666666666664 | 0.041666666666666664 |    24   |
# |   3   | 0.05263157894736842  | 0.05263157894736842  | 0.05263157894736842  |    19   |
# |   4   |         0.0          |         0.0          |         0.0          |    20   |
# |   5   | 0.17647058823529413  | 0.17647058823529413  | 0.17647058823529413  |    17   |
# |   6   | 0.11764705882352941  | 0.11764705882352941  | 0.11764705882352941  |    17   |
# |   7   | 0.058823529411764705 | 0.058823529411764705 | 0.058823529411764705 |    17   |
# |   8   | 0.045454545454545456 | 0.045454545454545456 | 0.045454545454545456 |    22   |
# |   9   | 0.15789473684210525  | 0.15789473684210525  | 0.15789473684210525  |    19   |
# |  box  |         0.05         |         0.05         |         0.05         |    20   |
# |  fun  |         0.05         |         0.05         |         0.05         |    20   |
# |  good | 0.08333333333333333  | 0.08333333333333333  | 0.08333333333333333  |    24   |
# |  grow |         0.0          |         0.0          |         0.0          |    20   |
# |  hero |         0.0          |         0.0          |         0.0          |    22   |
# | trust | 0.045454545454545456 | 0.045454545454545456 | 0.045454545454545456 |    22   |
# +-------+----------------------+----------------------+----------------------+---------+
#
# Validation Metrics:
# +-------+--------------------+--------+--------------------+---------+
# | Class |     Precision      | Recall |      F1 Score      | Support |
# +-------+--------------------+--------+--------------------+---------+
# |   0   | 0.6666666666666666 |  0.5   | 0.5714285714285714 |    4    |
# |   1   |        0.75        |  0.6   | 0.6666666666666666 |    5    |
# |   10  |        0.5         |  0.25  | 0.3333333333333333 |    4    |
# |   2   |        0.6         |  0.6   |        0.6         |    5    |
# |   3   |        0.5         |  0.5   |        0.5         |    4    |
# |   4   |        0.6         |  0.6   |        0.6         |    5    |
# |   5   |        0.5         |  0.25  | 0.3333333333333333 |    4    |
# |   6   |        1.0         |  0.75  | 0.8571428571428571 |    4    |
# |   7   |        0.5         |  0.25  | 0.3333333333333333 |    4    |
# |   8   |        0.6         |  0.6   |        0.6         |    5    |
# |   9   |        0.5         |  0.75  |        0.6         |    4    |
# |  box  |        0.75        |  0.6   | 0.6666666666666666 |    5    |
# |  fun  | 0.8333333333333334 |  1.0   | 0.9090909090909091 |    5    |
# |  good |        0.5         |  0.8   | 0.6153846153846154 |    5    |
# |  grow |        0.8         |  0.8   |        0.8         |    5    |
# |  hero |        0.8         |  0.8   |        0.8         |    5    |
# | trust | 0.5555555555555556 |  1.0   | 0.7142857142857143 |    5    |
# +-------+--------------------+--------+--------------------+---------+
# Combined metrics saved to combined_metricsVGGkfold5.xlsx
